# %%
import litellm
import time
import sys, os

if not os.environ["OPENAI_API_KEY"]: 
    os.environ["OPENAI_API_KEY"]= '<REDACTED>'

# %%
#MODEL = "gpt-4o"
#MODEL = "gpt-4o-mini"
MODEL = "ft:gpt-4o-mini-2024-07-18:personal:20qs-tuned:9ujvexa0"
EVALUATOR_MODEL="gpt-4o-mini"
# MODEL = "gpt-4o"
#MODEL = "claude-3-5-sonnet-20240620"
litellm.modify_params = True

# %%
def completion(model, messages):
    result = litellm.completion(model, messages)
    if "claude" in model:
        time.sleep(60/50) # Adjust based on rate limit (https://console.anthropic.com/settings/limits)
    return result

# %%
class DecisionNode:
    def __init__(self, query = None, yes_branch=None, no_branch=None):
        self.query = query
        self.yes_branch = yes_branch
        self.no_branch = no_branch
        
    def print_tree(self, level=0, prefix=""):
        if self.query:
            print(f"{prefix}-- {self.query}")
            if self.yes_branch:
                self.yes_branch.print_tree(level + 1, prefix + "  |")
            if self.no_branch:
                self.no_branch.print_tree(level + 1, prefix + "   ")
        else:
            print(f"{prefix}-- *")
            
    def write_tree_to_file(self, filename):
        with open(filename, 'w') as f:
            self._write_tree(f)

    def _write_tree(self, file, level=0, prefix=""):
        if self.query:
            file.write(f"{prefix}-- {self.query}\n")
            if self.yes_branch:
                self.yes_branch._write_tree(file, level + 1, prefix + "  |")
            if self.no_branch:
                self.no_branch._write_tree(file, level + 1, prefix + "   ")
        else:
            file.write(f"{prefix}-- *\n")

    @staticmethod
    def read_tree_from_file(filename):
        with open(filename, 'r') as f:
            lines = f.readlines()
        return DecisionNode._read_tree(lines, 0, "")

    @staticmethod
    def _read_tree(lines, indent_level, current_prefix):
        if not lines:
            return None

        line = lines.pop(0).rstrip()
        expected_prefix = current_prefix + "-- "

        if not line.startswith(expected_prefix):
            return None

        content = line[len(expected_prefix):]
        if content == "*":
            return DecisionNode()

        yes_branch = DecisionNode._read_tree(lines, indent_level + 1, current_prefix + "  |")
        no_branch = DecisionNode._read_tree(lines, indent_level + 1, current_prefix + "   ")

        return DecisionNode(content, yes_branch, no_branch)

# %% [markdown]
# # Creating the tree

# %%
MC_tree = DecisionNode.read_tree_from_file('20qs-data/decision_trees/decision_tree_v2.txt')
MC_tree.print_tree()
# Out:
# -- food, beverage, cooking
#   |-- food
#   |  |-- agriculture
#   |  |  |-- *
#   |  |   -- prepared food
#   |  |     |-- *
#   |  |      -- *
#   |   -- agriculture
#   |     |-- safety
#   |     |  |-- *
#   |     |   -- *
#   |      -- handheld
#   |        |-- beverage
#   |        |  |-- *
#   |        |   -- *
#   |         -- *
#    -- industry, manufacturing
#      |-- safety
#      |  |-- transportation, vehicles
#      |  |  |-- *
#      |  |   -- architecture, construction
#      |   -- electronics
#      |     |-- *
#      |      -- natural material, resource
#      |        |-- *
#      |         -- *
#       -- sports, entertainment
#         |-- handheld
#         |  |-- electronics
#         |  |  |-- *
#         |  |   -- arts, media
#         |  |     |-- *
#         |  |      -- *
#         |   -- *
#          -- clothing, accessories, beauty
#            |-- *
#             -- animal
#               |-- *
#                -- handheld
#                  |-- electronics
#                  |  |-- *
#                  |   -- safety
#                  |     |-- *
#                  |      -- *
#                   -- living
#                     |-- *
#                      -- furniture
#                        |-- *
#                         -- arts, media
#                           |-- *
#                            -- *

# %%
import pickle

with open('20qs-data/decision_trees/gpt_decision_tree_v2.p', 'rb') as f:
    gpt_tree_v2 = pickle.load(f)
    
with open('20qs-data/decision_trees/gpt_decision_tree_v3.p', 'rb') as f:
    gpt_tree_v3 = pickle.load(f)
    
with open('20qs-data/decision_trees/gpt_decision_tree_v3.p', 'rb') as f:
    gpt_tree_v4 = pickle.load(f)
    
big_tree = DecisionNode.read_tree_from_file('20qs-data/decision_trees/big_tree.txt')
    
big_tree.print_tree()
# Out:
# -- Is it related to food, beverages or cooking?
#   |-- Is it an edible item?
#   |  |-- Is it a plant or derived from a plant?
#   |  |  |-- Is it commonly found in Western cuisine?
#   |  |  |  |-- Is it typically cooked before consumption?
#   |  |  |  |  |-- Is it typically green in color when fresh?
#   |  |  |  |  |  |-- Is it a type of leafy green?
#   |  |  |  |  |  |  |-- Does it have a strong or pungent flavor?
#   |  |  |  |  |  |  |  |-- Is it commonly used as an herb or garnish rather than as a primary ingredient?
#   |  |  |  |  |  |  |  |  |-- *
#   |  |  |  |  |  |  |  |   -- *
#   |  |  |  |  |  |  |   -- Is it considered a bitter green?
#   |  |  |  |  |  |  |     |-- *
#   |  |  |  |  |  |  |      -- *
#   |  |  |  |  |  |   -- Is it a vegetable?
#   |  |  |  |  |  |     |-- Is it a fruit vegetable?
#   |  |  |  |  |  |     |  |-- *
#   |  |  |  |  |  |     |   -- *
#   |  |  |  |  |  |      -- Is it typically used as a seasoning or garnish?
#   |  |  |  |  |  |        |-- *
#   |  |  |  |  |  |         -- *
#   |  |  |  |  |   -- Is it commonly consumed as a side dish?
#   |  |  |  |  |     |-- Does it typically have a starchy texture when cooked?
#   |  |  |  |  |     |  |-- Is it commonly used to make purees or soups?
#   |  |  |  |  |     |  |  |-- *
#   |  |  |  |  |     |  |   -- *
#   |  |  |  |  |     |   -- Does it have a flesh that is typically white or pale in color when cooked?
#   |  |  |  |  |     |     |-- *
#   |  |  |  |  |     |      -- *
#   |  |  |  |  |      -- Is it typically used whole rather than ground or processed?
#   |  |  |  |  |        |-- Is it typically a root vegetable?
#   |  |  |  |  |        |  |-- *
#   |  |  |  |  |        |   -- *
#   |  |  |  |  |         -- *
#   |  |  |  |   -- Does it have a notable or strong flavor?
#   |  |  |  |     |-- Is it commonly used as a spice or seasoning?
#   |  |  |  |     |  |-- Does it have a sweet flavor profile?
#   |  |  |  |     |  |  |-- *
#   |  |  |  |     |  |   -- *
#   |  |  |  |     |   -- Is it commonly consumed in its raw form?
#   |  |  |  |     |     |-- *
#   |  |  |  |     |      -- *
#   |  |  |  |      -- Is it typically consumed as a snack?
#   |  |  |  |        |-- Is it considered a fruit?
#   |  |  |  |        |  |-- *
#   |  |  |  |        |   -- *
#   |  |  |  |         -- Is it typically leafy or have leaves?
#   |  |  |  |           |-- *
#   |  |  |  |            -- *
#   |  |  |   -- Is it commonly used in Asian cuisine?
#   |  |  |     |-- Is it commonly used as an ingredient in soups or broths?
#   |  |  |     |  |-- Does it have a strong or distinctive smell when raw?
#   |  |  |     |  |  |-- Does it have a leafy appearance?
#   |  |  |     |  |  |  |-- *
#   |  |  |     |  |  |   -- *
#   |  |  |     |  |   -- Is it processed or transformed before consumption?
#   |  |  |     |  |     |-- *
#   |  |  |     |  |      -- *
#   |  |  |     |   -- Is it used as a spice or seasoning?
#   |  |  |     |     |-- Is it typically used in dried form?
#   |  |  |     |     |  |-- *
#   |  |  |     |     |   -- *
#   |  |  |     |      -- Is it typically consumed raw?
#   |  |  |     |        |-- *
#   |  |  |     |         -- *
#   |  |  |      -- Is it a type of vegetable?
#   |  |  |        |-- Is it typically consumed raw?
#   |  |  |        |  |-- Is it a leafy vegetable?
#   |  |  |        |  |  |-- *
#   |  |  |        |  |   -- *
#   |  |  |        |   -- Is it known for being a root vegetable?
#   |  |  |        |     |-- *
#   |  |  |        |      -- *
#   |  |  |         -- Is it commonly used in beverages?
#   |  |  |           |-- Is it typically used in tea?
#   |  |  |           |  |-- *
#   |  |  |           |   -- *
#   |  |  |            -- Is it used as a spice or seasoning?
#   |  |  |              |-- *
#   |  |  |               -- *
#   |  |   -- Is it commonly served as a main course or main component of a meal?
#   |  |     |-- Is it typically made with meat as a primary ingredient?
#   |  |     |  |-- Is it typically cooked using an oven or stovetop rather than a grill or deep fryer?
#   |  |     |  |  |-- Is it commonly prepared with more than one type of meat?
#   |  |     |  |  |  |-- Does it typically include a carbohydrate component such as pasta, rice, or potatoes?
#   |  |     |  |  |  |  |-- *
#   |  |     |  |  |  |   -- *
#   |  |     |  |  |   -- Is it typically associated with American cuisine?
#   |  |     |  |  |     |-- *
#   |  |     |  |  |      -- *
#   |  |     |  |   -- Is it typically served with a sauce or gravy?
#   |  |     |  |     |-- Is it commonly made with beef as a primary ingredient?
#   |  |     |  |     |  |-- *
#   |  |     |  |     |   -- *
#   |  |     |  |      -- Is it typically associated with American cuisine?
#   |  |     |  |        |-- *
#   |  |     |  |         -- *
#   |  |     |   -- Does it commonly contain cheese?
#   |  |     |     |-- Does it have a crispy or crunchy component?
#   |  |     |     |  |-- Is it commonly classified as a baked dish?
#   |  |     |     |  |  |-- *
#   |  |     |     |  |   -- *
#   |  |     |     |   -- Is it commonly seen as a dish from Italian cuisine?
#   |  |     |     |     |-- *
#   |  |     |     |      -- *
#   |  |     |      -- Is it primarily associated with Asian cuisine?
#   |  |     |        |-- Is it usually served in a bowl?
#   |  |     |        |  |-- *
#   |  |     |        |   -- *
#   |  |     |         -- Is it primarily served hot?
#   |  |     |           |-- *
#   |  |     |            -- *
#   |  |      -- Is it typically sweet?
#   |  |        |-- Does it contain any form of dairy or lactose?
#   |  |        |  |-- Is it typically served frozen or chilled?
#   |  |        |  |  |-- Does it usually involve more than one type of dairy product?
#   |  |        |  |  |  |-- *
#   |  |        |  |  |   -- *
#   |  |        |  |   -- Is it generally baked or cooked in an oven?
#   |  |        |  |     |-- *
#   |  |        |  |      -- *
#   |  |        |   -- Is it typically consumed in solid pieces rather than as a spread or liquid?
#   |  |        |     |-- Is it known for having a crispy or crunchy texture?
#   |  |        |     |  |-- *
#   |  |        |     |   -- *
#   |  |        |      -- Is it a type of candy or similar confection?
#   |  |        |        |-- *
#   |  |        |         -- *
#   |  |         -- Is it typically used as a condiment or seasoning?
#   |  |           |-- Is it typically found in liquid or paste form?
#   |  |           |  |-- Is it opaque in appearance?
#   |  |           |  |  |-- *
#   |  |           |  |   -- *
#   |  |           |   -- Is it primarily used in Asian cuisine?
#   |  |           |     |-- *
#   |  |           |      -- *
#   |  |            -- Is it typically found in a liquid or semi-liquid form?
#   |  |              |-- Is it used in beverages?
#   |  |              |  |-- *
#   |  |              |   -- *
#   |  |               -- Is it a protein source?
#   |  |                 |-- *
#   |  |                  -- *
#   |   -- Is it typically used in the preparation of food?
#   |     |-- Is it generally used for baking?
#   |     |  |-- Is it primarily made of metal?
#   |     |  |  |-- Does it have a handle or gripping point for use?
#   |     |  |  |  |-- Is it used in direct contact with dough?
#   |     |  |  |  |  |-- Is it a type of container or surface used for baking?
#   |     |  |  |  |  |  |-- *
#   |     |  |  |  |  |   -- *
#   |     |  |  |  |   -- Does it have a cutting edge?
#   |     |  |  |  |     |-- *
#   |     |  |  |  |      -- *
#   |     |  |  |   -- Is it commonly used in the preparation or baking of cakes?
#   |     |  |  |     |-- Is it typically used in the baking of breads?
#   |     |  |  |     |  |-- *
#   |     |  |  |     |   -- *
#   |     |  |  |      -- Is it used directly in the oven?
#   |     |  |  |        |-- *
#   |     |  |  |         -- *
#   |     |  |   -- Is it made from silicone?
#   |     |  |     |-- Is it typically flat in shape?
#   |     |  |     |  |-- Does it have a smooth surface without any detailing or grooves?
#   |     |  |     |  |  |-- *
#   |     |  |     |  |   -- *
#   |     |  |     |   -- Is it designed to be used with heat or in the oven?
#   |     |  |     |     |-- *
#   |     |  |     |      -- *
#   |     |  |      -- Is it an electronic device?
#   |     |  |        |-- Does it have a heating element?
#   |     |  |        |  |-- *
#   |     |  |        |   -- *
#   |     |  |         -- Is it primarily made of glass or ceramic?
#   |     |  |           |-- *
#   |     |  |            -- *
#   |     |   -- Is it a handheld tool?
#   |     |     |-- Is it commonly associated with liquid or fluid handling?
#   |     |     |  |-- Is it made of metal?
#   |     |     |  |  |-- Does it have a sharp edge or blades?
#   |     |     |  |  |  |-- *
#   |     |     |  |  |   -- *
#   |     |     |  |   -- Does it involve some form of stirring?
#   |     |     |  |     |-- *
#   |     |     |  |      -- *
#   |     |     |   -- Does it have any sharp edges or points?
#   |     |     |     |-- Is it commonly used in the preparation of vegetables or fruits?
#   |     |     |     |  |-- *
#   |     |     |     |   -- *
#   |     |     |      -- Does it have any moving parts?
#   |     |     |        |-- *
#   |     |     |         -- *
#   |     |      -- Is it commonly found in a drawer?
#   |     |        |-- Is it primarily made of metal?
#   |     |        |  |-- Is it a type of container?
#   |     |        |  |  |-- *
#   |     |        |  |   -- *
#   |     |        |   -- Does it have a significant plastic component?
#   |     |        |     |-- *
#   |     |        |      -- *
#   |     |         -- Is it made primarily of metal?
#   |     |           |-- Does it require an external heat source to function?
#   |     |           |  |-- *
#   |     |           |   -- *
#   |     |            -- Is it designed to hold or contain food items?
#   |     |              |-- *
#   |     |               -- *
#   |      -- Is it primarily found or used in the dining area?
#   |        |-- Is it typically used to serve food or drink?
#   |        |  |-- Is it intended for holding liquids?
#   |        |  |  |-- Is it commonly made of glass?
#   |        |  |  |  |-- Is it frequently used during meal service rather than for decoration?
#   |        |  |  |  |  |-- *
#   |        |  |  |  |   -- *
#   |        |  |  |   -- Is it typically found in a restaurant setting?
#   |        |  |  |     |-- *
#   |        |  |  |      -- *
#   |        |  |   -- Is it typically used to serve a specific type of food (e.g., dessert, bread)?
#   |        |  |     |-- Does it have a flat surface?
#   |        |  |     |  |-- *
#   |        |  |     |   -- *
#   |        |  |      -- Does it typically come into direct contact with food?
#   |        |  |        |-- *
#   |        |  |         -- *
#   |        |   -- Is it commonly found on the table surface?
#   |        |     |-- Does it typically have a utility function other than decoration?
#   |        |     |  |-- Is it used to contain or hold items?
#   |        |     |  |  |-- *
#   |        |     |  |   -- *
#   |        |     |   -- Is it typically used to protect the table surface?
#   |        |     |     |-- *
#   |        |     |      -- *
#   |        |      -- Is it primarily used for storage?
#   |        |        |-- Is it a type of container?
#   |        |        |  |-- *
#   |        |        |   -- *
#   |        |         -- Is it commonly used to maintain cleanliness or orderliness?
#   |        |           |-- *
#   |        |            -- *
#   |         -- Is it mainly used on a table or countertop?
#   |           |-- Is it primarily used for serving food or beverages?
#   |           |  |-- Is it commonly made of metal?
#   |           |  |  |-- Is it usually used for a specific type of food or beverage?
#   |           |  |  |  |-- *
#   |           |  |  |   -- *
#   |           |  |   -- Is it commonly made of ceramics or glass?
#   |           |  |     |-- *
#   |           |  |      -- *
#   |           |   -- Is it often found in a set or as a pair?
#   |           |     |-- Is it usually made of ceramic or glass?
#   |           |     |  |-- *
#   |           |     |   -- *
#   |           |      -- Does it typically occupy a permanent or semi-permanent spot on the table or countertop?
#   |           |        |-- *
#   |           |         -- *
#   |            -- Is it bigger than a breadbox?
#   |              |-- Is it an appliance?
#   |              |  |-- Does it have a heating element?
#   |              |  |  |-- *
#   |              |  |   -- *
#   |              |   -- Is it made mostly out of metal?
#   |              |     |-- *
#   |              |      -- *
#   |               -- Is it involved in the storage of food?
#   |                 |-- Is it made of plastic?
#   |                 |  |-- *
#   |                 |   -- *
#   |                  -- Is it made mostly of metal?
#   |                    |-- *
#   |                     -- *
#    -- Is it typically found inside a home?
#      |-- Is it commonly found in a bathroom?
#      |  |-- Is it used for personal hygiene?
#      |  |  |-- Is it a liquid or gel?
#      |  |  |  |-- Is it typically scented?
#      |  |  |  |  |-- Is it typically applied directly by hand?
#      |  |  |  |  |  |-- Is it associated with moisturizing?
#      |  |  |  |  |  |  |-- *
#      |  |  |  |  |  |   -- *
#      |  |  |  |  |   -- Does it provide odor control?
#      |  |  |  |  |     |-- *
#      |  |  |  |  |      -- *
#      |  |  |  |   -- Does it come in a container that requires pumping or squeezing to dispense?
#      |  |  |  |     |-- Is it intended for use on the face?
#      |  |  |  |     |  |-- *
#      |  |  |  |     |   -- *
#      |  |  |  |      -- Does it have a primary function related to skincare?
#      |  |  |  |        |-- *
#      |  |  |  |         -- *
#      |  |  |   -- Is it typically used for hair care?
#      |  |  |     |-- Is it typically used daily?
#      |  |  |     |  |-- Is it handheld?
#      |  |  |     |  |  |-- *
#      |  |  |     |  |   -- *
#      |  |  |     |   -- Does it usually come in a set or kit?
#      |  |  |     |     |-- *
#      |  |  |     |      -- *
#      |  |  |      -- Is it used for skincare?
#      |  |  |        |-- Is it used for application or removal of substances on the skin?
#      |  |  |        |  |-- *
#      |  |  |        |   -- *
#      |  |  |         -- Is it used to keep surfaces clean?
#      |  |  |           |-- *
#      |  |  |            -- *
#      |  |   -- Is it typically mounted or installed?
#      |  |     |-- Is it related to water flow or water management?
#      |  |     |  |-- Is it part of the plumbing system?
#      |  |     |  |  |-- Is it part of a shower setup?
#      |  |     |  |  |  |-- *
#      |  |     |  |  |   -- *
#      |  |     |  |   -- Does it directly contact water during its normal use?
#      |  |     |  |     |-- *
#      |  |     |  |      -- *
#      |  |     |   -- Does it typically hang on or attach to the wall?
#      |  |     |     |-- Is it primarily used for storage?
#      |  |     |     |  |-- *
#      |  |     |     |   -- *
#      |  |     |      -- Does it have a primary storage function?
#      |  |     |        |-- *
#      |  |     |         -- *
#      |  |      -- Does it serve a decorative purpose?
#      |  |        |-- Does it involve water in its usual function?
#      |  |        |  |-- Is it soft to the touch?
#      |  |        |  |  |-- *
#      |  |        |  |   -- *
#      |  |        |   -- Is it typically used for storage?
#      |  |        |     |-- *
#      |  |        |      -- *
#      |  |         -- Is it used for cleaning?
#      |  |           |-- Does it have a handle?
#      |  |           |  |-- *
#      |  |           |   -- *
#      |  |            -- Is it primarily used in conjunction with water?
#      |  |              |-- *
#      |  |               -- *
#      |   -- Is it typically found in a living room?
#      |     |-- Is it typically placed on the floor?
#      |     |  |-- Does it typically have legs?
#      |     |  |  |-- Is it associated with holding or displaying objects?
#      |     |  |  |  |-- Is it primarily used for storage?
#      |     |  |  |  |  |-- *
#      |     |  |  |  |   -- *
#      |     |  |  |   -- Is it typically used for seating?
#      |     |  |  |     |-- *
#      |     |  |  |      -- *
#      |     |  |   -- Is it mainly used for storage or organization?
#      |     |  |     |-- Does it have a lid or cover that can open and close?
#      |     |  |     |  |-- *
#      |     |  |     |   -- *
#      |     |  |      -- Does it usually have a fabric or cloth component?
#      |     |  |        |-- *
#      |     |  |         -- *
#      |     |   -- Is it commonly mounted on or hung from a wall?
#      |     |     |-- Is it used to display items or information?
#      |     |     |  |-- Is it primarily used for organizing items?
#      |     |     |  |  |-- *
#      |     |     |  |   -- *
#      |     |     |   -- Is it primarily decorative?
#      |     |     |     |-- *
#      |     |     |      -- *
#      |     |      -- Is it smaller than a microwave oven?
#      |     |        |-- Is it related to storage or organization?
#      |     |        |  |-- *
#      |     |        |   -- *
#      |     |         -- Is it used primarily for decoration?
#      |     |           |-- *
#      |     |            -- *
#      |      -- Is it primarily used for storage or organization?
#      |        |-- Is it often placed on top of or inside another piece of furniture?
#      |        |  |-- Is it commonly found in a bedroom?
#      |        |  |  |-- Does it store or organize clothing or accessories?
#      |        |  |  |  |-- *
#      |        |  |  |   -- *
#      |        |  |   -- Is it commonly used in an office setting?
#      |        |  |     |-- *
#      |        |  |      -- *
#      |        |   -- Does it have compartments or drawers?
#      |        |     |-- Does it typically have a place in an office or study?
#      |        |     |  |-- *
#      |        |     |   -- *
#      |        |      -- Is it commonly found in a bedroom?
#      |        |        |-- *
#      |        |         -- *
#      |         -- Is it a type of tool?
#      |           |-- Is it commonly associated with painting or decorating tasks?
#      |           |  |-- Is it a handheld tool?
#      |           |  |  |-- *
#      |           |  |   -- *
#      |           |   -- Is it generally handheld?
#      |           |     |-- *
#      |           |      -- *
#      |            -- Is it used for decoration?
#      |              |-- Is it commonly found in a bedroom?
#      |              |  |-- *
#      |              |   -- *
#      |               -- Is it related to cleaning or maintenance?
#      |                 |-- *
#      |                  -- *
#       -- Is it typically found in recreational or outdoor activities?
#         |-- Is it primarily used for relaxation or leisure?
#         |  |-- Can it be carried or held in one hand?
#         |  |  |-- Can it be used as a toy or for playing games?
#         |  |  |  |-- Is it typically used on a regular basis by children?
#         |  |  |  |  |-- Is it typically used in a competitive or team activity?
#         |  |  |  |  |  |-- *
#         |  |  |  |  |   -- *
#         |  |  |  |   -- Is it commonly used near or in water?
#         |  |  |  |     |-- *
#         |  |  |  |      -- *
#         |  |  |   -- Is it something that is typically used while stationary, rather than while moving?
#         |  |  |     |-- Does it provide protection from elements like sun, rain, or wind?
#         |  |  |     |  |-- *
#         |  |  |     |   -- *
#         |  |  |      -- Is it used in or around water?
#         |  |  |        |-- *
#         |  |  |         -- *
#         |  |   -- Is it designed to accommodate multiple people at once?
#         |  |     |-- Is it designed to be stationary rather than mobile?
#         |  |     |  |-- Is it an object that requires assembly?
#         |  |     |  |  |-- *
#         |  |     |  |   -- *
#         |  |     |   -- Does it involve or require some form of transportation to be used?
#         |  |     |     |-- *
#         |  |     |      -- *
#         |  |      -- Does it require a form of propulsion to use?
#         |  |        |-- Is it primarily used on water?
#         |  |        |  |-- *
#         |  |        |   -- *
#         |  |         -- Does it involve any form of seating or lying down?
#         |  |           |-- *
#         |  |            -- *
#         |   -- Is it typically used in a specific sport or physical activity?
#         |     |-- Is it primarily used on land rather than water or air?
#         |     |  |-- Is it used with or on the feet?
#         |     |  |  |-- Does it require a smooth surface to be used effectively?
#         |     |  |  |  |-- *
#         |     |  |  |   -- *
#         |     |  |   -- Does it involve the use of protective gear for safety?
#         |     |  |     |-- *
#         |     |  |      -- *
#         |     |   -- Does it require additional equipment or accessories to be used?
#         |     |     |-- Is it primarily used on water surfaces rather than underwater or in the air?
#         |     |     |  |-- *
#         |     |     |   -- *
#         |     |      -- Is it primarily used in water-based activities?
#         |     |        |-- *
#         |     |         -- *
#         |      -- Is it typically used in a camping setting?
#         |        |-- Does it provide shelter or coverage?
#         |        |  |-- Is it mainly composed of fabric or other flexible material?
#         |        |  |  |-- *
#         |        |  |   -- *
#         |        |   -- Is it used for navigation or safety purposes?
#         |        |     |-- *
#         |        |      -- *
#         |         -- Is it typically found in a garden or yard setting?
#         |           |-- Is it an item used for decoration or aesthetic purposes?
#         |           |  |-- *
#         |           |   -- *
#         |            -- Is it typically used directly by a person during an activity?
#         |              |-- *
#         |               -- *
#          -- Is it a type of tool or equipment?
#            |-- Is it a hand-held device?
#            |  |-- Is it commonly used in automotive repair or maintenance?
#            |  |  |-- Does it require electricity or batteries to operate?
#            |  |  |  |-- Does it have a main function related to measuring or testing?
#            |  |  |  |  |-- *
#            |  |  |  |   -- *
#            |  |  |   -- Does it have a primary function related to tightening or loosening fasteners?
#            |  |  |     |-- *
#            |  |  |      -- *
#            |  |   -- Is it often associated with construction or building?
#            |  |     |-- Is it designed to cut or shape materials?
#            |  |     |  |-- *
#            |  |     |   -- *
#            |  |      -- Is it often utilized in woodworking or carpentry?
#            |  |        |-- *
#            |  |         -- *
#            |   -- Is it powered by electricity?
#            |     |-- Is it primarily used in construction or industrial applications?
#            |     |  |-- Is it typically stationary during operation?
#            |     |  |  |-- *
#            |     |  |   -- *
#            |     |   -- Is it used in maintenance or upkeep activities?
#            |     |     |-- *
#            |     |      -- *
#            |      -- Is it used in construction or building maintenance?
#            |        |-- Is it used to lift or move heavy objects?
#            |        |  |-- *
#            |        |   -- *
#            |         -- Is it primarily used for gardening or lawn care?
#            |           |-- *
#            |            -- *
#             -- Does it have a primarily decorative function?
#               |-- Is it primarily used outdoors?
#               |  |-- Is it associated with plants or gardening?
#               |  |  |-- Is it typically placed on the ground or at ground level?
#               |  |  |  |-- *
#               |  |  |   -- *
#               |  |   -- Is it generally freestanding?
#               |  |     |-- *
#               |  |      -- *
#               |   -- Is it smaller than a football?
#               |     |-- Is it usually found in living rooms?
#               |     |  |-- *
#               |     |   -- *
#               |      -- Does it generally hang on or attach to a wall or ceiling?
#               |        |-- *
#               |         -- *
#                -- Is it primarily used in outdoor environments?
#                  |-- Is it related to weather or climate?
#                  |  |-- Does it primarily involve water?
#                  |  |  |-- *
#                  |  |   -- *
#                  |   -- Is it mobile or can it be easily moved?
#                  |     |-- *
#                  |      -- *
#                   -- Can it fit inside a typical backpack?
#                     |-- Does it have any electronic components?
#                     |  |-- *
#                     |   -- *
#                      -- Is it used in an educational or institutional setting?
#                        |-- *
#                         -- *

# %%
query_map = {
    'food': "Is it a food?",
    'beverage': "Is it a beverage?",
    'living': "Is it a living thing?",
    'plant': "Is it a plant?",
    'animal': 'Is it an animal?',
    'electronics': "Is it related to electronics or technology?",
    'furniture': 'Is it furniture?',
    'transportation, vehicles': 'Is it related to transportation or vehicles?',
    'man-made': "Is it a man-made thing?",
    'architecture, construction': 'Is it related to architectural structures or construction?',
    'natural material, resource': 'Is it a natural material or resource?',
    'natural phenomenon': 'Is it a natural phenomenon?',
    'industry, manufacturing': "Is it related to industrial production or manufacturing?",
    'food, beverage, cooking': 'Is it related to food, beverages or cooking?',
    'handheld': 'Is it something a person can hold in their hand?',
    'agriculture': "Is it related to agriculture?",
    'indoors': 'Is it something that can be found indoors?',
    'arts, media': "Is it broadly related to the arts or media?",
    'safety': "Is it related to safety or safety equipment?",
    'medicine': "Is it broadly related to medicine or healthcare?",
    'clothing, accessories, beauty': "Is it related to clothing, accessories or beauty products?",
    'sports, entertainment': "Is it broadly related to entertainment or sports?",
    'prepared food': "Is it a prepared food or dish?"
}

# %%
def game_to_string(questions, answers, guesses):
    game_text = ""
    turn = len(questions)
    for i in range(turn):
        game_text += f"Question {i+1}: {questions[i]}\n"
        game_text += f"Answer {i+1}: {answers[i]}\n"  
        if i < turn-1: game_text += f"Guess {i+1}: {guesses[i]}\n"
    return game_text

def construct_messages(game, role, keyword=None, guesses=[],  questions = [], answers = []):
    if role == "questioner":
        prompt = {
            "role": "system",
            "content": (
                "You are an AI assistant playing the 20 Questions game. In this game the Answerer is given a secret keyword. "
                "The Questioner then asks yes-or-no questions regarding the keyword, and the Answerer answers them accurately. "
                "Then the Guesser tries to guess the keyword based on the questions and answers in the game. The keyword is a specific thing, NOT a place and NOT a person.\n\n "
                "You are participating in a new game of 20 Questions. Your role is to be the Questioner. You will ask successive yes-or-no questions to determine the keyword. "
                "You have a limited number of questions to ask, so choose a question that will eliminate half of the possible keywords to maximize efficiency. "
                "Avoid asking questions that are too specific too early on. Ask questions that are as broad as possible while still eliminating half of the remaining possibilities. "
                "DO NOT ask if the keyword is a specific thing, rather ask something about the keyword.\n"
                "Example 1: DO NOT ASK: 'Is the keyword car?', INSTEAD ASK: 'Is it a specific type of car, such as a sedan?\n"
                "Example 2: DO NOT ASK: 'Is the keyword cow?', INSTEAD ASK: 'Is it a specific type of cow?\n"
                "Example 3: DO NOT ASK: 'Is the keyword bottle?', INSTEAD ASK: 'Is it a bottle made of a specific material?\n"
                "Example 4: DO NOT ASK: 'Is the keyword lamp?', INSTEAD ASK: 'Is it a type of lamp?\n"
                "Do NOT assume the game has ended, the game will determine when to stop. Do not output any text other than the question."
            ),
        }
        messages = [prompt]
        for message in game:
            if message["role"] == "questioner":
                messages.append({
                    "role": "assistant",
                    "content": message["content"]
                })
            else:
                messages.append({
                    "role": "user",
                    "content": message["content"] + "\nAsk your next question. Remember to NOT ask if the keyword is a specific thing, but rather ask something about the keyword."
                })
    elif role == "answerer":
        prompt = {
            "role": "system",
            "content": (
                f"You are an AI assistant playing the 20 Questions game. In this game the Answerer is given a secret keyword. "
                "The Questioner then asks yes-or-no questions regarding the keyword, and the Answerer answers them accurately. "
                "Then the Guesser tries to guess the keyword based on the questions and answers in the game. The keyword is a specific thing, NOT a place and NOT a person. "
                "You are participating in a new game of 20 Questions. Your role is to be the Answerer. "
                f"The keyword is {keyword}. Answer only Yes or No based on the keyword. Do not output any other text."
            ),
        }
        messages = [prompt]
        for message in game:
            if message["role"] == "questioner":
                messages.append({
                    "role": "user",
                    "content": f"Answer the following question about the keyword: '{keyword}'. " + message["content"]
                })
            else:
                messages.append({
                    "role": "assistant",
                    "content": message["content"]
                })
    elif role == "guesser":
        prompt = {
            "role": "system",
            "content": (
                "You are an AI assistant playing the 20 Questions game. In this game the Answerer is given a secret keyword. "
                "The Questioner then asks yes-or-no questions regarding the keyword, and the Answerer answers them accurately. "
                "Then the Guesser tries to guess the keyword based on the questions and answers in the game. The keyword is a specific thing, NOT a place and NOT a person. "
                "You are participating in a new game of 20 Questions. Your role is to be the Guesser. Based on the given questions and answers, guess the keyword at this point. "
                "Even if information is limited, guess a keyword. Do not ask a question, just state the guessed keyword with no other text except the keyword itself. "
                "DO NOT output any other text other than the guessed keyword. DO NOT refuse to guess. DO NOT REPEAT A PREVIOUS GUESS."
            ),
        }
        messages = [prompt, {
            "role": "user",
            "content": "Game so far:\n" + game_to_string(questions, answers, guesses) +"\nBased on all questions and answers so far, enter your guess. Do not repeat a guess.\nGuess:"
        }]
    elif role == "evaluator":
        prompt = {
            "role": "system",
            "content": (
                "You are an evaluator for the game 20 Questions. Given a keyword and a guess, return True if the guess was correct and False otherwise. "
                "The guess should refer to the same thing as the keyword but the guess should NOT be more vague or general than the keyword. DO NOT output anything except 'True' or 'False'."
                "Here are some guiding examples: \n\n"
                "Example 1:\nKeyword: USA\n Guess: United States\nEvaluation: True\n\n"
                "Example 2:\nKeyword: Peking duck\n Guess: duck\nEvaluation: False\n\n"
                "Example 3:\nKeyword: iPad\n Guess: tablet\nEvaluation: False\n\n"
                "Example 4:\nKeyword: pretoria south africa\n Guess: Pretoria\nEvaluation: True\n\n"
                "Example 5:\nKeyword: Bed and Breakfast\n Guess: BnB\nEvaluation: True\n\n"
                "Example 6:\nKeyword: Diet coke\n Guess: coca-cola\nEvaluation: False\n\n"
            ),
        }
        messages = [prompt, {
            "role": "user",
            "content": f"Keyword: {keyword}\nGuess: {guesses[-1]}\nEvaluation: "
        }]
    return messages

# %%
construct_messages([{"role": "questioner", "content": "Is it a place?"}], "answerer", "chair")
# Out:
# [{'role': 'system',
#   'content': 'You are an AI assistant playing the 20 Questions game. In this game the Answerer is given a secret keyword. The Questioner then asks yes-or-no questions regarding the keyword, and the Answerer answers them accurately. Then the Guesser tries to guess the keyword based on the questions and answers in the game. The keyword is a specific thing, NOT a place and NOT a person. You are participating in a new game of 20 Questions. Your role is to be the Answerer. The keyword is chair. Answer only Yes or No based on the keyword. Do not output any other text.'},
#  {'role': 'user',
#   'content': "Answer the following question about the keyword: 'chair'. Is it a place?"}]

# %% [markdown]
# ## Game Simulator

# %%
def simulate_game(keyword, tree, print_game = True):
    if print_game: print(f"USING MODEL: {MODEL}")
    if print_game: print(f"KEYWORD: {keyword}")
    if print_game: print()
    
    game = []
    questions = [step["content"] for step in game if step["role"] == "questioner"]
    answers = [step["content"] for step in game if step["role"] == "answerer"]
    guesses = []
    game_won = False
    decision_node = tree
    
    for turn in range(20):
        
        if decision_node and decision_node.query:
            if "?" in decision_node.query:
                question = decision_node.query
            else:
                question = query_map[decision_node.query]
        else:
            question = completion(model=MODEL, messages=construct_messages(game, "questioner", keyword)).choices[0].message.content
    
        game.append({
            "role": "questioner",
            "content": question
        })

        if print_game: print(f"questioner: {question}")

        if "OVER" in question:
            break
        
        questions.append(question)

        answer = completion(model=MODEL, messages=construct_messages(game, "answerer", keyword)).choices[0].message.content
    
        game.append({
            "role": "answerer",
            "content": answer
        })

        answers.append(answer)
        if print_game: print(f"answerer: {answer}")

        if decision_node and decision_node.yes_branch != None and "yes" in answer.lower():
            decision_node = decision_node.yes_branch
        elif decision_node and decision_node.no_branch != None and "no" in answer.lower():
            decision_node = decision_node.no_branch
        else:
            decision_node = None
            
        guess = completion(model=MODEL, messages=construct_messages(game, "guesser", keyword, guesses, questions, answers)).choices[0].message.content

        guesses.append(guess)
        if print_game: print(f"guesser: {guess}")

        evaluation = completion(model=EVALUATOR_MODEL, messages=construct_messages(game, "evaluator", keyword, guesses)).choices[0].message.content
        if print_game: print(f"evaluator: {evaluation}")
        if "true" in evaluation.lower(): 
            game_won = True
            break

        if print_game: print()

    return {
        "keyword": keyword,
        "questions": questions,
        "answers": answers,
        "guesses": guesses,
        "win" : game_won,
    }

# %%
simulate_game("barbell", big_tree)
# Out:
# USING MODEL: ft:gpt-4o-mini-2024-07-18:personal:20qs-tuned:9ujvexa0
# KEYWORD: barbell
#
# !
# questioner: Is it related to food, beverages or cooking?
# answerer: no
# guesser: Smartphone
# evaluator: False
#
# !
# questioner: Is it typically found inside a home?
# answerer: yes
# guesser: Television
# evaluator: False
#
# !
# questioner: Is it commonly found in a bathroom?
# answerer: no
# guesser: Lamp
# evaluator: False
#
# !
# questioner: Is it typically found in a living room?
# answerer: no
# guesser: Refrigerator
# evaluator: False
#
# !
# questioner: Is it primarily used for storage or organization?
# answerer: no
# guesser: Computer
# evaluator: False
#
# !
# questioner: Is it a type of tool?
# answerer: yes
# guesser: Hammer
# evaluator: False
#
# !
# questioner: Is it commonly associated with painting or decorating tasks?
# answerer: no
# guesser: Screwdriver
# evaluator: False
#
# !
# questioner: Is it generally handheld?
# answerer: yes
# guesser: Electric drill
# evaluator: False
#
# questioner: Is it used in the kitchen?
# answerer: no
# guesser: Flashlight
# evaluator: False
#
# questioner: Is it commonly used for repairs or maintenance around the house?
# answerer: no
# guesser: Scissors
# evaluator: False
#
# questioner: Is it used for cleaning purposes?
# answerer: no
# guesser: Electric toothbrush
# evaluator: False
#
# questioner: Is it an electrical tool or device?
# answerer: no
# guesser: Tape measure
# evaluator: False
#
# questioner: Is it related to gardening or outdoor activities?
# answerer: no
# guesser: Wrench
# evaluator: False
#
# questioner: Is it used for crafting or DIY projects?
# answerer: no
# guesser: Pencil
# evaluator: False
#
# questioner: Is it associated with personal grooming or care?
# answerer: no
# guesser: Saw
# evaluator: False
#
# questioner: Is it a type of measuring tool?
# answerer: no
# guesser: Knife
# evaluator: False
#
# questioner: Is it used for office or school work?
# answerer: no
# guesser: Chisel
# evaluator: False
#
# questioner: Is it used for sewing or mending clothes?
# answerer: no
# guesser: Spatula
# evaluator: False
#
# questioner: Is it used for personal fitness or exercise?
# answerer: yes
# guesser: Dumbbell
# evaluator: False
#
# questioner: Is it primarily used for strength training?
# answerer: yes
# guesser: Resistance band
# evaluator: False
# {'keyword': 'barbell',
#  'questions': ['Is it related to food, beverages or cooking?',
#   'Is it typically found inside a home?',
#   'Is it commonly found in a bathroom?',
#   'Is it typically found in a living room?',
#   'Is it primarily used for storage or organization?',
#   'Is it a type of tool?',
#   'Is it commonly associated with painting or decorating tasks?',
#   'Is it generally handheld?',
#   'Is it used in the kitchen?',
#   'Is it commonly used for repairs or maintenance around the house?',
#   'Is it used for cleaning purposes?',
#   'Is it an electrical tool or device?',
#   'Is it related to gardening or outdoor activities?',
#   'Is it used for crafting or DIY projects?',
#   'Is it associated with personal grooming or care?',
#   'Is it a type of measuring tool?',
#   'Is it used for office or school work?',
#   'Is it used for sewing or mending clothes?',
#   'Is it used for personal fitness or exercise?',
#   'Is it primarily used for strength training?'],
#  'answers': ['no',
#   'yes',
#   'no',
#   'no',
#   'no',
#   'yes',
#   'no',
#   'yes',
#   'no',
#   'no',
#   'no',
#   'no',
#   'no',
#   'no',
#   'no',
#   'no',
#   'no',
#   'no',
#   'yes',
#   'yes'],
#  'guesses': ['Smartphone',
#   'Television',
#   'Lamp',
#   'Refrigerator',
#   'Computer',
#   'Hammer',
#   'Screwdriver',
#   'Electric drill',
#   'Flashlight',
#   'Scissors',
#   'Electric toothbrush',
#   'Tape measure',
#   'Wrench',
#   'Pencil',
#   'Saw',
#   'Knife',
#   'Chisel',
#   'Spatula',
#   'Dumbbell',
#   'Resistance band'],
#  'win': False}

# %% [markdown]
# ## Test trees:

# %%
first_100_test_words = ['Dandelion', 'weasel', 'pot holder', 'casket', 'push pin', 'Protein bar', 'junction box', 'bonsai tree', 'Nail Polish Remover', 'livestock trailer', 'amazon echo', 'wire brush', 'rocketship', 'Paper towels', 'dresser', 'lemming', 'pear tree', 'conference table', 'extension ladder', 'vortex mixer', 'Wine Aerator', 'Golf Cart', 'Tweezers', 'catalytic converter', 'Ointment', 'Frappuccino', 'aluminum foil', 'headboard', 'butter knife', 'chimney', 'sewing needle', 'angelfish', 'bird netting', 'level sensor', 'cane', 'palmetto tree', 'coal crusher', 'Sprinkler', 'king snake', 'plant saucer', 'beer coaster', 'espresso machine', 'desk lamp', 'Wine Tasting Kit', 'fossil', 'oatmeal cookie', 'rubber', 'Pallet Jack', 'butter knife', 'Sticker', 'lace dress', 'wind vane', 'Mouse', 'fudge brownie', 'Sippy cup', 'loose change', 'baggage conveyor', 'zinc', 'Screwdriver', 'binder clip', 'Matches', 'pumpkin', 'medication dispenser', 'electronic piano', 'Dish soap', 'tea cup', 'Air Conditioner', 'Reptile', 'Pressure gauge', 'Toiletries bag', 'safety glasses', 'fishing net', 'Swing set', 'Grapefruit', 'neon light', 'Stain Remover', 'Screwdriver', 'game board', 'climbing rope', 'Ventilation System', 'Pumpkin pie', 'Olive Oil', 'infrared sensor', 'petunia', 'anchovy', 'user manual', 'upright piano', 'lifting crane', 'reading pillow', 'Spatula', 'Stain Remover', 'Komodo dragon', 'Floor jacks', 'sweetgum tree', 'grape juice', 'ultrasound', 'plastic baggie', 'Soldering iron', 'Reptile', 'caribou']

# %%
from tqdm.notebook import tqdm
import numpy as np

trees_map = {'gpt_tree_v2': gpt_tree_v2, 'gpt_tree_v3': gpt_tree_v3, 'gpt_tree_v4': gpt_tree_v4, 'MC_tree': MC_tree}
test_results = {'gpt_tree_v2': {}, 'gpt_tree_v3': {}, 'gpt_tree_v4': {}, 'MC_tree': {}}
# Out:
# trees:   0%|          | 0/4 [00:00<?, ?it/s]
# keywords:   0%|          | 0/100 [00:00<?, ?it/s]
# keywords:   0%|          | 0/100 [00:00<?, ?it/s]
# keywords:   0%|          | 0/100 [00:00<?, ?it/s]
# keywords:   0%|          | 0/100 [00:00<?, ?it/s]
# Tree: gpt_tree_v2
# Number of keywords guessed correctly: 19
# Average length of games won: 19
# Keywords guessed correctly:
# Ointment
# butter knife
# oatmeal cookie
# Mouse
# fudge brownie
# Screwdriver
# Dish soap
# Air Conditioner
# safety glasses
# fishing net
# neon light
# game board
# climbing rope
# petunia
# lifting crane
# Spatula
# Komodo dragon
# grape juice
# plastic baggie
#
# Tree: gpt_tree_v3
# Number of keywords guessed correctly: 30
# Average length of games won: 30
# Keywords guessed correctly:
# weasel
# Protein bar
# amazon echo
# dresser
# Golf Cart
# Tweezers
# cane
# king snake
# espresso machine
# fossil
# oatmeal cookie
# Sticker
# Mouse
# fudge brownie
# Screwdriver
# binder clip
# electronic piano
# Dish soap
# Air Conditioner
# Reptile
# Swing set
# Grapefruit
# game board
# Pumpkin pie
# petunia
# anchovy
# lifting crane
# Spatula
# grape juice
# caribou
#
# Tree: gpt_tree_v4
# Number of keywords guessed correctly: 25
# Average length of games won: 25
# Keywords guessed correctly:
# weasel
# Protein bar
# amazon echo
# Tweezers
# palmetto tree
# Sprinkler
# king snake
# desk lamp
# oatmeal cookie
# Sticker
# Mouse
# Screwdriver
# Dish soap
# Air Conditioner
# Reptile
# safety glasses
# Grapefruit
# Stain Remover
# game board
# Pumpkin pie
# petunia
# lifting crane
# Komodo dragon
# grape juice
# caribou
#
# Tree: MC_tree
# Number of keywords guessed correctly: 22
# Average length of games won: 22
# Keywords guessed correctly:
# Protein bar
# Nail Polish Remover
# conference table
# aluminum foil
# butter knife
# angelfish
# palmetto tree
# king snake
# rubber
# Mouse
# electronic piano
# Dish soap
# Reptile
# Pressure gauge
# safety glasses
# Grapefruit
# game board
# lifting crane
# Spatula
# Komodo dragon
# plastic baggie
# caribou

# %%
import random

test_words = random.choices([keyword for keyword in keyword_things if keyword not in test_results['gpt_tree_v2']], k = 150)

# %%
print(test_words)
# Out:
# ['groundhog', 'Utility Cart', 'Pamphlet', 'cockroach', 'bank statement', 'vegetarian chili', 'Luggage', 'oxygen', 'planter', 'butterfly net', 'parrot', 'smoke alarm', 'hand drill', 'peony', 'fire helmet', 'cupcake', 'hot tea', 'Hairbrush', 'Lathe', 'meatloaf', 'dust jacket', 'medical chart', 'bald eagle', 'Rat', 'pipe', 'hazelnut tree', 'pineapple', 'cable tie', 'steam iron', 'Ultraviolet Lamp', 'Phone charger', 'hair elastic', 'wine decanter', 'Umbrella stand', 'Ear protection', 'pillow sham', 'volleyball', 'metal file', 'earring', 'charger', 'honeydew', 'relief valve', 'Bulb', 'teddy bear', 'silicon', 'Ironing Board', 'chair cushion', 'microphone stand', 'hamster', 'wire hanger', 'jacket', 'Mushroom', 'elastic bandage', 'Muffin Tin', 'doughnut', 'postage stamp', 'Fungi', 'picture frame', 'vest', 'cooler', 'perfume bottle', 'foil paper', 'Ocarina', 'Index Card', 'steak', 'Ear protection', 'Radio scanner', 'chicken wire', 'Floor Mats', 'rice krispie', 'moving walkway', 'Disinfectant', 'fishnet', 'utility belt', 'merchandise rack', 'seagull', 'garden rake', 'nylon', 'Hazelnut', 'Shipping label', 'tire', 'Stage lights', 'exhibit sign', 'Agave', 'Medication', 'Coffee beans', 'Sleeping bag', 'Milling machine', 'Scratching posts', 'Hazelnut', 'Light Switch', 'Khaki pants', 'Radio scanner', 'garden shovel', 'Light Switch', 'common milkweed', 'Conveyor belt', 'Gym Mats', 'Library Card', 'Pamphlet', 'candy wrapper', 'Necklace', 'ruby', 'Beanbag', 'shower mat', 'mop', 'Handbag', 'plastic pallet', 'Conveyor belt', 'coffee machine', 'broken glass', 'ribbon', 'porcupine', 'Stair Stepper', 'Coffee grounds', 'seedling tray', 'Piping tips', 'entrance door', 'clay', 'swamp milkweed', 'Bacteria', 'guitar pick', 'agave plant', 'Jumper Cables', 'lime', 'mucus', 'coffee table', 'Pesticide', 'impact crusher', 'deposit slip', 'Vending Machine', 'strainer', 'ruler', 'tape measure', 'mangrove seedling', 'nightshade', 'Journal', 'bulletin', 'Stove', 'Polyester', 'refrigerator', 'aerator', 'enamel', 'IV', 'Oxygen tank', 'acacia', 'Hazelnut', 'beer glass', 'guitar pick', 'Pants']

# %%
for tree in tqdm(trees_map, desc = 'trees'):
    for keyword in tqdm(test_words, leave = False, desc = 'keywords'):
        game_result = simulate_game(keyword, trees_map[tree], print_game = False)
        test_results[tree][keyword] = game_result
        
for tree in test_results:
    keywords_guessed_correctly = [keyword for keyword in test_results[tree] if test_results[tree][keyword]["win"] == True]
    print(f"Tree: {tree}")
    print(f"Number of keywords guessed correctly: {len(keywords_guessed_correctly)}")
    keywords_print = "\n".join(keywords_guessed_correctly)
    avg_len_games_won = np.mean([len(test_results[tree][keyword]['questions']) for keyword in keywords_guessed_correctly])
    print(f"Average length of games won: {avg_len_games_won}")
    print(f"Keywords guessed correctly:\n{keywords_print}\n")

with open("20qs-data/final_games/results_by_tree.jsonl", "w") as f:
    json.dump(test_results, f)
# Out:
# trees:   0%|          | 0/4 [00:00<?, ?it/s]
# keywords:   0%|          | 0/150 [00:00<?, ?it/s]
# keywords:   0%|          | 0/150 [00:00<?, ?it/s]
# keywords:   0%|          | 0/150 [00:00<?, ?it/s]
# keywords:   0%|          | 0/150 [00:00<?, ?it/s]
# Tree: gpt_tree_v2
# Number of keywords guessed correctly: 52
# Average length of games won: 14.076923076923077
# Keywords guessed correctly:
# Ointment
# butter knife
# oatmeal cookie
# Mouse
# fudge brownie
# Screwdriver
# Dish soap
# Air Conditioner
# safety glasses
# fishing net
# neon light
# game board
# climbing rope
# petunia
# lifting crane
# Spatula
# Komodo dragon
# grape juice
# plastic baggie
# Luggage
# cupcake
# hot tea
# Lathe
# Rat
# volleyball
# charger
# honeydew
# Bulb
# jacket
# Mushroom
# doughnut
# Fungi
# picture frame
# cooler
# steak
# Disinfectant
# Hazelnut
# Agave
# Sleeping bag
# Milling machine
# garden shovel
# Gym Mats
# mop
# coffee machine
# Stair Stepper
# lime
# impact crusher
# strainer
# Stove
# Oxygen tank
# beer glass
# Pants
#
# Tree: gpt_tree_v3
# Number of keywords guessed correctly: 67
# Average length of games won: 14.656716417910447
# Keywords guessed correctly:
# weasel
# Protein bar
# amazon echo
# dresser
# Golf Cart
# Tweezers
# cane
# king snake
# espresso machine
# fossil
# oatmeal cookie
# Sticker
# Mouse
# fudge brownie
# Screwdriver
# binder clip
# electronic piano
# Dish soap
# Air Conditioner
# Reptile
# Swing set
# Grapefruit
# game board
# Pumpkin pie
# petunia
# anchovy
# lifting crane
# Spatula
# grape juice
# caribou
# groundhog
# parrot
# cupcake
# hot tea
# Hairbrush
# pipe
# pineapple
# wine decanter
# volleyball
# charger
# honeydew
# Bulb
# chair cushion
# Muffin Tin
# doughnut
# Fungi
# picture frame
# steak
# Floor Mats
# rice krispie
# seagull
# Hazelnut
# Shipping label
# Agave
# Khaki pants
# garden shovel
# ruby
# Beanbag
# coffee machine
# porcupine
# coffee table
# ruler
# nightshade
# Journal
# Stove
# refrigerator
# beer glass
#
# Tree: gpt_tree_v4
# Number of keywords guessed correctly: 59
# Average length of games won: 14.677966101694915
# Keywords guessed correctly:
# weasel
# Protein bar
# amazon echo
# Tweezers
# palmetto tree
# Sprinkler
# king snake
# desk lamp
# oatmeal cookie
# Sticker
# Mouse
# Screwdriver
# Dish soap
# Air Conditioner
# Reptile
# safety glasses
# Grapefruit
# Stain Remover
# game board
# Pumpkin pie
# petunia
# lifting crane
# Komodo dragon
# grape juice
# caribou
# parrot
# cupcake
# hot tea
# Hairbrush
# Lathe
# bald eagle
# hair elastic
# volleyball
# charger
# honeydew
# chair cushion
# jacket
# doughnut
# picture frame
# steak
# rice krispie
# seagull
# Shipping label
# Agave
# Sleeping bag
# garden shovel
# Beanbag
# mop
# plastic pallet
# coffee machine
# porcupine
# clay
# coffee table
# strainer
# ruler
# tape measure
# Journal
# Stove
# beer glass
#
# Tree: MC_tree
# Number of keywords guessed correctly: 61
# Average length of games won: 13.918032786885245
# Keywords guessed correctly:
# Protein bar
# Nail Polish Remover
# conference table
# aluminum foil
# butter knife
# angelfish
# palmetto tree
# king snake
# rubber
# Mouse
# electronic piano
# Dish soap
# Reptile
# Pressure gauge
# safety glasses
# Grapefruit
# game board
# lifting crane
# Spatula
# Komodo dragon
# plastic baggie
# caribou
# cockroach
# Hairbrush
# meatloaf
# bald eagle
# Rat
# pipe
# pineapple
# Phone charger
# hair elastic
# Ear protection
# volleyball
# metal file
# earring
# charger
# honeydew
# hamster
# jacket
# Muffin Tin
# doughnut
# picture frame
# perfume bottle
# foil paper
# seagull
# Khaki pants
# Gym Mats
# Necklace
# ruby
# mop
# Handbag
# Stair Stepper
# clay
# lime
# Pesticide
# ruler
# tape measure
# nightshade
# Stove
# Oxygen tank
# Pants

# %% [markdown]
# ## Generate all the games

# %%
import json

def read_jsonl_and_transform(file_path):
    result_dict = {}

    with open(file_path, 'r') as file:
        for line in file:
            record = json.loads(line)
            keyword = record.pop('keyword')
            result_dict[keyword] = record

    return result_dict

def read_json_to_dict(file_path):
    with open(file_path, 'r') as file:
        data = json.load(file)
    return data

keyword_labels, results = read_jsonl_and_transform('20qs-data/keywords_data/labeled_keywords_v2.jsonl'), read_json_to_dict('20qs-data/keywords_data/labeling_results_v2.jsonl')

def read_file_to_list(file_path):
    with open(file_path, 'r') as file:
        lines = file.read().splitlines()
    return lines

keywords_list = read_file_to_list('20qs-data/keywords_data/keywords.txt')
similar_keywords_list = read_file_to_list('20qs-data/keywords_data/similar_keywords.txt')
twice_removed_keywords_list = read_file_to_list('20qs-data/keywords_data/twice_removed_more_similar_keywords.txt')

keywords_list = keywords_list[1:]
print(f"Number of keywords in data: {len(keywords_list)}")

keyword_places = [keyword for keyword in keywords_list if keyword_labels[keyword]['place'] == 'yes']
keyword_things = [keyword for keyword in keywords_list if keyword_labels[keyword]['place'] == 'no']

print(f"Number of keywords labeled as things: {len(keyword_things)}.")
# Out:
# Number of keywords in data: 2046
# Number of keywords labeled as things: 1347.

# %% [markdown]
# Read current games:

# %%
import json

def read_jsonl_and_transform(file_path):
    result_dict = {}

    with open(file_path, 'r') as file:
        for line in file:
            if line.strip():  # Skip empty lines
                try:
                    record = json.loads(line)
                    keyword = record.pop('keyword')
                    result_dict[keyword] = record
                except json.JSONDecodeError as e:
                    print(f"Error decoding JSON for line: {line}")
                    print(f"Error message: {e}")

    return result_dict

# Path to the uploaded file
#file_path = '20qs-data/real_keyword_games_extended.jsonl'

# Read and transform the JSONL file
#result_dict = read_jsonl_and_transform(file_path)

# Get the current keywords with games
current_keywords_with_games = read_jsonl_and_transform('20qs-data/final_games/530-games-for-training.jsonl')

# %%
game_results = []

# %%
import random
from tqdm.notebook import tqdm

dict_keywords = {d['keyword'] for d in game_results}

keywords_left = [keyword for keyword in keyword_things if (keyword not in dict_keywords) and (keyword not in current_keywords_with_games)]
similar_keywords_left = [keyword for keyword in similar_keywords_list if (keyword not in dict_keywords) and (keyword not in current_keywords_with_games)]

print(f"Keywords left: {len(keywords_left)}\n")
print(f"Similar Keywords left: {len(similar_keywords_left)}\n")

generated_keywords = random.choices(keywords_left, k=100)
generated_similar_keywords = random.choices(similar_keywords_left, k=100)
generated_keywords_combined = list(set(generated_keywords + generated_similar_keywords))

for generated_keyword in tqdm(twice_removed_keywords_list, desc = 'games generated'):
    print("Generated keyword:", generated_keyword)
    game_result = simulate_game(generated_keyword, MC_tree)
    game_results.append(game_result)
# Out:
# Keywords left: 1074
#
# Similar Keywords left: 984
# games generated:   0%|          | 0/348 [00:00<?, ?it/s]
# Generated keyword: Toggle bolt
# USING MODEL: ft:gpt-4o-mini-2024-07-18:personal:20qs-tuned:9ujvexa0
# KEYWORD: Toggle bolt
#
# questioner: Is it related to food, beverages or cooking?
# answerer: no
# guesser: Car
# evaluator: False
#
# questioner: Is it related to industrial production or manufacturing?
# answerer: yes
# guesser: Robot
# evaluator: False
#
# questioner: Is it related to safety or safety equipment?
# answerer: no
# guesser: Factory
# evaluator: False
#
# questioner: Is it related to electronics or technology?
# answerer: no
# guesser: Machine
# evaluator: False
#
# questioner: Is it a natural material or resource?
# answerer: no
# guesser: Tool
# evaluator: False
#
# questioner: Is it commonly used in construction or building?
# answerer: yes
# guesser: Concrete
# evaluator: False
#
# questioner: Is it typically used as a structural component?
# answerer: no
# guesser: Insulation
# evaluator: False
#
# questioner: Is it primarily used for finishing or interior work?
# answerer: yes
# guesser: Paint
# evaluator: False
#
# questioner: Is it commonly used for wall treatments or coverings?
# answerer: yes
# guesser: Wallpaper
# evaluator: False
#
# questioner: Is it typically used for both residential and commercial buildings?
# answerer: yes
# guesser: Drywall
# evaluator: False
#
# questioner: Is it typically made from a type of synthetic material?
# answerer: no
# guesser: Wood
# evaluator: False
#
# questioner: Is it primarily associated with providing insulation?
# answerer: no
# guesser: Tile
# evaluator: False
#
# questioner: Is it commonly used in bathrooms or kitchens?
# answerer: yes
# guesser: Ceramic
# evaluator: False
#
# questioner: Is it a type of tile?
# answerer: no
# guesser: Countertop
# evaluator: False
#
# questioner: Is it used as a wall covering?
# answerer: no
# guesser: Bathtub
# evaluator: False
#
# questioner: Is it primarily used for decorative purposes?
# answerer: no
# guesser: Sink
# evaluator: False
#
# questioner: Is it involved in the waterproofing process?
# answerer: no
# guesser: Grout
# evaluator: False
#
# questioner: Is it a type of paneling?
# answerer: no
# guesser: Ceramic tile
# evaluator: False
#
# questioner: Is it commonly painted?
# answerer: no
# guesser: Laminate
# evaluator: False
#
# questioner: Is it related to providing surface protection?
# answerer: no
# guesser: Plumbing fixture
# evaluator: False
#
# Generated keyword: Serrano pepper
# USING MODEL: ft:gpt-4o-mini-2024-07-18:personal:20qs-tuned:9ujvexa0
# KEYWORD: Serrano pepper
#
# questioner: Is it related to food, beverages or cooking?
# answerer: yes
# guesser: Bread
# evaluator: False
#
# questioner: Is it a food?
# answerer: yes
# guesser: Pizza
# evaluator: False
#
# questioner: Is it related to agriculture?
# answerer: yes
# guesser: Corn
# evaluator: False
#
# questioner: Is it a fruit?
# answerer: yes
# guesser: Apple
# evaluator: False
#
# questioner: Is it grown primarily in tropical climates?
# answerer: no
# guesser: Pear
# evaluator: False
#
# questioner: Is it typically eaten raw?
# answerer: yes
# guesser: Grape
# evaluator: False
#
# questioner: Is it grown primarily in temperate climates?
# answerer: yes
# guesser: Plum
# evaluator: False
#
# questioner: Is it commonly available year-round?
# answerer: yes
# guesser: Orange
# evaluator: False
#
# questioner: Is it a type of berry?
# answerer: yes
# guesser: Strawberry
# evaluator: False
#
# questioner: Is it commonly used in desserts or sweet dishes?
# answerer: no
# guesser: Blueberry
# evaluator: False
#
# questioner: Is it known for having a high antioxidant content?
# answerer: yes
# guesser: Cranberry
# evaluator: False
#
# questioner: Is it typically consumed in small quantities, like a handful?
# answerer: yes
# guesser: Raspberry
# evaluator: False
#
# questioner: Is it commonly added to salads?
# answerer: yes
# guesser: Blackberry
# evaluator: False
#
# questioner: Is it known for its vibrant red color?
# answerer: yes
# guesser: Tomato
# evaluator: False
#
# questioner: Is it a strawberry?
# answerer: no
# guesser: Cherry
# evaluator: False
#
# questioner: Is it a raspberry?
# answerer: no
# guesser: Tomato
# evaluator: False
#
# questioner: Is it a cranberry?
# answerer: no
# guesser: Red currant
# evaluator: False
#
# questioner: Is it a red currant?
# answerer: no
# guesser: Bell pepper
# evaluator: False
#
# questioner: Is it commonly grown in home gardens?
# answerer: yes
# guesser: Radish
# evaluator: False
#
# questioner: Is it known for having a small, edible seed at its core?
# answerer: yes
# guesser: Cherry
# evaluator: False
#
# Generated keyword: Fabric sofa
# USING MODEL: ft:gpt-4o-mini-2024-07-18:personal:20qs-tuned:9ujvexa0
# KEYWORD: Fabric sofa
#
# questioner: Is it related to food, beverages or cooking?
# answerer: no
# guesser: Laptop
# evaluator: False
#
# questioner: Is it related to industrial production or manufacturing?
# answerer: yes
# guesser: Factory
# evaluator: False
#
# questioner: Is it related to safety or safety equipment?
# answerer: no
# guesser: Robot
# evaluator: False
#
# questioner: Is it related to electronics or technology?
# answerer: no
# guesser: Machinery
# evaluator: False
#
# questioner: Is it a natural material or resource?
# answerer: no
# guesser: Car
# evaluator: False
#
# questioner: Is it a tool or piece of equipment used in manufacturing or production?
# answerer: no
# guesser: Textiles
# evaluator: False
#
# questioner: Is it a product created through manufacturing or industrial processes?
# answerer: yes
# guesser: Furniture
# evaluator: False
#
# questioner: Is it a consumer product, intended for public use?
# answerer: yes
# guesser: Clothing
# evaluator: False
#
# questioner: Is it typically found in households?
# answerer: yes
# guesser: Television
# evaluator: False
#
# questioner: Is it an appliance?
# answerer: no
# guesser: Toy
# evaluator: False
#
# questioner: Is it something typically used for cleaning?
# answerer: no
# guesser: Light bulb
# evaluator: False
#
# questioner: Is it a piece of furniture?
# answerer: yes
# guesser: Chair
# evaluator: False
#
# questioner: Is it primarily used for sitting or lying down?
# answerer: yes
# guesser: Couch
# evaluator: False
#
# questioner: Is it a chair?
# answerer: no
# guesser: Bed
# evaluator: False
#
# questioner: Is it a bed?
# answerer: no
# guesser: Sofa
# evaluator: False
#
# questioner: Is it a sofa or couch?
# answerer: yes
# guesser: Sofa
# evaluator: False
#
# questioner: Is it a sectional sofa or couch?
# answerer: no
# guesser: Recliner
# evaluator: False
#
# questioner: Is it a loveseat?
# answerer: no
# guesser: Couch
# evaluator: False
#
# questioner: Is it a recliner?
# answerer: no
# guesser: Sectional sofa
# evaluator: False
#
# questioner: Is it a specific type of chaise lounge?
# answerer: no
# guesser: Futon
# evaluator: False
#
# Generated keyword: ID badge holder
# USING MODEL: ft:gpt-4o-mini-2024-07-18:personal:20qs-tuned:9ujvexa0
# KEYWORD: ID badge holder
#
# questioner: Is it related to food, beverages or cooking?
# answerer: no
# guesser: Glue stick
# evaluator: False
#
# questioner: Is it related to industrial production or manufacturing?
# answerer: no
# guesser: Smartphone
# evaluator: False
#
# questioner: Is it broadly related to entertainment or sports?
# answerer: no
# guesser: Chair
# evaluator: False
#
# questioner: Is it related to clothing, accessories or beauty products?
# answerer: no
# guesser: Bicycle
# evaluator: False
#
# questioner: Is it an animal?
# answerer: no
# guesser: Coffee filter
# evaluator: False
#
# questioner: Is it something a person can hold in their hand?
# answerer: yes
# guesser: Flashlight
# evaluator: False
#
# questioner: Is it related to electronics or technology?
# answerer: no
# guesser: Book
# evaluator: False
#
# questioner: Is it related to safety or safety equipment?
# answerer: yes
# guesser: Fire extinguisher
# evaluator: False
#
# questioner: Is it typically worn on the body?
# answerer: yes
# guesser: Helmet
# evaluator: False
#
# questioner: Is it used primarily for head protection?
# answerer: no
# guesser: Gloves
# evaluator: False
#
# questioner: Is it often used in construction or industrial settings?
# answerer: yes
# guesser: Safety glasses
# evaluator: False
#
# questioner: Is it used to protect the hands?
# answerer: no
# guesser: Hard hat
# evaluator: False
#
# questioner: Is it used to protect the feet?
# answerer: no
# guesser: Earplugs
# evaluator: False
#
# questioner: Is it used to protect the body or torso?
# answerer: no
# guesser: Respirator
# evaluator: False
#
# questioner: Is it used to protect the eyes?
# answerer: no
# guesser: Steel-toed boots
# evaluator: False
#
# questioner: Is it used to protect the ears?
# answerer: no
# guesser: Safety vest
# evaluator: False
#
# questioner: Is it used to protect the respiratory system?
# answerer: no
# guesser: Face shield
# evaluator: False
#
# questioner: Is it worn on the hands?
# answerer: no
# guesser: Safety harness
# evaluator: False
#
# questioner: Is it used to protect the legs?
# answerer: no
# guesser: Safety shoes
# evaluator: False
#
# questioner: Is it designed to protect the face?
# answerer: no
# guesser: Safety cone
# evaluator: False
#
# Generated keyword: Plaster cast
# USING MODEL: ft:gpt-4o-mini-2024-07-18:personal:20qs-tuned:9ujvexa0
# KEYWORD: Plaster cast
#
# questioner: Is it related to food, beverages or cooking?
# answerer: no
# guesser: Library
# evaluator: False
#
# questioner: Is it related to industrial production or manufacturing?
# answerer: yes
# guesser: Factory
# evaluator: False
#
# questioner: Is it related to safety or safety equipment?
# answerer: yes
# guesser: Helmet
# evaluator: False
#
# questioner: Is it related to transportation or vehicles?
# answerer: no
# guesser: Fire extinguisher
# evaluator: False
#
# questioner: Is it related to architectural structures or construction?
# answerer: yes
# guesser: Scaffolding
# evaluator: False
#
# questioner: Is it a type of personal protective equipment (PPE)?
# answerer: no
# guesser: Hard hat
# evaluator: False
#
# questioner: Is it a tool or device used primarily in construction?
# answerer: no
# guesser: Safety barrier
# evaluator: False
#
# questioner: Is it a structural component used in building construction?
# answerer: no
# guesser: Safety harness
# evaluator: False
#
# questioner: Is it used for maintaining safety during the construction process?
# answerer: no
# guesser: Fire alarm
# evaluator: False
#
# questioner: Is it related to fire safety or prevention?
# answerer: no
# guesser: First aid kit
# evaluator: False
#
# questioner: Is it used for monitoring or signaling in safety-related contexts?
# answerer: no
# guesser: Safety cone
# evaluator: False
#
# questioner: Is it associated with environmental safety or hazard control?
# answerer: no
# guesser: Safety vest
# evaluator: False
#
# questioner: Is it a type of equipment specifically designed for lifting or hoisting?
# answerer: no
# guesser: Building code
# evaluator: False
#
# questioner: Is it a type of barrier or guard used in construction sites?
# answerer: no
# guesser: Blueprint
# evaluator: False
#
# questioner: Is it used for scaffolding or temporary supports in construction?
# answerer: no
# guesser: Safety goggles
# evaluator: False
#
# questioner: Is it related to lighting or visibility for safety on construction sites?
# answerer: no
# guesser: Hard hat
# evaluator: False
#
# questioner: Is it related to cleaning or maintaining a safe work environment in construction?
# answerer: no
# guesser: Safety sign
# evaluator: False
#
# questioner: Is it a type of safety signage or indicator used on construction sites?
# answerer: no
# guesser: Blueprint
# evaluator: False
#
# questioner: Is it a device or tool used for measuring safety compliance or standards?
# answerer: no
# guesser: Safety net
# evaluator: False
#
# questioner: Is it an automated or robotic system used for safety monitoring in construction?
# answerer: no
# guesser: Building permit
# evaluator: False
#
# Generated keyword: Rain gutter
# USING MODEL: ft:gpt-4o-mini-2024-07-18:personal:20qs-tuned:9ujvexa0
# KEYWORD: Rain gutter
#
# questioner: Is it related to food, beverages or cooking?
# answerer: no
# guesser: Computer
# evaluator: False
#
# questioner: Is it related to industrial production or manufacturing?
# answerer: no
# guesser: Car
# evaluator: False
#
# questioner: Is it broadly related to entertainment or sports?
# answerer: no
# guesser: Tree
# evaluator: False
#
# questioner: Is it related to clothing, accessories or beauty products?
# answerer: no
# guesser: Book
# evaluator: False
#
# questioner: Is it an animal?
# answerer: no
# guesser: Chair
# evaluator: False
#
# questioner: Is it something a person can hold in their hand?
# answerer: no
# guesser: Building
# evaluator: False
#
# questioner: Is it a living thing?
# answerer: no
# guesser: Mountain
# evaluator: False
#
# questioner: Is it furniture?
# answerer: no
# guesser: Road
# evaluator: False
#
# questioner: Is it broadly related to the arts or media?
# answerer: no
# guesser: Planet
# evaluator: False
#
# questioner: Is it something commonly found outdoors?
# answerer: yes
# guesser: Rock
# evaluator: False
#
# questioner: Is it a natural feature or occurrence?
# answerer: no
# guesser: Cloud
# evaluator: False
#
# questioner: Is it something that is typically found in a garden or yard?
# answerer: no
# guesser: Ocean
# evaluator: False
#
# questioner: Is it a type of building or structure?
# answerer: yes
# guesser: Bridge
# evaluator: False
#
# questioner: Is it related to transportation, such as a bridge or tunnel?
# answerer: no
# guesser: House
# evaluator: False
#
# questioner: Is it typically used for recreational purposes?
# answerer: no
# guesser: Skyscraper
# evaluator: False
#
# questioner: Is it a type of utility or infrastructure building, such as a power plant or water tower?
# answerer: no
# guesser: Airport
# evaluator: False
#
# questioner: Is it a type of commercial building?
# answerer: no
# guesser: Museum
# evaluator: False
#
# questioner: Is it a public building or facility?
# answerer: no
# guesser: Private residence
# evaluator: False
#
# questioner: Is it primarily used for storage purposes?
# answerer: no
# guesser: Temple
# evaluator: False
#
# questioner: Is it an agricultural building, like a barn or silo?
# answerer: no
# guesser: Mansion
# evaluator: False
#
# Generated keyword: Curling stone
# USING MODEL: ft:gpt-4o-mini-2024-07-18:personal:20qs-tuned:9ujvexa0
# KEYWORD: Curling stone
#
# questioner: Is it related to food, beverages or cooking?
# answerer: no
# guesser: Glue stick
# evaluator: False
#
# questioner: Is it related to industrial production or manufacturing?
# answerer: no
# guesser: Coffee filter
# evaluator: False
#
# questioner: Is it broadly related to entertainment or sports?
# answerer: yes
# guesser: Stadium
# evaluator: False
#
# questioner: Is it something a person can hold in their hand?
# answerer: yes
# guesser: Basketball
# evaluator: False
#
# questioner: Is it related to electronics or technology?
# answerer: no
# guesser: Playing cards
# evaluator: False
#
# questioner: Is it broadly related to the arts or media?
# answerer: no
# guesser: Fishing rod
# evaluator: False
#
# questioner: Is it used in sports equipment?
# answerer: yes
# guesser: Baseball bat
# evaluator: False
#
# questioner: Is it specifically used for outdoor sports?
# answerer: no
# guesser: Tennis racket
# evaluator: False
#
# questioner: Is it used in a game that involves a ball?
# answerer: no
# guesser: Hockey stick
# evaluator: False
#
# questioner: Is it used in a winter sport?
# answerer: yes
# guesser: Ski poles
# evaluator: False
#
# questioner: Is it used in skiing or snowboarding?
# answerer: no
# guesser: Ice skate
# evaluator: False
#
# questioner: Is it a piece of clothing or gear that provides protection?
# answerer: no
# guesser: Sled
# evaluator: False
#
# questioner: Is it an object used for competition?
# answerer: yes
# guesser: Curling stone
# evaluator: True
# Generated keyword: Drumsticks
# USING MODEL: ft:gpt-4o-mini-2024-07-18:personal:20qs-tuned:9ujvexa0
# KEYWORD: Drumsticks
#
# questioner: Is it related to food, beverages or cooking?
# answerer: yes
# guesser: Pizza
# evaluator: False
#
# questioner: Is it a food?
# answerer: yes
# guesser: Apple
# evaluator: False
#
# questioner: Is it related to agriculture?
# answerer: no
# guesser: Chocolate
# evaluator: False
#
# questioner: Is it a prepared food or dish?
# answerer: yes
# guesser: Sandwich
# evaluator: False
#
# questioner: Is it typically served hot?
# answerer: yes
# guesser: Soup
# evaluator: False
#
# questioner: Is it a main course?
# answerer: yes
# guesser: Pizza
# evaluator: False
#
# questioner: Does it contain meat?
# answerer: yes
# guesser: Burger
# evaluator: False
#
# questioner: Is it commonly associated with a specific cuisine, such as Italian or Chinese?
# answerer: no
# guesser: Casserole
# evaluator: False
#
# questioner: Is it typically served with a sauce?
# answerer: yes
# guesser: Taco
# evaluator: False
#
# questioner: Is it a type of pasta dish?
# answerer: no
# guesser: Meatloaf
# evaluator: False
#
# questioner: Is it commonly prepared by baking?
# answerer: yes
# guesser: Lasagna
# evaluator: False
#
# questioner: Is it a type of casserole?
# answerer: no
# guesser: Baked Ziti
# evaluator: False
#
# questioner: Is it a dish typically made with poultry, such as chicken or turkey?
# answerer: yes
# guesser: Chicken Pot Pie
# evaluator: False
#
# questioner: Is it a chicken pot pie?
# answerer: no
# guesser: Baked Chicken
# evaluator: False
#
# questioner: Is it a roasted chicken dish?
# answerer: yes
# guesser: Roast Chicken
# evaluator: False
#
# questioner: Is it typically prepared by roasting the whole bird?
# answerer: no
# guesser: Baked Chicken Wings
# evaluator: False
#
# questioner: Is it a chicken breast dish?
# answerer: no
# guesser: Chicken thighs
# evaluator: False
#
# questioner: Is it a chicken thigh dish?
# answerer: yes
# guesser: Baked chicken thighs
# evaluator: False
#
# questioner: Is it baked chicken thighs with skin on?
# answerer: yes
# guesser: Baked chicken thighs with skin on
# evaluator: False
#
# questioner: Is it baked chicken thighs with skin on?
# answerer: yes
# guesser: Baked chicken thighs
# evaluator: False
#
# Generated keyword: Hiker
# USING MODEL: ft:gpt-4o-mini-2024-07-18:personal:20qs-tuned:9ujvexa0
# KEYWORD: Hiker
#
# questioner: Is it related to food, beverages or cooking?
# answerer: no
# guesser: Chair
# evaluator: False
#
# questioner: Is it related to industrial production or manufacturing?
# answerer: no
# guesser: Car
# evaluator: False
#
# questioner: Is it broadly related to entertainment or sports?
# answerer: yes
# guesser: Television
# evaluator: False
#
# questioner: Is it something a person can hold in their hand?
# answerer: no
# guesser: Basketball
# evaluator: False
#
# questioner: Is it typically used indoors?
# answerer: no
# guesser: Soccer Field
# evaluator: False
#
# questioner: Is it related to a specific type of sport?
# answerer: yes
# guesser: Tennis Court
# evaluator: False
#
# questioner: Is it a type of vehicle used in the sport?
# answerer: no
# guesser: Surfboard
# evaluator: False
#
# questioner: Is it used in a team sport?
# answerer: no
# guesser: Golf Club
# evaluator: False
#
# questioner: Is it used in an outdoor individual sport?
# answerer: yes
# guesser: Tennis Ball
# evaluator: False
#
# questioner: Is it related to a winter sport?
# answerer: no
# guesser: Hiking Trail
# evaluator: False
#
# questioner: Is it related to a water sport?
# answerer: no
# guesser: Running Shoes
# evaluator: False
#
# questioner: Is it an item of clothing or equipment worn by the athlete?
# answerer: no
# guesser: Fishing Rod
# evaluator: False
#
# questioner: Is it related to a sport that involves running or jogging?
# answerer: yes
# guesser: Running Track
# evaluator: False
#
# questioner: Is it a type of running surface or track?
# answerer: no
# guesser: Marathon
# evaluator: False
#
# questioner: Is it a tool or accessory used by runners for training or exercise?
# answerer: no
# guesser: Race Car
# evaluator: False
#
# questioner: Is it a type of event or race in running?
# answerer: no
# guesser: Running Shoe
# evaluator: False
#
# questioner: Is it commonly found along running routes or trails?
# answerer: yes
# guesser: Water Fountain
# evaluator: False
#
# questioner: Is it a form of signage or marker?
# answerer: no
# guesser: Tree
# evaluator: False
#
# questioner: Is it related to measuring distance or time for runners?
# answerer: no
# guesser: Running Trail
# evaluator: False
#
# questioner: Is it part of the natural environment, such as trees or landmarks?
# answerer: no
# guesser: Road
# evaluator: False
#
# Generated keyword: Sputum
# USING MODEL: ft:gpt-4o-mini-2024-07-18:personal:20qs-tuned:9ujvexa0
# KEYWORD: Sputum
#
# questioner: Is it related to food, beverages or cooking?
# answerer: no
# guesser: Car
# evaluator: False
#
# questioner: Is it related to industrial production or manufacturing?
# answerer: no
# guesser: Computer
# evaluator: False
#
# questioner: Is it broadly related to entertainment or sports?
# answerer: no
# guesser: Bicycle
# evaluator: False
#
# questioner: Is it related to clothing, accessories or beauty products?
# answerer: no
# guesser: Smartphone
# evaluator: False
#
# questioner: Is it an animal?
# answerer: no
# guesser: Tree
# evaluator: False
#
# questioner: Is it something a person can hold in their hand?
# answerer: yes
# guesser: Lamp
# evaluator: False
#
# questioner: Is it related to electronics or technology?
# answerer: no
# guesser: Book
# evaluator: False
#
# questioner: Is it related to safety or safety equipment?
# answerer: no
# guesser: Pen
# evaluator: False
#
# questioner: Is it a tool or utensil used for specific tasks?
# answerer: no
# guesser: Key
# evaluator: False
#
# questioner: Is it a type of toy or game?
# answerer: no
# guesser: Clock
# evaluator: False
#
# questioner: Is it something that can be classified as a household item?
# answerer: no
# guesser: Flower
# evaluator: False
#
# questioner: Is it something related to art or office supplies?
# answerer: no
# guesser: Rock
# evaluator: False
#
# questioner: Is it something that is commonly found in nature?
# answerer: no
# guesser: Bottle
# evaluator: False
#
# questioner: Is it something that is consumable or perishable?
# answerer: no
# guesser: Coin
# evaluator: False
#
# questioner: Is it a type of structure or construction?
# answerer: no
# guesser: Balloon
# evaluator: False
#
# questioner: Is it related to transportation or vehicles?
# answerer: no
# guesser: Mirror
# evaluator: False
#
# questioner: Is it something associated with communication?
# answerer: no
# guesser: Scissors
# evaluator: False
#
# questioner: Is it typically found outdoors?
# answerer: no
# guesser: Mug
# evaluator: False
#
# questioner: Is it a form of currency or something related to finance?
# answerer: no
# guesser: Ruler
# evaluator: False
#
# questioner: Is it something that can produce light?
# answerer: no
# guesser: Keychain
# evaluator: False
#
# Generated keyword: Boston fern
# USING MODEL: ft:gpt-4o-mini-2024-07-18:personal:20qs-tuned:9ujvexa0
# KEYWORD: Boston fern
#
# questioner: Is it related to food, beverages or cooking?
# answerer: no
# guesser: Car
# evaluator: False
#
# questioner: Is it related to industrial production or manufacturing?
# answerer: no
# guesser: Coffee filter
# evaluator: False
#
# questioner: Is it broadly related to entertainment or sports?
# answerer: no
# guesser: Chair
# evaluator: False
#
# questioner: Is it related to clothing, accessories or beauty products?
# answerer: no
# guesser: Cat
# evaluator: False
#
# questioner: Is it an animal?
# answerer: no
# guesser: Television
# evaluator: False
#
# questioner: Is it something a person can hold in their hand?
# answerer: yes
# guesser: Smartphone
# evaluator: False
#
# questioner: Is it related to electronics or technology?
# answerer: no
# guesser: Book
# evaluator: False
#
# questioner: Is it related to safety or safety equipment?
# answerer: no
# guesser: Key
# evaluator: False
#
# questioner: Is it a toy or a game?
# answerer: no
# guesser: Lamp
# evaluator: False
#
# questioner: Is it used for writing or drawing?
# answerer: no
# guesser: Bicycle
# evaluator: False
#
# questioner: Is it used for personal hygiene or grooming?
# answerer: no
# guesser: Table
# evaluator: False
#
# questioner: Is it used in the home or office environment?
# answerer: yes
# guesser: Pen
# evaluator: False
#
# questioner: Is it used for cleaning or maintenance?
# answerer: no
# guesser: Clock
# evaluator: False
#
# questioner: Is it a piece of furniture?
# answerer: no
# guesser: Chair
# evaluator: False
#
# questioner: Is it used for organizing or storing items?
# answerer: no
# guesser: Refrigerator
# evaluator: False
#
# questioner: Is it related to home decor?
# answerer: yes
# guesser: Vase
# evaluator: False
#
# questioner: Is it something that provides lighting?
# answerer: no
# guesser: Picture frame
# evaluator: False
#
# questioner: Is it something that can be hung on a wall?
# answerer: no
# guesser: Candle
# evaluator: False
#
# questioner: Is it something that can be placed on a table or shelf?
# answerer: yes
# guesser: Statue
# evaluator: False
#
# questioner: Is it a plant or a plant-related item?
# answerer: yes
# guesser: Plant
# evaluator: False
#
# Generated keyword: amber fossil
# USING MODEL: ft:gpt-4o-mini-2024-07-18:personal:20qs-tuned:9ujvexa0
# KEYWORD: amber fossil
#
# questioner: Is it related to food, beverages or cooking?
# answerer: no
# guesser: Computer
# evaluator: False
#
# questioner: Is it related to industrial production or manufacturing?
# answerer: no
# guesser: Smartphone
# evaluator: False
#
# questioner: Is it broadly related to entertainment or sports?
# answerer: no
# guesser: Chair
# evaluator: False
#
# questioner: Is it related to clothing, accessories or beauty products?
# answerer: no
# guesser: Television
# evaluator: False
#
# questioner: Is it an animal?
# answerer: no
# guesser: Tree
# evaluator: False
#
# questioner: Is it something a person can hold in their hand?
# answerer: yes
# guesser: Book
# evaluator: False
#
# questioner: Is it related to electronics or technology?
# answerer: no
# guesser: Pen
# evaluator: False
#
# questioner: Is it related to safety or safety equipment?
# answerer: no
# guesser: Flashlight
# evaluator: False
#
# questioner: Is it something typically found in an office or school setting?
# answerer: no
# guesser: Football
# evaluator: False
#
# questioner: Is it something used for leisure activities or hobbies?
# answerer: yes
# guesser: Board game
# evaluator: False
#
# questioner: Is it primarily used outdoors?
# answerer: no
# guesser: Painting
# evaluator: False
#
# questioner: Is it something that can produce or is used to create art?
# answerer: no
# guesser: Puzzle
# evaluator: False
#
# questioner: Is it something associated with games or gaming?
# answerer: no
# guesser: Musical instrument
# evaluator: False
#
# questioner: Is it something related to physical fitness or exercise?
# answerer: no
# guesser: Toy
# evaluator: False
#
# questioner: Is it something used for reading or writing?
# answerer: no
# guesser: Video
# evaluator: False
#
# questioner: Is it related to music or musical instruments?
# answerer: no
# guesser: Bicycle
# evaluator: False
#
# questioner: Is it a type of craft supply?
# answerer: no
# guesser: Puzzle piece
# evaluator: False
#
# questioner: Is it something typically found in the home?
# answerer: no
# guesser: Balloon
# evaluator: False
#
# questioner: Is it primarily used indoors?
# answerer: no
# guesser: Fishing rod
# evaluator: False
#
# questioner: Is it something used in or associated with science or scientific experiments?
# answerer: yes
# guesser: Microscope
# evaluator: False
#
# Generated keyword: Hair tie
# USING MODEL: ft:gpt-4o-mini-2024-07-18:personal:20qs-tuned:9ujvexa0
# KEYWORD: Hair tie
#
# questioner: Is it related to food, beverages or cooking?
# answerer: no
# guesser: Car
# evaluator: False
#
# questioner: Is it related to industrial production or manufacturing?
# answerer: no
# guesser: Library
# evaluator: False
#
# questioner: Is it broadly related to entertainment or sports?
# answerer: no
# guesser: Mountain
# evaluator: False
#
# questioner: Is it related to clothing, accessories or beauty products?
# answerer: yes
# guesser: Perfume
# evaluator: False
#
# questioner: Is it something that can be worn?
# answerer: yes
# guesser: Hat
# evaluator: False
#
# questioner: Is it primarily worn on the upper body?
# answerer: yes
# guesser: Shirt
# evaluator: False
#
# questioner: Is it typically considered outerwear?
# answerer: no
# guesser: Blouse
# evaluator: False
#
# questioner: Is it an item of clothing that is often worn at formal events?
# answerer: no
# guesser: T-shirt
# evaluator: False
#
# questioner: Is it an undergarment?
# answerer: no
# guesser: Sweater
# evaluator: False
#
# questioner: Is it something that is typically worn in casual settings?
# answerer: yes
# guesser: Jacket
# evaluator: False
#
# questioner: Is it a type of shirt?
# answerer: no
# guesser: Tunic
# evaluator: False
#
# questioner: Is it commonly worn during physical activities or exercise?
# answerer: yes
# guesser: Tank top
# evaluator: False
#
# questioner: Is it a type of athletic top or tank?
# answerer: no
# guesser: Hoodie
# evaluator: False
#
# questioner: Is it often worn as part of a uniform for a specific sport?
# answerer: no
# guesser: T-shirt
# evaluator: False
#
# questioner: Is it typically made from stretchy or form-fitting material?
# answerer: yes
# guesser: Leotard
# evaluator: False
#
# questioner: Is it commonly worn on the lower part of the upper body, such as a crop top or sports bra?
# answerer: no
# guesser: Compression shirt
# evaluator: False
#
# questioner: Is it a type of jacket or outer layer commonly used in exercise settings?
# answerer: no
# guesser: Sweatshirt
# evaluator: False
#
# questioner: Is it often worn during activities like running, yoga, or aerobics?
# answerer: yes
# guesser: Tights
# evaluator: False
#
# questioner: Is it typically designed to provide support or compression?
# answerer: no
# guesser: Workout top
# evaluator: False
#
# questioner: Is it commonly long-sleeved?
# answerer: no
# guesser: Sports bra
# evaluator: False
#
# Generated keyword: Oregano
# USING MODEL: ft:gpt-4o-mini-2024-07-18:personal:20qs-tuned:9ujvexa0
# KEYWORD: Oregano
#
# questioner: Is it related to food, beverages or cooking?
# answerer: yes
# guesser: Apple
# evaluator: False
#
# questioner: Is it a food?
# answerer: no
# guesser: Coffee
# evaluator: False
#
# questioner: Is it related to agriculture?
# answerer: yes
# guesser: Farm
# evaluator: False
#
# questioner: Is it related to safety or safety equipment?
# answerer: no
# guesser: Tractor
# evaluator: False
#
# questioner: Is it a type of machine or equipment used in agriculture?
# answerer: no
# guesser: Pesticide
# evaluator: False
#
# questioner: Is it a natural product of agriculture, such as a crop or plant?
# answerer: yes
# guesser: Wheat
# evaluator: False
#
# questioner: Is it commonly grown for its edible parts?
# answerer: yes
# guesser: Corn
# evaluator: False
#
# questioner: Is it a type of fruit?
# answerer: no
# guesser: Tomato
# evaluator: False
#
# questioner: Is it a type of vegetable?
# answerer: no
# guesser: Soybean
# evaluator: False
#
# questioner: Is it a type of grain or cereal?
# answerer: no
# guesser: Sugarcane
# evaluator: False
#
# questioner: Is it a type of herb or spice?
# answerer: yes
# guesser: Basil
# evaluator: False
#
# questioner: Is it commonly used in cooking for its aromatic properties?
# answerer: yes
# guesser: Rosemary
# evaluator: False
#
# questioner: Is it a leafy herb?
# answerer: yes
# guesser: Cilantro
# evaluator: False
#
# questioner: Is it commonly used in Mediterranean cuisine?
# answerer: yes
# guesser: Oregano
# evaluator: True
# Generated keyword: Aluminum
# USING MODEL: ft:gpt-4o-mini-2024-07-18:personal:20qs-tuned:9ujvexa0
# KEYWORD: Aluminum
#
# questioner: Is it related to food, beverages or cooking?
# answerer: no
# guesser: Laptop
# evaluator: False
#
# questioner: Is it related to industrial production or manufacturing?
# answerer: yes
# guesser: Car
# evaluator: False
#
# questioner: Is it related to safety or safety equipment?
# answerer: no
# guesser: Machine
# evaluator: False
#
# questioner: Is it related to electronics or technology?
# answerer: yes
# guesser: Smartphone
# evaluator: False
#
# questioner: Is it a consumer electronic device?
# answerer: no
# guesser: Robot
# evaluator: False
#
# questioner: Is it used in the process of manufacturing electronic components or devices?
# answerer: yes
# guesser: 3D Printer
# evaluator: False
#
# questioner: Is it a type of machinery or equipment?
# answerer: no
# guesser: Semiconductor
# evaluator: False
#
# questioner: Is it related to software or a digital tool?
# answerer: no
# guesser: Circuit board
# evaluator: False
#
# questioner: Is it a material used in the manufacturing process?
# answerer: yes
# guesser: Silicon
# evaluator: False
#
# questioner: Is it a type of semiconductor material?
# answerer: no
# guesser: Plastic
# evaluator: False
#
# questioner: Is it a type of metal?
# answerer: yes
# guesser: Copper
# evaluator: False
#
# questioner: Is it commonly used for wiring or electrical connections?
# answerer: yes
# guesser: Aluminum
# evaluator: True
# Generated keyword: Geothermal energy
# USING MODEL: ft:gpt-4o-mini-2024-07-18:personal:20qs-tuned:9ujvexa0
# KEYWORD: Geothermal energy
#
# questioner: Is it related to food, beverages or cooking?
# answerer: no
# guesser: Car.
# evaluator: False
#
# questioner: Is it related to industrial production or manufacturing?
# answerer: yes
# guesser: Robot
# evaluator: False
#
# questioner: Is it related to safety or safety equipment?
# answerer: no
# guesser: Machine
# evaluator: False
#
# questioner: Is it related to electronics or technology?
# answerer: yes
# guesser: Computer
# evaluator: False
#
# questioner: Is it a consumer electronic device?
# answerer: no
# guesser: Semiconductor fabrication device
# evaluator: False
#
# questioner: Is it primarily used in the manufacturing process?
# answerer: no
# guesser: Smartphone
# evaluator: False
#
# questioner: Is it a component or part used within electronic devices?
# answerer: no
# guesser: Factory machine
# evaluator: False
#
# questioner: Is it related to communication technology?
# answerer: no
# guesser: Electricity
# evaluator: False
#
# questioner: Is it related to data processing or computing?
# answerer: no
# guesser: Solar panel
# evaluator: False
#
# questioner: Is it a type of industrial machinery?
# answerer: no
# guesser: 3D printer
# evaluator: False
#
# questioner: Is it an equipment used for testing or measurement?
# answerer: no
# guesser: Electric battery
# evaluator: False
#
# questioner: Is it related to power generation or management?
# answerer: yes
# guesser: Transformer
# evaluator: False
#
# questioner: Is it a type of power supply or transformer?
# answerer: no
# guesser: Power grid
# evaluator: False
#
# questioner: Is it related to renewable energy sources?
# answerer: yes
# guesser: Wind turbine
# evaluator: False
#
# questioner: Is it a solar panel or solar collector?
# answerer: no
# guesser: Hydroelectric dam
# evaluator: False
#
# questioner: Is it a wind turbine?
# answerer: no
# guesser: Biofuel
# evaluator: False
#
# questioner: Is it related to energy storage, such as a battery or capacitor?
# answerer: no
# guesser: Renewable energy
# evaluator: False
#
# questioner: Is it used in the process of converting renewable energy into usable power?
# answerer: yes
# guesser: Inverter
# evaluator: False
#
# questioner: Is it an inverter?
# answerer: no
# guesser: Solar energy
# evaluator: False
#
# questioner: Is it a charge controller?
# answerer: no
# guesser: Energy converter
# evaluator: False
#
# Generated keyword: Workbench
# USING MODEL: ft:gpt-4o-mini-2024-07-18:personal:20qs-tuned:9ujvexa0
# KEYWORD: Workbench
#
# questioner: Is it related to food, beverages or cooking?
# answerer: no
# guesser: Telephone
# evaluator: False
#
# questioner: Is it related to industrial production or manufacturing?
# answerer: yes
# guesser: Car
# evaluator: False
#
# questioner: Is it related to safety or safety equipment?
# answerer: no
# guesser: Robot
# evaluator: False
#
# questioner: Is it related to electronics or technology?
# answerer: no
# guesser: Machine
# evaluator: False
#
# questioner: Is it a natural material or resource?
# answerer: no
# guesser: Factory
# evaluator: False
#
# questioner: Is it a type of machinery or equipment?
# answerer: yes
# guesser: Conveyor belt
# evaluator: False
#
# questioner: Is it commonly used in construction or building work?
# answerer: yes
# guesser: Excavator
# evaluator: False
#
# questioner: Is it a handheld tool?
# answerer: no
# guesser: Crane
# evaluator: False
#
# questioner: Is it powered by electricity?
# answerer: no
# guesser: Hammer
# evaluator: False
#
# questioner: Is it primarily used for lifting or moving heavy materials?
# answerer: no
# guesser: Backhoe
# evaluator: False
#
# questioner: Is it typically used for cutting or shaping materials?
# answerer: yes
# guesser: Saw
# evaluator: False
#
# questioner: Is it a type of saw?
# answerer: no
# guesser: Chisel
# evaluator: False
#
# questioner: Is it used for working with metal?
# answerer: yes
# guesser: Welding machine
# evaluator: False
#
# questioner: Is it a type of welding equipment?
# answerer: no
# guesser: Lathe
# evaluator: False
#
# questioner: Is it a type of machine used in the fabrication process?
# answerer: no
# guesser: Anvil
# evaluator: False
#
# questioner: Is it a tool that requires manual operation?
# answerer: yes
# guesser: File
# evaluator: False
#
# questioner: Is it used for grinding or smoothing metal surfaces?
# answerer: no
# guesser: Drill
# evaluator: False
#
# questioner: Is it used for cutting metal sheets or pieces?
# answerer: no
# guesser: Forge
# evaluator: False
#
# questioner: Is it used for shaping or forming metal by hand?
# answerer: yes
# guesser: Hammer
# evaluator: False
#
# questioner: Is it a type of hammer?
# answerer: no
# guesser: Pliers
# evaluator: False
#
# Generated keyword: Tennis net
# USING MODEL: ft:gpt-4o-mini-2024-07-18:personal:20qs-tuned:9ujvexa0
# KEYWORD: Tennis net
#
# questioner: Is it related to food, beverages or cooking?
# answerer: no
# guesser: Smartphone
# evaluator: False
#
# questioner: Is it related to industrial production or manufacturing?
# answerer: no
# guesser: Laptop
# evaluator: False
#
# questioner: Is it broadly related to entertainment or sports?
# answerer: yes
# guesser: Television
# evaluator: False
#
# questioner: Is it something a person can hold in their hand?
# answerer: no
# guesser: Football
# evaluator: False
#
# questioner: Is it something that is typically used outdoors?
# answerer: yes
# guesser: Frisbee
# evaluator: False
#
# questioner: Is it equipment or gear used in sports?
# answerer: yes
# guesser: Tennis racket
# evaluator: False
#
# questioner: Is it used in a team sport?
# answerer: no
# guesser: Golf club
# evaluator: False
#
# questioner: Is it used in an individual outdoor sport that involves speed or racing?
# answerer: no
# guesser: Fishing rod
# evaluator: False
#
# questioner: Is it used in an outdoor sport that involves hitting or striking an object?
# answerer: yes
# guesser: Bat
# evaluator: False
#
# questioner: Is it used in a sport that involves a ball?
# answerer: yes
# guesser: Golf ball
# evaluator: False
#
# questioner: Is it used in golf?
# answerer: no
# guesser: Tennis ball
# evaluator: False
#
# questioner: Is it used in tennis?
# answerer: yes
# guesser: Tennis court
# evaluator: False
#
# questioner: Is it a piece of sporting equipment that is primarily used to hit the ball?
# answerer: no
# guesser: Tennis ball
# evaluator: False
#
# questioner: Is it a net?
# answerer: yes
# guesser: Frisbee
# evaluator: False
#
# questioner: Is it part of a tennis court?
# answerer: yes
# guesser: Tennis net
# evaluator: True
# Generated keyword: Smart television
# USING MODEL: ft:gpt-4o-mini-2024-07-18:personal:20qs-tuned:9ujvexa0
# KEYWORD: Smart television
#
# questioner: Is it related to food, beverages or cooking?
# answerer: no
# guesser: chair
# evaluator: False
#
# questioner: Is it related to industrial production or manufacturing?
# answerer: no
# guesser: Car
# evaluator: False
#
# questioner: Is it broadly related to entertainment or sports?
# answerer: yes
# guesser: Television
# evaluator: False
#
# questioner: Is it something a person can hold in their hand?
# answerer: no
# guesser: Computer
# evaluator: False
#
# questioner: Is it related to a specific type of sport?
# answerer: no
# guesser: Amusement park
# evaluator: False
#
# questioner: Is it primarily used indoors?
# answerer: yes
# guesser: Board game
# evaluator: False
#
# questioner: Is it a form of digital entertainment?
# answerer: yes
# guesser: Video streaming service
# evaluator: False
#
# questioner: Is it a type of video game or gaming console?
# answerer: no
# guesser: Virtual reality headset
# evaluator: False
#
# questioner: Is it commonly viewed on a screen?
# answerer: yes
# guesser: Movie
# evaluator: False
#
# questioner: Is it related to streaming or broadcast media?
# answerer: yes
# guesser: YouTube
# evaluator: False
#
# questioner: Is it something that can be categorized as a television show or series?
# answerer: no
# guesser: Website
# evaluator: False
#
# questioner: Is it a type of online video content, such as a vlog or web series?
# answerer: no
# guesser: Streaming service
# evaluator: False
#
# questioner: Is it related to live streaming?
# answerer: yes
# guesser: Twitch
# evaluator: False
#
# questioner: Is it primarily associated with social media platforms?
# answerer: no
# guesser: Live broadcast
# evaluator: False
#
# questioner: Is it related to online gaming or esports events?
# answerer: no
# guesser: Live event
# evaluator: False
#
# questioner: Is it a type of live event, such as a concert or sports event, that can be streamed online?
# answerer: no
# guesser: Camera
# evaluator: False
#
# questioner: Is it a specific platform or service used for live streaming?
# answerer: no
# guesser: Live auction
# evaluator: False
#
# questioner: Is it something that can be interacted with in real-time during a live stream?
# answerer: no
# guesser: Live news report
# evaluator: False
#
# questioner: Is it a recorded piece of content that is made available for live streaming?
# answerer: no
# guesser: Webinar
# evaluator: False
#
# questioner: Is it related to live broadcasting, such as news or talk shows?
# answerer: no
# guesser: Live sports
# evaluator: False
#
# Generated keyword: Fabric loveseat
# USING MODEL: ft:gpt-4o-mini-2024-07-18:personal:20qs-tuned:9ujvexa0
# KEYWORD: Fabric loveseat
#
# questioner: Is it related to food, beverages or cooking?
# answerer: no
# guesser: Smartphone
# evaluator: False
#
# questioner: Is it related to industrial production or manufacturing?
# answerer: yes
# guesser: Car
# evaluator: False
#
# questioner: Is it related to safety or safety equipment?
# answerer: no
# guesser: Robot
# evaluator: False
#
# questioner: Is it related to electronics or technology?
# answerer: no
# guesser: Machine
# evaluator: False
#
# questioner: Is it a natural material or resource?
# answerer: no
# guesser: Factory
# evaluator: False
#
# questioner: Is it a tool or piece of equipment used in manufacturing?
# answerer: no
# guesser: Textile
# evaluator: False
#
# questioner: Is it a type of product produced through manufacturing?
# answerer: yes
# guesser: Furniture
# evaluator: False
#
# questioner: Is it commonly used in households?
# answerer: yes
# guesser: Appliance
# evaluator: False
#
# questioner: Is it related to cleaning or hygiene?
# answerer: no
# guesser: Light bulb
# evaluator: False
#
# questioner: Is it a piece of furniture?
# answerer: yes
# guesser: Chair
# evaluator: False
#
# questioner: Is it primarily used for seated activities?
# answerer: yes
# guesser: Table
# evaluator: False
#
# questioner: Is it commonly found in living rooms?
# answerer: yes
# guesser: Sofa
# evaluator: False
#
# questioner: Is it often used for relaxation or leisure?
# answerer: yes
# guesser: Recliner
# evaluator: False
#
# questioner: Is it typically upholstered?
# answerer: yes
# guesser: Armchair
# evaluator: False
#
# questioner: Is it a type of sofa or couch?
# answerer: yes
# guesser: Sectional sofa
# evaluator: False
#
# questioner: Is it a specific type of sofa or couch?
# answerer: yes
# guesser: Loveseat
# evaluator: False
#
# questioner: Is it a sectional sofa?
# answerer: no
# guesser: Chaise lounge
# evaluator: False
#
# questioner: Is it a recliner sofa?
# answerer: no
# guesser: Sofa bed
# evaluator: False
#
# questioner: Is it a sleeper sofa?
# answerer: no
# guesser: Couch
# evaluator: False
#
# questioner: Is it a loveseat?
# answerer: yes
# guesser: Loveseat
# evaluator: False
#
# Generated keyword: Mosaic lamp
# USING MODEL: ft:gpt-4o-mini-2024-07-18:personal:20qs-tuned:9ujvexa0
# KEYWORD: Mosaic lamp
#
# questioner: Is it related to food, beverages or cooking?
# answerer: no
# guesser: Computer
# evaluator: False
#
# questioner: Is it related to industrial production or manufacturing?
# answerer: no
# guesser: Bicycle
# evaluator: False
#
# questioner: Is it broadly related to entertainment or sports?
# answerer: no
# guesser: Television
# evaluator: False
#
# questioner: Is it related to clothing, accessories or beauty products?
# answerer: no
# guesser: Smartphone
# evaluator: False
#
# questioner: Is it an animal?
# answerer: no
# guesser: Tree
# evaluator: False
#
# questioner: Is it something a person can hold in their hand?
# answerer: yes
# guesser: Book
# evaluator: False
#
# questioner: Is it related to electronics or technology?
# answerer: no
# guesser: Pen
# evaluator: False
#
# questioner: Is it related to safety or safety equipment?
# answerer: no
# guesser: Toy
# evaluator: False
#
# questioner: Is it typically found in an office or school environment?
# answerer: no
# guesser: Lamp
# evaluator: False
#
# questioner: Is it something that is commonly used for or in a hobby?
# answerer: no
# guesser: Key
# evaluator: False
#
# questioner: Is it something one would typically find in a home?
# answerer: yes
# guesser: Candle
# evaluator: False
#
# questioner: Is it commonly found in the kitchen?
# answerer: no
# guesser: Chair
# evaluator: False
#
# questioner: Is it often found in the living room or family room?
# answerer: yes
# guesser: Remote control
# evaluator: False
#
# questioner: Is it something that is used for seating or furniture?
# answerer: no
# guesser: Photograph
# evaluator: False
#
# questioner: Is it used for decoration?
# answerer: yes
# guesser: Vase
# evaluator: False
#
# questioner: Is it typically hung on walls or ceilings?
# answerer: no
# guesser: Painting
# evaluator: False
#
# questioner: Is it something that is placed on a table or shelf?
# answerer: yes
# guesser: Statue
# evaluator: False
#
# questioner: Is it made primarily of glass or ceramic?
# answerer: yes
# guesser: Picture frame
# evaluator: False
#
# questioner: Is it used to hold or contain other items?
# answerer: no
# guesser: Crystal
# evaluator: False
#
# questioner: Is it a source of light or illumination?
# answerer: yes
# guesser: Lamp
# evaluator: False
#
# Generated keyword: Flat iron
# USING MODEL: ft:gpt-4o-mini-2024-07-18:personal:20qs-tuned:9ujvexa0
# KEYWORD: Flat iron
#
# questioner: Is it related to food, beverages or cooking?
# answerer: no
# guesser: Telephone
# evaluator: False
#
# questioner: Is it related to industrial production or manufacturing?
# answerer: no
# guesser: Bicycle
# evaluator: False
#
# questioner: Is it broadly related to entertainment or sports?
# answerer: no
# guesser: Book
# evaluator: False
#
# questioner: Is it related to clothing, accessories or beauty products?
# answerer: yes
# guesser: Watch
# evaluator: False
#
# questioner: Is it something you wear on your body?
# answerer: no
# guesser: Perfume
# evaluator: False
#
# questioner: Is it something you use on your body or face?
# answerer: yes
# guesser: Lotion
# evaluator: False
#
# questioner: Is it used for grooming or hygiene purposes?
# answerer: yes
# guesser: Toothbrush
# evaluator: False
#
# questioner: Is it used primarily in the bathroom?
# answerer: yes
# guesser: Shampoo
# evaluator: False
#
# questioner: Is it typically used daily?
# answerer: yes
# guesser: Soap
# evaluator: False
#
# questioner: Is it an electronic device?
# answerer: yes
# guesser: Electric toothbrush
# evaluator: False
#
# questioner: Is it used for cleaning or washing?
# answerer: no
# guesser: Hair dryer
# evaluator: False
#
# questioner: Is it used for personal grooming, such as hair styling or shaving?
# answerer: yes
# guesser: Razor
# evaluator: False
#
# questioner: Is it primarily used for hair grooming or styling?
# answerer: yes
# guesser: Hair straightener
# evaluator: True
# Generated keyword: Treehouse
# USING MODEL: ft:gpt-4o-mini-2024-07-18:personal:20qs-tuned:9ujvexa0
# KEYWORD: Treehouse
#
# questioner: Is it related to food, beverages or cooking?
# answerer: no
# guesser: Action figure
# evaluator: False
#
# questioner: Is it related to industrial production or manufacturing?
# answerer: no
# guesser: book
# evaluator: False
#
# questioner: Is it broadly related to entertainment or sports?
# answerer: yes
# guesser: Television
# evaluator: False
#
# questioner: Is it something a person can hold in their hand?
# answerer: no
# guesser: Theme Park
# evaluator: False
#
# questioner: Is it something that is primarily used indoors?
# answerer: no
# guesser: Stadium
# evaluator: False
#
# questioner: Is it associated with a specific sport?
# answerer: no
# guesser: Concert
# evaluator: False
#
# questioner: Is it something that involves physical activity or exercise?
# answerer: yes
# guesser: Playground
# evaluator: False
#
# questioner: Is it a specific type of outdoor game or activity?
# answerer: no
# guesser: Scuba diving
# evaluator: False
#
# questioner: Is it an organized competitive event?
# answerer: no
# guesser: Running track
# evaluator: False
#
# questioner: Is it equipment or gear used for outdoor physical activities?
# answerer: no
# guesser: Picnic
# evaluator: False
#
# questioner: Is it an activity that is typically performed alone rather than in a group?
# answerer: no
# guesser: Dance party
# evaluator: False
#
# questioner: Is it a type of recreational or leisure activity?
# answerer: yes
# guesser: Hiking
# evaluator: False
#
# questioner: Is it an activity that primarily requires the use of the body rather than specialized equipment?
# answerer: no
# guesser: Bicycle
# evaluator: False
#
# questioner: Is it a type of transportation used for recreation?
# answerer: no
# guesser: Swimming pool
# evaluator: False
#
# questioner: Is it something that people typically do in teams or pairs?
# answerer: no
# guesser: Exercise
# evaluator: False
#
# questioner: Is it associated with any specific skill or hobby?
# answerer: no
# guesser: Forest
# evaluator: False
#
# ...
#
# questioner: Is it a piece of machinery or equipment used in an industrial setting?
# answerer: no
# guesser: 3D printer
# evaluator: False
#
# questioner: Is it related to telecommunications or networking?
# answerer: no
# guesser: Solar panel
# evaluator: False
#
# questioner: Is it related to data storage or processing?
# answerer: no
# guesser: Smartwatch
# evaluator: False
#
# questioner: Is it a type of tool or instrument used in the electronics industry?
# answerer: no
# guesser: Electric vehicle
# evaluator: False
#
# questioner: Is it related to renewable energy or energy efficiency?
# answerer: no
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[93], line 18
#      16 for generated_keyword in tqdm(twice_removed_keywords_list, desc = 'games generated'):
#      17     print("Generated keyword:", generated_keyword)
# ---> 18     game_result = simulate_game(generated_keyword, MC_tree)
#      19     game_results.append(game_result)
#
# Cell In[85], line 52, in simulate_game(keyword, tree, print_game)
#      49 else:
#      50     decision_node = None
# ---> 52 guess = completion(model=MODEL, messages=construct_messages(game, "guesser", keyword, guesses, questions, answers)).choices[0].message.content
#      54 guesses.append(guess)
#      55 if print_game: print(f"guesser: {guess}")
#
# Cell In[74], line 2, in completion(model, messages)
#       1 def completion(model, messages):
# ----> 2     result = litellm.completion(model, messages)
#       3     if "claude" in model:
#       4         time.sleep(60/50) # Adjust based on rate limit (https://console.anthropic.com/settings/limits)
#
# File /opt/anaconda3/lib/python3.11/site-packages/litellm/utils.py:892, in client.<locals>.wrapper(*args, **kwargs)
#     890         print_verbose(f"Error while checking max token limit: {str(e)}")
#     891 # MODEL CALL
# --> 892 result = original_function(*args, **kwargs)
#     893 end_time = datetime.datetime.now()
#     894 if "stream" in kwargs and kwargs["stream"] == True:
#
# File /opt/anaconda3/lib/python3.11/site-packages/litellm/main.py:1337, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_tokens, presence_penalty, frequency_penalty, logit_bias, user, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, **kwargs)
#    1335 ## COMPLETION CALL
#    1336 try:
# -> 1337     response = openai_chat_completions.completion(
#    1338         model=model,
#    1339         messages=messages,
#    1340         headers=headers,
#    1341         model_response=model_response,
#    1342         print_verbose=print_verbose,
#    1343         api_key=api_key,
#    1344         api_base=api_base,
#    1345         acompletion=acompletion,
#    1346         logging_obj=logging,
#    1347         optional_params=optional_params,
#    1348         litellm_params=litellm_params,
#    1349         logger_fn=logger_fn,
#    1350         timeout=timeout,  # type: ignore
#    1351         custom_prompt_dict=custom_prompt_dict,
#    1352         client=client,  # pass AsyncOpenAI, OpenAI client
#    1353         organization=organization,
#    1354         custom_llm_provider=custom_llm_provider,
#    1355     )
#    1356 except Exception as e:
#    1357     ## LOGGING - log the original exception returned
#    1358     logging.post_call(
#    1359         input=messages,
#    1360         api_key=api_key,
#    1361         original_response=str(e),
#    1362         additional_args={"headers": headers},
#    1363     )
#
# File /opt/anaconda3/lib/python3.11/site-packages/litellm/llms/openai.py:948, in OpenAIChatCompletion.completion(self, model_response, timeout, optional_params, model, messages, print_verbose, api_key, api_base, acompletion, logging_obj, litellm_params, logger_fn, headers, custom_prompt_dict, client, organization, custom_llm_provider, drop_params)
#     935 ## LOGGING
#     936 logging_obj.pre_call(
#     937     input=messages,
#     938     api_key=openai_client.api_key,
#    (...)
#     944     },
#     945 )
#     947 headers, response = (
# --> 948     self.make_sync_openai_chat_completion_request(
#     949         openai_client=openai_client,
#     950         data=data,
#     951         timeout=timeout,
#     952     )
#     953 )
#     955 logging_obj.model_call_details["response_headers"] = headers
#     956 stringified_response = response.model_dump()
#
# File /opt/anaconda3/lib/python3.11/site-packages/litellm/llms/openai.py:808, in OpenAIChatCompletion.make_sync_openai_chat_completion_request(self, openai_client, data, timeout)
#     806         return headers, response
#     807     else:
# --> 808         response = openai_client.chat.completions.create(
#     809             **data, timeout=timeout
#     810         )
#     811         return None, response
#     812 except Exception as e:
#
# File /opt/anaconda3/lib/python3.11/site-packages/openai/_utils/_utils.py:277, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     275             msg = f"Missing required argument: {quote(missing[0])}"
#     276     raise TypeError(msg)
# --> 277 return func(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/openai/resources/chat/completions.py:646, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, parallel_tool_calls, presence_penalty, response_format, seed, service_tier, stop, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     612 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     613 def create(
#     614     self,
#    (...)
#     644     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     645 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
# --> 646     return self._post(
#     647         "/chat/completions",
#     648         body=maybe_transform(
#     649             {
#     650                 "messages": messages,
#     651                 "model": model,
#     652                 "frequency_penalty": frequency_penalty,
#     653                 "function_call": function_call,
#     654                 "functions": functions,
#     655                 "logit_bias": logit_bias,
#     656                 "logprobs": logprobs,
#     657                 "max_tokens": max_tokens,
#     658                 "n": n,
#     659                 "parallel_tool_calls": parallel_tool_calls,
#     660                 "presence_penalty": presence_penalty,
#     661                 "response_format": response_format,
#     662                 "seed": seed,
#     663                 "service_tier": service_tier,
#     664                 "stop": stop,
#     665                 "stream": stream,
#     666                 "stream_options": stream_options,
#     667                 "temperature": temperature,
#     668                 "tool_choice": tool_choice,
#     669                 "tools": tools,
#     670                 "top_logprobs": top_logprobs,
#     671                 "top_p": top_p,
#     672                 "user": user,
#     673             },
#     674             completion_create_params.CompletionCreateParams,
#     675         ),
#     676         options=make_request_options(
#     677             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     678         ),
#     679         cast_to=ChatCompletion,
#     680         stream=stream or False,
#     681         stream_cls=Stream[ChatCompletionChunk],
#     682     )
#
# File /opt/anaconda3/lib/python3.11/site-packages/openai/_base_client.py:1266, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1252 def post(
#    1253     self,
#    1254     path: str,
#    (...)
#    1261     stream_cls: type[_StreamT] | None = None,
#    1262 ) -> ResponseT | _StreamT:
#    1263     opts = FinalRequestOptions.construct(
#    1264         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1265     )
# -> 1266     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /opt/anaconda3/lib/python3.11/site-packages/openai/_base_client.py:942, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     933 def request(
#     934     self,
#     935     cast_to: Type[ResponseT],
#    (...)
#     940     stream_cls: type[_StreamT] | None = None,
#     941 ) -> ResponseT | _StreamT:
# --> 942     return self._request(
#     943         cast_to=cast_to,
#     944         options=options,
#     945         stream=stream,
#     946         stream_cls=stream_cls,
#     947         remaining_retries=remaining_retries,
#     948     )
#
# File /opt/anaconda3/lib/python3.11/site-packages/openai/_base_client.py:978, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     975 log.debug("Sending HTTP Request: %s %s", request.method, request.url)
#     977 try:
# --> 978     response = self._client.send(
#     979         request,
#     980         stream=stream or self._should_stream_response_body(request=request),
#     981         **kwargs,
#     982     )
#     983 except httpx.TimeoutException as err:
#     984     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     906 follow_redirects = (
#     907     self.follow_redirects
#     908     if isinstance(follow_redirects, UseClientDefault)
#     909     else follow_redirects
#     910 )
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpx/_client.py:1015, in Client._send_single_request(self, request)
#    1010     raise RuntimeError(
#    1011         "Attempted to send an async request with a sync Client instance."
#    1012     )
#    1014 with request_context(request=request):
# -> 1015     response = transport.handle_request(request)
#    1017 assert isinstance(response.stream, SyncByteStream)
#    1019 response.request = request
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpx/_transports/default.py:233, in HTTPTransport.handle_request(self, request)
#     220 req = httpcore.Request(
#     221     method=request.method,
#     222     url=httpcore.URL(
#    (...)
#     230     extensions=request.extensions,
#     231 )
#     232 with map_httpcore_exceptions():
# --> 233     resp = self._pool.handle_request(req)
#     235 assert isinstance(resp.stream, typing.Iterable)
#     237 return Response(
#     238     status_code=resp.status,
#     239     headers=resp.headers,
#     240     stream=ResponseStream(resp.stream),
#     241     extensions=resp.extensions,
#     242 )
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     213         closing = self._assign_requests_to_connections()
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
#     219 # the point at which the response is closed.
#     220 assert isinstance(response.stream, Iterable)
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:196, in ConnectionPool.handle_request(self, request)
#     192 connection = pool_request.wait_for_connection(timeout=timeout)
#     194 try:
#     195     # Send the request on the assigned connection.
# --> 196     response = connection.handle_request(
#     197         pool_request.request
#     198     )
#     199 except ConnectionNotAvailable:
#     200     # In some cases a connection may initially be available to
#     201     # handle a request, but then become unavailable.
#     202     #
#     203     # In this case we clear the connection and try again.
#     204     pool_request.clear_connection()
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpcore/_sync/connection.py:101, in HTTPConnection.handle_request(self, request)
#      98     self._connect_failed = True
#      99     raise exc
# --> 101 return self._connection.handle_request(request)
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpcore/_sync/http11.py:143, in HTTP11Connection.handle_request(self, request)
#     141     with Trace("response_closed", logger, request) as trace:
#     142         self._response_closed()
# --> 143 raise exc
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpcore/_sync/http11.py:113, in HTTP11Connection.handle_request(self, request)
#     102     pass
#     104 with Trace(
#     105     "receive_response_headers", logger, request, kwargs
#     106 ) as trace:
#     107     (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112         trailing_data,
# --> 113     ) = self._receive_response_headers(**kwargs)
#     114     trace.return_value = (
#     115         http_version,
#     116         status,
#     117         reason_phrase,
#     118         headers,
#     119     )
#     121 network_stream = self._network_stream
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpcore/_sync/http11.py:186, in HTTP11Connection._receive_response_headers(self, request)
#     183 timeout = timeouts.get("read", None)
#     185 while True:
# --> 186     event = self._receive_event(timeout=timeout)
#     187     if isinstance(event, h11.Response):
#     188         break
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpcore/_sync/http11.py:224, in HTTP11Connection._receive_event(self, timeout)
#     221     event = self._h11_state.next_event()
#     223 if event is h11.NEED_DATA:
# --> 224     data = self._network_stream.read(
#     225         self.READ_NUM_BYTES, timeout=timeout
#     226     )
#     228     # If we feed this case through h11 we'll raise an exception like:
#     229     #
#     230     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     234     # perspective. Instead we handle this case distinctly and treat
#     235     # it as a ConnectError.
#     236     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpcore/_backends/sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
# --> 126     return self._sock.recv(max_bytes)
#
# File /opt/anaconda3/lib/python3.11/ssl.py:1296, in SSLSocket.recv(self, buflen, flags)
#    1292     if flags != 0:
#    1293         raise ValueError(
#    1294             "non-zero flags not allowed in calls to recv() on %s" %
#    1295             self.__class__)
# -> 1296     return self.read(buflen)
#    1297 else:
#    1298     return super().recv(buflen, flags)
#
# File /opt/anaconda3/lib/python3.11/ssl.py:1169, in SSLSocket.read(self, len, buffer)
#    1167         return self._sslobj.read(len, buffer)
#    1168     else:
# -> 1169         return self._sslobj.read(len)
#    1170 except SSLError as x:
#    1171     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
new_games_won_words = [game for game in game_results if game['win'] == True]
print(len(new_games_won_words))
# Out:
# 155

# %%
print(keyword_things)
# Out:
# ['acacia', 'accent chair', 'acorn', 'adhd medication', 'adjustable bench', 'Advertisement', 'aerator', 'Agave', 'agave plant', 'Air compressor', 'Air Conditioner', 'Air filter', 'air handler', 'air plant', 'air tank', 'Air vent', 'airport lighting', 'Alarm system', 'alfalfa', 'almond milk', 'aluminum foil', 'amazon echo', 'analog stick', 'Analogy', 'anchovy', 'Anemone', 'Anesthesia', 'angelfish', 'ankle bracelet', 'antidepressant', 'antiseptic wipe', 'aperol spritz', 'apple', 'Apple pie', 'applesauce', 'apricot tree', 'Aprons', 'aquarium salt', 'archery target', 'arrival board', 'aspirin', 'Atmosphere', 'attic ladder', 'audio guide', 'autograph', 'automatic door', 'backgammon board', 'Backrest', 'bacon', 'Bacteria', 'baggage conveyor', 'Baguette', 'balance beam', 'bald eagle', 'ballpoint pen', 'bamboo', 'bamboo leaf', 'banana', 'bandana', 'bank statement', 'bar towel', 'barbell collar', 'Barber Chair', 'barcode', 'Bat', 'Bath Mat', 'battery', 'battery bank', 'beach chair', 'beach umbrella', 'bean', 'bean plant', 'Beanbag', 'bear', 'Bed frame', 'bedspread', 'beech tree', 'beer coaster', 'beer glass', 'beer stein', 'beer tap', 'Bike', 'binder clip', 'Binoculars', 'bird netting', 'Bird seed', 'Blinds', 'boa constrictor', 'Board Games', 'Bobby Pins', 'Bollards', 'Bonding Agent', 'bonsai tree', 'book cover', 'bookbag', 'Bookcase', 'bookend', 'Bookends', 'Bottled Water', 'bowl', 'bracelet', 'Bread knife', 'bread maker', 'Bread pudding', 'Brewery merchandise', 'Briefcase', 'Brochure', 'brochure stand', 'broken glass', 'broth', 'Brownies', 'brush', 'brussel sprout', 'buckle', 'Bug spray', 'Bulb', 'bulletin', 'bumble bee', 'bumper', 'Bumper sticker', 'bunk bed', 'Bunsen burner', 'butter', 'butter knife', 'butterfly', 'butterfly net', 'button', 'cable tie', 'cable tray', 'cactus flower', 'cake', 'calcite', 'calculator', 'camp stove', 'candle holder', 'candy wrapper', 'cane', 'canning jar', 'cannoli', 'Cantaloupe', 'car antenna', 'car engine', 'car seat', 'carbon', 'Card', 'cardboard', 'Cardboard box', 'cardboard tube', 'caribou', 'carnation', 'Cash Register', 'casket', 'Cat carrier', 'catalytic converter', 'catheter', 'Cauliflower', 'cedar', 'Ceiling fan', 'centerpiece', 'centipede', 'Cereal', 'cereal bar', 'chair cushion', 'Champagne flute', 'Chandelier', 'charger', 'charging cord', 'Cheesecake', 'cherry tree', 'Chessboard', 'Chew toy', 'chicken wire', 'chiller', 'chime', 'chimney', 'chimpanzee', 'chocolate bar', 'Chocolate cake', 'cholla cactus', 'christmas tree', 'chutney', 'cilantro', 'cinder block', 'Cinnamon roll', 'clay', 'climber', 'climbing rope', 'clip', 'clock', 'clog', 'clothes rack', 'clutch bag', 'coal crusher', 'Coat Rack', 'cobblestone', 'cobweb', 'cockroach', 'cocktail glass', 'coconut', 'coffee bag', 'Coffee beans', 'Coffee Grinder', 'coffee ground', 'Coffee grounds', 'coffee machine', 'Coffee Makers', 'coffee mug', 'coffee table', 'coffin', 'coke', 'colander', 'cold pack', 'Comic Book', 'common milkweed', 'compactor', 'compass', 'compost', 'concentrator', 'concrete block', 'concrete wall', 'condenser', 'conditioner', 'conference table', 'Contact lenses', 'Conveyor belt', 'cooler', 'Cooling Tower', 'cordless phone', 'corkscrew', 'cotton', 'cotton candy', 'cowboy boot', 'crayfish', 'Cream cheese', 'crochet hook', 'Croissant', 'cruise ship', 'crutch', 'cuff', 'culture medium', 'cupcake', 'curler', 'curling', 'curling iron', 'Curtains', 'cuticle', 'Cutlery', 'cutter', 'Cutting Board', 'cypress knee', 'daisy', 'damselfish', 'Dandelion', 'dashboard camera', 'dead leaf', 'decal', 'Deciduous tree', 'denim', 'denim jeans', 'dental chair', 'deposit slip', 'Desk Chairs', 'desk lamp', 'desktop computer', 'Diaper', 'diary', 'dill pickle', 'dining chair', 'dinosaur skeleton', 'Dish soap', 'dishcloth', 'dishtowel', 'dishwasher', 'Disinfectant', 'Diving board', 'dj mixer', 'dj turntable', 'docket', 'dog poop', 'Dog shampoo', 'dog tag', 'dogwood', 'dolphin', 'domino', 'Donuts', 'door', 'doughnut', 'Drain Hose', 'drainage pipe', 'drape ...

# %%
keywords_left = [keyword for keyword in keyword_things if (keyword not in dict_keywords) and (keyword not in current_keywords_with_games)]
similar_keywords_left = [keyword for keyword in similar_keywords_list if (keyword not in dict_keywords) and (keyword not in current_keywords_with_games)]

print(f"Keywords left: {len(keywords_left)}\n")
print(f"Similar Keywords left: {len(similar_keywords_left)}\n")

generated_keywords = random.choices(keywords_left, k=100)
generated_similar_keywords = random.choices(similar_keywords_left, k=100)
generated_keywords_combined = list(set(generated_keywords + generated_similar_keywords))
# Out:
# Keywords left: 1006
#
# Similar Keywords left: 925

# %%
print(generated_keywords_combined)
# Out:
# ['projector', 'Yoga Blocks', 'Rearview mirror', 'bamboo', 'Hibiscus', 'hay bale', 'Hedgehog', 'bee', 'mulch', 'Necklace', 'Sparkling water', 'turmeric', 'Toothbrush', 'water tank', 'Device', 'snowmobile', 'Cedar', 'Bluetooth headphones', 'Leather notebook', 'footbridge', 'Disinfectant wipes', 'ignition system', 'Vending Machine', 'maidenhair fern', 'Ray-Ban sunglasses', 'Plastic Gloves', 'Carrot cake', 'grape', 'humus', 'guppy', 'Circuit breaker', 'Moscow Mule', 'Vinaigrette', 'Champagne flutes', 'sword fern', 'rocking chair', 'serving bowl', 'tire gauge', 'Power drill', 'spare bulb', 'Drains and culverts', 'Glass Table', 'Brick fence', 'humidity meter', 'Clothes hamper', 'air tank', 'Dumbbell', 'phone case', 'Fuse', 'Toaster', 'Polyester', 'Cat trees', 'velvet ribbon', 'lace', 'Handrail', 'GPS device', 'Epoxy', 'Lawn chair', 'northern mockingbird', 'takeout container', 'mountaineer', 'Plastic fork', 'Apple tart', 'peeler', 'Bicycle', 'armoire', 'chimney', 'Headlamp', 'Vacuum sealer', 'Noise-cancelling headphones', 'Bobby Pins', 'dumbbell', 'Watercolor pad', 'Bowl', 'Scrap metal', 'Fortune cookie', 'mic stand', 'cotton', 'Silver ore', 'Seatbelt', 'Yacht', 'suture', 'power adapter', 'Juice', 'Eyeglasses', 'Digital Camcorder', 'gummy bears', 'Seesaw', 'Cordless drill', 'Pineapple', 'rope winch', 'Scoreboard', 'LED light', 'binder clip', 'internet modem', 'knapweed', 'jane', 'Garden fencing', 'Rooftop Ladder', 'test strip', 'Sleeping bag', 'Earbuds', 'Wire rack', 'Carrots', 'Earl Grey tea', 'Public Address System', 'Silicone mold', 'hamburger helper', 'Lottery Ticket', 'Portable speaker', 'Pumpkin pie', 'fabric roll', 'Scooter', 'Guitar bag', 'electric motorcycle', 'wrapping paper', 'Icicle', 'bank statement', 'loose change', 'Cooling Tower', 'Rush', 'Electric razor', 'Pajamas', 'Kale smoothie', 'Cereal', 'headband', 'medical cart', 'ventilation fan', 'internet router', 'Smith machine', 'paper roll', 'teddy bear', 'Paintbrush', 'Sewing Kit', 'hair tie', 'Key chain', 'Flatbed truck', 'plastic baggie', 'mangrove seedling', 'hazelnut tree', 'mri machine', 'Bathroom scale', 'coffin', 'Extension cord', 'Notebook', 'fence gate', 'Mars rover', 'Towel', 'Soundproofing', 'Mouse', 'Pine tree', 'Plectrum', 'relief valve', 'Thermal Flask', 'kimchi', 'concentrator', 'crayfish', 'Cable', 'Vodka', 'dresser', 'armchair', 'Carpet Runners', 'Dog shampoo', 'Keyboard', 'skewer', 'Chainsaw', 'Dandelion', 'Tempeh', 'Succulent', 'Recliner', 'Loft bed', 'Sump Pump', 'Flowerpot', 'Ceiling Fan', 'conduit system', 'Silicone', 'Smoothie', 'bulletin', 'laundry basket', 'Calendula', 'gear shift', 'Playing cards', 'Ticket stub']

# %% [markdown]
# ## Save as JSONL

# %%
with open("20qs-data/final_games/gpt-4o-mini-twice-removed-games.jsonl", "w") as f:
    for i in new_games_won_words:
        json.dump(i, f)
        f.write('\n')

# %%
new_games_won = [game for game in game_results if game['win'] == True]

with open("20qs-data/final_games/gpt-4o-mini-games-won.jsonl", "w") as f:
    for i in new_games_won:
        json.dump(i, f)
        f.write('\n')

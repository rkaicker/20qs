# %%
import litellm
import time
import sys, os

if not os.environ["OPENAI_API_KEY"]: 
    os.environ["OPENAI_API_KEY"]= '<REDACTED>'

# %%
#MODEL = "ft:gpt-4o-mini-2024-07-18:personal:20qs-ft-1:9tKOfrv9"
MODEL = "gpt-4o-mini"
#EVALUATOR_MODEL="gpt-4o-mini"
# MODEL = "gpt-4o"
#MODEL = "claude-3-5-sonnet-20240620"
litellm.modify_params = True

# %%
def completion(model, messages):
    result = litellm.completion(model, messages)
    if "claude" in model:
        time.sleep(60/50) # Adjust based on rate limit (https://console.anthropic.com/settings/limits)
    return result

# %%
class DecisionNode:
    def __init__(self, query = None, yes_branch=None, no_branch=None):
        self.query = query
        self.yes_branch = yes_branch
        self.no_branch = no_branch
        
    def print_tree(self, level=0, prefix=""):
        if self.query:
            print(f"{prefix}-- {self.query}")
            if self.yes_branch:
                self.yes_branch.print_tree(level + 1, prefix + "  |")
            if self.no_branch:
                self.no_branch.print_tree(level + 1, prefix + "   ")
        else:
            print(f"{prefix}-- *")
            
    def write_tree_to_file(self, filename):
        with open(filename, 'w') as f:
            self._write_tree(f)

    def _write_tree(self, file, level=0, prefix=""):
        if self.query:
            file.write(f"{prefix}-- {self.query}\n")
            if self.yes_branch:
                self.yes_branch._write_tree(file, level + 1, prefix + "  |")
            if self.no_branch:
                self.no_branch._write_tree(file, level + 1, prefix + "   ")
        else:
            file.write(f"{prefix}-- *\n")

    @staticmethod
    def read_tree_from_file(filename):
        with open(filename, 'r') as f:
            lines = f.readlines()
        return DecisionNode._read_tree(lines, 0, "")

    @staticmethod
    def _read_tree(lines, indent_level, current_prefix):
        if not lines:
            return None

        line = lines.pop(0).rstrip()
        expected_prefix = current_prefix + "-- "

        if not line.startswith(expected_prefix):
            return None

        content = line[len(expected_prefix):]
        if content == "*":
            return DecisionNode()

        yes_branch = DecisionNode._read_tree(lines, indent_level + 1, current_prefix + "  |")
        no_branch = DecisionNode._read_tree(lines, indent_level + 1, current_prefix + "   ")

        return DecisionNode(content, yes_branch, no_branch)

# %% [markdown]
# 1. Start with a list of 2000 or so example keywords
# 2. Have the questioner agent generate 5 yes / no questions that will attempt to bisect the remaining keywords in the list
# 3. For each question, have another agent go through each remaining keyword in the list and eliminate possible keywords based on if the answer to the question was "yes"
# 4. Determine which question eliminated closest to 50% of the remaining questions (i.e. not too specific and not too broad of a question).
# 5. For that chosen question, generate 5 new questions each for the "no" path and the "yes" path (i.e. recursively repeat this for each branch)

# %%
import json
with open("20qs-data/keywords_data/labeled_keywords_v2.jsonl", "r") as f:
    lines = f.read().split('\n')
objects = []
for line in lines:
    try:
        objects.append(json.loads(line))
    except:
        pass
all_keywords = [i["keyword"] for i in objects if i["place"] == "no"]

# %%
def generate_questions(questions, answers, remaining_keywords, num_questions=5):
    prompt = {
        "role": "system",
        "content": (
            "You are an data scientist who has dedicated his life's research to a scientific approach to the game 20 Questions."
            f"Given previous questions and answers, as well the remaining possible keywords, generate the {num_questions} best follow-up yes-or-no questions that attempt to reduce the remaining number of possible keywords by half."
            "The keyword is a specific thing, NOT a place and NOT a person."
            "Each question should be independent of the others."
            "Questions should be as vague and general as possible to attempt to eliminate 50% of possible keywords given the previous questions and answers. This is extremely important."
            "Output questions only, no other text. Each question should be numbered in markdown with no other formatting."
        ),
    }

    previous_q_and_a = ""
    for i in range(len(questions)):
        previous_q_and_a += f"{i+1}. Question: {questions[i]}  Answer: {answers[i]}\n"
    
    q_and_a = {
        "role": "user",
        "content": '\n'.join([f"Previous questions and answers: {previous_q_and_a}\n\nRemaining keywords: {remaining_keywords}" for i in range(len(questions))]),
    }

    print(previous_q_and_a)
    
    messages = [prompt, q_and_a]
    
    response = completion("gpt-4o", messages).choices[0].message.content
    
    return [i[3:].strip() for i in response.split('\n')]

generate_questions(["Is it related to cooking, food, or beverages?", "Is it commonly found in a kitchen?"], ["Yes", "Yes"], ["soda", "hamburger", "blender", "stove"], 5)
# Out:
# 1. Question: Is it related to cooking, food, or beverages?  Answer: Yes2. Question: Is it commonly found in a kitchen?  Answer: Yes
# ['Is it an appliance?',
#  'Is it a type of food?',
#  'Is it typically found inside a refrigerator?',
#  'Does it require preparation before consumption?',
#  'Does it use electricity to function?']

# %%
def rephrase_as_fact(question, answer):
    prompt = {
        "role": "system",
        "content": (
            "Given a question and answer pair, rephrase it as a single fact."
            "Example input:\nQuestion: Is it smaller than a breadbox?\nAnswer: No"
            "Example output: It is larger than a breadbox."
        ),
    }
    
    q_and_a = {
        "role": "user",
        "content": f"Question: {question}\nAnswer: {answer}",
    }
    
    messages = [prompt, q_and_a]
    
    response = completion(MODEL, messages).choices[0].message.content

    return response

rephrase_as_fact("Is it related to food, beverages or cooking?", "No")
# Out:
# 'It is not related to food, beverages, or cooking.'

# %%
def evaluate_keyword(fact, keyword):
    prompt = {
        "role": "system",
        "content": (
            "Given a fact, state whether or not the fact is true about a given keyword."
            "Reply only with the text 'True' or 'False'."
            # "If the keyword does not really fit with most people's definition of the question, reply with 'False'."
            # "If the keyword does fit with most people's definition of the question, reply with 'True'."
            # "Example input 1:\nFact: It is larger than a breadbox\nKeyword: spoon"
            # "Example output 1: False"
            # "Example input 2:\nFact: It is a common household item\nKeyword: bed"
            # "Example output 2: True"
            # "Example input 3:\nFact: It is related to food, beverages or cooking.\nKeyword: recipe"
            # "Example output 3: True"
            # "Example input 4 (keyword doesn't really fit):\nFact: It is related to food, beverages or cooking.\nKeyword: carbon"
            # "Example output 4: False"
        ),
    }
    
    q_and_a = {
        "role": "user",
        "content": f"Keyword: {keyword}\nFact: {fact}",
    }
    
    messages = [prompt, q_and_a]
    
    response = completion("gpt-4o-mini", messages).choices[0].message.content

    return "t" in response.lower()

evaluate_keyword("It is larger than a microwave.", "DVD.")
# Out:
# False

# %%
import math
import random

def most_common(lst):
    return max(set(lst), key=lst.count)

def test_keyword_percentage_eliminated(question, keywords, keyword_test_percentage=0.25):
    fact = rephrase_as_fact(question, "Yes")
    count = 0
    num_test_keywords = max(min(50, len(keywords)), math.floor(len(keywords) * keyword_test_percentage))
    keyword_test_set = random.sample(keywords, k=len(keywords))[:num_test_keywords]
    print(f"Num keywords in test set: {len(keyword_test_set)}")
    remaining_keywords_yes = []
    remaining_keywords_no = []
    for x, keyword in enumerate(keyword_test_set):
        #evaluations = [evaluate_keyword(fact, keyword) for _ in range(3)]
        #result = most_common(evaluations)
        #print(f"{x+1}) Keyword: {keyword}. Results: {evaluations} -> {result}")
        result = evaluate_keyword(fact, keyword)
        print(f"{x+1}) Keyword: {keyword}. Result: {result}")
        if result: 
            count += 1
            remaining_keywords_yes.append(keyword)
        else:
            remaining_keywords_no.append(keyword)
    return count / len(keyword_test_set), remaining_keywords_yes, remaining_keywords_no

# %%
test_keyword_percentage_eliminated("Is it be found indoors?", all_keywords, 0.01)
# Out:
# Num keywords in test set: 50
# 1) Keyword: nose. Result: True
# 2) Keyword: Public Address System. Result: True
# 3) Keyword: flashlight. Result: True
# 4) Keyword: sock. Result: True
# 5) Keyword: parts cleaner. Result: True
# 6) Keyword: Power strip. Result: True
# 7) Keyword: Chew toy. Result: True
# 8) Keyword: aspirin. Result: True
# 9) Keyword: Coffee beans. Result: True
# 10) Keyword: Cereal. Result: True
# 11) Keyword: butter knife. Result: True
# 12) Keyword: mango. Result: False
# 13) Keyword: velvet couch. Result: True
# 14) Keyword: electric motorcycle. Result: False
# 15) Keyword: seagull. Result: False
# 16) Keyword: sewing needle. Result: True
# 17) Keyword: steering wheel. Result: False
# 18) Keyword: wireless microphone. Result: True
# 19) Keyword: curling. Result: False
# 20) Keyword: unripe fruit. Result: False
# 21) Keyword: Yoga mat. Result: True
# 22) Keyword: Wheelchair ramp. Result: False
# 23) Keyword: whiteboard. Result: True
# 24) Keyword: cotton candy. Result: True
# 25) Keyword: rainbow cake. Result: True
# 26) Keyword: igloo. Result: False
# 27) Keyword: metal file. Result: True
# 28) Keyword: excavator. Result: False
# 29) Keyword: Soybeans. Result: False
# 30) Keyword: French toast. Result: True
# 31) Keyword: humidity meter. Result: True
# 32) Keyword: Wall Art. Result: True
# 33) Keyword: wonton. Result: True
# 34) Keyword: RV. Result: False
# 35) Keyword: tape measure. Result: True
# 36) Keyword: Ceiling fan. Result: True
# 37) Keyword: Backrest. Result: True
# 38) Keyword: cereal bar. Result: True
# 39) Keyword: Sunscreen. Result: False
# 40) Keyword: keyring. Result: True
# 41) Keyword: gown. Result: True
# 42) Keyword: autograph. Result: True
# 43) Keyword: safety glasses. Result: True
# 44) Keyword: camp stove. Result: True
# 45) Keyword: yeast. Result: True
# 46) Keyword: roadrunner. Result: False
# 47) Keyword: mri machine. Result: True
# 48) Keyword: concentrator. Result: True
# 49) Keyword: Salad Dressing. Result: True
# 50) Keyword: Onyx. Result: True
# (0.74,
#  ['nose',
#   'Public Address System',
#   'flashlight',
#   'sock',
#   'parts cleaner',
#   'Power strip',
#   'Chew toy',
#   'aspirin',
#   'Coffee beans',
#   'Cereal',
#   'butter knife',
#   'velvet couch',
#   'sewing needle',
#   'wireless microphone',
#   'Yoga mat',
#   'whiteboard',
#   'cotton candy',
#   'rainbow cake',
#   'metal file',
#   'French toast',
#   'humidity meter',
#   'Wall Art',
#   'wonton',
#   'tape measure',
#   'Ceiling fan',
#   'Backrest',
#   'cereal bar',
#   'keyring',
#   'gown',
#   'autograph',
#   'safety glasses',
#   'camp stove',
#   'yeast',
#   'mri machine',
#   'concentrator',
#   'Salad Dressing',
#   'Onyx'],
#  ['mango',
#   'electric motorcycle',
#   'seagull',
#   'steering wheel',
#   'curling',
#   'unripe fruit',
#   'Wheelchair ramp',
#   'igloo',
#   'excavator',
#   'Soybeans',
#   'RV',
#   'Sunscreen',
#   'roadrunner'])

# %%
def build_node(current_depth, remaining_keywords, questions, answers, max_depth=5, num_test_questions=5, keyword_test_percentage=0.25):
    possible_questions = generate_questions(questions, answers, remaining_keywords=remaining_keywords, num_questions=num_test_questions)

    best_question = None
    best_remaining_keywords_yes = []
    best_remaining_keywords_no = []
    best_question_score = 1 #lower is better
    for q in possible_questions:
        print(f"Question: {q}")
        percentage, new_remaining_keywords_yes, new_remaining_keywords_no = test_keyword_percentage_eliminated(q, remaining_keywords, keyword_test_percentage)
        score = abs(0.5 - percentage)
        print(f"Percentage: {percentage}%\tScore: {score}\n")
        if score < best_question_score:
            best_question_score = score
            best_question = q
            best_remaining_keywords_yes = new_remaining_keywords_yes
            best_remaining_keywords_no = new_remaining_keywords_no
            if score < 0.15:
                break

    if current_depth == max_depth or best_question_score == 0.5:
        return DecisionNode(query=best_question)

    else:
        print(f"_______\nDepth {current_depth} -- Starting Yes branch for question: {best_question}")
        print(f"Remaining keywords yes: {best_remaining_keywords_yes}")
        yes_node = build_node(current_depth + 1, best_remaining_keywords_yes, questions + [best_question], answers + ["Yes"], max_depth, num_test_questions, keyword_test_percentage)
        
        print(f"_______\nDepth {current_depth} -- Starting No branch for question: {best_question}")
        print(f"Remaining keywords no: {best_remaining_keywords_no}")
        no_node = build_node(current_depth + 1, best_remaining_keywords_no, questions + [best_question], answers + ["No"], max_depth, num_test_questions, keyword_test_percentage)
        
        return DecisionNode(query=best_question, no_branch=no_node, yes_branch=yes_node)

# %%
def build_tree(starting_question, keywords, initial_starting_keywords_yes=None, initial_starting_keywords_no=None, max_depth=5, num_test_questions=5, keyword_test_percentage=0.25):
    if initial_starting_keywords_yes and initial_starting_keywords_no:
        print("Using provided initial starting keywords")
        starting_keywords_yes = initial_starting_keywords_yes
        starting_keywords_no = initial_starting_keywords_no
    else:    
        print(f"Determining keyword split for starting question: {starting_question}")
        starting_percentage_split, starting_keywords_yes, starting_keywords_no = test_keyword_percentage_eliminated(starting_question, keywords, keyword_test_percentage=1)
        print(f"Starting percentage split: {starting_percentage_split}")
    
    print(f"Starting Yes branch for question {starting_question}")
    print(f"Remaining keywords yes: {starting_keywords_yes}")
    yes_node = build_node(1, starting_keywords_yes, [starting_question], ["Yes"], max_depth, num_test_questions, keyword_test_percentage)

    print(f"Starting No branch for question {starting_question}")
    print(f"Remaining keywords no: {starting_keywords_no}")
    no_node = build_node(1, starting_keywords_no, [starting_question], ["No"], max_depth, num_test_questions, keyword_test_percentage)
    
    return DecisionNode(query=starting_question, no_branch=no_node, yes_branch=yes_node)

# %% [markdown]
# ### Save these keywords for the starting question to save time since these won't change

# %%
culinary_starting_keywords_yes = ['pot holder', 'saltwater', 'thermometer probe', 'aperol spritz', 'banana', 'chutney', 'squid', 'pumpkin', 'unripe banana', 'nitrogen', 'measuring spoon', 'tea cup', 'hazelnut tree', 'cutter', 'Edible flowers', 'chiller', 'Garbage Disposal', 'Wine Opener', 'aerator', 'apple', 'raisin', 'fish scale', 'tongue', 'corkscrew', 'empty can', 'skewer', 'dining chair', 'pomegranate', 'beer coaster', 'colander', 'ice tray', 'bean', 'beer stein', 'electric oven', 'granola', 'Honeybee', 'agave plant', 'Udon Noodles', 'cocktail glass', 'yogurt container', 'unripe fruit', 'Green beans', 'crayfish', 'bread maker', 'beer glass', 'Snacks', 'bacon', 'lid', 'Bread knife', 'compost', 'butter knife', 'Popcorn', 'hot tea', 'Agave', 'Wire rack', 'Heating Element', 'Measuring cup', 'grape', 'Rice pudding', 'water jug', 'strainer', 'Cinnamon roll', 'grape juice', 'Scones', 'cake', 'protein shake', 'dishwasher', 'serving platter', 'cherry tree', 'bamboo', 'Nachos', 'tin foil', 'green alga', 'rooster', 'seltzer', 'Water Bottle', 'vegan chocolate', 'rhubarb', 'Coffee Grinder', 'Chocolate cake', 'ginger ale', 'Spatula', 'peeler', 'lemon juice', 'wonton', 'acacia', 'Potato', 'ramen', 'sushi', 'Grapefruit', 'gin', 'Plastic Gloves', 'spray', 'Red wine', 'water dish', 'rice krispie', 'wing', 'Bird seed', 'peanut butter', 'Croissant', 'almond milk', 'candy wrapper', 'seagrass', 'mango', 'cupcake', 'swedish fish', 'lemon balm', 'Tofu', 'vegetarian chili', 'tea leaf', 'bean plant', 'Protein bar', 'kitchen knife', 'pudding', 'flour', 'Coffee Makers', 'Bacteria', 'grill', 'ice crusher', 'nitrous', 'juniper tree', 'Brownies', 'Radish', 'Silicone', 'Fried rice', 'ice pop', 'barcode', 'vietnamese coffee', 'Roots', 'Sippy cup', 'Dandelion', 'goose', 'metal spoon', 'oatmeal cookie', 'soup', 'Pesticide', 'Water Buffalo', 'Hot dog', 'whisk', 'hamburger helper', 'ice tea', 'Olive Oil', 'lime', 'rosemary', 'brussel sprout', 'canning jar', 'Fortune cookie', 'metal foil', 'Soybeans', 'orange juice', 'metal lid', 'Orange tree', 'Donuts', 'broth', 'pear tree', 'ricotta', 'fudge brownie', 'Oven rack', 'rainbow cake', 'Latte', 'steak knife', 'syrup', 'doughnut', 'Oven door', 'tomato plant', 'Soda', 'juniper bush', 'applesauce', 'fishing net', 'kelp', 'cereal bar', 'coffee ground', 'Wine Tasting Kit', 'Conveyor belt', 'bar towel', 'lemon zest', 'Plastic wrap', 'Orange peel', 'martini', 'shaker', 'fanta', 'Cutlery', 'espresso machine', 'milling', 'sealing machine', 'hummus', 'carbon', 'fruit cup', 'pea soup', 'Cereal', 'maple tree', 'Iced coffee', 'coconut', 'Bonding Agent', 'pellet', 'salt shaker', 'juice box', 'pea plant', 'Water', 'anchovy', 'smoothie', 'Irrigation system', 'pizza box', 'squash', 'Iron', 'Ice Water', 'zinc', 'tiramisu', 'Earl Grey tea', 'cruise ship', 'Orange zest', 'Cauliflower', 'gelatin', 'Energy drink', 'coffee machine', 'Cutting Board', 'Finger food', 'cooler', 'ginger', 'High Chair', 'migraine', 'Baguette', 'Muffin', 'frozen meat', 'yeast', 'saucer', 'dill pickle', 'grinder', 'noodle', 'lemon wedge', 'plastic fork', 'dye', 'Toaster Oven', 'dishtowel', 'Kale smoothie', 'gel', 'coffee bag', 'frappe', 'Microwave', 'Food warmers', 'Bottled Water', 'kiwifruit', 'ziploc', 'Champagne flute', 'Hazelnut', 'Vanilla Extract', 'potato chip', 'plastic tube', 'Wine Aerator', 'Coffee grounds', 'yarrow', 'tupperware', 'jaffa cake', 'Mixing Bowl', 'ham', 'melon', 'sweet tea', 'Protein Shakes', 'Aprons', 'Vegetable', 'coffee mug', 'wine glass', 'Bread pudding', 'rose', 'mango tree', 'peach tree', 'Paper towels', 'Sieve', 'plastic tub', 'Grape Vine', 'raspberry', 'honeydew', 'Habanero pepper', 'yule log', 'Apple pie', 'peppermint', 'sauerkraut', 'Hash browns', 'apricot tree', 'pineapple', 'aluminum foil', 'beer tap', 'wine decanter', 'bamboo leaf', 'picnic basket', 'tea bag', 'Brewery merchandise', 'acorn', 'Popcorn machine', 'oak tree', 'water bowl', 'Edamame', 'cotton candy', 'kheer', 'mesquite tree', 'Unleavened Bread', 'meatloaf', 'French toast', 'Relish', 'Muffin Tin', 'Frappuccino', 'gas stove', 'Piping tips', 'oyster', 'Red velvet cake', 'juicer', 'ketchup', 'wonton soup', 'Salad Dressing', 'Cream cheese', 'honeycrisp', 'plastic pallet', 'Fungi', 'plastic baggie', 'evaporator', 'Quesadilla', 'Tomato', 'serving bowl', 'Stove', 'dishcloth', 'bowl', 'Veggie Burger', 'foil paper', 'wooden spoon', 'leaf', 'Mini fridge', 'Kitchen cabinet', 'Utility Cart', 'frozen waffle', 'Cantaloupe', 'Silicone mat', 'Marshmallow', 'Coffee beans', 'honey', 'Mushroom', 'cilantro', 'water chestnut', 'Cheesecake', 'fennel', 'Planter Box', 'Sugar packet', 'camp stove', 'coke', 'Yogurt', 'orange slice', 'Food bowl', 'chocolate bar', 'steak', 'toothpick', 'Pumpkin pie', 'Rolling pin', 'weighing scale', 'butter', 'jam', 'duckweed', 'Ice cream maker', 'cannoli', 'nightshade', 'jasmine', 'wild garlic', 'Plate', 'honeydew melon', 'alfalfa', 'Ice cube tray', 'parsley', 'Vending Machine', 'jello', 'refrigerator', 'Placemat', 'Hibiscus']
culinary_starting_keywords_no = [i for i in all_keywords if i not in culinary_starting_keywords_yes]

# %%
len(culinary_starting_keywords_yes) / len(all_keywords)
# Out:
# 0.2746844840386043

# %% [markdown]
# ### Generate the entire tree

# %%
test_tree  = build_tree(
    "Is it related to food, beverages or cooking?", 
    #"Is it larger than a microwave?",
    all_keywords, 
    initial_starting_keywords_yes=culinary_starting_keywords_yes, 
    initial_starting_keywords_no=culinary_starting_keywords_no, 
    max_depth=6, 
    num_test_questions=5,
    keyword_test_percentage=1
)
# Out:
# Using provided initial starting keywords
# Starting Yes branch for question Is it related to food, beverages or cooking?
# Remaining keywords yes: ['pot holder', 'saltwater', 'thermometer probe', 'aperol spritz', 'banana', 'chutney', 'squid', 'pumpkin', 'unripe banana', 'nitrogen', 'measuring spoon', 'tea cup', 'hazelnut tree', 'cutter', 'Edible flowers', 'chiller', 'Garbage Disposal', 'Wine Opener', 'aerator', 'apple', 'raisin', 'fish scale', 'tongue', 'corkscrew', 'empty can', 'skewer', 'dining chair', 'pomegranate', 'beer coaster', 'colander', 'ice tray', 'bean', 'beer stein', 'electric oven', 'granola', 'Honeybee', 'agave plant', 'Udon Noodles', 'cocktail glass', 'yogurt container', 'unripe fruit', 'Green beans', 'crayfish', 'bread maker', 'beer glass', 'Snacks', 'bacon', 'lid', 'Bread knife', 'compost', 'butter knife', 'Popcorn', 'hot tea', 'Agave', 'Wire rack', 'Heating Element', 'Measuring cup', 'grape', 'Rice pudding', 'water jug', 'strainer', 'Cinnamon roll', 'grape juice', 'Scones', 'cake', 'protein shake', 'dishwasher', 'serving platter', 'cherry tree', 'bamboo', 'Nachos', 'tin foil', 'green alga', 'rooster', 'seltzer', 'Water Bottle', 'vegan chocolate', 'rhubarb', 'Coffee Grinder', 'Chocolate cake', 'ginger ale', 'Spatula', 'peeler', 'lemon juice', 'wonton', 'acacia', 'Potato', 'ramen', 'sushi', 'Grapefruit', 'gin', 'Plastic Gloves', 'spray', 'Red wine', 'water dish', 'rice krispie', 'wing', 'Bird seed', 'peanut butter', 'Croissant', 'almond milk', 'candy wrapper', 'seagrass', 'mango', 'cupcake', 'swedish fish', 'lemon balm', 'Tofu', 'vegetarian chili', 'tea leaf', 'bean plant', 'Protein bar', 'kitchen knife', 'pudding', 'flour', 'Coffee Makers', 'Bacteria', 'grill', 'ice crusher', 'nitrous', 'juniper tree', 'Brownies', 'Radish', 'Silicone', 'Fried rice', 'ice pop', 'barcode', 'vietnamese coffee', 'Roots', 'Sippy cup', 'Dandelion', 'goose', 'metal spoon', 'oatmeal cookie', 'soup', 'Pesticide', 'Water Buffalo', 'Hot dog', 'whisk', 'hamburger helper', 'ice tea', 'Olive Oil', 'lime', 'rosemary', 'brussel sprout', 'canning jar', 'Fortune cookie', 'metal foil', 'Soybeans', 'orange juice', 'metal lid', 'Orange tree', 'Donuts', 'broth', 'pear tree', 'ricotta', 'fudge brownie', 'Oven rack', 'rainbow cake', 'Latte', 'steak knife', 'syrup', 'doughnut', 'Oven door', 'tomato plant', 'Soda', 'juniper bush', 'applesauce', 'fishing net', 'kelp', 'cereal bar', 'coffee ground', 'Wine Tasting Kit', 'Conveyor belt', 'bar towel', 'lemon zest', 'Plastic wrap', 'Orange peel', 'martini', 'shaker', 'fanta', 'Cutlery', 'espresso machine', 'milling', 'sealing machine', 'hummus', 'carbon', 'fruit cup', 'pea soup', 'Cereal', 'maple tree', 'Iced coffee', 'coconut', 'Bonding Agent', 'pellet', 'salt shaker', 'juice box', 'pea plant', 'Water', 'anchovy', 'smoothie', 'Irrigation system', 'pizza box', 'squash', 'Iron', 'Ice Water', 'zinc', 'tiramisu', 'Earl Grey tea', 'cruise ship', 'Orange zest', 'Cauliflower', 'gelatin', 'Energy drink', 'coffee machine', 'Cutting Board', 'Finger food', 'cooler', 'ginger', 'High Chair', 'migraine', 'Baguette', 'Muffin', 'frozen meat', 'yeast', 'saucer', 'dill pickle', 'grinder', 'noodle', 'lemon wedge', 'plastic fork', 'dye', 'Toaster Oven', 'dishtowel', 'Kale smoothie', 'gel', 'coffee bag', 'frappe', 'Microwave', 'Food warmers', 'Bottled Water', 'kiwifruit', 'ziploc', 'Champagne flute', 'Hazelnut', 'Vanilla Extract', 'potato chip', 'plastic tube', 'Wine Aerator', 'Coffee grounds', 'yarrow', 'tupperware', 'jaffa cake', 'Mixing Bowl', 'ham', 'melon', 'sweet tea', 'Protein Shakes', 'Aprons', 'Vegetable', 'coffee mug', 'wine glass', 'Bread pudding', 'rose', 'mango tree', 'peach tree', 'Paper towels', 'Sieve', 'plastic tub', 'Grape Vine', 'raspberry', 'honeydew', 'Habanero pepper', 'yule log', 'Apple pie', 'peppermint', 'sauerkraut', 'Hash browns', 'apricot tree', 'pineapple', 'aluminum foil', 'beer tap', 'wine decanter', 'bamboo leaf', 'picnic basket', 'tea bag', 'Brewery merchandise', 'acorn', 'Popcorn machine', 'oak tree', 'water bowl', 'Edamame', 'cotton candy', 'kheer', 'mesquite tree', 'Unleavened Bread', 'meatloaf', 'French toast', ...
# 1. Question: Is it related to food, beverages or cooking?  Answer: Yes
# Question: Is it an edible item?
# Num keywords in test set: 370
# 1) Keyword: plastic tub. Result: False
# 2) Keyword: beer tap. Result: False
# 3) Keyword: ice tea. Result: True
# 4) Keyword: water dish. Result: False
# 5) Keyword: bamboo. Result: True
# 6) Keyword: Fungi. Result: True
# 7) Keyword: jasmine. Result: True
# 8) Keyword: Pumpkin pie. Result: True
# 9) Keyword: fishing net. Result: False
# 10) Keyword: potato chip. Result: True
# 11) Keyword: Coffee Makers. Result: False
# 12) Keyword: cilantro. Result: True
# 13) Keyword: Iron. Result: False
# 14) Keyword: applesauce. Result: True
# 15) Keyword: Hash browns. Result: True
# 16) Keyword: weighing scale. Result: False
# 17) Keyword: lid. Result: False
# 18) Keyword: aperol spritz. Result: True
# 19) Keyword: strainer. Result: False
# 20) Keyword: Silicone mat. Result: False
# 21) Keyword: Wine Tasting Kit. Result: False
# 22) Keyword: Garbage Disposal. Result: False
# 23) Keyword: leaf. Result: True
# 24) Keyword: Unleavened Bread. Result: True
# 25) Keyword: Microwave. Result: False
# 26) Keyword: hummus. Result: True
# 27) Keyword: Bird seed. Result: True
# 28) Keyword: metal spoon. Result: False
# 29) Keyword: yeast. Result: True
# 30) Keyword: Piping tips. Result: False
# 31) Keyword: Stove. Result: False
# 32) Keyword: lemon juice. Result: True
# 33) Keyword: Heating Element. Result: False
# 34) Keyword: coffee mug. Result: False
# 35) Keyword: jam. Result: True
# 36) Keyword: Paper towels. Result: False
# 37) Keyword: Honeybee. Result: True
# 38) Keyword: water chestnut. Result: True
# 39) Keyword: nitrogen. Result: False
# 40) Keyword: pellet. Result: False
# 41) Keyword: tin foil. Result: False
# 42) Keyword: Olive Oil. Result: True
# 43) Keyword: plastic tube. Result: False
# 44) Keyword: Udon Noodles. Result: True
# 45) Keyword: noodle. Result: True
# 46) Keyword: jello. Result: True
# 47) Keyword: Roots. Result: True
# 48) Keyword: Coffee beans. Result: True
# 49) Keyword: Food warmers. Result: False
# 50) Keyword: gin. Result: True
# 51) Keyword: Kale smoothie. Result: True
# 52) Keyword: shaker. Result: False
# 53) Keyword: Cinnamon roll. Result: True
# 54) Keyword: juice box. Result: True
# 55) Keyword: wine decanter. Result: False
# 56) Keyword: Cheesecake. Result: True
# 57) Keyword: Energy drink. Result: True
# 58) Keyword: ham. Result: True
# 59) Keyword: Nachos. Result: True
# 60) Keyword: syrup. Result: True
# 61) Keyword: chutney. Result: True
# 62) Keyword: hot tea. Result: True
# 63) Keyword: Wine Opener. Result: False
# 64) Keyword: Spatula. Result: False
# 65) Keyword: Mini fridge. Result: False
# 66) Keyword: oyster. Result: True
# 67) Keyword: evaporator. Result: False
# 68) Keyword: pumpkin. Result: True
# 69) Keyword: doughnut. Result: True
# 70) Keyword: Cantaloupe. Result: True
# 71) Keyword: Apple pie. Result: True
# 72) Keyword: Protein bar. Result: True
# 73) Keyword: juniper tree. Result: False
# 74) Keyword: vietnamese coffee. Result: True
# 75) Keyword: fruit cup. Result: True
# 76) Keyword: bean. Result: True
# 77) Keyword: Cutting Board. Result: False
# 78) Keyword: Bread knife. Result: False
# 79) Keyword: lemon balm. Result: True
# 80) Keyword: aluminum foil. Result: False
# 81) Keyword: fish scale. Result: False
# 82) Keyword: Scones. Result: True
# 83) Keyword: wine glass. Result: False
# 84) Keyword: camp stove. Result: False
# 85) Keyword: dye. Result: False
# 86) Keyword: Marshmallow. Result: True
# 87) Keyword: grape juice. Result: True
# 88) Keyword: serving bowl. Result: False
# 89) Keyword: wild garlic. Result: True
# 90) Keyword: frozen meat. Result: True
# 91) Keyword: seagrass. Result: True
# 92) Keyword: sushi. Result: True
# 93) Keyword: espresso machine. Result: False
# 94) Keyword: Utility Cart. Result: False
# 95) Keyword: almond milk. Result: True
# 96) Keyword: Salad Dressing. Result: True
# 97) Keyword: nitrous. Result: False
# 98) Keyword: cake. Result: True
# 99) Keyword: honey. Result: True
# 100) Keyword: fanta. Result: True
# 101) Keyword: Champagne flute. Result: False
# 102) Keyword: fudge brownie. Result: True
# 103) Keyword: Wine Aerator. Result: False
# 104) Keyword: Hibiscus. Result: True
# 105) Keyword: Iced coffee. Result: True
# 106) Keyword: foil paper. Result: False
# 107) Keyword: compost. Result: False
# 108) Keyword: soup. Result: True
# 109) Keyword: Brewery merchandise. Result: False
# 110) Keyword: pudding. Result: True
# 111) Keyword: protein shake. Result: True
# 112) Keyword: goose. Result: True
# 113) Keyword: peppermint. Result: True
# 114) Keyword: thermometer probe. Result: False
# 115) Keyword: dining chair. Result: False
# 116) Keyword: orange juice. Result: True
# 117) Keyword: Wire rack. Result: False
# 118) Keyword: cocktail glass. Result: False
# 119) Keyword: coke. Result: True
# 120) Keyword: tea leaf. Result: True
# 121) Keyword: unripe fruit. Result: False
# 122) Keyword: Finger food. Result: True
# 123) Keyword: flour. Result: True
# 124) Keyword: lemon wedge. Result: True
# 125) Keyword: bread maker. Result: False
# 126) Keyword: smoothie. Result: True
# 127) Keyword: frappe. Result: True
# 128) Keyword: water jug. Result: False
# 129) Keyword: peach tree. Result: True
# 130) Keyword: metal foil. Result: False
# 131) Keyword: dill pickle. Result: True
# 132) Keyword: ginger. Result: True
# 133) Keyword: bamboo leaf. Result: True
# 134) Keyword: yarrow. Result: True
# 135) Keyword: plastic baggie. Result: False
# 136) Keyword: rainbow cake. Result: True
# 137) Keyword: Popcorn. Result: True
# 138) Keyword: Silicone. Result: False
# 139) Keyword: ice tray. Result: False
# 140) Keyword: meatloaf. Result: True
# 141) Keyword: orange slice. Result: True
# 142) Keyword: mango. Result: True
# 143) Keyword: bar towel. Result: False
# 144) Keyword: Cutlery. Result: False
# 145) Keyword: Soybeans. Result: True
# 146) Keyword: tiramisu. Result: True
# 147) Keyword: squid. Result: True
# 148) Keyword: rooster. Result: True
# 149) Keyword: Veggie Burger. Result: True
# 150) Keyword: dishcloth. Result: False
# 151) Keyword: honeycrisp. Result: True
# 152) Keyword: peeler. Result: False
# 153) Keyword: acacia. Result: True
# 154) Keyword: bacon. Result: True
# 155) Keyword: saltwater. Result: False
# 156) Keyword: Planter Box. Result: False
# 157) Keyword: alfalfa. Result: True
# 158) Keyword: kelp. Result: True
# 159) Keyword: Latte. Result: True
# 160) Keyword: fennel. Result: True
# 161) Keyword: Bread pudding. Result: True
# 162) Keyword: Vegetable. Result: True
# 163) Keyword: gel. Result: False
# 164) Keyword: Mixing Bowl. Result: False
# 165) Keyword: water bowl. Result: False
# 166) Keyword: zinc. Result: True
# 167) Keyword: Chocolate cake. Result: True
# 168) Keyword: grape. Result: True
# 169) Keyword: brussel sprout. Result: True
# 170) Keyword: Ice cream maker. Result: False
# 171) Keyword: Bacteria. Result: True
# 172) Keyword: candy wrapper. Result: False
# 173) Keyword: Quesadilla. Result: True
# 174) Keyword: vegan chocolate. Result: True
# 175) Keyword: apple. Result: True
# 176) Keyword: Vending Machine. Result: False
# 177) Keyword: Red velvet cake. Result: True
# 178) Keyword: migraine. Result: False
# 179) Keyword: raisin. Result: True
# 180) Keyword: yogurt container. Result: False
# 181) Keyword: kheer. Result: True
# 182) Keyword: empty can. Result: False
# 183) Keyword: Soda. Result: True
# 184) Keyword: Ice cube tray. Result: False
# 185) Keyword: parsley. Result: True
# 186) Keyword: tea cup. Result: False
# 187) Keyword: sweet tea. Result: True
# 188) Keyword: Plastic Gloves. Result: False
# 189) Keyword: Hot dog. Result: True
# 190) Keyword: steak. Result: True
# 191) Keyword: metal lid. Result: False
# 192) Keyword: plastic pallet. Result: False
# 193) Keyword: Ice Water. Result: True
# 194) Keyword: sealing machine. Result: False
# 195) Keyword: cupcake. Result: True
# 196) Keyword: rhubarb. Result: True
# 197) Keyword: Bottled Water. Result: True
# 198) Keyword: saucer. Result: False
# 199) Keyword: Aprons. Result: False
# 200) Keyword: Tomato. Result: True
# 201) Keyword: Snacks. Result: True
# 202) Keyword: Rice pudding. Result: True
# 203) Keyword: wonton soup. Result: True
# 204) Keyword: Bonding Agent. Result: False
# 205) Keyword: Water. Result: True
# 206) Keyword: ketchup. Result: True
# 207) Keyword: Croissant. Result: True
# 208) Keyword: Coffee Grinder. Result: False
# 209) Keyword: tupperware. Result: False
# 210) Keyword: Red wine. Result: True
# 211) Keyword: beer stein. Result: False
# 212) Keyword: barcode. Result: False
# 213) Keyword: vegetarian chili. Result: True
# 214) Keyword: Sieve. Result: False
# 215) Keyword: duckweed. Result: True
# 216) Keyword: toothpick. Result: False
# 217) Keyword: Orange tree. Result: True
# 218) Keyword: wooden spoon. Result: False
# 219) Keyword: Yogurt. Result: True
# 220) Keyword: coffee ground. Result: True
# 221) Keyword: Edible flowers. Result: True
# 222) Keyword: Placemat. Result: False
# 223) Keyword: Relish. Result: True
# 224) Keyword: pizza box. Result: False
# 225) Keyword: honeydew. Result: True
# 226) Keyword: Habanero pepper. Result: True
# 227) Keyword: Muffin. Result: True
# 228) Keyword: pineapple. Result: True
# 229) Keyword: pomegranate. Result: True
# 230) Keyword: unripe banana. Result: True
# 231) Keyword: apricot tree. Result: True
# 232) Keyword: Grape Vine. Result: True
# 233) Keyword: mesquite tree. Result: True
# 234) Keyword: crayfish. Result: True
# 235) Keyword: cutter. Result: False
# 236) Keyword: hazelnut tree. Result: False
# 237) Keyword: nightshade. Result: False
# 238) Keyword: dishtowel. Result: False
# 239) Keyword: whisk. Result: False
# 240) Keyword: Orange peel. Result: True
# 241) Keyword: gelatin. Result: True
# 242) Keyword: refrigerator. Result: False
# 243) Keyword: electric oven. Result: False
# 244) Keyword: pot holder. Result: False
# 245) Keyword: Oven door. Result: False
# 246) Keyword: ziploc. Result: False
# 247) Keyword: colander. Result: False
# 248) Keyword: Potato. Result: True
# 249) Keyword: pear tree. Result: True
# 250) Keyword: lime. Result: True
# 251) Keyword: tea bag. Result: False
# 252) Keyword: chiller. Result: False
# 253) Keyword: ginger ale. Result: True
# 254) Keyword: Grapefruit. Result: True
# 255) Keyword: jaffa cake. Result: True
# 256) Keyword: Frappuccino. Result: True
# 257) Keyword: oatmeal cookie. Result: True
# 258) Keyword: Sippy cup. Result: False
# 259) Keyword: sauerkraut. Result: True
# 260) Keyword: butter. Result: True
# 261) Keyword: green alga. Result: True
# 262) Keyword: cruise ship. Result: False
# 263) Keyword: Kitchen cabinet. Result: False
# 264) Keyword: peanut butter. Result: True
# 265) Keyword: ice pop. Result: True
# 266) Keyword: cotton candy. Result: True
# 267) Keyword: melon. Result: True
# 268) Keyword: mango tree. Result: False
# 269) Keyword: coffee machine. Result: False
# 270) Keyword: Fortune cookie. Result: True
# 271) Keyword: aerator. Result: False
# 272) Keyword: dishwasher. Result: False
# 273) Keyword: granola. Result: True
# 274) Keyword: Edamame. Result: True
# 275) Keyword: bean plant. Result: True
# 276) Keyword: coffee bag. Result: False
# 277) Keyword: lemon zest. Result: True
# 278) Keyword: Cereal. Result: True
# 279) Keyword: Sugar packet. Result: True
# 280) Keyword: Fried rice. Result: True
# 281) Keyword: tongue. Result: True
# 282) Keyword: cooler. Result: False
# 283) Keyword: agave plant. Result: True
# 284) Keyword: butter knife. Result: False
# 285) Keyword: oak tree. Result: False
# 286) Keyword: Oven rack. Result: False
# 287) Keyword: Irrigation system. Result: False
# 288) Keyword: maple tree. Result: True
# 289) Keyword: Plate. Result: False
# 290) Keyword: Green beans. Result: True
# 291) Keyword: banana. Result: True
# 292) Keyword: seltzer. Result: True
# 293) Keyword: plastic fork. Result: False
# 294) Keyword: cereal bar. Result: True
# 295) Keyword: acorn. Result: True
# 296) Keyword: swedish fish. Result: True
# 297) Keyword: honeydew melon. Result: True
# 298) Keyword: kiwifruit. Result: True
# 299) Keyword: broth. Result: True
# 300) Keyword: wonton. Result: True
# 301) Keyword: grinder. Result: False
# 302) Keyword: kitchen knife. Result: False
# 303) Keyword: measuring spoon. Result: False
# 304) Keyword: frozen waffle. Result: True
# 305) Keyword: Water Bottle. Result: False
# 306) Keyword: milling. Result: False
# 307) Keyword: steak knife. Result: False
# 308) Keyword: gas stove. Result: False
# 309) Keyword: cannoli. Result: True
# 310) Keyword: ice crusher. Result: False
# 311) Keyword: skewer. Result: False
# 312) Keyword: rosemary. Result: True
# 313) Keyword: beer glass. Result: False
# 314) Keyword: French toast. Result: True
# 315) Keyword: Food bowl. Result: False
# 316) Keyword: juicer. Result: False
# 317) Keyword: tomato plant. Result: True
# 318) Keyword: serving platter. Result: False
# 319) Keyword: canning jar. Result: False
# 320) Keyword: Rolling pin. Result: False
# 321) Keyword: Conveyor belt. Result: False
# 322) Keyword: pea plant. Result: True
# 323) Keyword: anchovy. Result: True
# 324) Keyword: picnic basket. Result: False
# 325) Keyword: Radish. Result: True
# 326) Keyword: rice krispie. Result: True
# 327) Keyword: ramen. Result: True
# 328) Keyword: raspberry. Result: True
# 329) Keyword: yule log. Result: True
# 330) Keyword: ricotta. Result: True
# 331) Keyword: Plastic wrap. Result: False
# 332) Keyword: Donuts. Result: True
# 333) Keyword: Hazelnut. Result: True
# 334) Keyword: coconut. Result: True
# 335) Keyword: martini. Result: True
# 336) Keyword: Toaster Oven. Result: False
# 337) Keyword: Cream cheese. Result: True
# 338) Keyword: squash. Result: True
# 339) Keyword: Cauliflower. Result: True
# 340) Keyword: Pesticide. Result: False
# 341) Keyword: beer coaster. Result: False
# 342) Keyword: chocolate bar. Result: True
# 343) Keyword: Protein Shakes. Result: True
# 344) Keyword: carbon. Result: False
# 345) Keyword: Baguette. Result: True
# 346) Keyword: High Chair. Result: False
# 347) Keyword: salt shaker. Result: True
# 348) Keyword: Agave. Result: True
# 349) Keyword: bowl. Result: False
# 350) Keyword: Tofu. Result: True
# 351) Keyword: juniper bush. Result: False
# 352) Keyword: pea soup. Result: True
# 353) Keyword: Mushroom. Result: True
# 354) Keyword: Brownies. Result: True
# 355) Keyword: wing. Result: True
# 356) Keyword: Popcorn machine. Result: False
# 357) Keyword: Earl Grey tea. Result: True
# 358) Keyword: rose. Result: True
# 359) Keyword: Orange zest. Result: True
# 360) Keyword: Measuring cup. Result: False
# 361) Keyword: Vanilla Extract. Result: True
# 362) Keyword: Coffee grounds. Result: True
# 363) Keyword: hamburger helper. Result: True
# 364) Keyword: Water Buffalo. Result: True
# 365) Keyword: spray. Result: False
# 366) Keyword: Dandelion. Result: True
# 367) Keyword: Muffin Tin. Result: False
# 368) Keyword: corkscrew. Result: False
# 369) Keyword: grill. Result: False
# 370) Keyword: cherry tree. Result: True
# Percentage: 0.5945945945945946%	Score: 0.09459459459459463
#
# _______
# Depth 1 -- Starting Yes branch for question: Is it an edible item?
# Remaining keywords yes: ['ice tea', 'bamboo', 'Fungi', 'jasmine', 'Pumpkin pie', 'potato chip', 'cilantro', 'applesauce', 'Hash browns', 'aperol spritz', 'leaf', 'Unleavened Bread', 'hummus', 'Bird seed', 'yeast', 'lemon juice', 'jam', 'Honeybee', 'water chestnut', 'Olive Oil', 'Udon Noodles', 'noodle', 'jello', 'Roots', 'Coffee beans', 'gin', 'Kale smoothie', 'Cinnamon roll', 'juice box', 'Cheesecake', 'Energy drink', 'ham', 'Nachos', 'syrup', 'chutney', 'hot tea', 'oyster', 'pumpkin', 'doughnut', 'Cantaloupe', 'Apple pie', 'Protein bar', 'vietnamese coffee', 'fruit cup', 'bean', 'lemon balm', 'Scones', 'Marshmallow', 'grape juice', 'wild garlic', 'frozen meat', 'seagrass', 'sushi', 'almond milk', 'Salad Dressing', 'cake', 'honey', 'fanta', 'fudge brownie', 'Hibiscus', 'Iced coffee', 'soup', 'pudding', 'protein shake', 'goose', 'peppermint', 'orange juice', 'coke', 'tea leaf', 'Finger food', 'flour', 'lemon wedge', 'smoothie', 'frappe', 'peach tree', 'dill pickle', 'ginger', 'bamboo leaf', 'yarrow', 'rainbow cake', 'Popcorn', 'meatloaf', 'orange slice', 'mango', 'Soybeans', 'tiramisu', 'squid', 'rooster', 'Veggie Burger', 'honeycrisp', 'acacia', 'bacon', 'alfalfa', 'kelp', 'Latte', 'fennel', 'Bread pudding', 'Vegetable', 'zinc', 'Chocolate cake', 'grape', 'brussel sprout', 'Bacteria', 'Quesadilla', 'vegan chocolate', 'apple', 'Red velvet cake', 'raisin', 'kheer', 'Soda', 'parsley', 'sweet tea', 'Hot dog', 'steak', 'Ice Water', 'cupcake', 'rhubarb', 'Bottled Water', 'Tomato', 'Snacks', 'Rice pudding', 'wonton soup', 'Water', 'ketchup', 'Croissant', 'Red wine', 'vegetarian chili', 'duckweed', 'Orange tree', 'Yogurt', 'coffee ground', 'Edible flowers', 'Relish', 'honeydew', 'Habanero pepper', 'Muffin', 'pineapple', 'pomegranate', 'unripe banana', 'apricot tree', 'Grape Vine', 'mesquite tree', 'crayfish', 'Orange peel', 'gelatin', 'Potato', 'pear tree', 'lime', 'ginger ale', 'Grapefruit', 'jaffa cake', 'Frappuccino', 'oatmeal cookie', 'sauerkraut', 'butter', 'green alga', 'peanut butter', 'ice pop', 'cotton candy', 'melon', 'Fortune cookie', 'granola', 'Edamame', 'bean plant', 'lemon zest', 'Cereal', 'Sugar packet', 'Fried rice', 'tongue', 'agave plant', 'maple tree', 'Green beans', 'banana', 'seltzer', 'cereal bar', 'acorn', 'swedish fish', 'honeydew melon', 'kiwifruit', 'broth', 'wonton', 'frozen waffle', 'cannoli', 'rosemary', 'French toast', 'tomato plant', 'pea plant', 'anchovy', 'Radish', 'rice krispie', 'ramen', 'raspberry', 'yule log', 'ricotta', 'Donuts', 'Hazelnut', 'coconut', 'martini', 'Cream cheese', 'squash', 'Cauliflower', 'chocolate bar', 'Protein Shakes', 'Baguette', 'salt shaker', 'Agave', 'Tofu', 'pea soup', 'Mushroom', 'Brownies', 'wing', 'Earl Grey tea', 'rose', 'Orange zest', 'Vanilla Extract', 'Coffee grounds', 'hamburger helper', 'Water Buffalo', 'Dandelion', 'cherry tree']
# 1. Question: Is it related to food, beverages or cooking?  Answer: Yes2. Question: Is it an edible item?  Answer: Yes
# Question: Is it a type of beverage?
# Num keywords in test set: 220
# 1) Keyword: chocolate bar. Result: False
# 2) Keyword: parsley. Result: False
# 3) Keyword: martini. Result: True
# 4) Keyword: Marshmallow. Result: False
# 5) Keyword: Water. Result: True
# 6) Keyword: crayfish. Result: False
# 7) Keyword: vietnamese coffee. Result: True
# 8) Keyword: coke. Result: True
# 9) Keyword: frozen meat. Result: False
# 10) Keyword: Cinnamon roll. Result: False
# 11) Keyword: Donuts. Result: False
# 12) Keyword: Quesadilla. Result: False
# 13) Keyword: fudge brownie. Result: False
# 14) Keyword: apricot tree. Result: False
# 15) Keyword: pumpkin. Result: False
# 16) Keyword: Tomato. Result: False
# 17) Keyword: pea soup. Result: False
# 18) Keyword: gelatin. Result: False
# 19) Keyword: cilantro. Result: False
# 20) Keyword: doughnut. Result: False
# 21) Keyword: peppermint. Result: False
# 22) Keyword: rice krispie. Result: False
# 23) Keyword: Cantaloupe. Result: False
# 24) Keyword: yeast. Result: False
# 25) Keyword: ramen. Result: False
# 26) Keyword: jam. Result: False
# 27) Keyword: honey. Result: False
# 28) Keyword: rosemary. Result: False
# 29) Keyword: cannoli. Result: False
# 30) Keyword: Honeybee. Result: False
# 31) Keyword: leaf. Result: False
# 32) Keyword: cake. Result: False
# 33) Keyword: Latte. Result: True
# 34) Keyword: Hazelnut. Result: False
# 35) Keyword: Agave. Result: False
# 36) Keyword: yule log. Result: False
# 37) Keyword: seltzer. Result: True
# 38) Keyword: zinc. Result: False
# 39) Keyword: honeydew melon. Result: False
# 40) Keyword: salt shaker. Result: False
# 41) Keyword: ginger. Result: False
# 42) Keyword: orange slice. Result: False
# 43) Keyword: soup. Result: False
# 44) Keyword: Orange zest. Result: False
# 45) Keyword: frozen waffle. Result: False
# 46) Keyword: Soda. Result: True
# 47) Keyword: maple tree. Result: False
# 48) Keyword: bacon. Result: False
# 49) Keyword: Coffee beans. Result: False
# 50) Keyword: Green beans. Result: False
# 51) Keyword: honeydew. Result: False
# 52) Keyword: Yogurt. Result: False
# 53) Keyword: fennel. Result: False
# 54) Keyword: Mushroom. Result: False
# 55) Keyword: bean plant. Result: False
# 56) Keyword: Muffin. Result: False
# 57) Keyword: water chestnut. Result: False
# 58) Keyword: pineapple. Result: False
# 59) Keyword: cupcake. Result: False
# 60) Keyword: goose. Result: False
# 61) Keyword: brussel sprout. Result: False
# 62) Keyword: mesquite tree. Result: False
# 63) Keyword: flour. Result: False
# 64) Keyword: meatloaf. Result: False
# 65) Keyword: wonton soup. Result: False
# 66) Keyword: Habanero pepper. Result: False
# 67) Keyword: syrup. Result: False
# 68) Keyword: fruit cup. Result: False
# 69) Keyword: cotton candy. Result: False
# 70) Keyword: lime. Result: False
# 71) Keyword: rainbow cake. Result: False
# 72) Keyword: Sugar packet. Result: False
# 73) Keyword: dill pickle. Result: False
# 74) Keyword: duckweed. Result: False
# 75) Keyword: swedish fish. Result: False
# 76) Keyword: cereal bar. Result: False
# 77) Keyword: ricotta. Result: False
# 78) Keyword: sushi. Result: False
# 79) Keyword: Roots. Result: False
# 80) Keyword: acorn. Result: False
# 81) Keyword: acacia. Result: False
# 82) Keyword: Finger food. Result: False
# 83) Keyword: vegan chocolate. Result: False
# 84) Keyword: Bread pudding. Result: False
# 85) Keyword: Pumpkin pie. Result: False
# 86) Keyword: lemon balm. Result: False
# 87) Keyword: Udon Noodles. Result: False
# 88) Keyword: Dandelion. Result: False
# 89) Keyword: potato chip. Result: False
# 90) Keyword: orange juice. Result: True
# 91) Keyword: jello. Result: False
# 92) Keyword: ham. Result: False
# 93) Keyword: Grapefruit. Result: False
# 94) Keyword: Popcorn. Result: False
# 95) Keyword: chutney. Result: False
# 96) Keyword: green alga. Result: False
# 97) Keyword: granola. Result: False
# 98) Keyword: Fungi. Result: False
# 99) Keyword: raspberry. Result: False
# 100) Keyword: hamburger helper. Result: False
# 101) Keyword: coconut. Result: False
# 102) Keyword: Nachos. Result: False
# 103) Keyword: frappe. Result: True
# 104) Keyword: Salad Dressing. Result: False
# 105) Keyword: tomato plant. Result: False
# 106) Keyword: Protein Shakes. Result: True
# 107) Keyword: Olive Oil. Result: False
# 108) Keyword: ice tea. Result: True
# 109) Keyword: Protein bar. Result: False
# 110) Keyword: squid. Result: False
# 111) Keyword: gin. Result: True
# 112) Keyword: smoothie. Result: True
# 113) Keyword: fanta. Result: True
# 114) Keyword: cherry tree. Result: False
# 115) Keyword: mango. Result: False
# 116) Keyword: Cream cheese. Result: False
# 117) Keyword: Iced coffee. Result: True
# 118) Keyword: agave plant. Result: False
# 119) Keyword: Coffee grounds. Result: False
# 120) Keyword: tiramisu. Result: False
# 121) Keyword: Snacks. Result: False
# 122) Keyword: Cauliflower. Result: False
# 123) Keyword: kheer. Result: False
# 124) Keyword: tea leaf. Result: False
# 125) Keyword: Croissant. Result: False
# 126) Keyword: anchovy. Result: False
# 127) Keyword: sauerkraut. Result: False
# 128) Keyword: peanut butter. Result: False
# 129) Keyword: Grape Vine. Result: False
# 130) Keyword: Soybeans. Result: False
# 131) Keyword: Vanilla Extract. Result: False
# 132) Keyword: Unleavened Bread. Result: False
# 133) Keyword: Earl Grey tea. Result: True
# 134) Keyword: pomegranate. Result: False
# 135) Keyword: Veggie Burger. Result: False
# 136) Keyword: Relish. Result: False
# 137) Keyword: Brownies. Result: False
# 138) Keyword: banana. Result: False
# 139) Keyword: Water Buffalo. Result: False
# 140) Keyword: Red velvet cake. Result: False
# 141) Keyword: Radish. Result: False
# 142) Keyword: raisin. Result: False
# 143) Keyword: hummus. Result: False
# 144) Keyword: wing. Result: False
# 145) Keyword: pear tree. Result: False
# 146) Keyword: honeycrisp. Result: False
# 147) Keyword: French toast. Result: False
# 148) Keyword: Apple pie. Result: False
# 149) Keyword: noodle. Result: False
# 150) Keyword: pea plant. Result: False
# 151) Keyword: Cereal. Result: False
# 152) Keyword: Hash browns. Result: False
# 153) Keyword: tongue. Result: False
# 154) Keyword: grape. Result: False
# 155) Keyword: Rice pudding. Result: False
# 156) Keyword: Energy drink. Result: True
# 157) Keyword: Potato. Result: False
# 158) Keyword: jaffa cake. Result: False
# 159) Keyword: rooster. Result: False
# 160) Keyword: applesauce. Result: False
# 161) Keyword: aperol spritz. Result: True
# 162) Keyword: kiwifruit. Result: False
# 163) Keyword: wonton. Result: False
# 164) Keyword: seagrass. Result: False
# 165) Keyword: Edible flowers. Result: False
# 166) Keyword: Frappuccino. Result: True
# 167) Keyword: Kale smoothie. Result: True
# 168) Keyword: Edamame. Result: False
# 169) Keyword: bamboo leaf. Result: False
# 170) Keyword: yarrow. Result: False
# 171) Keyword: sweet tea. Result: True
# 172) Keyword: Fortune cookie. Result: False
# 173) Keyword: Chocolate cake. Result: False
# 174) Keyword: squash. Result: False
# 175) Keyword: grape juice. Result: True
# 176) Keyword: juice box. Result: True
# 177) Keyword: Ice Water. Result: True
# 178) Keyword: ketchup. Result: False
# 179) Keyword: ginger ale. Result: True
# 180) Keyword: vegetarian chili. Result: False
# 181) Keyword: Red wine. Result: True
# 182) Keyword: Cheesecake. Result: False
# 183) Keyword: ice pop. Result: False
# 184) Keyword: Scones. Result: False
# 185) Keyword: jasmine. Result: False
# 186) Keyword: Tofu. Result: False
# 187) Keyword: Hibiscus. Result: False
# 188) Keyword: coffee ground. Result: False
# 189) Keyword: rhubarb. Result: False
# 190) Keyword: Bottled Water. Result: True
# 191) Keyword: Bird seed. Result: False
# 192) Keyword: bean. Result: False
# 193) Keyword: Orange tree. Result: False
# 194) Keyword: rose. Result: False
# 195) Keyword: protein shake. Result: True
# 196) Keyword: Orange peel. Result: False
# 197) Keyword: Vegetable. Result: False
# 198) Keyword: almond milk. Result: True
# 199) Keyword: peach tree. Result: False
# 200) Keyword: butter. Result: False
# 201) Keyword: melon. Result: False
# 202) Keyword: broth. Result: False
# 203) Keyword: apple. Result: False
# 204) Keyword: Baguette. Result: False
# 205) Keyword: lemon zest. Result: False
# 206) Keyword: oyster. Result: False
# 207) Keyword: unripe banana. Result: False
# 208) Keyword: lemon wedge. Result: False
# 209) Keyword: Fried rice. Result: False
# 210) Keyword: lemon juice. Result: True
# 211) Keyword: bamboo. Result: False
# 212) Keyword: hot tea. Result: True
# 213) Keyword: wild garlic. Result: False
# 214) Keyword: steak. Result: False
# 215) Keyword: oatmeal cookie. Result: False
# 216) Keyword: kelp. Result: False
# 217) Keyword: pudding. Result: False
# 218) Keyword: alfalfa. Result: False
# 219) Keyword: Bacteria. Result: False
# 220) Keyword: Hot dog. Result: False
# Percentage: 0.1409090909090909%	Score: 0.3590909090909091
#
# Question: Is it primarily sweet?
# Num keywords in test set: 220
# 1) Keyword: lemon juice. Result: False
# 2) Keyword: alfalfa. Result: False
# 3) Keyword: coconut. Result: False
# 4) Keyword: Hibiscus. Result: False
# 5) Keyword: Bottled Water. Result: False
# 6) Keyword: rice krispie. Result: True
# 7) Keyword: wild garlic. Result: False
# 8) Keyword: ricotta. Result: False
# 9) Keyword: chocolate bar. Result: True
# 10) Keyword: raspberry. Result: True
# 11) Keyword: rooster. Result: False
# 12) Keyword: Croissant. Result: False
# 13) Keyword: crayfish. Result: False
# 14) Keyword: Cantaloupe. Result: True
# 15) Keyword: sweet tea. Result: True
# 16) Keyword: water chestnut. Result: False
# 17) Keyword: acacia. Result: False
# 18) Keyword: Snacks. Result: False
# 19) Keyword: jaffa cake. Result: True
# 20) Keyword: goose. Result: False
# 21) Keyword: kheer. Result: True
# 22) Keyword: noodle. Result: False
# 23) Keyword: frozen waffle. Result: False
# 24) Keyword: Cinnamon roll. Result: True
# 25) Keyword: zinc. Result: False
# 26) Keyword: pumpkin. Result: False
# 27) Keyword: frozen meat. Result: False
# 28) Keyword: green alga. Result: False
# 29) Keyword: lemon balm. Result: False
# 30) Keyword: sauerkraut. Result: False
# 31) Keyword: Orange tree. Result: True
# 32) Keyword: cilantro. Result: False
# 33) Keyword: jasmine. Result: True
# 34) Keyword: Chocolate cake. Result: True
# 35) Keyword: Yogurt. Result: False
# 36) Keyword: hummus. Result: False
# 37) Keyword: swedish fish. Result: True
# 38) Keyword: Finger food. Result: False
# 39) Keyword: bean. Result: False
# 40) Keyword: rainbow cake. Result: True
# 41) Keyword: Baguette. Result: False
# 42) Keyword: Red velvet cake. Result: True
# 43) Keyword: Orange peel. Result: False
# 44) Keyword: melon. Result: True
# 45) Keyword: butter. Result: False
# 46) Keyword: Bread pudding. Result: True
# 47) Keyword: Fungi. Result: False
# 48) Keyword: bean plant. Result: False
# 49) Keyword: Coffee beans. Result: False
# 50) Keyword: broth. Result: False
# 51) Keyword: lime. Result: False
# 52) Keyword: cherry tree. Result: False
# 53) Keyword: mesquite tree. Result: False
# 54) Keyword: cake. Result: True
# 55) Keyword: ginger ale. Result: True
# 56) Keyword: vietnamese coffee. Result: True
# 57) Keyword: Muffin. Result: True
# 58) Keyword: rosemary. Result: False
# 59) Keyword: oyster. Result: False
# 60) Keyword: orange juice. Result: True
# 61) Keyword: kiwifruit. Result: False
# 62) Keyword: tomato plant. Result: True
# 63) Keyword: Habanero pepper. Result: False
# 64) Keyword: steak. Result: False
# 65) Keyword: orange slice. Result: True
# 66) Keyword: rhubarb. Result: False
# 67) Keyword: anchovy. Result: False
# 68) Keyword: Relish. Result: False
# 69) Keyword: honeycrisp. Result: True
# 70) Keyword: Veggie Burger. Result: False
# 71) Keyword: Protein bar. Result: False
# 72) Keyword: granola. Result: True
# 73) Keyword: cereal bar. Result: True
# 74) Keyword: Donuts. Result: True
# 75) Keyword: smoothie. Result: True
# 76) Keyword: pomegranate. Result: False
# 77) Keyword: Udon Noodles. Result: False
# 78) Keyword: juice box. Result: True
# 79) Keyword: honeydew melon. Result: True
# 80) Keyword: Hot dog. Result: False
# 81) Keyword: Bacteria. Result: False
# 82) Keyword: pudding. Result: True
# 83) Keyword: fruit cup. Result: True
# 84) Keyword: Scones. Result: False
# 85) Keyword: almond milk. Result: False
# 86) Keyword: peanut butter. Result: False
# 87) Keyword: wonton soup. Result: False
# 88) Keyword: Olive Oil. Result: False
# 89) Keyword: Grapefruit. Result: False
# 90) Keyword: kelp. Result: False
# 91) Keyword: Grape Vine. Result: True
# 92) Keyword: bamboo. Result: False
# 93) Keyword: wing. Result: False
# 94) Keyword: banana. Result: True
# 95) Keyword: brussel sprout. Result: False
# 96) Keyword: maple tree. Result: True
# 97) Keyword: squash. Result: False
# 98) Keyword: chutney. Result: False
# 99) Keyword: Tofu. Result: False
# 100) Keyword: Kale smoothie. Result: False
# 101) Keyword: Agave. Result: False
# 102) Keyword: ginger. Result: False
# 103) Keyword: squid. Result: False
# 104) Keyword: pea soup. Result: False
# 105) Keyword: oatmeal cookie. Result: True
# 106) Keyword: Honeybee. Result: False
# 107) Keyword: Fried rice. Result: False
# 108) Keyword: raisin. Result: True
# 109) Keyword: jam. Result: True
# 110) Keyword: Red wine. Result: False
# 111) Keyword: coffee ground. Result: False
# 112) Keyword: bacon. Result: False
# 113) Keyword: wonton. Result: False
# 114) Keyword: Nachos. Result: False
# 115) Keyword: pineapple. Result: True
# 116) Keyword: cannoli. Result: True
# 117) Keyword: Latte. Result: False
# 118) Keyword: hamburger helper. Result: False
# 119) Keyword: Cauliflower. Result: False
# 120) Keyword: cupcake. Result: True
# 121) Keyword: pea plant. Result: False
# 122) Keyword: Tomato. Result: True
# 123) Keyword: martini. Result: False
# 124) Keyword: apricot tree. Result: True
# 125) Keyword: sushi. Result: False
# 126) Keyword: applesauce. Result: True
# 127) Keyword: salt shaker. Result: False
# 128) Keyword: tiramisu. Result: True
# 129) Keyword: Ice Water. Result: False
# 130) Keyword: Cereal. Result: False
# 131) Keyword: grape. Result: True
# 132) Keyword: Brownies. Result: True
# 133) Keyword: duckweed. Result: False
# 134) Keyword: Vanilla Extract. Result: False
# 135) Keyword: peppermint. Result: False
# 136) Keyword: Iced coffee. Result: False
# 137) Keyword: soup. Result: False
# 138) Keyword: vegetarian chili. Result: False
# 139) Keyword: potato chip. Result: False
# 140) Keyword: Unleavened Bread. Result: False
# 141) Keyword: Energy drink. Result: True
# 142) Keyword: ramen. Result: False
# 143) Keyword: Quesadilla. Result: False
# 144) Keyword: aperol spritz. Result: False
# 145) Keyword: Soda. Result: True
# 146) Keyword: syrup. Result: True
# 147) Keyword: Earl Grey tea. Result: False
# 148) Keyword: Radish. Result: False
# 149) Keyword: unripe banana. Result: False
# 150) Keyword: fudge brownie. Result: True
# 151) Keyword: hot tea. Result: False
# 152) Keyword: Vegetable. Result: False
# 153) Keyword: parsley. Result: False
# 154) Keyword: honey. Result: True
# 155) Keyword: leaf. Result: False
# 156) Keyword: Salad Dressing. Result: False
# 157) Keyword: yarrow. Result: False
# 158) Keyword: French toast. Result: True
# 159) Keyword: seagrass. Result: False
# 160) Keyword: ham. Result: False
# 161) Keyword: Edamame. Result: False
# 162) Keyword: mango. Result: True
# 163) Keyword: Hash browns. Result: False
# 164) Keyword: Water Buffalo. Result: False
# 165) Keyword: Protein Shakes. Result: False
# 166) Keyword: Edible flowers. Result: False
# 167) Keyword: Cheesecake. Result: True
# 168) Keyword: yule log. Result: False
# 169) Keyword: agave plant. Result: False
# 170) Keyword: Sugar packet. Result: True
# 171) Keyword: doughnut. Result: True
# 172) Keyword: gelatin. Result: False
# 173) Keyword: lemon wedge. Result: False
# 174) Keyword: jello. Result: True
# 175) Keyword: bamboo leaf. Result: False
# 176) Keyword: Mushroom. Result: False
# 177) Keyword: frappe. Result: False
# 178) Keyword: peach tree. Result: True
# 179) Keyword: Potato. Result: False
# 180) Keyword: apple. Result: True
# 181) Keyword: Green beans. Result: False
# 182) Keyword: Popcorn. Result: False
# 183) Keyword: Coffee grounds. Result: False
# 184) Keyword: Apple pie. Result: True
# 185) Keyword: ketchup. Result: False
# 186) Keyword: Rice pudding. Result: True
# 187) Keyword: fennel. Result: False
# 188) Keyword: Soybeans. Result: False
# 189) Keyword: grape juice. Result: True
# 190) Keyword: dill pickle. Result: False
# 191) Keyword: vegan chocolate. Result: True
# 192) Keyword: ice tea. Result: False
# 193) Keyword: cotton candy. Result: True
# 194) Keyword: tea leaf. Result: False
# 195) Keyword: honeydew. Result: True
# 196) Keyword: Bird seed. Result: False
# 197) Keyword: Water. Result: False
# 198) Keyword: fanta. Result: True
# 199) Keyword: ice pop. Result: True
# 200) Keyword: coke. Result: True
# 201) Keyword: yeast. Result: False
# 202) Keyword: Orange zest. Result: False
# 203) Keyword: Dandelion. Result: False
# 204) Keyword: Frappuccino. Result: True
# 205) Keyword: Hazelnut. Result: False
# 206) Keyword: flour. Result: False
# 207) Keyword: Fortune cookie. Result: True
# 208) Keyword: tongue. Result: False
# 209) Keyword: Cream cheese. Result: False
# 210) Keyword: meatloaf. Result: False
# 211) Keyword: Marshmallow. Result: True
# 212) Keyword: seltzer. Result: False
# 213) Keyword: acorn. Result: False
# 214) Keyword: Pumpkin pie. Result: True
# 215) Keyword: rose. Result: False
# 216) Keyword: gin. Result: False
# 217) Keyword: protein shake. Result: True
# 218) Keyword: lemon zest. Result: False
# 219) Keyword: pear tree. Result: True
# 220) Keyword: Roots. Result: False
# Percentage: 0.3409090909090909%	Score: 0.15909090909090912
#
# Question: Is it a type of fruit or made from fruit?
# Num keywords in test set: 220
# 1) Keyword: Grape Vine. Result: True
# 2) Keyword: banana. Result: True
# 3) Keyword: pudding. Result: False
# 4) Keyword: granola. Result: False
# 5) Keyword: fudge brownie. Result: False
# 6) Keyword: fennel. Result: False
# 7) Keyword: Tomato. Result: True
# 8) Keyword: tea leaf. Result: False
# 9) Keyword: brussel sprout. Result: False
# 10) Keyword: frappe. Result: False
# 11) Keyword: Protein Shakes. Result: False
# 12) Keyword: hummus. Result: False
# 13) Keyword: doughnut. Result: False
# 14) Keyword: mesquite tree. Result: False
# 15) Keyword: lemon juice. Result: True
# 16) Keyword: bean. Result: False
# 17) Keyword: Honeybee. Result: False
# 18) Keyword: yeast. Result: False
# 19) Keyword: orange juice. Result: True
# 20) Keyword: Bacteria. Result: False
# 21) Keyword: agave plant. Result: False
# 22) Keyword: bamboo. Result: False
# 23) Keyword: Red velvet cake. Result: False
# 24) Keyword: almond milk. Result: False
# 25) Keyword: Hash browns. Result: False
# 26) Keyword: rose. Result: False
# 27) Keyword: soup. Result: False
# 28) Keyword: grape juice. Result: True
# 29) Keyword: acacia. Result: False
# 30) Keyword: Tofu. Result: False
# 31) Keyword: Soda. Result: False
# 32) Keyword: tiramisu. Result: False
# 33) Keyword: Donuts. Result: False
# 34) Keyword: Bird seed. Result: False
# 35) Keyword: Quesadilla. Result: False
# 36) Keyword: Udon Noodles. Result: False
# 37) Keyword: Edible flowers. Result: False
# 38) Keyword: Chocolate cake. Result: False
# 39) Keyword: Radish. Result: False
# 40) Keyword: cereal bar. Result: False
# 41) Keyword: orange slice. Result: True
# 42) Keyword: Green beans. Result: False
# 43) Keyword: raisin. Result: True
# 44) Keyword: coconut. Result: True
# 45) Keyword: alfalfa. Result: False
# 46) Keyword: steak. Result: False
# 47) Keyword: cupcake. Result: False
# 48) Keyword: Hibiscus. Result: False
# 49) Keyword: Popcorn. Result: False
# 50) Keyword: fruit cup. Result: True
# 51) Keyword: pea plant. Result: False
# 52) Keyword: Apple pie. Result: True
# 53) Keyword: coffee ground. Result: False
# 54) Keyword: ice pop. Result: True
# 55) Keyword: Roots. Result: False
# 56) Keyword: rainbow cake. Result: False
# 57) Keyword: salt shaker. Result: False
# 58) Keyword: acorn. Result: True
# 59) Keyword: Relish. Result: False
# 60) Keyword: rhubarb. Result: False
# 61) Keyword: maple tree. Result: False
# 62) Keyword: Red wine. Result: False
# 63) Keyword: apricot tree. Result: False
# 64) Keyword: anchovy. Result: False
# 65) Keyword: ricotta. Result: False
# 66) Keyword: parsley. Result: False
# 67) Keyword: Agave. Result: False
# 68) Keyword: sweet tea. Result: False
# 69) Keyword: sauerkraut. Result: False
# 70) Keyword: tongue. Result: False
# 71) Keyword: honeycrisp. Result: True
# 72) Keyword: meatloaf. Result: False
# 73) Keyword: Veggie Burger. Result: False
# 74) Keyword: vietnamese coffee. Result: False
# 75) Keyword: raspberry. Result: True
# 76) Keyword: Marshmallow. Result: False
# 77) Keyword: Cauliflower. Result: False
# 78) Keyword: Coffee grounds. Result: False
# 79) Keyword: duckweed. Result: False
# 80) Keyword: rosemary. Result: False
# 81) Keyword: Iced coffee. Result: False
# 82) Keyword: hamburger helper. Result: False
# 83) Keyword: Croissant. Result: False
# 84) Keyword: pineapple. Result: True
# 85) Keyword: martini. Result: False
# 86) Keyword: gelatin. Result: False
# 87) Keyword: cilantro. Result: False
# 88) Keyword: Cantaloupe. Result: True
# 89) Keyword: squid. Result: False
# 90) Keyword: Kale smoothie. Result: False
# 91) Keyword: pumpkin. Result: True
# 92) Keyword: jam. Result: True
# 93) Keyword: dill pickle. Result: False
# 94) Keyword: Salad Dressing. Result: False
# 95) Keyword: leaf. Result: False
# 96) Keyword: cherry tree. Result: True
# 97) Keyword: ramen. Result: False
# 98) Keyword: Cheesecake. Result: False
# 99) Keyword: pea soup. Result: False
# 100) Keyword: Fortune cookie. Result: False
# 101) Keyword: chocolate bar. Result: False
# 102) Keyword: juice box. Result: True
# 103) Keyword: water chestnut. Result: False
# 104) Keyword: Water. Result: False
# 105) Keyword: wild garlic. Result: False
# 106) Keyword: zinc. Result: False
# 107) Keyword: honeydew. Result: True
# 108) Keyword: honeydew melon. Result: True
# 109) Keyword: protein shake. Result: False
# 110) Keyword: kheer. Result: False
# 111) Keyword: Scones. Result: False
# 112) Keyword: cake. Result: False
# 113) Keyword: bamboo leaf. Result: False
# 114) Keyword: peach tree. Result: False
# 115) Keyword: pear tree. Result: True
# 116) Keyword: chutney. Result: True
# 117) Keyword: Muffin. Result: False
# 118) Keyword: melon. Result: True
# 119) Keyword: Grapefruit. Result: True
# 120) Keyword: jello. Result: False
# 121) Keyword: ice tea. Result: False
# 122) Keyword: frozen waffle. Result: False
# 123) Keyword: fanta. Result: False
# 124) Keyword: jasmine. Result: False
# 125) Keyword: Orange tree. Result: False
# 126) Keyword: hot tea. Result: False
# 127) Keyword: Earl Grey tea. Result: False
# 128) Keyword: flour. Result: False
# 129) Keyword: Nachos. Result: False
# 130) Keyword: French toast. Result: False
# 131) Keyword: coke. Result: False
# 132) Keyword: ginger. Result: False
# 133) Keyword: applesauce. Result: True
# 134) Keyword: lemon zest. Result: False
# 135) Keyword: wonton soup. Result: False
# 136) Keyword: Bread pudding. Result: False
# 137) Keyword: ginger ale. Result: False
# 138) Keyword: Dandelion. Result: False
# 139) Keyword: wonton. Result: False
# 140) Keyword: Water Buffalo. Result: False
# 141) Keyword: gin. Result: False
# 142) Keyword: wing. Result: False
# 143) Keyword: oatmeal cookie. Result: False
# 144) Keyword: Cereal. Result: False
# 145) Keyword: potato chip. Result: False
# 146) Keyword: Cinnamon roll. Result: False
# 147) Keyword: seagrass. Result: False
# 148) Keyword: crayfish. Result: False
# 149) Keyword: ketchup. Result: False
# 150) Keyword: vegan chocolate. Result: False
# 151) Keyword: Latte. Result: False
# 152) Keyword: Unleavened Bread. Result: False
# 153) Keyword: bean plant. Result: False
# 154) Keyword: Orange zest. Result: False
# 155) Keyword: unripe banana. Result: True
# 156) Keyword: jaffa cake. Result: False
# 157) Keyword: Habanero pepper. Result: True
# 158) Keyword: Coffee beans. Result: True
# 159) Keyword: lemon wedge. Result: True
# 160) Keyword: cannoli. Result: False
# 161) Keyword: cotton candy. Result: False
# 162) Keyword: Olive Oil. Result: True
# 163) Keyword: green alga. Result: False
# 164) Keyword: bacon. Result: False
# 165) Keyword: grape. Result: True
# 166) Keyword: honey. Result: False
# 167) Keyword: Soybeans. Result: False
# 168) Keyword: pomegranate. Result: True
# 169) Keyword: Edamame. Result: False
# 170) Keyword: Vanilla Extract. Result: False
# 171) Keyword: Protein bar. Result: False
# 172) Keyword: ham. Result: False
# 173) Keyword: Hot dog. Result: False
# 174) Keyword: swedish fish. Result: False
# 175) Keyword: rooster. Result: False
# 176) Keyword: Pumpkin pie. Result: False
# 177) Keyword: squash. Result: True
# 178) Keyword: Snacks. Result: False
# 179) Keyword: broth. Result: False
# 180) Keyword: rice krispie. Result: False
# 181) Keyword: Baguette. Result: False
# 182) Keyword: aperol spritz. Result: False
# 183) Keyword: seltzer. Result: False
# 184) Keyword: goose. Result: False
# 185) Keyword: Ice Water. Result: False
# 186) Keyword: smoothie. Result: True
# 187) Keyword: apple. Result: True
# 188) Keyword: oyster. Result: False
# 189) Keyword: mango. Result: True
# 190) Keyword: Yogurt. Result: False
# 191) Keyword: lime. Result: True
# 192) Keyword: Frappuccino. Result: False
# 193) Keyword: Bottled Water. Result: False
# 194) Keyword: vegetarian chili. Result: False
# 195) Keyword: lemon balm. Result: False
# 196) Keyword: Cream cheese. Result: False
# 197) Keyword: Potato. Result: False
# 198) Keyword: yarrow. Result: False
# 199) Keyword: Sugar packet. Result: False
# 200) Keyword: peppermint. Result: False
# 201) Keyword: peanut butter. Result: False
# 202) Keyword: syrup. Result: False
# 203) Keyword: Brownies. Result: False
# 204) Keyword: kiwifruit. Result: True
# 205) Keyword: sushi. Result: False
# 206) Keyword: Finger food. Result: False
# 207) Keyword: frozen meat. Result: False
# 208) Keyword: yule log. Result: False
# 209) Keyword: Fried rice. Result: False
# 210) Keyword: Rice pudding. Result: False
# 211) Keyword: butter. Result: False
# 212) Keyword: Orange peel. Result: True
# 213) Keyword: Mushroom. Result: False
# 214) Keyword: Hazelnut. Result: False
# 215) Keyword: Vegetable. Result: False
# 216) Keyword: noodle. Result: False
# 217) Keyword: Fungi. Result: False
# 218) Keyword: kelp. Result: False
# 219) Keyword: Energy drink. Result: False
# 220) Keyword: tomato plant. Result: True
# Percentage: 0.19545454545454546%	Score: 0.30454545454545456
#
# Question: Is it a processed or packaged food product?
# Num keywords in test set: 220
# 1) Keyword: jaffa cake. Result: True
# 2) Keyword: Pumpkin pie. Result: False
# 3) Keyword: agave plant. Result: False
# 4) Keyword: tiramisu. Result: False
# 5) Keyword: Hibiscus. Result: False
# 6) Keyword: goose. Result: False
# 7) Keyword: kiwifruit. Result: False
# 8) Keyword: fennel. Result: False
# 9) Keyword: green alga. Result: False
# 10) Keyword: Cheesecake. Result: False
# 11) Keyword: rooster. Result: False
# 12) Keyword: Hot dog. Result: True
# 13) Keyword: Salad Dressing. Result: True
# 14) Keyword: lemon wedge. Result: False
# 15) Keyword: Orange peel. Result: False
# 16) Keyword: Udon Noodles. Result: False
# 17) Keyword: Orange tree. Result: False
# 18) Keyword: Vanilla Extract. Result: True
# 19) Keyword: hot tea. Result: False
# 20) Keyword: lemon balm. Result: False
# ...
# 27) Keyword: garment rack. Result: False
# 28) Keyword: porcupine. Result: False
# 29) Keyword: shoelace. Result: False
# 30) Keyword: curling iron. Result: False
# 31) Keyword: Hair Dryer. Result: False
# 32) Keyword: Gas Mask. Result: False
# 33) Keyword: concentrator. Result: False
# 34) Keyword: phone case. Result: False
# 35) Keyword: Cat carrier. Result: False
# 36) Keyword: lace. Result: False
# 37) Keyword: gown. Result: False
# 38) Keyword: Scratching posts. Result: False
# 39) Keyword: pilates reformer. Result: False
# 40) Keyword: angelfish. Result: False
# 41) Keyword: Shower caddy. Result: False
# 42) Keyword: garter. Result: True
# 43) Keyword: sash. Result: False
# 44) Keyword: enamel. Result: False
# 45) Keyword: piranha. Result: False
# 46) Keyword: northern mockingbird. Result: False
# 47) Keyword: punching bag. Result: False
# 48) Keyword: parts cleaner. Result: False
# 49) Keyword: scrubber. Result: False
# 50) Keyword: lace dress. Result: False
# 51) Keyword: Dumbbells. Result: False
# 52) Keyword: clutch bag. Result: False
# 53) Keyword: Necklace. Result: True
# 54) Keyword: car seat. Result: False
# 55) Keyword: centerpiece. Result: False
# 56) Keyword: candle holder. Result: False
# 57) Keyword: adjustable bench. Result: False
# 58) Keyword: christmas tree. Result: False
# 59) Keyword: velvet rug. Result: False
# 60) Keyword: Nail Polish Remover. Result: False
# 61) Keyword: pitcher. Result: False
# 62) Keyword: bald eagle. Result: False
# 63) Keyword: casket. Result: False
# 64) Keyword: coffin. Result: False
# 65) Keyword: woodpecker. Result: False
# 66) Keyword: salt scrub. Result: False
# 67) Keyword: inverter. Result: False
# 68) Keyword: Barber Chair. Result: False
# 69) Keyword: wire hanger. Result: False
# 70) Keyword: Hamstring Curl Machine. Result: False
# 71) Keyword: Suitcase. Result: False
# 72) Keyword: aquarium salt. Result: False
# 73) Keyword: Jewelry Box. Result: False
# 74) Keyword: Packing peanuts. Result: False
# 75) Keyword: pillowtop. Result: False
# 76) Keyword: Engravings. Result: False
# 77) Keyword: weasel. Result: False
# 78) Keyword: oil filter. Result: False
# 79) Keyword: Ear protection. Result: False
# 80) Keyword: Soap Suds. Result: False
# 81) Keyword: Milling machine. Result: False
# 82) Keyword: handcuff. Result: False
# 83) Keyword: Fitness tracker. Result: False
# 84) Keyword: gas cap. Result: False
# 85) Keyword: Vase. Result: False
# 86) Keyword: Facial Toner. Result: False
# 87) Keyword: eruption. Result: False
# 88) Keyword: lifting belt. Result: False
# 89) Keyword: shower cap. Result: False
# 90) Keyword: earring. Result: True
# 91) Keyword: Stain Remover. Result: False
# 92) Keyword: catalytic converter. Result: False
# 93) Keyword: ankle bracelet. Result: True
# 94) Keyword: Litter scooper. Result: False
# 95) Keyword: wedding ring. Result: True
# 96) Keyword: toilet brush. Result: False
# 97) Keyword: lace top. Result: False
# 98) Keyword: relief valve. Result: False
# 99) Keyword: bank statement. Result: False
# 100) Keyword: lug. Result: False
# 101) Keyword: fuel filter. Result: False
# 102) Keyword: jane. Result: False
# 103) Keyword: house key. Result: False
# 104) Keyword: miniskirt. Result: False
# 105) Keyword: Lathe. Result: False
# 106) Keyword: electric toothbrush. Result: False
# 107) Keyword: Dog shampoo. Result: False
# 108) Keyword: coal crusher. Result: False
# 109) Keyword: steam iron. Result: False
# 110) Keyword: sumantri. Result: False
# 111) Keyword: Perfume. Result: False
# 112) Keyword: Muffler. Result: False
# 113) Keyword: Wrist Weights. Result: False
# 114) Keyword: Washing machine. Result: False
# 115) Keyword: vintage clock. Result: False
# 116) Keyword: dust jacket. Result: False
# 117) Keyword: Jumper Cables. Result: False
# 118) Keyword: nose ring. Result: True
# 119) Keyword: buckle. Result: True
# 120) Keyword: Stair Stepper. Result: False
# 121) Keyword: Free Weights. Result: False
# 122) Keyword: arrival board. Result: False
# 123) Keyword: woolen blanket. Result: False
# 124) Keyword: balance beam. Result: False
# 125) Keyword: laundry basket. Result: False
# 126) Keyword: Menorah. Result: False
# 127) Keyword: Water Heater. Result: False
# 128) Keyword: flea. Result: False
# 129) Keyword: pillowcase. Result: False
# 130) Keyword: plunger. Result: False
# 131) Keyword: smith machine. Result: False
# 132) Keyword: fabric roll. Result: False
# 133) Keyword: dog tag. Result: True
# 134) Keyword: Parallel bars. Result: False
# 135) Keyword: hair clipper. Result: False
# 136) Keyword: nile monitor. Result: False
# 137) Keyword: Pallet Jack. Result: False
# 138) Keyword: Handbag. Result: False
# 139) Keyword: Yoga mat. Result: False
# 140) Keyword: ukulele case. Result: False
# 141) Keyword: moving walkway. Result: False
# 142) Keyword: bracelet. Result: True
# 143) Keyword: Duvet. Result: False
# 144) Keyword: seedling tray. Result: False
# 145) Keyword: travel pillow. Result: False
# 146) Keyword: damselfish. Result: False
# 147) Keyword: weightlifting belt. Result: False
# 148) Keyword: engine oil. Result: False
# 149) Keyword: engagement ring. Result: True
# 150) Keyword: Pacifier. Result: False
# 151) Keyword: Gravity. Result: False
# 152) Keyword: throw rug. Result: False
# 153) Keyword: Rowing machines. Result: False
# 154) Keyword: sandhill crane. Result: False
# 155) Keyword: hairspray can. Result: False
# 156) Keyword: fire helmet. Result: False
# 157) Keyword: barbell collar. Result: False
# 158) Keyword: clog. Result: False
# 159) Keyword: dresser. Result: False
# 160) Keyword: Interstate. Result: False
# 161) Keyword: Furniture polish. Result: False
# 162) Keyword: conditioner. Result: False
# 163) Keyword: foam roller. Result: False
# 164) Keyword: Shin Guards. Result: False
# 165) Keyword: tire iron. Result: False
# 166) Keyword: polar bear. Result: False
# 167) Keyword: Toothpaste. Result: False
# 168) Keyword: mount saint lias. Result: False
# 169) Keyword: gift box. Result: False
# 170) Keyword: exercise mat. Result: False
# 171) Keyword: straightening iron. Result: False
# 172) Keyword: Turn signal. Result: False
# 173) Keyword: tire inflator. Result: False
# 174) Keyword: Dish soap. Result: False
# 175) Keyword: electric razor. Result: False
# 176) Keyword: seam. Result: False
# 177) Keyword: garment steamer. Result: False
# 178) Keyword: Gym Mats. Result: False
# 179) Keyword: seahorse. Result: False
# 180) Keyword: parrotfish. Result: False
# 181) Keyword: deposit slip. Result: False
# 182) Keyword: bunk bed. Result: False
# 183) Keyword: leopard. Result: False
# 184) Keyword: velvet ribbon. Result: False
# 185) Keyword: towel basket. Result: False
# 186) Keyword: baggage conveyor. Result: False
# 187) Keyword: ottoman. Result: False
# 188) Keyword: Toiletries bag. Result: False
# 189) Keyword: perfume bottle. Result: False
# 190) Keyword: sea turtle. Result: False
# 191) Keyword: lint trap. Result: False
# 192) Keyword: earplug. Result: False
# 193) Keyword: Vanity mirror. Result: False
# 194) Keyword: manicure set. Result: False
# 195) Keyword: end table. Result: False
# 196) Keyword: ruby. Result: False
# 197) Keyword: merchandise rack. Result: False
# 198) Keyword: utility belt. Result: False
# 199) Keyword: Rags. Result: False
# 200) Keyword: battery bank. Result: False
# 201) Keyword: slit. Result: False
# 202) Keyword: Elliptical Trainers. Result: False
# 203) Keyword: cuticle. Result: False
# 204) Keyword: shower mat. Result: False
# 205) Keyword: Bath Mat. Result: False
# 206) Keyword: Luggage. Result: False
# 207) Keyword: tire gauge. Result: False
# 208) Keyword: possum. Result: False
# 209) Keyword: dashboard camera. Result: False
# 210) Keyword: sorting machine. Result: False
# Percentage: 0.05714285714285714%	Score: 0.44285714285714284
#
# Question: Is it primarily used for personal grooming?
# Num keywords in test set: 210
# 1) Keyword: hair clipper. Result: True
# 2) Keyword: bank statement. Result: False
# 3) Keyword: sandhill crane. Result: False
# 4) Keyword: sea turtle. Result: False
# 5) Keyword: lug. Result: False
# 6) Keyword: Washing machine. Result: False
# 7) Keyword: phone case. Result: False
# 8) Keyword: Vanity mirror. Result: True
# 9) Keyword: punching bag. Result: False
# 10) Keyword: velvet rug. Result: False
# 11) Keyword: wedding ring. Result: False
# 12) Keyword: arrival board. Result: False
# 13) Keyword: seam. Result: False
# 14) Keyword: ruby. Result: False
# 15) Keyword: velvet ribbon. Result: False
# 16) Keyword: Nail Polish Remover. Result: True
# 17) Keyword: shower mat. Result: False
# 18) Keyword: Reptile. Result: False
# 19) Keyword: gift box. Result: False
# 20) Keyword: earplug. Result: False
# 21) Keyword: Water Heater. Result: False
# 22) Keyword: Ear protection. Result: False
# 23) Keyword: eruption. Result: False
# 24) Keyword: Jumper Cables. Result: False
# 25) Keyword: Advertisement. Result: False
# 26) Keyword: power meter. Result: False
# 27) Keyword: christmas tree. Result: False
# 28) Keyword: battery bank. Result: False
# 29) Keyword: perfume bottle. Result: True
# 30) Keyword: lace top. Result: False
# 31) Keyword: bedspread. Result: False
# 32) Keyword: travel pillow. Result: False
# 33) Keyword: barbell collar. Result: False
# 34) Keyword: Barber Chair. Result: True
# 35) Keyword: pillowcase. Result: False
# 36) Keyword: shoelace. Result: False
# 37) Keyword: fire helmet. Result: False
# 38) Keyword: hairspray can. Result: True
# 39) Keyword: baggage conveyor. Result: False
# 40) Keyword: Dish soap. Result: False
# 41) Keyword: damselfish. Result: False
# 42) Keyword: trinket box. Result: False
# 43) Keyword: balance beam. Result: False
# 44) Keyword: relief valve. Result: False
# 45) Keyword: bald eagle. Result: False
# 46) Keyword: enamel. Result: False
# 47) Keyword: adjustable bench. Result: False
# 48) Keyword: electric razor. Result: True
# 49) Keyword: Duvet. Result: False
# 50) Keyword: scrubber. Result: False
# 51) Keyword: sorting machine. Result: False
# 52) Keyword: workout log. Result: False
# 53) Keyword: Toiletries bag. Result: True
# 54) Keyword: cuticle. Result: True
# 55) Keyword: Furniture polish. Result: False
# 56) Keyword: bunk bed. Result: False
# 57) Keyword: Luggage. Result: False
# 58) Keyword: fuel filter. Result: False
# 59) Keyword: piranha. Result: False
# 60) Keyword: tire gauge. Result: False
# 61) Keyword: nile monitor. Result: False
# 62) Keyword: seedling tray. Result: False
# 63) Keyword: Gym Mats. Result: False
# 64) Keyword: ignition system. Result: False
# 65) Keyword: Engravings. Result: False
# 66) Keyword: seahorse. Result: False
# 67) Keyword: salt scrub. Result: True
# 68) Keyword: angelfish. Result: False
# 69) Keyword: ukulele case. Result: False
# 70) Keyword: Pallet Jack. Result: False
# 71) Keyword: Komodo dragon. Result: False
# 72) Keyword: Pacifier. Result: False
# 73) Keyword: Vase. Result: False
# 74) Keyword: woodpecker. Result: False
# 75) Keyword: Wrist Weights. Result: False
# 76) Keyword: Litter scooper. Result: False
# 77) Keyword: Bath Mat. Result: False
# 78) Keyword: engagement ring. Result: False
# 79) Keyword: weasel. Result: False
# 80) Keyword: weight plate. Result: False
# 81) Keyword: Milling machine. Result: False
# 82) Keyword: Hair Dryer. Result: True
# 83) Keyword: Stain Remover. Result: False
# 84) Keyword: shower cap. Result: True
# 85) Keyword: conditioner. Result: True
# 86) Keyword: moving walkway. Result: False
# 87) Keyword: pilates reformer. Result: False
# 88) Keyword: pillow sham. Result: False
# 89) Keyword: Parallel bars. Result: False
# 90) Keyword: Rowing machines. Result: False
# 91) Keyword: toilet brush. Result: False
# 92) Keyword: medallion. Result: False
# 93) Keyword: candle holder. Result: False
# 94) Keyword: Bed frame. Result: False
# 95) Keyword: Hairbrush. Result: True
# 96) Keyword: dashboard camera. Result: False
# 97) Keyword: northern mockingbird. Result: False
# 98) Keyword: Dumbbells. Result: False
# 99) Keyword: duvet cover. Result: False
# 100) Keyword: manicure set. Result: True
# 101) Keyword: Stair Stepper. Result: False
# 102) Keyword: parts cleaner. Result: False
# 103) Keyword: nose ring. Result: False
# 104) Keyword: possum. Result: False
# 105) Keyword: lace. Result: False
# 106) Keyword: steam iron. Result: True
# 107) Keyword: pitcher. Result: False
# 108) Keyword: Elliptical Trainers. Result: False
# 109) Keyword: fabric roll. Result: False
# 110) Keyword: slit. Result: False
# 111) Keyword: tire inflator. Result: False
# 112) Keyword: Menorah. Result: False
# 113) Keyword: headboard. Result: False
# 114) Keyword: lint trap. Result: False
# 115) Keyword: casket. Result: False
# 116) Keyword: plunger. Result: False
# 117) Keyword: Toothpaste. Result: True
# 118) Keyword: sumantri. Result: False
# 119) Keyword: Taser. Result: False
# 120) Keyword: garment rack. Result: False
# 121) Keyword: yoga block. Result: False
# 122) Keyword: bracelet. Result: False
# 123) Keyword: sash. Result: False
# 124) Keyword: oil filter. Result: False
# 125) Keyword: parrotfish. Result: False
# 126) Keyword: lace dress. Result: False
# 127) Keyword: laundry basket. Result: False
# 128) Keyword: foam roller. Result: False
# 129) Keyword: Free Weights. Result: False
# 130) Keyword: coal crusher. Result: False
# 131) Keyword: Cat carrier. Result: False
# 132) Keyword: Hamster wheel. Result: False
# 133) Keyword: Suitcase. Result: False
# 134) Keyword: Fitness tracker. Result: False
# 135) Keyword: garter. Result: False
# 136) Keyword: dog tag. Result: False
# 137) Keyword: pillowtop. Result: False
# 138) Keyword: inverter. Result: False
# 139) Keyword: lifting belt. Result: False
# 140) Keyword: Turn signal. Result: False
# 141) Keyword: Scratching posts. Result: False
# 142) Keyword: tire iron. Result: False
# 143) Keyword: catalytic converter. Result: False
# 144) Keyword: purse. Result: False
# 145) Keyword: gas cap. Result: False
# 146) Keyword: Gravity. Result: False
# 147) Keyword: utility belt. Result: False
# 148) Keyword: gown. Result: False
# 149) Keyword: flea. Result: False
# 150) Keyword: Perfume. Result: True
# 151) Keyword: tassel. Result: False
# 152) Keyword: handcuff. Result: False
# 153) Keyword: house key. Result: False
# 154) Keyword: curling iron. Result: True
# 155) Keyword: eye mask. Result: False
# 156) Keyword: Packing peanuts. Result: False
# 157) Keyword: mount saint lias. Result: False
# 158) Keyword: dresser. Result: False
# 159) Keyword: porcupine. Result: False
# 160) Keyword: Lathe. Result: False
# 161) Keyword: weightlifting belt. Result: False
# 162) Keyword: Rags. Result: False
# 163) Keyword: wire hanger. Result: False
# 164) Keyword: electric toothbrush. Result: True
# 165) Keyword: steering wheel. Result: False
# 166) Keyword: Gas Mask. Result: False
# 167) Keyword: towel basket. Result: False
# 168) Keyword: Seed packet. Result: False
# 169) Keyword: deposit slip. Result: False
# 170) Keyword: buckle. Result: False
# 171) Keyword: vintage clock. Result: False
# 172) Keyword: Hamstring Curl Machine. Result: False
# 173) Keyword: polar bear. Result: False
# 174) Keyword: coffin. Result: False
# 175) Keyword: engine oil. Result: False
# 176) Keyword: woolen blanket. Result: False
# 177) Keyword: Necklace. Result: False
# 178) Keyword: straightening iron. Result: True
# 179) Keyword: Jewelry Box. Result: False
# 180) Keyword: ankle bracelet. Result: False
# 181) Keyword: merchandise rack. Result: False
# 182) Keyword: Yoga mat. Result: False
# 183) Keyword: throw rug. Result: False
# 184) Keyword: Dog shampoo. Result: False
# 185) Keyword: Interstate. Result: False
# 186) Keyword: clutch bag. Result: False
# 187) Keyword: miniskirt. Result: False
# 188) Keyword: garment steamer. Result: False
# 189) Keyword: Cash Register. Result: False
# 190) Keyword: clog. Result: False
# 191) Keyword: car seat. Result: False
# 192) Keyword: end table. Result: False
# 193) Keyword: concentrator. Result: False
# 194) Keyword: smith machine. Result: False
# 195) Keyword: dust jacket. Result: False
# 196) Keyword: aquarium salt. Result: False
# 197) Keyword: king snake. Result: False
# 198) Keyword: Handbag. Result: False
# 199) Keyword: Muffler. Result: False
# 200) Keyword: jane. Result: False
# 201) Keyword: Shower caddy. Result: True
# 202) Keyword: exercise mat. Result: False
# 203) Keyword: centerpiece. Result: False
# 204) Keyword: Facial Toner. Result: False
# 205) Keyword: Ironing Board. Result: False
# 206) Keyword: Soap Suds. Result: False
# 207) Keyword: earring. Result: False
# 208) Keyword: ottoman. Result: False
# 209) Keyword: Shin Guards. Result: False
# 210) Keyword: leopard. Result: False
# Percentage: 0.10476190476190476%	Score: 0.3952380952380952

# %%
def add_empty_leaves(node):
    if not node.no_branch and not node.yes_branch:
        node.no_branch = DecisionNode()
        node.yes_branch = DecisionNode()
        return 
    add_empty_leaves(node.no_branch) 
    add_empty_leaves(node.yes_branch)

# %%
add_empty_leaves(test_tree)

# %%
test_tree.print_tree()
# Out:
# -- Is it related to food, beverages or cooking?
#   |-- Is it an edible item?
#   |  |-- Is it primarily sweet?
#   |  |  |-- Is it typically consumed as a dessert?
#   |  |  |  |-- Can it be found in a liquid or semi-liquid form?
#   |  |  |  |  |-- Is it fruit-based?
#   |  |  |  |  |  |-- Does it come from a tropical region?
#   |  |  |  |  |  |  |-- *
#   |  |  |  |  |  |   -- *
#   |  |  |  |  |   -- Is it dairy-based?
#   |  |  |  |  |     |-- *
#   |  |  |  |  |      -- *
#   |  |  |  |   -- Is it typically baked?
#   |  |  |  |     |-- Is it commonly decorated with frosting or icing?
#   |  |  |  |     |  |-- *
#   |  |  |  |     |   -- *
#   |  |  |  |      -- Is it predominantly eaten cold or frozen?
#   |  |  |  |        |-- *
#   |  |  |  |         -- *
#   |  |  |   -- Is it a beverage?
#   |  |  |     |-- Does it contain caffeine?
#   |  |  |     |  |-- Does it commonly come in a can?
#   |  |  |     |  |  |-- *
#   |  |  |     |  |   -- *
#   |  |  |     |   -- Does it have fruit juice as a primary ingredient?
#   |  |  |     |     |-- *
#   |  |  |     |      -- *
#   |  |  |      -- Is it a plant or a part of a plant?
#   |  |  |        |-- Does it typically grow on a vine?
#   |  |  |        |  |-- *
#   |  |  |        |   -- *
#   |  |  |         -- Is it more commonly found in individual packaging?
#   |  |  |           |-- *
#   |  |  |            -- *
#   |  |   -- Is it a plant or plant-based product?
#   |  |     |-- Is it typically consumed whole or in a minimally processed form?
#   |  |     |  |-- Is it typically consumed raw?
#   |  |     |  |  |-- Is it primarily used as a garnish or herb?
#   |  |     |  |  |  |-- *
#   |  |     |  |  |   -- *
#   |  |     |  |   -- Is it a type of vegetable?
#   |  |     |  |     |-- *
#   |  |     |  |      -- *
#   |  |     |   -- Is it commonly used as an ingredient rather than consumed on its own?
#   |  |     |     |-- Is it commonly used in liquid form?
#   |  |     |     |  |-- *
#   |  |     |     |   -- *
#   |  |     |      -- Is it a beverage or associated with beverages?
#   |  |     |        |-- *
#   |  |     |         -- *
#   |  |      -- Is it commonly served hot?
#   |  |        |-- Does it contain meat?
#   |  |        |  |-- Is it usually served with bread or a bun?
#   |  |        |  |  |-- *
#   |  |        |  |   -- *
#   |  |        |   -- Is it a solid food item?
#   |  |        |     |-- *
#   |  |        |      -- *
#   |  |         -- Is it derived from or contains an animal product?
#   |  |           |-- Is it primarily used as an ingredient rather than consumed on its own?
#   |  |           |  |-- *
#   |  |           |   -- *
#   |  |            -- Is it a type of beverage?
#   |  |              |-- *
#   |  |               -- *
#   |   -- Is it typically found in a residential kitchen?
#   |     |-- Is it primarily made of metal?
#   |     |  |-- Is it associated with beverages?
#   |     |  |  |-- Can it be held in one hand?
#   |     |  |  |  |-- Is it typically used during the preparation of beverages?
#   |     |  |  |  |  |-- *
#   |     |  |  |  |   -- *
#   |     |  |  |   -- Does it have a built-in water reservoir?
#   |     |  |  |     |-- *
#   |     |  |  |      -- *
#   |     |  |   -- Is it used in baking or cooking in an oven?
#   |     |  |     |-- Is it flat and used to support or hold items for baking?
#   |     |  |     |  |-- *
#   |     |  |     |   -- *
#   |     |  |      -- Is it primarily a cutting tool?
#   |     |  |        |-- *
#   |     |  |         -- *
#   |     |   -- Is it used for serving food or beverages?
#   |     |     |-- Is it primarily used for drinking beverages?
#   |     |     |  |-- Does it have a handle?
#   |     |     |  |  |-- *
#   |     |     |  |   -- *
#   |     |     |   -- Does it typically come in a standard size or shape?
#   |     |     |     |-- *
#   |     |     |      -- *
#   |     |      -- Is it used primarily for food preparation?
#   |     |        |-- Is it commonly used in baking?
#   |     |        |  |-- *
#   |     |        |   -- *
#   |     |         -- Is it commonly made of plastic?
#   |     |           |-- *
#   |     |            -- *
#   |      -- Is it commonly associated with beverages?
#   |        |-- Is it typically used in the serving or consumption of beverages?
#   |        |  |-- Is it primarily associated with alcoholic beverages?
#   |        |  |  |-- Is it commonly found in bars or pubs?
#   |        |  |  |  |-- *
#   |        |  |  |   -- *
#   |        |  |   -- Is it an electrically powered device?
#   |        |  |     |-- *
#   |        |  |      -- *
#   |        |   -- Is it mainly used outdoors?
#   |        |     |-- Does it have a direct role in the production of beverages?
#   |        |     |  |-- *
#   |        |     |   -- *
#   |        |      -- Does it involve chemical compounds heavily in its function?
#   |        |        |-- *
#   |        |         -- *
#   |         -- Is it commonly found in agricultural or gardening settings?
#   |           |-- Does it have any relation to plants or trees?
#   |           |  |-- Is it an item used primarily for plant care or maintenance?
#   |           |  |  |-- *
#   |           |  |   -- *
#   |           |   -- Is it commonly found in manufacturing plants?
#   |           |     |-- *
#   |           |      -- *
#   |            -- Is it a machine or equipment?
#   |              |-- Is it used for a specific type of food preparation or cooking method?
#   |              |  |-- *
#   |              |   -- *
#   |               -- Is it often found in a natural environment?
#   |                 |-- *
#   |                  -- *
#    -- Is it used for home improvement or construction?
#      |-- Is it a tool?
#      |  |-- Does it have a handle or can it be held in your hand?
#      |  |  |-- Is it battery-operated or powered by electricity?
#      |  |  |  |-- Does it emit light?
#      |  |  |  |  |-- Is it primarily used for measuring distances or locating points?
#      |  |  |  |  |  |-- *
#      |  |  |  |  |   -- *
#      |  |  |  |   -- Is it primarily used to apply or remove material?
#      |  |  |  |     |-- *
#      |  |  |  |      -- *
#      |  |  |   -- Is it commonly used in gardening or outdoor activities?
#      |  |  |     |-- Is it made mostly of metal?
#      |  |  |     |  |-- *
#      |  |  |     |   -- *
#      |  |  |      -- Is it made primarily of metal and has no moving parts?
#      |  |  |        |-- *
#      |  |  |         -- *
#      |  |   -- Is it typically stationary when in use?
#      |  |     |-- Does it require power or electricity to operate?
#      |  |     |  |-- Does it measure or detect something?
#      |  |     |  |  |-- *
#      |  |     |  |   -- *
#      |  |     |   -- Can it support or elevate other objects?
#      |  |     |     |-- *
#      |  |     |      -- *
#      |  |      -- Is it powered by electricity or batteries?
#      |  |        |-- Is it primarily used for air movement or ventilation?
#      |  |        |  |-- *
#      |  |        |   -- *
#      |  |         -- Does it require precise measurement or alignment when in use?
#      |  |           |-- *
#      |  |            -- *
#      |   -- Is it an item that is usually found in a residential setting?
#      |     |-- Is it typically found on or around windows?
#      |     |  |-- Is it typically used to cover or obscure the window?
#      |     |  |  |-- Is it made primarily from fabric?
#      |     |  |  |  |-- *
#      |     |  |  |   -- *
#      |     |  |   -- Is it generally a liquid or semi-liquid substance?
#      |     |  |     |-- *
#      |     |  |      -- *
#      |     |   -- Is it an item that is usually found inside the house?
#      |     |     |-- Is it something that is fixed or attached to a wall?
#      |     |     |  |-- *
#      |     |     |   -- *
#      |     |      -- Is it typically part of the building structure itself?
#      |     |        |-- *
#      |     |         -- *
#      |      -- Is it a type of material?
#      |        |-- Is it a natural material?
#      |        |  |-- Can it be classified as a mineral?
#      |        |  |  |-- *
#      |        |  |   -- *
#      |        |   -- Is it commonly used in the automotive industry?
#      |        |     |-- *
#      |        |      -- *
#      |         -- Is it a stationary item?
#      |           |-- Is it used for safety purposes?
#      |           |  |-- *
#      |           |   -- *
#      |            -- Is it used for safety purposes?
#      |              |-- *
#      |               -- *
#       -- Is it commonly found in an office or school setting?
#         |-- Is it an electronic device?
#         |  |-- Is it a portable device?
#         |  |  |-- Does it have a display screen?
#         |  |  |  |-- Does it have the capability to access the internet?
#         |  |  |  |  |-- *
#         |  |  |  |   -- *
#         |  |  |   -- Does it produce sound?
#         |  |  |     |-- *
#         |  |  |      -- *
#         |  |   -- Is it related to safety or security?
#         |  |     |-- Does it emit a loud sound when activated?
#         |  |     |  |-- *
#         |  |     |   -- *
#         |  |      -- Is it typically mounted or installed in a fixed position?
#         |  |        |-- *
#         |  |         -- *
#         |   -- Is it something that can be worn?
#         |     |-- Is it typically made of fabric?
#         |     |  |-- Is it typically worn on the lower body?
#         |     |  |  |-- *
#         |     |  |   -- *
#         |     |   -- Is it worn on or related to the head?
#         |     |     |-- *
#         |     |      -- *
#         |      -- Is it primarily made of paper or cardboard?
#         |        |-- Is it used for writing or recording information?
#         |        |  |-- *
#         |        |   -- *
#         |         -- Is it typically found on a desk?
#         |           |-- *
#         |            -- *
#          -- Is it an object that can be found outdoors?
#            |-- Does it have a natural origin?
#            |  |-- Does it have a lifespan of more than one year?
#            |  |  |-- Is it something that can be found in a garden?
#            |  |  |  |-- *
#            |  |  |   -- *
#            |  |   -- Does it have a specific seasonal occurrence?
#            |  |     |-- *
#            |  |      -- *
#            |   -- Is it typically used for recreational activities?
#            |     |-- Is it used for competitive sports?
#            |     |  |-- *
#            |     |   -- *
#            |      -- Is it primarily associated with transportation or vehicles?
#            |        |-- *
#            |         -- *
#             -- Is it used for entertainment or leisure activities?
#               |-- Does it involve or require any kind of artistry or craft?
#               |  |-- Is it utilized in any form of visual media, like movies or graphic novels?
#               |  |  |-- *
#               |  |   -- *
#               |   -- Is it larger than a breadbox?
#               |     |-- *
#               |      -- *
#                -- Is it commonly found in or associated with a healthcare or medical setting?
#                  |-- Is it primarily used by or for patients?
#                  |  |-- *
#                  |   -- *
#                   -- Does it have mechanical or electronic components?
#                     |-- *
#                      -- *

# %% [markdown]
# ### Save to text file

# %%
test_tree.write_tree_to_file('20qs-data/decision_trees/gpt_decision_tree_v4.txt')

# %% [markdown]
# ### Load tree from txt file (doesn't load the whole tree)

# %%
tree2 = DecisionNode.read_tree_from_file('20qs-data/decision_trees/gpt_decision_tree_v4.txt')

# %%
tree2.print_tree()
# Out:
# -- Is it related to food, beverages or cooking?
#   |-- Is it an edible item?
#   |  |-- Is it primarily sweet?
#   |  |  |-- Is it typically consumed as a dessert?
#   |  |  |  |-- Can it be found in a liquid or semi-liquid form?
#   |  |  |  |  |-- Is it fruit-based?
#   |  |  |  |  |  |-- Does it come from a tropical region?
#   |  |  |  |  |  |  |-- *
#   |  |  |  |  |  |   -- *
#   |  |  |  |  |   -- Is it dairy-based?
#   |  |  |  |  |     |-- *
#   |  |  |  |  |      -- *
#   |  |  |  |   -- Is it typically baked?
#   |  |  |  |     |-- Is it commonly decorated with frosting or icing?
#   |  |  |  |     |  |-- *
#   |  |  |  |     |   -- *
#   |  |  |  |      -- Is it predominantly eaten cold or frozen?
#   |  |  |  |        |-- *
#   |  |  |  |         -- *
#   |  |  |   -- Is it a beverage?
#   |  |  |     |-- Does it contain caffeine?
#   |  |  |     |  |-- Does it commonly come in a can?
#   |  |  |     |  |  |-- *
#   |  |  |     |  |   -- *
#   |  |  |     |   -- Does it have fruit juice as a primary ingredient?
#   |  |  |     |     |-- *
#   |  |  |     |      -- *
#   |  |  |      -- Is it a plant or a part of a plant?
#   |  |  |        |-- Does it typically grow on a vine?
#   |  |  |        |  |-- *
#   |  |  |        |   -- *
#   |  |  |         -- Is it more commonly found in individual packaging?
#   |  |  |           |-- *
#   |  |  |            -- *
#   |  |   -- Is it a plant or plant-based product?
#   |  |     |-- Is it typically consumed whole or in a minimally processed form?
#   |  |     |  |-- Is it typically consumed raw?
#   |  |     |  |  |-- Is it primarily used as a garnish or herb?
#   |  |     |  |  |  |-- *
#   |  |     |  |  |   -- *
#   |  |     |  |   -- Is it a type of vegetable?
#   |  |     |  |     |-- *
#   |  |     |  |      -- *
#   |  |     |   -- Is it commonly used as an ingredient rather than consumed on its own?
#   |  |     |     |-- Is it commonly used in liquid form?
#   |  |     |     |  |-- *
#   |  |     |     |   -- *
#   |  |     |      -- Is it a beverage or associated with beverages?
#   |  |     |        |-- *
#   |  |     |         -- *
#   |  |      -- Is it commonly served hot?
#   |  |        |-- Does it contain meat?
#   |  |        |  |-- Is it usually served with bread or a bun?
#   |  |        |  |  |-- *
#   |  |        |  |   -- *
#   |  |        |   -- Is it a solid food item?
#   |  |        |     |-- *
#   |  |        |      -- *
#   |  |         -- Is it derived from or contains an animal product?
#   |  |           |-- Is it primarily used as an ingredient rather than consumed on its own?
#   |  |           |  |-- *
#   |  |           |   -- *
#   |  |            -- Is it a type of beverage?
#   |  |              |-- *
#   |  |               -- *
#   |   -- Is it typically found in a residential kitchen?
#   |     |-- Is it primarily made of metal?
#   |     |  |-- Is it associated with beverages?
#   |     |  |  |-- Can it be held in one hand?
#   |     |  |  |  |-- Is it typically used during the preparation of beverages?
#   |     |  |  |  |  |-- *
#   |     |  |  |  |   -- *
#   |     |  |  |   -- Does it have a built-in water reservoir?
#   |     |  |  |     |-- *
#   |     |  |  |      -- *
#   |     |  |   -- Is it used in baking or cooking in an oven?
#   |     |  |     |-- Is it flat and used to support or hold items for baking?
#   |     |  |     |  |-- *
#   |     |  |     |   -- *
#   |     |  |      -- Is it primarily a cutting tool?
#   |     |  |        |-- *
#   |     |  |         -- *
#   |     |   -- Is it used for serving food or beverages?
#   |     |     |-- Is it primarily used for drinking beverages?
#   |     |     |  |-- Does it have a handle?
#   |     |     |  |  |-- *
#   |     |     |  |   -- *
#   |     |     |   -- Does it typically come in a standard size or shape?
#   |     |     |     |-- *
#   |     |     |      -- *
#   |     |      -- Is it used primarily for food preparation?
#   |     |        |-- Is it commonly used in baking?
#   |     |        |  |-- *
#   |     |        |   -- *
#   |     |         -- Is it commonly made of plastic?
#   |     |           |-- *
#   |     |            -- *
#   |      -- Is it commonly associated with beverages?
#   |        |-- Is it typically used in the serving or consumption of beverages?
#   |        |  |-- Is it primarily associated with alcoholic beverages?
#   |        |  |  |-- Is it commonly found in bars or pubs?
#   |        |  |  |  |-- *
#   |        |  |  |   -- *
#   |        |  |   -- Is it an electrically powered device?
#   |        |  |     |-- *
#   |        |  |      -- *
#   |        |   -- Is it mainly used outdoors?
#   |        |     |-- Does it have a direct role in the production of beverages?
#   |        |     |  |-- *
#   |        |     |   -- *
#   |        |      -- Does it involve chemical compounds heavily in its function?
#   |        |        |-- *
#   |        |         -- *
#   |         -- Is it commonly found in agricultural or gardening settings?
#   |           |-- Does it have any relation to plants or trees?
#   |           |  |-- Is it an item used primarily for plant care or maintenance?
#   |           |  |  |-- *
#   |           |  |   -- *
#   |           |   -- Is it commonly found in manufacturing plants?
#   |           |     |-- *
#   |           |      -- *
#   |            -- Is it a machine or equipment?
#   |              |-- Is it used for a specific type of food preparation or cooking method?
#   |              |  |-- *
#   |              |   -- *
#   |               -- Is it often found in a natural environment?
#   |                 |-- *
#   |                  -- *
#    -- Is it used for home improvement or construction?
#      |-- Is it a tool?
#      |  |-- Does it have a handle or can it be held in your hand?
#      |  |  |-- Is it battery-operated or powered by electricity?
#      |  |  |  |-- Does it emit light?
#      |  |  |  |  |-- Is it primarily used for measuring distances or locating points?
#      |  |  |  |  |  |-- *
#      |  |  |  |  |   -- *
#      |  |  |  |   -- Is it primarily used to apply or remove material?
#      |  |  |  |     |-- *
#      |  |  |  |      -- *
#      |  |  |   -- Is it commonly used in gardening or outdoor activities?
#      |  |  |     |-- Is it made mostly of metal?
#      |  |  |     |  |-- *
#      |  |  |     |   -- *
#      |  |  |      -- Is it made primarily of metal and has no moving parts?
#      |  |  |        |-- *
#      |  |  |         -- *
#      |  |   -- Is it typically stationary when in use?
#      |  |     |-- Does it require power or electricity to operate?
#      |  |     |  |-- Does it measure or detect something?
#      |  |     |  |  |-- *
#      |  |     |  |   -- *
#      |  |     |   -- Can it support or elevate other objects?
#      |  |     |     |-- *
#      |  |     |      -- *
#      |  |      -- Is it powered by electricity or batteries?
#      |  |        |-- Is it primarily used for air movement or ventilation?
#      |  |        |  |-- *
#      |  |        |   -- *
#      |  |         -- Does it require precise measurement or alignment when in use?
#      |  |           |-- *
#      |  |            -- *
#      |   -- Is it an item that is usually found in a residential setting?
#      |     |-- Is it typically found on or around windows?
#      |     |  |-- Is it typically used to cover or obscure the window?
#      |     |  |  |-- Is it made primarily from fabric?
#      |     |  |  |  |-- *
#      |     |  |  |   -- *
#      |     |  |   -- Is it generally a liquid or semi-liquid substance?
#      |     |  |     |-- *
#      |     |  |      -- *
#      |     |   -- Is it an item that is usually found inside the house?
#      |     |     |-- Is it something that is fixed or attached to a wall?
#      |     |     |  |-- *
#      |     |     |   -- *
#      |     |      -- Is it typically part of the building structure itself?
#      |     |        |-- *
#      |     |         -- *
#      |      -- Is it a type of material?
#      |        |-- Is it a natural material?
#      |        |  |-- Can it be classified as a mineral?
#      |        |  |  |-- *
#      |        |  |   -- *
#      |        |   -- Is it commonly used in the automotive industry?
#      |        |     |-- *
#      |        |      -- *
#      |         -- Is it a stationary item?
#      |           |-- Is it used for safety purposes?
#      |           |  |-- *
#      |           |   -- *
#      |            -- Is it used for safety purposes?
#      |              |-- *
#      |               -- *
#       -- Is it commonly found in an office or school setting?
#         |-- Is it an electronic device?
#         |  |-- Is it a portable device?
#         |  |  |-- Does it have a display screen?
#         |  |  |  |-- Does it have the capability to access the internet?
#         |  |  |  |  |-- *
#         |  |  |  |   -- *
#         |  |  |   -- Does it produce sound?
#         |  |  |     |-- *
#         |  |  |      -- *
#         |  |   -- Is it related to safety or security?
#         |  |     |-- Does it emit a loud sound when activated?
#         |  |     |  |-- *
#         |  |     |   -- *
#         |  |      -- Is it typically mounted or installed in a fixed position?
#         |  |        |-- *
#         |  |         -- *
#         |   -- Is it something that can be worn?
#         |     |-- Is it typically made of fabric?
#         |     |  |-- Is it typically worn on the lower body?
#         |     |  |  |-- *
#         |     |  |   -- *
#         |     |   -- Is it worn on or related to the head?
#         |     |     |-- *
#         |     |      -- *
#         |      -- Is it primarily made of paper or cardboard?
#         |        |-- Is it used for writing or recording information?
#         |        |  |-- *
#         |        |   -- *
#         |         -- Is it typically found on a desk?
#         |           |-- *
#         |            -- *
#          -- Is it an object that can be found outdoors?
#            |-- Does it have a natural origin?
#            |  |-- Does it have a lifespan of more than one year?
#            |  |  |-- Is it something that can be found in a garden?
#            |  |  |  |-- *
#            |  |  |   -- *
#            |  |   -- Does it have a specific seasonal occurrence?
#            |  |     |-- *
#            |  |      -- *
#            |   -- Is it typically used for recreational activities?
#            |     |-- Is it used for competitive sports?
#            |     |  |-- *
#            |     |   -- *
#            |      -- Is it primarily associated with transportation or vehicles?
#            |        |-- *
#            |         -- *
#             -- Is it used for entertainment or leisure activities?
#               |-- Does it involve or require any kind of artistry or craft?
#               |  |-- Is it utilized in any form of visual media, like movies or graphic novels?
#               |  |  |-- *
#               |  |   -- *
#               |   -- Is it larger than a breadbox?
#               |     |-- *
#               |      -- *
#                -- Is it commonly found in or associated with a healthcare or medical setting?
#                  |-- Is it primarily used by or for patients?
#                  |  |-- *
#                  |   -- *
#                   -- Does it have mechanical or electronic components?
#                     |-- *
#                      -- *

# %% [markdown]
# ### Save with pickle

# %%
import pickle
with open('20qs-data/decision_trees/gpt_decision_tree_v3.p', 'wb') as f:
    pickle.dump(test_tree, f)

# %% [markdown]
# ### Example of loading decision tree with Pickle

# %%
with open('20qs-data/decision_trees/gpt_decision_tree_v2.p', 'rb') as f:
    tree3 = pickle.load(f)

# %% [markdown]
# ### Testing some alternative starting questions

# %%
question = "Is it related to food, beverages or cooking?"
result, _, _ = test_keyword_percentage_eliminated(question, all_keywords, 0.1)
print(f"Question: {question}  {result}")
# Out:
# Num keywords in test set: 134
# 1) Keyword: Incense. Result: False
# 2) Keyword: bookbag. Result: False
# 3) Keyword: Joystick. Result: False
# 4) Keyword: baggage conveyor. Result: False
# 5) Keyword: Emergency Exit Sign. Result: False
# 6) Keyword: zinc. Result: True
# 7) Keyword: vintage clock. Result: False
# 8) Keyword: dinosaur skeleton. Result: False
# 9) Keyword: tongue. Result: True
# 10) Keyword: Lawnmower. Result: False
# 11) Keyword: flea. Result: False
# 12) Keyword: dogwood. Result: False
# 13) Keyword: corkscrew. Result: True
# 14) Keyword: paint thinner. Result: False
# 15) Keyword: Nap mat. Result: False
# 16) Keyword: ice tea. Result: True
# 17) Keyword: pea plant. Result: True
# 18) Keyword: Sound system. Result: False
# 19) Keyword: cutter. Result: True
# 20) Keyword: ginger ale. Result: True
# 21) Keyword: mixing console. Result: False
# 22) Keyword: chimney. Result: False
# 23) Keyword: frisbee. Result: False
# 24) Keyword: wall mirror. Result: False
# 25) Keyword: rollercoaster. Result: False
# 26) Keyword: Paperwork. Result: False
# 27) Keyword: maxi dress. Result: False
# 28) Keyword: vacuum cleaner. Result: False
# 29) Keyword: grape. Result: True
# 30) Keyword: curler. Result: False
# 31) Keyword: cocktail glass. Result: True
# 32) Keyword: Nail Polish Remover. Result: False
# 33) Keyword: bumper. Result: False
# 34) Keyword: hamburger helper. Result: True
# 35) Keyword: tire inflator. Result: False
# 36) Keyword: Tank. Result: False
# 37) Keyword: barcode. Result: True
# 38) Keyword: lighting rig. Result: False
# 39) Keyword: sofa. Result: False
# 40) Keyword: straightening iron. Result: False
# 41) Keyword: medical chart. Result: False
# 42) Keyword: evaporator. Result: True
# 43) Keyword: Orange peel. Result: True
# 44) Keyword: Medical Records. Result: False
# 45) Keyword: security gate. Result: False
# 46) Keyword: butter knife. Result: True
# 47) Keyword: cane. Result: False
# 48) Keyword: Bonding Agent. Result: True
# 49) Keyword: Bunsen burner. Result: False
# 50) Keyword: yarrow. Result: True
# 51) Keyword: Bread pudding. Result: True
# 52) Keyword: rice krispie. Result: True
# 53) Keyword: mangrove seedling. Result: False
# 54) Keyword: Personal protective equipment. Result: False
# 55) Keyword: Smartwatch. Result: False
# 56) Keyword: Wire rack. Result: True
# 57) Keyword: excavator. Result: False
# 58) Keyword: throw rug. Result: False
# 59) Keyword: archery target. Result: False
# 60) Keyword: laboratory manual. Result: False
# 61) Keyword: Resin. Result: False
# 62) Keyword: kitchen knife. Result: True
# 63) Keyword: polar bear. Result: False
# 64) Keyword: Toothpaste. Result: False
# 65) Keyword: Headphones. Result: False
# 66) Keyword: eye mask. Result: False
# 67) Keyword: Taser. Result: False
# 68) Keyword: frozen meat. Result: True
# 69) Keyword: pellet. Result: True
# 70) Keyword: Yoga mat. Result: False
# 71) Keyword: Dish soap. Result: False
# 72) Keyword: Roots. Result: True
# 73) Keyword: serving platter. Result: True
# 74) Keyword: compactor. Result: False
# 75) Keyword: vintage dollhouse. Result: False
# 76) Keyword: end table. Result: False
# 77) Keyword: lemon zest. Result: True
# 78) Keyword: Tablet. Result: False
# 79) Keyword: climber. Result: False
# 80) Keyword: underwater volcano. Result: False
# 81) Keyword: power pole. Result: False
# 82) Keyword: plastic pipe. Result: False
# 83) Keyword: cockroach. Result: False
# 84) Keyword: Silver ore. Result: False
# 85) Keyword: smoothie. Result: True
# 86) Keyword: gin. Result: True
# 87) Keyword: sheetrock. Result: False
# 88) Keyword: decal. Result: False
# 89) Keyword: Kale smoothie. Result: True
# 90) Keyword: zip tie. Result: False
# 91) Keyword: crayfish. Result: True
# 92) Keyword: Cutting Board. Result: True
# 93) Keyword: Lightbulb. Result: False
# 94) Keyword: Swing set. Result: False
# 95) Keyword: Stained glass window. Result: False
# 96) Keyword: Curtains. Result: False
# 97) Keyword: bamboo. Result: True
# 98) Keyword: Fanny pack. Result: False
# 99) Keyword: receipt printer. Result: False
# 100) Keyword: garbage truck. Result: False
# 101) Keyword: lifter. Result: False
# 102) Keyword: RV. Result: False
# 103) Keyword: carbon. Result: True
# 104) Keyword: beer coaster. Result: True
# 105) Keyword: Fitness tracker. Result: False
# 106) Keyword: nose. Result: True
# 107) Keyword: flat shoe. Result: False
# 108) Keyword: level sensor. Result: False
# 109) Keyword: Hair Gel. Result: False
# 110) Keyword: infrared sensor. Result: False
# 111) Keyword: water pump. Result: False
# 112) Keyword: fuel filter. Result: False
# 113) Keyword: underwater camera. Result: False
# 114) Keyword: pine cone. Result: False
# 115) Keyword: training cone. Result: False
# 116) Keyword: loose change. Result: False
# 117) Keyword: HDMI cable. Result: False
# 118) Keyword: Windbreak. Result: False
# 119) Keyword: mount saint lias. Result: False
# 120) Keyword: piano. Result: False
# 121) Keyword: wax. Result: False
# 122) Keyword: granola. Result: True
# 123) Keyword: bean. Result: True
# 124) Keyword: Measuring cup. Result: True
# 125) Keyword: exhibit sign. Result: False
# 126) Keyword: tow strap. Result: False
# 127) Keyword: Microscope. Result: False
# 128) Keyword: mri. Result: False
# 129) Keyword: iv bag. Result: False
# 130) Keyword: Brochure. Result: False
# 131) Keyword: ricotta. Result: True
# 132) Keyword: lemon balm. Result: True
# 133) Keyword: DVD. Result: False
# 134) Keyword: Floor jacks. Result: False
# Question: Is it related to food, beverages or cooking?  0.291044776119403

# %%
result, _, _ = test_keyword_percentage_eliminated("Is it something you can hold in your hand?", all_keywords, 0.2)
print(f"Question: Is it something you can hold in your hand?  {result}")

result, _, _ = test_keyword_percentage_eliminated("Is it used primarily for entertainment purposes?", all_keywords, 0.2)
print(f"Question: Is it used primarily for entertainment purposes?  {result}")

result, _, _ = test_keyword_percentage_eliminated("Is it found in nature (not man-made)?", all_keywords, 0.2)
print(f"Question: Is it found in nature (not man-made)?  {result}")

result, _, _ = test_keyword_percentage_eliminated("Is it something you would typically find in a kitchen?", all_keywords, 0.2)
print(f"Question: Is it something you would typically find in a kitchen?  {result}")

result, _, _ = test_keyword_percentage_eliminated("Does it require electricity to function?", all_keywords, 0.2)
print(f"Question: Does it require electricity to function?  {result}")
# Out:
# Num keywords in test set: 269
# 1) Keyword: unripe banana. Result: True
# 2) Keyword: colander. Result: True
# 3) Keyword: pail. Result: True
# 4) Keyword: flashlight. Result: True
# 5) Keyword: water snake. Result: True
# 6) Keyword: weight plate. Result: True
# 7) Keyword: power adapter. Result: True
# 8) Keyword: valve. Result: True
# 9) Keyword: Lawnmower. Result: False
# 10) Keyword: ice tea. Result: True
# 11) Keyword: plastic fork. Result: True
# 12) Keyword: martini. Result: True
# 13) Keyword: Plastic wrap. Result: True
# 14) Keyword: hole puncher. Result: True
# 15) Keyword: centerpiece. Result: True
# 16) Keyword: travel pillow. Result: True
# 17) Keyword: waterslide. Result: False
# 18) Keyword: teddy bear. Result: True
# 19) Keyword: parking pass. Result: True
# 20) Keyword: Mushroom. Result: True
# 21) Keyword: Bird seed. Result: True
# 22) Keyword: bedspread. Result: False
# 23) Keyword: shower mat. Result: True
# 24) Keyword: groundhog. Result: True
# 25) Keyword: plant saucer. Result: True
# 26) Keyword: Hot water bottle. Result: True
# 27) Keyword: cruise ship. Result: False
# 28) Keyword: Parallel bars. Result: False
# 29) Keyword: tea cup. Result: True
# 30) Keyword: rocketship. Result: False
# 31) Keyword: conference table. Result: False
# 32) Keyword: lipstick. Result: True
# 33) Keyword: Reindeer. Result: False
# 34) Keyword: vespa. Result: False
# 35) Keyword: walking stick. Result: True
# 36) Keyword: stationary bike. Result: False
# 37) Keyword: clutch bag. Result: True
# 38) Keyword: sandhill crane. Result: False
# 39) Keyword: plastic pallet. Result: False
# 40) Keyword: crayfish. Result: True
# 41) Keyword: unripe fruit. Result: True
# 42) Keyword: Hair Dryer. Result: True
# 43) Keyword: seltzer. Result: True
# 44) Keyword: utility belt. Result: True
# 45) Keyword: lace dress. Result: True
# 46) Keyword: Fungi. Result: True
# 47) Keyword: Coffee Makers. Result: False
# 48) Keyword: swamp milkweed. Result: True
# 49) Keyword: Sticker. Result: True
# 50) Keyword: Lint Roller. Result: True
# 51) Keyword: sash. Result: True
# 52) Keyword: calculator. Result: True
# 53) Keyword: vintage clock. Result: True
# 54) Keyword: almond milk. Result: True
# 55) Keyword: pilates reformer. Result: False
# 56) Keyword: Milling machine. Result: False
# 57) Keyword: Cutlery. Result: True
# 58) Keyword: Oven rack. Result: False
# 59) Keyword: impact wrench. Result: True
# 60) Keyword: Latte. Result: True
# 61) Keyword: arrival board. Result: False
# 62) Keyword: smoothie. Result: True
# 63) Keyword: Binoculars. Result: True
# 64) Keyword: glass figurine. Result: True
# 65) Keyword: Cardboard box. Result: True
# 66) Keyword: mortar. Result: True
# 67) Keyword: mic stand. Result: True
# 68) Keyword: backgammon board. Result: False
# 69) Keyword: pitcher. Result: True
# 70) Keyword: Smoke Detector. Result: True
# 71) Keyword: Tofu. Result: True
# 72) Keyword: sunglasses. Result: True
# 73) Keyword: Scones. Result: True
# 74) Keyword: gin. Result: True
# 75) Keyword: volkswagen. Result: True
# 76) Keyword: safety goggles. Result: True
# 77) Keyword: fence panel. Result: False
# 78) Keyword: Quesadilla. Result: True
# 79) Keyword: leaf rake. Result: True
# 80) Keyword: lily. Result: True
# 81) Keyword: culture medium. Result: True
# 82) Keyword: jacket. Result: True
# 83) Keyword: Matches. Result: True
# 84) Keyword: beach umbrella. Result: False
# 85) Keyword: cactus flower. Result: True
# 86) Keyword: hair tie. Result: True
# 87) Keyword: Edible flowers. Result: True
# 88) Keyword: potted plant. Result: True
# 89) Keyword: Face mask. Result: True
# 90) Keyword: Jumper Cables. Result: True
# 91) Keyword: metal spoon. Result: True
# 92) Keyword: Stain Remover. Result: True
# 93) Keyword: ruler. Result: True
# 94) Keyword: Curtains. Result: False
# 95) Keyword: rhubarb. Result: True
# 96) Keyword: wine glass. Result: True
# 97) Keyword: straightening iron. Result: True
# 98) Keyword: Journal. Result: True
# 99) Keyword: Wristband. Result: True
# 100) Keyword: Power lines. Result: False
# 101) Keyword: Scoreboard. Result: True
# 102) Keyword: stump. Result: True
# 103) Keyword: juice box. Result: True
# 104) Keyword: Movie poster. Result: True
# 105) Keyword: Power Drill. Result: True
# 106) Keyword: unbuttoned jacket. Result: True
# 107) Keyword: Karaoke machine. Result: False
# 108) Keyword: tupperware. Result: True
# 109) Keyword: Earl Grey tea. Result: True
# 110) Keyword: apple. Result: True
# 111) Keyword: Turn signal. Result: True
# 112) Keyword: Pesticide. Result: True
# 113) Keyword: Ceiling fan. Result: False
# 114) Keyword: fish scale. Result: True
# 115) Keyword: silicon. Result: True
# 116) Keyword: Outdoor Furniture. Result: True
# 117) Keyword: wind vane. Result: True
# 118) Keyword: file folder. Result: True
# 119) Keyword: drill bit. Result: True
# 120) Keyword: eyeglass. Result: True
# 121) Keyword: grinder. Result: True
# 122) Keyword: cocktail glass. Result: True
# 123) Keyword: coconut. Result: True
# 124) Keyword: Personal protective equipment. Result: True
# 125) Keyword: Ocarina. Result: True
# 126) Keyword: cane. Result: True
# 127) Keyword: antiseptic wipe. Result: True
# 128) Keyword: seam. Result: False
# 129) Keyword: Oxygen tank. Result: True
# 130) Keyword: Honeybee. Result: True
# 131) Keyword: fire coral. Result: False
# 132) Keyword: dead leaf. Result: True
# 133) Keyword: nose ring. Result: True
# 134) Keyword: ice tray. Result: True
# 135) Keyword: Handbag. Result: True
# 136) Keyword: yeast. Result: False
# 137) Keyword: Furniture polish. Result: True
# 138) Keyword: denim jeans. Result: True
# 139) Keyword: Comic Book. Result: True
# 140) Keyword: concrete wall. Result: False
# 141) Keyword: petroleum. Result: False
# 142) Keyword: Vase. Result: True
# 143) Keyword: Microwave. Result: False
# 144) Keyword: book cover. Result: True
# 145) Keyword: moleskin. Result: True
# 146) Keyword: vegan chocolate. Result: True
# 147) Keyword: caribou. Result: False
# 148) Keyword: power cord. Result: True
# 149) Keyword: bamboo leaf. Result: True
# 150) Keyword: Card. Result: True
# 151) Keyword: Mini fridge. Result: False
# 152) Keyword: petunia. Result: True
# 153) Keyword: mixing console. Result: False
# 154) Keyword: amazon echo. Result: True
# 155) Keyword: maxi dress. Result: False
# 156) Keyword: Urinal. Result: True
# 157) Keyword: alfalfa. Result: True
# 158) Keyword: Shipping label. Result: True
# 159) Keyword: Lottery Ticket. Result: True
# 160) Keyword: baggage conveyor. Result: False
# 161) Keyword: moss ball. Result: True
# 162) Keyword: yoga block. Result: True
# 163) Keyword: chimney. Result: False
# 164) Keyword: Chessboard. Result: False
# 165) Keyword: cooler. Result: True
# 166) Keyword: sheetrock. Result: True
# 167) Keyword: solar panel. Result: False
# 168) Keyword: Ice cream maker. Result: True
# 169) Keyword: wastewater. Result: False
# 170) Keyword: footrest. Result: True
# 171) Keyword: Chocolate cake. Result: True
# 172) Keyword: catalytic converter. Result: False
# 173) Keyword: cobblestone. Result: True
# 174) Keyword: Baguette. Result: True
# 175) Keyword: mesquite tree. Result: False
# 176) Keyword: maple tree. Result: False
# 177) Keyword: concentrator. Result: True
# 178) Keyword: ducky. Result: True
# 179) Keyword: sedge. Result: True
# 180) Keyword: Olive Oil. Result: True
# 181) Keyword: oakley sunglasses. Result: True
# 182) Keyword: hummus. Result: True
# 183) Keyword: Name tag. Result: True
# 184) Keyword: lid. Result: True
# 185) Keyword: purse. Result: True
# 186) Keyword: Nachos. Result: True
# 187) Keyword: rice krispie. Result: True
# 188) Keyword: Wall Art. Result: True
# 189) Keyword: Pry Bar. Result: True
# 190) Keyword: Shin Guards. Result: True
# 191) Keyword: Towel. Result: True
# 192) Keyword: tiramisu. Result: True
# 193) Keyword: Analogy. Result: False
# 194) Keyword: steel sheet. Result: True
# 195) Keyword: washcloth. Result: True
# 196) Keyword: Pad. Result: True
# 197) Keyword: tire inflator. Result: True
# 198) Keyword: train horn. Result: False
# 199) Keyword: trouser. Result: False
# 200) Keyword: Heating Element. Result: True
# 201) Keyword: power cable. Result: True
# 202) Keyword: license plate. Result: True
# 203) Keyword: butterfly net. Result: True
# 204) Keyword: Packing peanuts. Result: True
# 205) Keyword: Soldering iron. Result: True
# 206) Keyword: dishcloth. Result: True
# 207) Keyword: ignition system. Result: False
# 208) Keyword: Safety harness. Result: True
# 209) Keyword: Metal detector. Result: True
# 210) Keyword: cinder block. Result: False
# 211) Keyword: Stage lights. Result: False
# 212) Keyword: steak knife. Result: True
# 213) Keyword: penguin. Result: False
# 214) Keyword: Paperweights. Result: True
# 215) Keyword: calcite. Result: True
# 216) Keyword: Mouse. Result: True
# 217) Keyword: Chandelier. Result: False
# 218) Keyword: beach chair. Result: False
# 219) Keyword: wild garlic. Result: True
# 220) Keyword: electric razor. Result: True
# 221) Keyword: Hash browns. Result: True
# 222) Keyword: Desk Chairs. Result: False
# 223) Keyword: orange slice. Result: True
# 224) Keyword: Tracksuit. Result: False
# 225) Keyword: bandana. Result: True
# 226) Keyword: chutney. Result: True
# 227) Keyword: plunger. Result: True
# 228) Keyword: office chair. Result: False
# 229) Keyword: sweet tea. Result: True
# 230) Keyword: peace lily. Result: True
# 231) Keyword: wood chip. Result: True
# 232) Keyword: honey. Result: True
# 233) Keyword: medical chart. Result: True
# 234) Keyword: Dumbbells. Result: True
# 235) Keyword: ultrasound. Result: False
# 236) Keyword: whiteboard. Result: False
# 237) Keyword: shower cap. Result: True
# 238) Keyword: Elliptical Trainers. Result: False
# 239) Keyword: Marshmallow. Result: True
# 240) Keyword: Key chain. Result: True
# 241) Keyword: Rolling pin. Result: True
# 242) Keyword: zip tie. Result: True
# 243) Keyword: Motorcycle Helmet. Result: True
# 244) Keyword: sock. Result: True
# 245) Keyword: Silicone. Result: True
# 246) Keyword: zinc. Result: True
# 247) Keyword: volcanic ash. Result: True
# 248) Keyword: vacuum cleaner. Result: False
# 249) Keyword: aerator. Result: True
# 250) Keyword: Engravings. Result: True
# 251) Keyword: projector. Result: False
# 252) Keyword: toothpick. Result: True
# 253) Keyword: Hairspray. Result: True
# 254) Keyword: migraine. Result: False
# 255) Keyword: bar towel. Result: True
# 256) Keyword: Air filter. Result: True
# 257) Keyword: water hose. Result: False
# 258) Keyword: giraffe. Result: False
# 259) Keyword: Sleeping bag. Result: False
# 260) Keyword: curler. Result: True
# 261) Keyword: Graphing Calculator. Result: True
# 262) Keyword: ham. Result: True
# 263) Keyword: Violin Strings. Result: True
# 264) Keyword: Touchscreen. Result: True
# 265) Keyword: snake. Result: True
# 266) Keyword: piano. Result: False
# 267) Keyword: tank top. Result: True
# 268) Keyword: Diaper. Result: True
# 269) Keyword: carbon. Result: False
# Question: Is it something you can hold in your hand?  0.758364312267658
# Num keywords in test set: 269
# 1) Keyword: Coffee Grinder. Result: False
# 2) Keyword: fennel. Result: False
# 3) Keyword: penguin. Result: False
# 4) Keyword: highlighter. Result: False
# 5) Keyword: vintage dollhouse. Result: True
# 6) Keyword: Outdoor Furniture. Result: False
# 7) Keyword: metal spoon. Result: False
# 8) Keyword: bean plant. Result: False
# 9) Keyword: Cantaloupe. Result: False
# 10) Keyword: Water Heater. Result: False
# 11) Keyword: rollercoaster. Result: True
# 12) Keyword: telephone. Result: False
# 13) Keyword: Scones. Result: False
# 14) Keyword: Soda. Result: True
# 15) Keyword: water bowl. Result: False
# 16) Keyword: violin bow. Result: False
# 17) Keyword: mango. Result: False
# 18) Keyword: dolphin. Result: True
# 19) Keyword: seltzer. Result: False
# 20) Keyword: chutney. Result: False
# 21) Keyword: Brochure. Result: False
# 22) Keyword: gas turbine. Result: False
# 23) Keyword: migraine. Result: False
# 24) Keyword: yogurt container. Result: False
# 25) Keyword: Yogurt. Result: False
# 26) Keyword: shipping container. Result: False
# 27) Keyword: steak. Result: False
# 28) Keyword: fan blade. Result: False
# 29) Keyword: Lathe. Result: False
# 30) Keyword: Plastic Gloves. Result: False
# 31) Keyword: skewer. Result: False
# 32) Keyword: pine cone. Result: False
# 33) Keyword: Grapefruit. Result: False
# 34) Keyword: juice box. Result: False
# 35) Keyword: pilates reformer. Result: False
# 36) Keyword: spider web. Result: False
# 37) Keyword: yoga block. Result: False
# 38) Keyword: Bread pudding. Result: False
# 39) Keyword: headband. Result: False
# 40) Keyword: concrete block. Result: False
# 41) Keyword: Nozzle. Result: False
# 42) Keyword: jacket. Result: False
# 43) Keyword: power adapter. Result: False
# 44) Keyword: Guitar String. Result: False
# 45) Keyword: unbuttoned jacket. Result: False
# 46) Keyword: Coat Rack. Result: False
# 47) Keyword: Board Games. Result: True
# 48) Keyword: Cash Register. Result: False
# 49) Keyword: Graphing Calculator. Result: False
# 50) Keyword: metal lid. Result: False
# 51) Keyword: electric motorcycle. Result: False
# 52) Keyword: woodpecker. Result: False
# 53) Keyword: medical cart. Result: False
# 54) Keyword: fallen tree. Result: False
# 55) Keyword: Eucalyptus. Result: False
# 56) Keyword: Elliptical Trainers. Result: False
# 57) Keyword: IV. Result: False
# 58) Keyword: Cereal. Result: False
# 59) Keyword: Glass Table. Result: False
# 60) Keyword: user manual. Result: False
# 61) Keyword: chime. Result: True
# 62) Keyword: prairie sunflower. Result: False
# 63) Keyword: Vans. Result: False
# 64) Keyword: hose line. Result: False
# 65) Keyword: cupcake. Result: False
# 66) Keyword: velvet couch. Result: True
# 67) Keyword: Lint Roller. Result: False
# 68) Keyword: Bread knife. Result: False
# 69) Keyword: invoice. Result: False
# 70) Keyword: Medication. Result: False
# 71) Keyword: broken glass. Result: False
# 72) Keyword: hazelnut tree. Result: False
# 73) Keyword: Kitchen cabinet. Result: False
# 74) Keyword: phone case. Result: False
# 75) Keyword: pot holder. Result: False
# 76) Keyword: shingle. Result: False
# 77) Keyword: salt scrub. Result: False
# 78) Keyword: car seat. Result: False
# 79) Keyword: fence gate. Result: False
# 80) Keyword: Stain Remover. Result: False
# 81) Keyword: Ticket Machine. Result: False
# 82) Keyword: spare bulb. Result: False
# 83) Keyword: almond milk. Result: False
# 84) Keyword: livestock trailer. Result: False
# 85) Keyword: Hand dryer. Result: False
# 86) Keyword: Movie poster. Result: True
# 87) Keyword: coffee machine. Result: False
# 88) Keyword: Cinnamon roll. Result: False
# 89) Keyword: Necklace. Result: False
# 90) Keyword: Pliers. Result: False
# 91) Keyword: Sugar packet. Result: False
# 92) Keyword: crayfish. Result: False
# 93) Keyword: Piping tips. Result: False
# 94) Keyword: mic stand. Result: False
# 95) Keyword: maple tree. Result: False
# 96) Keyword: Screwdriver. Result: False
# 97) Keyword: upright piano. Result: True
# 98) Keyword: Phone charger. Result: False
# 99) Keyword: Duffle Bags. Result: False
# 100) Keyword: Onyx. Result: False
# 101) Keyword: pineapple. Result: False
# 102) Keyword: Fitness tracker. Result: False
# 103) Keyword: Paperwork. Result: False
# 104) Keyword: Lightbulb. Result: False
# 105) Keyword: emergency light. Result: False
# 106) Keyword: bookbag. Result: False
# 107) Keyword: turtle. Result: False
# 108) Keyword: unripe banana. Result: False
# 109) Keyword: Tulip. Result: False
# 110) Keyword: vintage clock. Result: False
# 111) Keyword: cowboy boot. Result: False
# 112) Keyword: sedge. Result: False
# 113) Keyword: Power strip. Result: False
# 114) Keyword: toothpick. Result: False
# 115) Keyword: sandhill crane. Result: False
# 116) Keyword: cotton candy. Result: True
# 117) Keyword: cinder block. Result: False
# 118) Keyword: barbell collar. Result: False
# 119) Keyword: laundry basket. Result: False
# 120) Keyword: office chair. Result: False
# 121) Keyword: gecko. Result: False
# 122) Keyword: Exit sign. Result: False
# 123) Keyword: Jewelry Box. Result: True
# 124) Keyword: glass panel. Result: False
# 125) Keyword: pedal boat. Result: True
# 126) Keyword: ballpoint pen. Result: False
# 127) Keyword: Croissant. Result: False
# 128) Keyword: fresheners. Result: False
# 129) Keyword: rooster. Result: False
# 130) Keyword: alfalfa. Result: False
# 131) Keyword: dining chair. Result: False
# 132) Keyword: Diving board. Result: False
# 133) Keyword: Measuring Tape. Result: False
# 134) Keyword: clog. Result: False
# 135) Keyword: Photo album. Result: True
# 136) Keyword: Ceiling fan. Result: False
# 137) Keyword: Contact lenses. Result: False
# 138) Keyword: binder clip. Result: False
# 139) Keyword: Wine Tasting Kit. Result: True
# 140) Keyword: noodle. Result: False
# 141) Keyword: parrot. Result: False
# 142) Keyword: bowl. Result: False
# 143) Keyword: shower chair. Result: False
# 144) Keyword: archery target. Result: False
# 145) Keyword: hot tea. Result: False
# 146) Keyword: Beanbag. Result: True
# 147) Keyword: Engravings. Result: False
# 148) Keyword: Fire Extinguisher. Result: False
# 149) Keyword: Sewing Kit. Result: False
# 150) Keyword: leash. Result: False
# 151) Keyword: cane. Result: False
# 152) Keyword: Advertisement. Result: True
# 153) Keyword: peeler. Result: False
# 154) Keyword: Vegetation. Result: False
# 155) Keyword: hairspray can. Result: False
# 156) Keyword: autograph. Result: False
# 157) Keyword: bracelet. Result: True
# 158) Keyword: Anesthesia. Result: False
# 159) Keyword: tomato plant. Result: False
# 160) Keyword: Bed frame. Result: False
# 161) Keyword: Muffin. Result: False
# 162) Keyword: clock. Result: False
# 163) Keyword: water hyacinth. Result: False
# 164) Keyword: motor. Result: False
# 165) Keyword: file folder. Result: False
# 166) Keyword: apricot tree. Result: False
# 167) Keyword: oak tree. Result: False
# 168) Keyword: peppermint. Result: False
# 169) Keyword: piranha. Result: False
# 170) Keyword: gold. Result: False
# 171) Keyword: Fried rice. Result: False
# 172) Keyword: Air compressor. Result: False
# 173) Keyword: Honeybee. Result: False
# 174) Keyword: Safety harness. Result: False
# 175) Keyword: fudge brownie. Result: False
# 176) Keyword: drill bit. Result: False
# 177) Keyword: tote bin. Result: False
# 178) Keyword: Rat. Result: False
# 179) Keyword: vespa. Result: False
# 180) Keyword: flat shoe. Result: False
# 181) Keyword: snowmobile. Result: False
# 182) Keyword: Laser beam. Result: True
# 183) Keyword: coffee table. Result: True
# 184) Keyword: Emergency lights. Result: False
# 185) Keyword: leaf. Result: False
# 186) Keyword: pellet. Result: False
# 187) Keyword: pipe. Result: False
# 188) Keyword: Hand Sanitizer. Result: False
# 189) Keyword: aperol spritz. Result: True
# 190) Keyword: Touchscreen. Result: True
# 191) Keyword: Chew toy. Result: True
# 192) Keyword: vietnamese coffee. Result: False
# 193) Keyword: water pump. Result: False
# 194) Keyword: chimney. Result: False
# 195) Keyword: Incense. Result: False
# 196) Keyword: wall mirror. Result: True
# 197) Keyword: impact crusher. Result: False
# 198) Keyword: garbage truck. Result: False
# 199) Keyword: Scoreboard. Result: False
# 200) Keyword: Udon Noodles. Result: False
# 201) Keyword: measuring spoon. Result: False
# 202) Keyword: car engine. Result: False
# 203) Keyword: wild garlic. Result: False
# 204) Keyword: swedish fish. Result: True
# 205) Keyword: Hair Dryer. Result: False
# 206) Keyword: yarrow. Result: False
# 207) Keyword: Hazelnut. Result: False
# 208) Keyword: water well. Result: False
# 209) Keyword: Hairspray. Result: True
# 210) Keyword: applesauce. Result: False
# 211) Keyword: electric razor. Result: False
# 212) Keyword: common milkweed. Result: False
# 213) Keyword: Toothbrush. Result: False
# 214) Keyword: Barber Chair. Result: False
# 215) Keyword: audio guide. Result: False
# 216) Keyword: lace top. Result: False
# 217) Keyword: Tweezers. Result: False
# 218) Keyword: tuning fork. Result: False
# 219) Keyword: lug. Result: False
# 220) Keyword: relief valve. Result: False
# 221) Keyword: Bird seed. Result: False
# 222) Keyword: Sketchbook. Result: True
# 223) Keyword: mri. Result: False
# 224) Keyword: overhead wire. Result: False
# 225) Keyword: giraffe. Result: False
# 226) Keyword: oxygen. Result: False
# 227) Keyword: receipt printer. Result: False
# 228) Keyword: strainer. Result: False
# 229) Keyword: ribbon. Result: False
# 230) Keyword: Fanny pack. Result: False
# 231) Keyword: milling. Result: False
# 232) Keyword: Pickaxe. Result: False
# 233) Keyword: underwater volcano. Result: False
# 234) Keyword: Suitcase. Result: False
# 235) Keyword: gown. Result: True
# 236) Keyword: tea leaf. Result: False
# 237) Keyword: traffic signal. Result: False
# 238) Keyword: Pry Bar. Result: False
# 239) Keyword: Pamphlet. Result: False
# 240) Keyword: air tank. Result: False
# 241) Keyword: frozen waffle. Result: False
# 242) Keyword: Olive Oil. Result: False
# 243) Keyword: miniskirt. Result: True
# 244) Keyword: door. Result: False
# 245) Keyword: coffin. Result: False
# 246) Keyword: ham. Result: False
# 247) Keyword: noise-canceling headphones. Result: False
# 248) Keyword: Air Conditioner. Result: False
# 249) Keyword: Polyester. Result: False
# 250) Keyword: Video Camera. Result: True
# 251) Keyword: Hearing aid. Result: False
# 252) Keyword: mesquite tree. Result: False
# 253) Keyword: eyeglass. Result: False
# 254) Keyword: Velvet rope. Result: True
# 255) Keyword: power cable. Result: False
# 256) Keyword: Desk Chairs. Result: False
# 257) Keyword: book cover. Result: True
# 258) Keyword: balance beam. Result: False
# 259) Keyword: Scrap metal. Result: False
# 260) Keyword: igloo. Result: False
# 261) Keyword: seam. Result: False
# 262) Keyword: drapery. Result: False
# 263) Keyword: inverter. Result: False
# 264) Keyword: punching bag. Result: False
# 265) Keyword: tape dispenser. Result: False
# 266) Keyword: martini. Result: True
# 267) Keyword: desktop computer. Result: False
# 268) Keyword: Dog shampoo. Result: False
# 269) Keyword: wonton. Result: False
# Question: Is it used primarily for entertainment purposes?  0.11895910780669144
# Num keywords in test set: 269
# 1) Keyword: dog tag. Result: False
# 2) Keyword: training cone. Result: False
# 3) Keyword: dinosaur skeleton. Result: True
# 4) Keyword: Urinal. Result: False
# 5) Keyword: wedding ring. Result: False
# 6) Keyword: neon light. Result: False
# 7) Keyword: chimney. Result: False
# 8) Keyword: plastic tube. Result: False
# 9) Keyword: seagull. Result: True
# 10) Keyword: leaf rake. Result: False
# 11) Keyword: entrance door. Result: False
# 12) Keyword: Plaque. Result: True
# 13) Keyword: beer coaster. Result: False
# 14) Keyword: domino. Result: False
# 15) Keyword: silicon. Result: True
# 16) Keyword: thermal underwear. Result: False
# 17) Keyword: Water Fountain. Result: False
# 18) Keyword: Face mask. Result: False
# 19) Keyword: peace lily. Result: True
# 20) Keyword: pea plant. Result: True
# 21) Keyword: cockroach. Result: True
# 22) Keyword: sweet tea. Result: False
# 23) Keyword: vegetarian chili. Result: False
# 24) Keyword: vegan chocolate. Result: True
# 25) Keyword: engine oil. Result: False
# 26) Keyword: grape. Result: True
# 27) Keyword: Stove. Result: False
# 28) Keyword: underwater camera. Result: False
# 29) Keyword: shipping container. Result: False
# 30) Keyword: rollercoaster. Result: False
# 31) Keyword: dill pickle. Result: False
# 32) Keyword: Cash Register. Result: False
# 33) Keyword: sandstorm. Result: True
# 34) Keyword: Latte. Result: False
# 35) Keyword: tank top. Result: False
# 36) Keyword: coke. Result: False
# 37) Keyword: Robot arm. Result: False
# 38) Keyword: Mixing Bowl. Result: False
# 39) Keyword: strainer. Result: False
# 40) Keyword: Portable speaker. Result: False
# 41) Keyword: Pumpkin pie. Result: False
# 42) Keyword: electric oven. Result: False
# 43) Keyword: thermometer probe. Result: False
# 44) Keyword: wonton. Result: False
# 45) Keyword: Exit sign. Result: False
# 46) Keyword: Mural. Result: False
# 47) Keyword: security gate. Result: False
# 48) Keyword: chicken wire. Result: False
# 49) Keyword: fuel filter. Result: False
# 50) Keyword: picture frame. Result: False
# 51) Keyword: Hair Dryer. Result: False
# 52) Keyword: Coffee beans. Result: True
# 53) Keyword: compactor. Result: False
# 54) Keyword: Snacks. Result: False
# 55) Keyword: shirt. Result: False
# 56) Keyword: parrot. Result: True
# 57) Keyword: duct. Result: False
# 58) Keyword: excavator. Result: False
# 59) Keyword: fanta. Result: False
# 60) Keyword: wire brush. Result: False
# 61) Keyword: Heart Rate Monitors. Result: False
# 62) Keyword: Hot dog. Result: False
# 63) Keyword: cordless phone. Result: False
# 64) Keyword: Sprinkler. Result: False
# 65) Keyword: mango. Result: True
# 66) Keyword: Sunscreen. Result: False
# 67) Keyword: Ointment. Result: False
# 68) Keyword: parking pass. Result: False
# 69) Keyword: Nap mat. Result: False
# 70) Keyword: dishcloth. Result: False
# 71) Keyword: nose. Result: False
# 72) Keyword: wall shelf. Result: False
# 73) Keyword: bookend. Result: False
# 74) Keyword: broken glass. Result: False
# 75) Keyword: Power Drill. Result: False
# 76) Keyword: window cleaner. Result: False
# 77) Keyword: Soybeans. Result: True
# 78) Keyword: grinder. Result: False
# 79) Keyword: broth. Result: False
# 80) Keyword: lace. Result: False
# 81) Keyword: Popcorn. Result: False
# 82) Keyword: buckle. Result: False
# 83) Keyword: Bottled Water. Result: False
# 84) Keyword: drill bit. Result: False
# 85) Keyword: Play mat. Result: False
# 86) Keyword: jack stand. Result: False
# 87) Keyword: HDMI cable. Result: False
# 88) Keyword: medallion. Result: False
# 89) Keyword: garden rake. Result: False
# 90) Keyword: conditioner. Result: False
# 91) Keyword: sling. Result: False
# 92) Keyword: compass. Result: False
# 93) Keyword: twine. Result: False
# 94) Keyword: rusty nail. Result: False
# 95) Keyword: tea leaf. Result: True
# 96) Keyword: Floor Mats. Result: False
# 97) Keyword: battery. Result: False
# 98) Keyword: lug. Result: False
# 99) Keyword: beer tap. Result: False
# 100) Keyword: Muffin Tin. Result: False
# 101) Keyword: Lottery Ticket. Result: False
# 102) Keyword: swimsuit. Result: False
# 103) Keyword: cutter. Result: False
# 104) Keyword: Wristband. Result: False
# 105) Keyword: Honeybee. Result: True
# 106) Keyword: Green beans. Result: True
# 107) Keyword: Donuts. Result: False
# 108) Keyword: Wall Art. Result: False
# 109) Keyword: Nachos. Result: False
# 110) Keyword: Vegetable. Result: True
# 111) Keyword: trinket box. Result: False
# 112) Keyword: ventilation fan. Result: False
# 113) Keyword: Scrap metal. Result: False
# 114) Keyword: Bread pudding. Result: False
# 115) Keyword: paint thinner. Result: False
# 116) Keyword: juicer. Result: False
# 117) Keyword: invoice. Result: False
# 118) Keyword: laundry cart. Result: False
# 119) Keyword: iris. Result: True
# 120) Keyword: gas cap. Result: False
# 121) Keyword: Joystick. Result: False
# 122) Keyword: electric motorcycle. Result: False
# 123) Keyword: clip. Result: False
# 124) Keyword: Velvet rope. Result: False
# 125) Keyword: power adapter. Result: False
# 126) Keyword: Train door. Result: False
# 127) Keyword: Metal detector. Result: True
# 128) Keyword: accent chair. Result: False
# 129) Keyword: Cooling Tower. Result: False
# 130) Keyword: drapery. Result: False
# 131) Keyword: Orange peel. Result: True
# 132) Keyword: ice pop. Result: False
# 133) Keyword: park map. Result: False
# 134) Keyword: refrigerator. Result: False
# 135) Keyword: bracelet. Result: False
# 136) Keyword: velvet rug. Result: False
# 137) Keyword: smartboard. Result: False
# 138) Keyword: dust jacket. Result: False
# 139) Keyword: Tweezers. Result: False
# 140) Keyword: Shin Guards. Result: False
# 141) Keyword: Wire rack. Result: False
# 142) Keyword: moving walkway. Result: False
# 143) Keyword: sword fern. Result: True
# 144) Keyword: Towel. Result: False
# 145) Keyword: crayfish. Result: True
# 146) Keyword: glass sheet. Result: False
# 147) Keyword: key ring. Result: False
# 148) Keyword: mount saint lias. Result: True
# 149) Keyword: Sewing Kit. Result: False
# 150) Keyword: cereal bar. Result: False
# 151) Keyword: evaporator. Result: False
# 152) Keyword: water dish. Result: False
# 153) Keyword: dashboard camera. Result: False
# 154) Keyword: aquarium salt. Result: False
# 155) Keyword: spider web. Result: True
# 156) Keyword: docket. Result: False
# 157) Keyword: toad. Result: True
# 158) Keyword: Hash browns. Result: False
# 159) Keyword: Dandelion. Result: True
# 160) Keyword: Ultraviolet Lamp. Result: False
# 161) Keyword: corkscrew. Result: False
# 162) Keyword: sauerkraut. Result: False
# 163) Keyword: plastic baggie. Result: False
# 164) Keyword: Sugar packet. Result: False
# 165) Keyword: Bonding Agent. Result: False
# 166) Keyword: Glove. Result: False
# 167) Keyword: metal foil. Result: False
# 168) Keyword: butter. Result: False
# 169) Keyword: electric razor. Result: False
# 170) Keyword: fire helmet. Result: False
# 171) Keyword: Paper towels. Result: False
# 172) Keyword: christmas tree. Result: True
# 173) Keyword: pilates. Result: False
# 174) Keyword: Notebook. Result: False
# 175) Keyword: sheetrock. Result: False
# 176) Keyword: Handbag. Result: False
# 177) Keyword: gecko. Result: True
# 178) Keyword: Nail Polish Remover. Result: False
# 179) Keyword: Wheelchair ramp. Result: False
# 180) Keyword: Gym Mats. Result: False
# 181) Keyword: Relish. Result: False
# 182) Keyword: Aprons. Result: False
# 183) Keyword: garment rack. Result: False
# 184) Keyword: parts cleaner. Result: False
# 185) Keyword: tire inflator. Result: False
# 186) Keyword: alfalfa. Result: True
# 187) Keyword: cinder block. Result: False
# 188) Keyword: impact crusher. Result: False
# 189) Keyword: handcuff. Result: False
# 190) Keyword: Curtains. Result: False
# 191) Keyword: model airplane. Result: False
# 192) Keyword: kheer. Result: False
# 193) Keyword: flashlight. Result: False
# 194) Keyword: power cord. Result: False
# 195) Keyword: Dynamite. Result: False
# 196) Keyword: glass figurine. Result: False
# 197) Keyword: cupcake. Result: False
# 198) Keyword: roadrunner. Result: True
# 199) Keyword: hazelnut tree. Result: True
# 200) Keyword: acorn. Result: True
# 201) Keyword: shower chair. Result: False
# 202) Keyword: Orange tree. Result: True
# 203) Keyword: tape measure. Result: False
# 204) Keyword: brochure stand. Result: False
# 205) Keyword: Contact lenses. Result: False
# 206) Keyword: yogurt container. Result: False
# 207) Keyword: leopard. Result: True
# 208) Keyword: butter knife. Result: False
# 209) Keyword: teddy bear. Result: False
# 210) Keyword: Satellite. Result: False
# 211) Keyword: denim. Result: False
# 212) Keyword: raccoon. Result: True
# 213) Keyword: Onyx. Result: True
# 214) Keyword: Generator. Result: False
# 215) Keyword: headband. Result: False
# 216) Keyword: Bug spray. Result: False
# 217) Keyword: ramen. Result: False
# 218) Keyword: maxi dress. Result: False
# 219) Keyword: Ticket stub. Result: False
# 220) Keyword: Graphing Calculator. Result: False
# 221) Keyword: volcanic ash. Result: True
# 222) Keyword: Croissant. Result: False
# 223) Keyword: Fanny pack. Result: False
# 224) Keyword: casket. Result: False
# 225) Keyword: cowboy boot. Result: False
# 226) Keyword: ruby. Result: True
# 227) Keyword: beech tree. Result: True
# 228) Keyword: Swing set. Result: False
# 229) Keyword: wasp. Result: True
# 230) Keyword: Reindeer. Result: True
# 231) Keyword: curling iron. Result: False
# 232) Keyword: ice tray. Result: False
# 233) Keyword: Suitcase. Result: False
# 234) Keyword: cruise ship. Result: False
# 235) Keyword: Cream cheese. Result: False
# 236) Keyword: Coat Rack. Result: False
# 237) Keyword: hospital bed. Result: False
# 238) Keyword: orange juice. Result: False
# 239) Keyword: carbon. Result: True
# 240) Keyword: colander. Result: False
# 241) Keyword: centerpiece. Result: True
# 242) Keyword: bread maker. Result: False
# 243) Keyword: yoga block. Result: False
# 244) Keyword: inverter. Result: False
# 245) Keyword: Soldering iron. Result: False
# 246) Keyword: unbuttoned jacket. Result: False
# 247) Keyword: Komodo dragon. Result: True
# 248) Keyword: dye. Result: True
# 249) Keyword: woolen blanket. Result: False
# 250) Keyword: lifter. Result: False
# 251) Keyword: webcam. Result: False
# 252) Keyword: butterfly. Result: True
# 253) Keyword: vintage clock. Result: False
# 254) Keyword: solar panel. Result: False
# 255) Keyword: Jewelry Box. Result: False
# 256) Keyword: medical gown. Result: False
# 257) Keyword: mousepad. Result: False
# 258) Keyword: aperol spritz. Result: False
# 259) Keyword: wastewater. Result: False
# 260) Keyword: Fridge magnet. Result: False
# 261) Keyword: overhead wire. Result: False
# 262) Keyword: drainage pipe. Result: False
# 263) Keyword: wine glass. Result: False
# 264) Keyword: measuring spoon. Result: False
# 265) Keyword: Planter Box. Result: False
# 266) Keyword: tile. Result: False
# 267) Keyword: legal pad. Result: False
# 268) Keyword: arrival board. Result: False
# 269) Keyword: vacuum cleaner. Result: False
# Question: Is it found in nature (not man-made)?  0.17472118959107807
# Num keywords in test set: 269
# 1) Keyword: wine glass. Result: True
# 2) Keyword: sunglasses. Result: False
# 3) Keyword: bacon. Result: True
# 4) Keyword: calculator. Result: False
# 5) Keyword: bread maker. Result: True
# 6) Keyword: flower crown. Result: False
# 7) Keyword: Watering Can. Result: False
# 8) Keyword: beech tree. Result: False
# 9) Keyword: tire. Result: False
# 10) Keyword: tape measure. Result: False
# 11) Keyword: Desk Chairs. Result: False
# 12) Keyword: stump. Result: False
# 13) Keyword: gold. Result: False
# 14) Keyword: exhibit sign. Result: False
# 15) Keyword: prairie sunflower. Result: False
# 16) Keyword: doughnut. Result: True
# 17) Keyword: limousine. Result: False
# 18) Keyword: medallion. Result: False
# 19) Keyword: yarrow. Result: False
# 20) Keyword: butterfly net. Result: False
# 21) Keyword: Brownies. Result: True
# 22) Keyword: Cheesecake. Result: True
# 23) Keyword: projector. Result: False
# 24) Keyword: Truck. Result: False
# 25) Keyword: nitrogen. Result: False
# 26) Keyword: Cinnamon roll. Result: True
# 27) Keyword: upright piano. Result: False
# 28) Keyword: lint trap. Result: False
# 29) Keyword: suture. Result: False
# 30) Keyword: sock. Result: False
# 31) Keyword: Ceiling fan. Result: False
# 32) Keyword: metal file. Result: False
# 33) Keyword: manicure set. Result: False
# 34) Keyword: polar bear. Result: False
# 35) Keyword: lime. Result: True
# 36) Keyword: travel pillow. Result: False
# 37) Keyword: rocketship. Result: False
# 38) Keyword: solar panel. Result: False
# 39) Keyword: Pencil Sharpener. Result: False
# 40) Keyword: rucksack. Result: False
# 41) Keyword: snowball. Result: False
# 42) Keyword: Gravity. Result: False
# 43) Keyword: iris. Result: False
# 44) Keyword: piano stool. Result: False
# 45) Keyword: power grid. Result: False
# 46) Keyword: frozen waffle. Result: True
# 47) Keyword: Piping tips. Result: True
# 48) Keyword: Litter scooper. Result: True
# 49) Keyword: Perfume. Result: False
# 50) Keyword: Security systems. Result: False
# 51) Keyword: pant. Result: False
# 52) Keyword: Safety harness. Result: False
# 53) Keyword: dead leaf. Result: False
# 54) Keyword: electric violin. Result: False
# 55) Keyword: Grapefruit. Result: True
# 56) Keyword: pepper spray. Result: False
# 57) Keyword: Oven door. Result: True
# 58) Keyword: Drapes. Result: False
# 59) Keyword: eyeglass. Result: False
# 60) Keyword: medical gown. Result: False
# 61) Keyword: linen. Result: True
# 62) Keyword: smoke alarm. Result: False
# 63) Keyword: parrotfish. Result: False
# 64) Keyword: brussel sprout. Result: True
# 65) Keyword: Irrigation system. Result: False
# 66) Keyword: GPS. Result: False
# 67) Keyword: Brochure. Result: False
# 68) Keyword: end table. Result: False
# 69) Keyword: Tissue box. Result: False
# 70) Keyword: DVD Player. Result: False
# 71) Keyword: Diving board. Result: False
# 72) Keyword: glass panel. Result: False
# 73) Keyword: internet router. Result: False
# 74) Keyword: pilates. Result: False
# 75) Keyword: legal pad. Result: False
# 76) Keyword: denim jeans. Result: False
# 77) Keyword: gas turbine. Result: False
# 78) Keyword: violin. Result: False
# 79) Keyword: silicon. Result: True
# 80) Keyword: pomegranate. Result: False
# 81) Keyword: Lego. Result: False
# 82) Keyword: potted plant. Result: False
# 83) Keyword: audio guide. Result: False
# 84) Keyword: hamster. Result: False
# 85) Keyword: Public Address System. Result: False
# 86) Keyword: grinder. Result: True
# 87) Keyword: Notebook. Result: False
# 88) Keyword: Water. Result: True
# 89) Keyword: ankle bracelet. Result: False
# 90) Keyword: Masks. Result: False
# 91) Keyword: bookend. Result: False
# 92) Keyword: Nap mat. Result: False
# 93) Keyword: Fanny pack. Result: False
# 94) Keyword: support beam. Result: False
# 95) Keyword: plastic pipe. Result: False
# 96) Keyword: nile monitor. Result: False
# 97) Keyword: electrical tape. Result: False
# 98) Keyword: sofa. Result: False
# 99) Keyword: Spatula. Result: True
# 100) Keyword: Hairspray. Result: False
# 101) Keyword: hot tea. Result: True
# 102) Keyword: Engravings. Result: False
# 103) Keyword: Water Fountain. Result: False
# 104) Keyword: Measuring Tape. Result: False
# 105) Keyword: desktop computer. Result: False
# 106) Keyword: DVD. Result: False
# 107) Keyword: safety railing. Result: False
# 108) Keyword: dishwasher. Result: True
# 109) Keyword: Emergency lights. Result: False
# 110) Keyword: Cauliflower. Result: True
# 111) Keyword: Scoreboard. Result: False
# 112) Keyword: wild garlic. Result: True
# 113) Keyword: Microwave. Result: True
# 114) Keyword: tape dispenser. Result: True
# 115) Keyword: Face mask. Result: False
# 116) Keyword: stationary bike. Result: False
# 117) Keyword: Baguette. Result: True
# 118) Keyword: sedge. Result: False
# 119) Keyword: glass figurine. Result: False
# 120) Keyword: plastic tub. Result: True
# 121) Keyword: Sugar packet. Result: True
# 122) Keyword: Rabbit. Result: False
# 123) Keyword: coffin. Result: False
# 124) Keyword: Rice pudding. Result: True
# 125) Keyword: butter. Result: True
# 126) Keyword: Air compressor. Result: False
# 127) Keyword: Binoculars. Result: False
# 128) Keyword: Muffler. Result: False
# 129) Keyword: lemon wedge. Result: True
# 130) Keyword: juniper bush. Result: False
# 131) Keyword: sea turtle. Result: False
# 132) Keyword: fox. Result: False
# 133) Keyword: concentrator. Result: False
# 134) Keyword: piranha. Result: False
# 135) Keyword: clip. Result: True
# 136) Keyword: battery bank. Result: False
# 137) Keyword: satellite dish. Result: False
# 138) Keyword: foil paper. Result: True
# 139) Keyword: Aprons. Result: True
# 140) Keyword: Pants. Result: False
# 141) Keyword: wisteria. Result: False
# 142) Keyword: Mobile phone. Result: False
# 143) Keyword: elbow pad. Result: False
# 144) Keyword: Ice cream maker. Result: True
# 145) Keyword: unbuttoned jacket. Result: False
# 146) Keyword: ziploc. Result: True
# 147) Keyword: Popcorn machine. Result: True
# 148) Keyword: paintbrush. Result: False
# 149) Keyword: curling iron. Result: False
# 150) Keyword: tire inflator. Result: False
# 151) Keyword: coffee bag. Result: True
# 152) Keyword: tin foil. Result: True
# 153) Keyword: Bobby Pins. Result: False
# 154) Keyword: purse. Result: False
# 155) Keyword: concrete block. Result: False
# 156) Keyword: car seat. Result: False
# 157) Keyword: Pesticide. Result: False
# 158) Keyword: ventilation fan. Result: True
# 159) Keyword: crochet hook. Result: False
# 160) Keyword: Oxygen tank. Result: False
# 161) Keyword: serving platter. Result: True
# 162) Keyword: steel sheet. Result: False
# 163) Keyword: vacuum cleaner. Result: False
# 164) Keyword: moving walkway. Result: False
# 165) Keyword: Mixing Bowl. Result: True
# 166) Keyword: angelfish. Result: False
# 167) Keyword: adjustable bench. Result: False
# 168) Keyword: cedar. Result: False
# 169) Keyword: sumantri. Result: False
# 170) Keyword: thumbtack. Result: False
# 171) Keyword: Puzzle. Result: False
# 172) Keyword: juniper tree. Result: False
# 173) Keyword: ukulele case. Result: False
# 174) Keyword: ham. Result: True
# 175) Keyword: trouser. Result: False
# 176) Keyword: Eucalyptus. Result: False
# 177) Keyword: Power Drill. Result: False
# 178) Keyword: moss ball. Result: False
# 179) Keyword: Tool Box. Result: False
# 180) Keyword: bunk bed. Result: False
# 181) Keyword: chutney. Result: True
# 182) Keyword: Touchscreen. Result: False
# 183) Keyword: toad. Result: False
# 184) Keyword: sealant. Result: True
# 185) Keyword: leaf rake. Result: False
# 186) Keyword: Turn signal. Result: False
# 187) Keyword: Power strip. Result: False
# 188) Keyword: glitter. Result: False
# 189) Keyword: Swing set. Result: False
# 190) Keyword: cannoli. Result: True
# 191) Keyword: cobweb. Result: False
# 192) Keyword: hydrant. Result: False
# 193) Keyword: spirit level. Result: False
# 194) Keyword: Umbrella stand. Result: False
# 195) Keyword: enamel. Result: True
# 196) Keyword: migraine. Result: False
# 197) Keyword: Gadget. Result: True
# 198) Keyword: Smoke Detector. Result: False
# 199) Keyword: pilates reformer. Result: False
# 200) Keyword: glass shelf. Result: True
# 201) Keyword: Fertilizer. Result: False
# 202) Keyword: mount saint lias. Result: False
# 203) Keyword: lace top. Result: False
# 204) Keyword: Bug spray. Result: False
# 205) Keyword: Plate. Result: True
# 206) Keyword: cinder block. Result: False
# 207) Keyword: Reptile. Result: False
# 208) Keyword: headboard. Result: False
# 209) Keyword: garden rake. Result: False
# 210) Keyword: Generator. Result: False
# 211) Keyword: wind chime. Result: False
# 212) Keyword: cherry tree. Result: False
# 213) Keyword: snake. Result: False
# 214) Keyword: Vase. Result: False
# 215) Keyword: volcanic ash. Result: False
# 216) Keyword: window cleaner. Result: True
# 217) Keyword: garment rack. Result: False
# 218) Keyword: shingle. Result: False
# 219) Keyword: Glove. Result: False
# 220) Keyword: Virus. Result: False
# 221) Keyword: mic stand. Result: False
# 222) Keyword: Pliers. Result: False
# 223) Keyword: Soldering iron. Result: False
# 224) Keyword: lemon juice. Result: True
# 225) Keyword: penguin. Result: False
# 226) Keyword: candle holder. Result: True
# 227) Keyword: woodpecker. Result: False
# 228) Keyword: electric saw. Result: False
# 229) Keyword: Coffee Makers. Result: True
# 230) Keyword: cold pack. Result: True
# 231) Keyword: drapery. Result: False
# 232) Keyword: wig. Result: False
# 233) Keyword: Ventilation System. Result: True
# 234) Keyword: needle. Result: False
# 235) Keyword: Turnstiles. Result: False
# 236) Keyword: Cereal. Result: True
# 237) Keyword: seahorse. Result: False
# 238) Keyword: lace. Result: False
# 239) Keyword: loose change. Result: False
# 240) Keyword: upholstered sofa. Result: False
# 241) Keyword: hospital bed. Result: False
# 242) Keyword: duct. Result: False
# 243) Keyword: Plaque. Result: False
# 244) Keyword: keyring. Result: False
# 245) Keyword: Lab coat. Result: False
# 246) Keyword: surgical drape. Result: False
# 247) Keyword: kiwifruit. Result: True
# 248) Keyword: Hard hat. Result: False
# 249) Keyword: bracelet. Result: False
# 250) Keyword: raccoon. Result: False
# 251) Keyword: archery target. Result: False
# 252) Keyword: cutter. Result: True
# 253) Keyword: seagrass. Result: False
# 254) Keyword: water jug. Result: True
# 255) Keyword: jello. Result: True
# 256) Keyword: wax. Result: True
# 257) Keyword: Iced coffee. Result: True
# 258) Keyword: calcite. Result: False
# 259) Keyword: rollercoaster. Result: False
# 260) Keyword: kelp. Result: False
# 261) Keyword: Wine Aerator. Result: True
# 262) Keyword: ignition system. Result: False
# 263) Keyword: christmas tree. Result: False
# 264) Keyword: Radio scanner. Result: False
# 265) Keyword: denim. Result: False
# 266) Keyword: noodle. Result: True
# 267) Keyword: electronic keyboard. Result: False
# 268) Keyword: cilantro. Result: True
# 269) Keyword: mri. Result: False
# Question: Is it something you would typically find in a kitchen?  0.24535315985130113
# Num keywords in test set: 269
# 1) Keyword: bonsai tree. Result: False
# 2) Keyword: traffic signal. Result: True
# 3) Keyword: Croissant. Result: False
# 4) Keyword: cable tray. Result: True
# 5) Keyword: serving bowl. Result: False
# 6) Keyword: steering wheel. Result: False
# 7) Keyword: chimpanzee. Result: False
# 8) Keyword: Spatula. Result: False
# 9) Keyword: Roots. Result: False
# 10) Keyword: Bath Mat. Result: False
# 11) Keyword: colander. Result: False
# 12) Keyword: compactor. Result: True
# 13) Keyword: Rice pudding. Result: False
# 14) Keyword: parrotfish. Result: False
# 15) Keyword: sedge. Result: False
# 16) Keyword: Television. Result: True
# 17) Keyword: French toast. Result: False
# 18) Keyword: Washing machine. Result: True
# 19) Keyword: Chocolate cake. Result: False
# 20) Keyword: Coffee beans. Result: False
# 21) Keyword: tupperware. Result: False
# 22) Keyword: owl. Result: False
# 23) Keyword: Pamphlet. Result: False
# 24) Keyword: fire hydrant. Result: False
# 25) Keyword: protein shake. Result: False
# 26) Keyword: rosemary. Result: False
# 27) Keyword: Scrap metal. Result: False
# 28) Keyword: serving platter. Result: False
# 29) Keyword: Salad Dressing. Result: False
# 30) Keyword: bird netting. Result: False
# 31) Keyword: wonton soup. Result: False
# 32) Keyword: yeast. Result: False
# 33) Keyword: Litter scooper. Result: False
# 34) Keyword: saltwater. Result: False
# 35) Keyword: Hazelnut. Result: False
# 36) Keyword: Play mat. Result: False
# 37) Keyword: Edamame. Result: False
# 38) Keyword: trench coat. Result: False
# 39) Keyword: ice crusher. Result: True
# 40) Keyword: honeydew melon. Result: False
# 41) Keyword: Brownies. Result: False
# 42) Keyword: Advertisement. Result: False
# 43) Keyword: Tool Box. Result: False
# 44) Keyword: Cardboard box. Result: False
# 45) Keyword: Bike. Result: False
# 46) Keyword: metal file. Result: False
# 47) Keyword: snake. Result: False
# 48) Keyword: fossil. Result: False
# 49) Keyword: book cover. Result: False
# 50) Keyword: Wireless Speaker. Result: True
# 51) Keyword: lug. Result: False
# 52) Keyword: Library Card. Result: False
# 53) Keyword: Floor jacks. Result: False
# 54) Keyword: wire hanger. Result: False
# 55) Keyword: Muffin. Result: False
# 56) Keyword: cannoli. Result: False
# 57) Keyword: shovel. Result: False
# 58) Keyword: audio guide. Result: True
# 59) Keyword: sword fern. Result: False
# 60) Keyword: VR Headset. Result: True
# 61) Keyword: dishtowel. Result: False
# 62) Keyword: melon. Result: False
# 63) Keyword: Paper towels. Result: False
# 64) Keyword: beer stein. Result: False
# 65) Keyword: pillowtop. Result: False
# 66) Keyword: fire helmet. Result: False
# 67) Keyword: Rabbit. Result: False
# 68) Keyword: Comic Book. Result: False
# 69) Keyword: corkscrew. Result: False
# 70) Keyword: thermometer probe. Result: True
# 71) Keyword: lace dress. Result: False
# 72) Keyword: Laser beam. Result: True
# 73) Keyword: cuff. Result: False
# 74) Keyword: drill bit. Result: False
# 75) Keyword: Resin. Result: False
# 76) Keyword: Video Camera. Result: True
# 77) Keyword: fern. Result: False
# 78) Keyword: Baguette. Result: False
# 79) Keyword: graduated cylinder. Result: False
# 80) Keyword: footbridge. Result: False
# 81) Keyword: denim. Result: False
# 82) Keyword: yarrow. Result: False
# 83) Keyword: possum. Result: False
# 84) Keyword: fennel. Result: False
# 85) Keyword: shaker. Result: True
# 86) Keyword: raspberry. Result: False
# 87) Keyword: iv bag. Result: False
# 88) Keyword: charging cord. Result: True
# 89) Keyword: Touchscreen. Result: True
# 90) Keyword: Fertilizer. Result: False
# 91) Keyword: solar panel. Result: False
# 92) Keyword: rail track. Result: False
# 93) Keyword: legal pad. Result: False
# 94) Keyword: concrete wall. Result: False
# 95) Keyword: enamel. Result: False
# 96) Keyword: Wine Aerator. Result: True
# 97) Keyword: penguin. Result: False
# 98) Keyword: Modem. Result: True
# 99) Keyword: Rolling pin. Result: False
# 100) Keyword: Menorah. Result: False
# 101) Keyword: Lego. Result: False
# 102) Keyword: oatmeal cookie. Result: False
# 103) Keyword: bar towel. Result: False
# 104) Keyword: lemon zest. Result: False
# 105) Keyword: northern mockingbird. Result: False
# 106) Keyword: pear tree. Result: False
# 107) Keyword: Electrical panel. Result: True
# 108) Keyword: sycamore tree. Result: False
# 109) Keyword: climber. Result: False
# 110) Keyword: butter. Result: False
# 111) Keyword: Fanny pack. Result: False
# 112) Keyword: casket. Result: False
# 113) Keyword: jack stand. Result: False
# 114) Keyword: Cooling Tower. Result: False
# 115) Keyword: candle holder. Result: False
# 116) Keyword: Hair Dryer. Result: True
# 117) Keyword: garden shovel. Result: False
# 118) Keyword: hanging hook. Result: False
# 119) Keyword: rangefinder. Result: True
# 120) Keyword: bumper. Result: False
# 121) Keyword: Fortune cookie. Result: False
# 122) Keyword: Desk Chairs. Result: False
# 123) Keyword: Public Address System. Result: True
# 124) Keyword: Shipping label. Result: False
# 125) Keyword: ukulele case. Result: False
# 126) Keyword: Chandelier. Result: True
# 127) Keyword: Drain Hose. Result: False
# 128) Keyword: grape. Result: False
# 129) Keyword: shower mat. Result: False
# 130) Keyword: espresso machine. Result: True
# 131) Keyword: gator. Result: False
# 132) Keyword: gelatin. Result: False
# 133) Keyword: sealing machine. Result: True
# 134) Keyword: hanging basket. Result: False
# 135) Keyword: vest. Result: False
# 136) Keyword: drainage pipe. Result: False
# 137) Keyword: coke. Result: False
# 138) Keyword: pipette. Result: False
# 139) Keyword: Furniture polish. Result: False
# 140) Keyword: flat shoe. Result: False
# 141) Keyword: Cream cheese. Result: False
# 142) Keyword: coconut. Result: False
# 143) Keyword: Hairspray. Result: False
# 144) Keyword: measuring spoon. Result: False
# 145) Keyword: power adapter. Result: True
# 146) Keyword: bumble bee. Result: False
# 147) Keyword: Guitar String. Result: False
# 148) Keyword: Frappuccino. Result: True
# 149) Keyword: Vegetable. Result: False
# 150) Keyword: Garbage Disposal. Result: True
# 151) Keyword: Raindrops. Result: False
# 152) Keyword: Soybeans. Result: False
# 153) Keyword: Pool cleaner. Result: True
# 154) Keyword: potato chip. Result: False
# 155) Keyword: Duffle Bags. Result: False
# 156) Keyword: milling. Result: True
# 157) Keyword: Swing set. Result: False
# 158) Keyword: Gadget. Result: True
# 159) Keyword: motorcycle. Result: False
# 160) Keyword: emergency lighting. Result: False
# 161) Keyword: sofa. Result: False
# 162) Keyword: ginger ale. Result: False
# 163) Keyword: dining chair. Result: False
# 164) Keyword: tomato plant. Result: False
# 165) Keyword: plastic pallet. Result: False
# 166) Keyword: dye. Result: False
# 167) Keyword: picnic basket. Result: False
# 168) Keyword: bunk bed. Result: False
# 169) Keyword: adjustable bench. Result: False
# 170) Keyword: IV. Result: True
# 171) Keyword: stump. Result: False
# 172) Keyword: garbage truck. Result: True
# 173) Keyword: sandhill crane. Result: False
# 174) Keyword: velvet couch. Result: False
# 175) Keyword: squash. Result: False
# 176) Keyword: Nap mat. Result: False
# 177) Keyword: Plaque. Result: False
# 178) Keyword: fan blade. Result: True
# 179) Keyword: juniper bush. Result: False
# 180) Keyword: safety railing. Result: False
# 181) Keyword: Silver ore. Result: False
# 182) Keyword: DVD. Result: True
# 183) Keyword: peony. Result: False
# 184) Keyword: sunglass. Result: False
# 185) Keyword: Nail clipper. Result: False
# 186) Keyword: piano stool. Result: False
# 187) Keyword: acorn. Result: False
# 188) Keyword: pepper spray. Result: False
# 189) Keyword: ankle bracelet. Result: True
# 190) Keyword: Escalators. Result: True
# 191) Keyword: survey marker. Result: False
# 192) Keyword: gutter. Result: False
# 193) Keyword: smith machine. Result: False
# 194) Keyword: Oven door. Result: True
# 195) Keyword: reading pillow. Result: False
# 196) Keyword: park map. Result: False
# 197) Keyword: skewer. Result: False
# 198) Keyword: yogurt container. Result: False
# 199) Keyword: bean. Result: False
# 200) Keyword: Anesthesia. Result: True
# 201) Keyword: Hair Gel. Result: False
# 202) Keyword: test strip. Result: False
# 203) Keyword: dust jacket. Result: False
# 204) Keyword: electric scooter. Result: True
# 205) Keyword: Earl Grey tea. Result: False
# 206) Keyword: sling. Result: False
# 207) Keyword: Hair clip. Result: False
# 208) Keyword: wooden spoon. Result: False
# 209) Keyword: weasel. Result: False
# 210) Keyword: snowdrift. Result: False
# 211) Keyword: fox. Result: False
# 212) Keyword: peace lily. Result: False
# 213) Keyword: cold pack. Result: False
# 214) Keyword: catheter. Result: False
# 215) Keyword: motion sensor. Result: True
# 216) Keyword: Fuse. Result: True
# 217) Keyword: wax. Result: False
# 218) Keyword: velvet rug. Result: False
# 219) Keyword: electric razor. Result: True
# 220) Keyword: dead leaf. Result: False
# 221) Keyword: fabric roll. Result: False
# 222) Keyword: stationary bike. Result: True
# 223) Keyword: shipping container. Result: False
# 224) Keyword: dishwasher. Result: True
# 225) Keyword: plastic chair. Result: False
# 226) Keyword: woodpecker. Result: False
# 227) Keyword: garment rack. Result: False
# 228) Keyword: hydrant. Result: False
# 229) Keyword: power cord. Result: True
# 230) Keyword: Elliptical Trainers. Result: True
# 231) Keyword: Bonding Agent. Result: False
# 232) Keyword: mousepad. Result: False
# 233) Keyword: ketchup. Result: False
# 234) Keyword: foam roller. Result: False
# 235) Keyword: Power lines. Result: True
# 236) Keyword: fur. Result: False
# 237) Keyword: Vending Machine. Result: True
# 238) Keyword: Silicone. Result: False
# 239) Keyword: nose ring. Result: False
# 240) Keyword: exhibit sign. Result: False
# 241) Keyword: cedar. Result: False
# 242) Keyword: Tulip. Result: False
# 243) Keyword: chime. Result: True
# 244) Keyword: flower crown. Result: False
# 245) Keyword: lipstick. Result: False
# 246) Keyword: diary. Result: False
# 247) Keyword: netgear. Result: True
# 248) Keyword: rose bush. Result: False
# 249) Keyword: cilantro. Result: False
# 250) Keyword: maxi dress. Result: False
# 251) Keyword: plant saucer. Result: False
# 252) Keyword: soundboard. Result: True
# 253) Keyword: sheetrock. Result: False
# 254) Keyword: camp stove. Result: False
# 255) Keyword: mangrove seedling. Result: False
# 256) Keyword: postage stamp. Result: False
# 257) Keyword: mango. Result: False
# 258) Keyword: carnation. Result: False
# 259) Keyword: cutter. Result: True
# 260) Keyword: Water Heater. Result: True
# 261) Keyword: aerator. Result: True
# 262) Keyword: Wine Opener. Result: True
# 263) Keyword: twine. Result: False
# 264) Keyword: nitrogen. Result: False
# 265) Keyword: shoelace. Result: False
# 266) Keyword: cardboard tube. Result: False
# 267) Keyword: peach tree. Result: False
# 268) Keyword: crochet hook. Result: False
# 269) Keyword: butterfly. Result: False
# Question: Does it require electricity to function?  0.20446096654275092

# %%
def generate_first_question(previous_questions):
    prompt = {
        "role": "system",
        "content": (
            "You are an data scientist who has dedicated his life's research to a scientific approach to the game 20 Questions."
            f"When requested, generate the best yes-or-no question that will reduce the remaining number of possible keywords by half."
            "The keyword is a specific thing, NOT a place and NOT a person."
            "Questions should be as vague and general as possible to attempt to eliminate 50% of possible keywords given the previous questions and answers. This is extremely important."
            "Additionally, it should not be one of the questions that the user has already tried."
            "Output the question only, no other text."
        ),
    }
    
    q_and_a = {
        "role": "user",
        "content": f"Here are the previous questions I've tried: {previous_questions}. Generate a new starting question please.",
    }
    
    messages = [prompt, q_and_a]
    
    response = completion("gpt-4o", messages).choices[0].message.content
    
    return response

# %%
previous_questions = []
for i in range(50):
    question = generate_first_question(previous_questions)
    print(f"Question: {question}")
    result, _, _ = test_keyword_percentage_eliminated(question, all_keywords, 0.1)
    print(f"Result: {result}\n___________\n")
    previous_questions.append(question)
# Out:
# Question: Is it a living thing?
# Num keywords in test set: 134
# 1) Keyword: Baguette. Result: False
# 2) Keyword: Guitar String. Result: False
# 3) Keyword: Cantaloupe. Result: True
# 4) Keyword: junction box. Result: False
# 5) Keyword: water snake. Result: True
# 6) Keyword: Nail polish. Result: False
# 7) Keyword: ham. Result: False
# 8) Keyword: grape juice. Result: False
# 9) Keyword: ice crusher. Result: False
# 10) Keyword: Tongue Depressor. Result: False
# 11) Keyword: internet router. Result: False
# 12) Keyword: Luggage. Result: False
# 13) Keyword: Oxygen tank. Result: False
# 14) Keyword: Sunscreen. Result: False
# 15) Keyword: Karaoke machine. Result: False
# 16) Keyword: lifting belt. Result: False
# 17) Keyword: trellis. Result: False
# 18) Keyword: Bulb. Result: False
# 19) Keyword: HDMI cable. Result: False
# 20) Keyword: Floor jacks. Result: False
# 21) Keyword: Utility Box. Result: False
# 22) Keyword: Fertilizer. Result: False
# 23) Keyword: maxi dress. Result: False
# 24) Keyword: wire hanger. Result: False
# 25) Keyword: Lego. Result: False
# 26) Keyword: Laptop. Result: False
# 27) Keyword: Television. Result: False
# 28) Keyword: school bus. Result: False
# 29) Keyword: sunglass. Result: False
# 30) Keyword: dolphin. Result: True
# 31) Keyword: Microwave. Result: False
# 32) Keyword: headboard. Result: False
# 33) Keyword: Stain Remover. Result: False
# 34) Keyword: domino. Result: False
# 35) Keyword: enamel. Result: False
# 36) Keyword: Play mat. Result: False
# 37) Keyword: wedding ring. Result: False
# 38) Keyword: Wine Opener. Result: False
# 39) Keyword: Emergency Exit Sign. Result: False
# 40) Keyword: wisteria. Result: True
# 41) Keyword: roadrunner. Result: True
# 42) Keyword: hamburger helper. Result: False
# 43) Keyword: weightlifting belt. Result: False
# 44) Keyword: Cream cheese. Result: False
# 45) Keyword: tow strap. Result: False
# 46) Keyword: carnation. Result: True
# 47) Keyword: velvet ribbon. Result: False
# 48) Keyword: picnic basket. Result: False
# 49) Keyword: Coffee grounds. Result: False
# 50) Keyword: Piping tips. Result: False
# 51) Keyword: gecko. Result: True
# 52) Keyword: Motorcycle Helmet. Result: False
# 53) Keyword: Pool cleaner. Result: False
# 54) Keyword: Towel. Result: False
# 55) Keyword: Bottled Water. Result: False
# 56) Keyword: metal lid. Result: False
# 57) Keyword: nile monitor. Result: True
# 58) Keyword: medical chart. Result: False
# 59) Keyword: beer glass. Result: False
# 60) Keyword: pear tree. Result: True
# 61) Keyword: desktop computer. Result: False
# 62) Keyword: lemon juice. Result: False
# 63) Keyword: Hamstring Curl Machine. Result: False
# 64) Keyword: Bookends. Result: False
# 65) Keyword: northern cardinal. Result: True
# 66) Keyword: Dump truck. Result: False
# 67) Keyword: fanta. Result: False
# 68) Keyword: hand lotion. Result: False
# 69) Keyword: Tablet. Result: False
# 70) Keyword: tiramisu. Result: False
# 71) Keyword: pillowtop. Result: False
# 72) Keyword: Shipping label. Result: False
# 73) Keyword: air tank. Result: False
# 74) Keyword: unripe banana. Result: True
# 75) Keyword: parachute. Result: False
# 76) Keyword: Tissue box. Result: False
# 77) Keyword: gelatin. Result: False
# 78) Keyword: Cardboard box. Result: False
# 79) Keyword: office chair. Result: False
# 80) Keyword: shovel. Result: False
# 81) Keyword: game board. Result: False
# 82) Keyword: sushi. Result: False
# 83) Keyword: Red wine. Result: False
# 84) Keyword: Relish. Result: False
# 85) Keyword: Lawnmower. Result: False
# 86) Keyword: telephone. Result: False
# 87) Keyword: Iron. Result: False
# 88) Keyword: palmetto tree. Result: True
# 89) Keyword: catheter. Result: False
# 90) Keyword: kelp. Result: True
# 91) Keyword: pail. Result: False
# 92) Keyword: gator. Result: True
# 93) Keyword: handcuff. Result: False
# 94) Keyword: hat. Result: False
# 95) Keyword: wonton. Result: False
# 96) Keyword: thumbtack. Result: False
# 97) Keyword: audio guide. Result: False
# 98) Keyword: tile. Result: False
# 99) Keyword: Golf Cart. Result: False
# 100) Keyword: eye. Result: False
# 101) Keyword: cholla cactus. Result: True
# 102) Keyword: Sleeping bag. Result: False
# 103) Keyword: adhd medication. Result: False
# 104) Keyword: fox. Result: True
# 105) Keyword: Water Buffalo. Result: True
# 106) Keyword: paint sprayer. Result: False
# 107) Keyword: fern. Result: True
# 108) Keyword: steak. Result: False
# 109) Keyword: sweet tea. Result: False
# 110) Keyword: safety railing. Result: False
# 111) Keyword: Polyester. Result: False
# 112) Keyword: electric fan. Result: False
# 113) Keyword: beach umbrella. Result: False
# 114) Keyword: cilantro. Result: True
# 115) Keyword: plastic pipe. Result: False
# 116) Keyword: beer stein. Result: False
# 117) Keyword: swimsuit. Result: False
# 118) Keyword: wine decanter. Result: False
# 119) Keyword: measuring spoon. Result: False
# 120) Keyword: mousepad. Result: False
# 121) Keyword: varnish. Result: False
# 122) Keyword: dye. Result: False
# 123) Keyword: Vanity mirror. Result: False
# 124) Keyword: mango. Result: True
# 125) Keyword: Hiking boots. Result: False
# 126) Keyword: twine. Result: False
# 127) Keyword: cordless phone. Result: False
# 128) Keyword: Fitness tracker. Result: False
# 129) Keyword: transmission tower. Result: False
# 130) Keyword: Muffler. Result: False
# 131) Keyword: knapweed. Result: True
# 132) Keyword: fallen tree. Result: False
# 133) Keyword: swamp milkweed. Result: True
# 134) Keyword: Lottery Ticket. Result: False
# Result: 0.16417910447761194
# ___________
#
# Question: Is it man-made?
# Num keywords in test set: 134
# 1) Keyword: rosemary. Result: False
# 2) Keyword: calculator. Result: True
# 3) Keyword: wood chip. Result: False
# 4) Keyword: glass panel. Result: True
# 5) Keyword: dj turntable. Result: True
# 6) Keyword: apricot tree. Result: False
# 7) Keyword: rose bush. Result: False
# 8) Keyword: Scoreboard. Result: True
# 9) Keyword: Piping tips. Result: True
# 10) Keyword: spider web. Result: False
# 11) Keyword: battery. Result: True
# 12) Keyword: saucer. Result: True
# 13) Keyword: igloo. Result: True
# 14) Keyword: parrot. Result: False
# 15) Keyword: cereal bar. Result: True
# 16) Keyword: Rabbit. Result: False
# 17) Keyword: sushi. Result: True
# 18) Keyword: candle holder. Result: True
# 19) Keyword: pizza box. Result: True
# 20) Keyword: Ice cream maker. Result: True
# 21) Keyword: DVD Player. Result: True
# 22) Keyword: leash. Result: True
# 23) Keyword: Engravings. Result: True
# 24) Keyword: tape measure. Result: True
# 25) Keyword: weasel. Result: False
# 26) Keyword: Necklace. Result: True
# 27) Keyword: mri. Result: True
# 28) Keyword: Mural. Result: True
# 29) Keyword: Garbage Disposal. Result: True
# 30) Keyword: centerpiece. Result: True
# 31) Keyword: redwood tree. Result: False
# 32) Keyword: cordless phone. Result: True
# 33) Keyword: conditioner. Result: True
# 34) Keyword: Hair Gel. Result: True
# 35) Keyword: chicken wire. Result: True
# 36) Keyword: sandstorm. Result: False
# 37) Keyword: beer stein. Result: True
# 38) Keyword: model airplane. Result: True
# 39) Keyword: clock. Result: True
# 40) Keyword: beach chair. Result: True
# 41) Keyword: Hazelnut. Result: False
# 42) Keyword: office chair. Result: True
# 43) Keyword: chimney. Result: True
# 44) Keyword: Aprons. Result: True
# 45) Keyword: elastic bandage. Result: True
# 46) Keyword: Irrigation system. Result: True
# 47) Keyword: ducky. Result: False
# 48) Keyword: buckle. Result: True
# 49) Keyword: Sunscreen. Result: True
# 50) Keyword: chocolate bar. Result: True
# 51) Keyword: Red velvet cake. Result: True
# 52) Keyword: woodpecker. Result: False
# 53) Keyword: Ceiling fan. Result: True
# 54) Keyword: cactus flower. Result: False
# 55) Keyword: ruler. Result: True
# 56) Keyword: shirt. Result: True
# 57) Keyword: piano stool. Result: True
# 58) Keyword: peeler. Result: True
# 59) Keyword: exhibit sign. Result: True
# 60) Keyword: Furniture. Result: True
# 61) Keyword: juice box. Result: True
# 62) Keyword: Phone charger. Result: True
# 63) Keyword: butterfly. Result: False
# 64) Keyword: Cinnamon roll. Result: True
# 65) Keyword: spray. Result: True
# 66) Keyword: Vanilla Extract. Result: False
# 67) Keyword: cotton. Result: False
# 68) Keyword: fox. Result: False
# 69) Keyword: Stove. Result: True
# 70) Keyword: petroleum. Result: False
# 71) Keyword: Index Card. Result: True
# 72) Keyword: metal file. Result: True
# 73) Keyword: raccoon. Result: False
# 74) Keyword: Floor Mats. Result: True
# 75) Keyword: cable tie. Result: True
# 76) Keyword: hazelnut tree. Result: False
# 77) Keyword: power cable. Result: True
# 78) Keyword: oar. Result: True
# 79) Keyword: Food bowl. Result: True
# 80) Keyword: water bowl. Result: True
# 81) Keyword: gown. Result: True
# 82) Keyword: Interstate. Result: True
# 83) Keyword: Board Games. Result: True
# 84) Keyword: Water Fountain. Result: True
# 85) Keyword: shipping container. Result: True
# 86) Keyword: throw blanket. Result: True
# 87) Keyword: sweetgum tree. Result: False
# 88) Keyword: thumbtack. Result: True
# 89) Keyword: Olive Oil. Result: False
# 90) Keyword: Lightbulb. Result: True
# 91) Keyword: High Chair. Result: True
# 92) Keyword: curling iron. Result: True
# 93) Keyword: plastic pipe. Result: True
# 94) Keyword: chair cushion. Result: True
# 95) Keyword: Bollards. Result: True
# 96) Keyword: squash. Result: False
# 97) Keyword: hvac system. Result: True
# 98) Keyword: legal pad. Result: True
# 99) Keyword: enamel pin. Result: True
# 100) Keyword: Nail Polish Remover. Result: True
# 101) Keyword: metal foil. Result: True
# 102) Keyword: mesquite tree. Result: False
# 103) Keyword: bald eagle. Result: False
# 104) Keyword: Drain Hose. Result: True
# 105) Keyword: Virus. Result: True
# 106) Keyword: ankle bracelet. Result: True
# 107) Keyword: lifter. Result: True
# 108) Keyword: clothes rack. Result: True
# 109) Keyword: Tongue Depressor. Result: True
# 110) Keyword: Medication. Result: True
# 111) Keyword: vest. Result: True
# 112) Keyword: gift box. Result: True
# 113) Keyword: nokia phone. Result: True
# 114) Keyword: beach umbrella. Result: True
# 115) Keyword: Pliers. Result: True
# 116) Keyword: snowdrift. Result: False
# 117) Keyword: tow strap. Result: True
# 118) Keyword: vietnamese coffee. Result: True
# 119) Keyword: Cash Register. Result: True
# 120) Keyword: Space probe. Result: True
# 121) Keyword: Utility Cart. Result: True
# 122) Keyword: Personal protective equipment. Result: True
# 123) Keyword: Violin Strings. Result: True
# 124) Keyword: chiller. Result: True
# 125) Keyword: GPS. Result: True
# 126) Keyword: cold pack. Result: True
# 127) Keyword: excavator. Result: True
# 128) Keyword: whisk. Result: True
# 129) Keyword: spirit level. Result: True
# 130) Keyword: Luggage. Result: True
# 131) Keyword: Apple pie. Result: True
# 132) Keyword: gold. Result: False
# 133) Keyword: carbon. Result: False
# 134) Keyword: Golf Cart. Result: True
# Result: 0.7835820895522388
# ___________
#
# Question: Is it larger than a microwave?
# Num keywords in test set: 134
# 1) Keyword: pillowcase. Result: False
# 2) Keyword: hair clipper. Result: True
# 3) Keyword: wood chip. Result: False
# 4) Keyword: hand drill. Result: True
# 5) Keyword: Tweezers. Result: False
# 6) Keyword: cable tie. Result: False
# 7) Keyword: Stage lights. Result: True
# 8) Keyword: arrival board. Result: True
# 9) Keyword: plastic chair. Result: True
# 10) Keyword: DVD. Result: True
# 11) Keyword: desk lamp. Result: False
# 12) Keyword: upholstered sofa. Result: True
# 13) Keyword: electronic piano. Result: True
# 14) Keyword: voice recorder. Result: False
# 15) Keyword: Anesthesia. Result: False
# 16) Keyword: compass. Result: False
# 17) Keyword: weighing scale. Result: True
# 18) Keyword: Utility Box. Result: True
# 19) Keyword: possum. Result: True
# 20) Keyword: garden fork. Result: True
# 21) Keyword: tote bin. Result: True
# 22) Keyword: hanging basket. Result: False
# 23) Keyword: lipstick. Result: False
# 24) Keyword: Sound system. Result: True
# 25) Keyword: motion sensor. Result: False
# 26) Keyword: Emergency lights. Result: False
# 27) Keyword: Scratching posts. Result: True
# 28) Keyword: lace. Result: False
# 29) Keyword: motorcycle. Result: True
# 30) Keyword: air handler. Result: True
# 31) Keyword: coke. Result: True
# 32) Keyword: eruption. Result: False
# 33) Keyword: tire inflator. Result: True
# 34) Keyword: Graphing Calculator. Result: False
# 35) Keyword: coffin. Result: True
# 36) Keyword: Sticky notes. Result: False
# 37) Keyword: docket. Result: False
# 38) Keyword: Shipping label. Result: False
# 39) Keyword: Tricycle. Result: True
# 40) Keyword: Reptile. Result: False
# 41) Keyword: Soldering iron. Result: False
# 42) Keyword: nitrous. Result: False
# 43) Keyword: dresser. Result: True
# 44) Keyword: dishcloth. Result: False
# 45) Keyword: Hand dryer. Result: True
# 46) Keyword: daisy. Result: False
# 47) Keyword: tire gauge. Result: False
# 48) Keyword: wii. Result: True
# 49) Keyword: saltwater. Result: False
# 50) Keyword: fanta. Result: True
# 51) Keyword: Snacks. Result: False
# 52) Keyword: Ceiling fan. Result: True
# 53) Keyword: clothes rack. Result: True
# 54) Keyword: jaffa cake. Result: False
# 55) Keyword: pant. Result: False
# 56) Keyword: slit. Result: False
# 57) Keyword: cutter. Result: False
# 58) Keyword: wine glass. Result: False
# 59) Keyword: Floor Mats. Result: True
# 60) Keyword: Fried rice. Result: False
# 61) Keyword: skewer. Result: False
# 62) Keyword: Lathe. Result: True
# 63) Keyword: eyeglass. Result: False
# 64) Keyword: fallen tree. Result: True
# 65) Keyword: sunglass. Result: False
# 66) Keyword: saucer. Result: True
# 67) Keyword: vegan chocolate. Result: False
# 68) Keyword: lace dress. Result: False
# 69) Keyword: drill bit. Result: False
# 70) Keyword: RV. Result: True
# 71) Keyword: Bookends. Result: True
# 72) Keyword: milling. Result: False
# 73) Keyword: Disinfectant. Result: False
# 74) Keyword: climber. Result: False
# 75) Keyword: cuticle. Result: False
# 76) Keyword: Honeybee. Result: False
# 77) Keyword: pear tree. Result: True
# 78) Keyword: gator. Result: True
# 79) Keyword: swamp milkweed. Result: False
# 80) Keyword: conditioner. Result: True
# 81) Keyword: picture frame. Result: True
# 82) Keyword: Smartwatch. Result: False
# 83) Keyword: training cone. Result: False
# 84) Keyword: Robot arm. Result: True
# 85) Keyword: Fuse. Result: False
# 86) Keyword: Suitcase. Result: True
# 87) Keyword: Food warmers. Result: True
# 88) Keyword: Tablet. Result: False
# 89) Keyword: honeydew. Result: True
# 90) Keyword: salt scrub. Result: False
# 91) Keyword: trinket box. Result: False
# 92) Keyword: Sticker. Result: False
# 93) Keyword: sauerkraut. Result: True
# 94) Keyword: ruby. Result: False
# 95) Keyword: Rivet. Result: False
# 96) Keyword: aspirin. Result: False
# 97) Keyword: beer stein. Result: True
# 98) Keyword: rainboot. Result: True
# 99) Keyword: woodpecker. Result: False
# 100) Keyword: Hiking boots. Result: False
# 101) Keyword: brussel sprout. Result: False
# 102) Keyword: Eucalyptus. Result: True
# 103) Keyword: charger. Result: False
# 104) Keyword: tank top. Result: False
# 105) Keyword: silicon. Result: False
# 106) Keyword: climbing rope. Result: True
# 107) Keyword: raccoon. Result: True
# 108) Keyword: Inhaler. Result: False
# 109) Keyword: coffee table. Result: True
# 110) Keyword: Stained glass window. Result: True
# 111) Keyword: Irrigation system. Result: True
# 112) Keyword: cocktail glass. Result: False
# 113) Keyword: dogwood. Result: False
# 114) Keyword: aperol spritz. Result: False
# 115) Keyword: Utility Cart. Result: True
# 116) Keyword: pumpkin. Result: True
# 117) Keyword: Gas Mask. Result: False
# 118) Keyword: rangefinder. Result: False
# 119) Keyword: sweet tea. Result: False
# 120) Keyword: concrete block. Result: True
# 121) Keyword: cockroach. Result: True
# 122) Keyword: Pry Bar. Result: True
# 123) Keyword: shirt. Result: False
# 124) Keyword: juniper bush. Result: True
# 125) Keyword: Incense. Result: False
# 126) Keyword: Salad Dressing. Result: False
# 127) Keyword: Hash browns. Result: False
# 128) Keyword: elbow pad. Result: True
# 129) Keyword: agave plant. Result: True
# 130) Keyword: Blinds. Result: True
# 131) Keyword: apple. Result: False
# 132) Keyword: fire hydrant. Result: True
# 133) Keyword: Measuring Tape. Result: True
# 134) Keyword: livestock trailer. Result: True
# Result: 0.4626865671641791
# ___________
#
# Question: Is it commonly found indoors?
# Num keywords in test set: 134
# 1) Keyword: footbridge. Result: False
# 2) Keyword: reading glasses. Result: True
# 3) Keyword: glass panel. Result: True
# 4) Keyword: crutch. Result: True
# 5) Keyword: vegan chocolate. Result: True
# 6) Keyword: Pickaxe. Result: False
# 7) Keyword: strainer. Result: True
# 8) Keyword: Karaoke machine. Result: True
# 9) Keyword: clog. Result: True
# 10) Keyword: safety goggles. Result: True
# 11) Keyword: Water Bottle. Result: True
# 12) Keyword: shower chair. Result: True
# 13) Keyword: giraffe. Result: False
# 14) Keyword: earplug. Result: True
# 15) Keyword: melon. Result: False
# 16) Keyword: sewage system. Result: True
# 17) Keyword: Sticky notes. Result: True
# 18) Keyword: Scones. Result: False
# 19) Keyword: Deciduous tree. Result: False
# 20) Keyword: fanta. Result: False
# 21) Keyword: Puzzle. Result: True
# 22) Keyword: mucus. Result: True
# 23) Keyword: protein shake. Result: True
# 24) Keyword: invoice. Result: False
# 25) Keyword: cardboard. Result: True
# 26) Keyword: DVD Player. Result: True
# 27) Keyword: Train door. Result: False
# 28) Keyword: Spatula. Result: True
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[415], line 5
#       3 question = generate_first_question(previous_questions)
#       4 print(f"Question: {question}")
# ----> 5 result, _, _ = test_keyword_percentage_eliminated(question, all_keywords, 0.1)
#       6 print(f"Result: {result}\n___________\n")
#       7 previous_questions.append(question)
#
# Cell In[240], line 19, in test_keyword_percentage_eliminated(question, keywords, keyword_test_percentage)
#      14 remaining_keywords_no = []
#      15 for x, keyword in enumerate(keyword_test_set):
#      16     #evaluations = [evaluate_keyword(fact, keyword) for _ in range(3)]
#      17     #result = most_common(evaluations)
#      18     #print(f"{x+1}) Keyword: {keyword}. Results: {evaluations} -> {result}")
# ---> 19     result = evaluate_keyword(fact, keyword)
#      20     print(f"{x+1}) Keyword: {keyword}. Result: {result}")
#      21     if result:
#
# Cell In[410], line 27, in evaluate_keyword(fact, keyword)
#      20 q_and_a = {
#      21     "role": "user",
#      22     "content": f"Fact: {fact}\nKeyword: {keyword}",
#      23 }
#      25 messages = [prompt, q_and_a]
# ---> 27 response = completion("gpt-4o-mini", messages).choices[0].message.content
#      29 return "t" in response.lower()
#
# Cell In[3], line 2, in completion(model, messages)
#       1 def completion(model, messages):
# ----> 2     result = litellm.completion(model, messages)
#       3     if "claude" in model:
#       4         time.sleep(60/50) # Adjust based on rate limit (https://console.anthropic.com/settings/limits)
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/litellm/utils.py:902, in client.<locals>.wrapper(*args, **kwargs)
#     900         print_verbose(f"Error while checking max token limit: {str(e)}")
#     901 # MODEL CALL
# --> 902 result = original_function(*args, **kwargs)
#     903 end_time = datetime.datetime.now()
#     904 if "stream" in kwargs and kwargs["stream"] == True:
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/litellm/main.py:1334, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_tokens, presence_penalty, frequency_penalty, logit_bias, user, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, **kwargs)
#    1332 ## COMPLETION CALL
#    1333 try:
# -> 1334     response = openai_chat_completions.completion(
#    1335         model=model,
#    1336         messages=messages,
#    1337         headers=headers,
#    1338         model_response=model_response,
#    1339         print_verbose=print_verbose,
#    1340         api_key=api_key,
#    1341         api_base=api_base,
#    1342         acompletion=acompletion,
#    1343         logging_obj=logging,
#    1344         optional_params=optional_params,
#    1345         litellm_params=litellm_params,
#    1346         logger_fn=logger_fn,
#    1347         timeout=timeout,  # type: ignore
#    1348         custom_prompt_dict=custom_prompt_dict,
#    1349         client=client,  # pass AsyncOpenAI, OpenAI client
#    1350         organization=organization,
#    1351         custom_llm_provider=custom_llm_provider,
#    1352     )
#    1353 except Exception as e:
#    1354     ## LOGGING - log the original exception returned
#    1355     logging.post_call(
#    1356         input=messages,
#    1357         api_key=api_key,
#    1358         original_response=str(e),
#    1359         additional_args={"headers": headers},
#    1360     )
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/litellm/llms/openai.py:948, in OpenAIChatCompletion.completion(self, model_response, timeout, optional_params, model, messages, print_verbose, api_key, api_base, acompletion, logging_obj, litellm_params, logger_fn, headers, custom_prompt_dict, client, organization, custom_llm_provider, drop_params)
#     935 ## LOGGING
#     936 logging_obj.pre_call(
#     937     input=messages,
#     938     api_key=openai_client.api_key,
#    (...)
#     944     },
#     945 )
#     947 headers, response = (
# --> 948     self.make_sync_openai_chat_completion_request(
#     949         openai_client=openai_client,
#     950         data=data,
#     951         timeout=timeout,
#     952     )
#     953 )
#     955 logging_obj.model_call_details["response_headers"] = headers
#     956 stringified_response = response.model_dump()
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/litellm/llms/openai.py:808, in OpenAIChatCompletion.make_sync_openai_chat_completion_request(self, openai_client, data, timeout)
#     806         return headers, response
#     807     else:
# --> 808         response = openai_client.chat.completions.create(
#     809             **data, timeout=timeout
#     810         )
#     811         return None, response
#     812 except Exception as e:
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/openai/_utils/_utils.py:277, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     275             msg = f"Missing required argument: {quote(missing[0])}"
#     276     raise TypeError(msg)
# --> 277 return func(*args, **kwargs)
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/openai/resources/chat/completions.py:646, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, parallel_tool_calls, presence_penalty, response_format, seed, service_tier, stop, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     612 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     613 def create(
#     614     self,
#    (...)
#     644     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     645 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
# --> 646     return self._post(
#     647         "/chat/completions",
#     648         body=maybe_transform(
#     649             {
#     650                 "messages": messages,
#     651                 "model": model,
#     652                 "frequency_penalty": frequency_penalty,
#     653                 "function_call": function_call,
#     654                 "functions": functions,
#     655                 "logit_bias": logit_bias,
#     656                 "logprobs": logprobs,
#     657                 "max_tokens": max_tokens,
#     658                 "n": n,
#     659                 "parallel_tool_calls": parallel_tool_calls,
#     660                 "presence_penalty": presence_penalty,
#     661                 "response_format": response_format,
#     662                 "seed": seed,
#     663                 "service_tier": service_tier,
#     664                 "stop": stop,
#     665                 "stream": stream,
#     666                 "stream_options": stream_options,
#     667                 "temperature": temperature,
#     668                 "tool_choice": tool_choice,
#     669                 "tools": tools,
#     670                 "top_logprobs": top_logprobs,
#     671                 "top_p": top_p,
#     672                 "user": user,
#     673             },
#     674             completion_create_params.CompletionCreateParams,
#     675         ),
#     676         options=make_request_options(
#     677             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     678         ),
#     679         cast_to=ChatCompletion,
#     680         stream=stream or False,
#     681         stream_cls=Stream[ChatCompletionChunk],
#     682     )
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/openai/_base_client.py:1266, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1252 def post(
#    1253     self,
#    1254     path: str,
#    (...)
#    1261     stream_cls: type[_StreamT] | None = None,
#    1262 ) -> ResponseT | _StreamT:
#    1263     opts = FinalRequestOptions.construct(
#    1264         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1265     )
# -> 1266     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/openai/_base_client.py:942, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     933 def request(
#     934     self,
#     935     cast_to: Type[ResponseT],
#    (...)
#     940     stream_cls: type[_StreamT] | None = None,
#     941 ) -> ResponseT | _StreamT:
# --> 942     return self._request(
#     943         cast_to=cast_to,
#     944         options=options,
#     945         stream=stream,
#     946         stream_cls=stream_cls,
#     947         remaining_retries=remaining_retries,
#     948     )
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/openai/_base_client.py:978, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     975 log.debug("Sending HTTP Request: %s %s", request.method, request.url)
#     977 try:
# --> 978     response = self._client.send(
#     979         request,
#     980         stream=stream or self._should_stream_response_body(request=request),
#     981         **kwargs,
#     982     )
#     983 except httpx.TimeoutException as err:
#     984     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/httpx/_client.py:915, in Client.send(self, request, stream, auth, follow_redirects)
#     907 follow_redirects = (
#     908     self.follow_redirects
#     909     if isinstance(follow_redirects, UseClientDefault)
#     910     else follow_redirects
#     911 )
#     913 auth = self._build_request_auth(request, auth)
# --> 915 response = self._send_handling_auth(
#     916     request,
#     917     auth=auth,
#     918     follow_redirects=follow_redirects,
#     919     history=[],
#     920 )
#     921 try:
#     922     if not stream:
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/httpx/_client.py:943, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     940 request = next(auth_flow)
#     942 while True:
# --> 943     response = self._send_handling_redirects(
#     944         request,
#     945         follow_redirects=follow_redirects,
#     946         history=history,
#     947     )
#     948     try:
#     949         try:
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/httpx/_client.py:980, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     977 for hook in self._event_hooks["request"]:
#     978     hook(request)
# --> 980 response = self._send_single_request(request)
#     981 try:
#     982     for hook in self._event_hooks["response"]:
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/httpx/_client.py:1016, in Client._send_single_request(self, request)
#    1011     raise RuntimeError(
#    1012         "Attempted to send an async request with a sync Client instance."
#    1013     )
#    1015 with request_context(request=request):
# -> 1016     response = transport.handle_request(request)
#    1018 assert isinstance(response.stream, SyncByteStream)
#    1020 response.request = request
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/httpx/_transports/default.py:231, in HTTPTransport.handle_request(self, request)
#     218 req = httpcore.Request(
#     219     method=request.method,
#     220     url=httpcore.URL(
#    (...)
#     228     extensions=request.extensions,
#     229 )
#     230 with map_httpcore_exceptions():
# --> 231     resp = self._pool.handle_request(req)
#     233 assert isinstance(resp.stream, typing.Iterable)
#     235 return Response(
#     236     status_code=resp.status,
#     237     headers=resp.headers,
#     238     stream=ResponseStream(resp.stream),
#     239     extensions=resp.extensions,
#     240 )
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:268, in ConnectionPool.handle_request(self, request)
#     266     with ShieldCancellation():
#     267         self.response_closed(status)
# --> 268     raise exc
#     269 else:
#     270     break
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:251, in ConnectionPool.handle_request(self, request)
#     248         raise exc
#     250 try:
# --> 251     response = connection.handle_request(request)
#     252 except ConnectionNotAvailable:
#     253     # The ConnectionNotAvailable exception is a special case, that
#     254     # indicates we need to retry the request on a new connection.
#    (...)
#     258     # might end up as an HTTP/2 connection, but which actually ends
#     259     # up as HTTP/1.1.
#     260     with self._pool_lock:
#     261         # Maintain our position in the request queue, but reset the
#     262         # status so that the request becomes queued again.
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     elif not self._connection.is_available():
#     101         raise ConnectionNotAvailable()
# --> 103 return self._connection.handle_request(request)
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/httpcore/_sync/http11.py:133, in HTTP11Connection.handle_request(self, request)
#     131     with Trace("response_closed", logger, request) as trace:
#     132         self._response_closed()
# --> 133 raise exc
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/httpcore/_sync/http11.py:111, in HTTP11Connection.handle_request(self, request)
#     101     pass
#     103 with Trace(
#     104     "receive_response_headers", logger, request, kwargs
#     105 ) as trace:
#     106     (
#     107         http_version,
#     108         status,
#     109         reason_phrase,
#     110         headers,
# --> 111     ) = self._receive_response_headers(**kwargs)
#     112     trace.return_value = (
#     113         http_version,
#     114         status,
#     115         reason_phrase,
#     116         headers,
#     117     )
#     119 return Response(
#     120     status=status,
#     121     headers=headers,
#    (...)
#     127     },
#     128 )
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/httpcore/_sync/http11.py:176, in HTTP11Connection._receive_response_headers(self, request)
#     173 timeout = timeouts.get("read", None)
#     175 while True:
# --> 176     event = self._receive_event(timeout=timeout)
#     177     if isinstance(event, h11.Response):
#     178         break
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/httpcore/_sync/http11.py:212, in HTTP11Connection._receive_event(self, timeout)
#     209     event = self._h11_state.next_event()
#     211 if event is h11.NEED_DATA:
# --> 212     data = self._network_stream.read(
#     213         self.READ_NUM_BYTES, timeout=timeout
#     214     )
#     216     # If we feed this case through h11 we'll raise an exception like:
#     217     #
#     218     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     222     # perspective. Instead we handle this case distinctly and treat
#     223     # it as a ConnectError.
#     224     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/httpcore/_backends/sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
# --> 126     return self._sock.recv(max_bytes)
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/ssl.py:1296, in SSLSocket.recv(self, buflen, flags)
#    1292     if flags != 0:
#    1293         raise ValueError(
#    1294             "non-zero flags not allowed in calls to recv() on %s" %
#    1295             self.__class__)
# -> 1296     return self.read(buflen)
#    1297 else:
#    1298     return super().recv(buflen, flags)
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/ssl.py:1169, in SSLSocket.read(self, len, buffer)
#    1167         return self._sslobj.read(len, buffer)
#    1168     else:
# -> 1169         return self._sslobj.read(len)
#    1170 except SSLError as x:
#    1171     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

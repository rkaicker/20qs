# %% [markdown]
# # TODO
#
# ~~1. Generate a few keywords for each starting game~~
#
# ~~2. Write a guesser agent to guess the keyword after each answer~~
#
# ~~3. Generate a JSON list of all the games~~

# %%
import os
from openai import OpenAI

client = OpenAI(
    api_key=os.environ.get("OPENAI_API_KEY"),
)

# %%
class DecisionNode:
    def __init__(self, question=None, yes_branch=None, no_branch=None, examples=None, summary = None):
        self.question = question
        self.yes_branch = yes_branch
        self.no_branch = no_branch
        self.examples = examples
        self.summary = summary

def print_tree(node, indent=0):
    """ Recursively print the decision tree. """
    if node.summary:
        # Print leaf node examples
        print(' ' * indent + f'→ Summary: The keyword is {node.summary}.')
    if node.examples:
        # Print leaf node examples
        print(' ' * indent + f'→ Examples: {", ".join(node.examples)}')
    else:
        # Print the question node
        turn = indent // 4 + 1
        print(' ' * indent + f'Turn {turn}: {node.question}')
        if node.yes_branch or node.no_branch:
            print(' ' * indent + ' ├─ Yes:')
            print_tree(node.yes_branch, indent + 4)  # Print yes branch
            print(' ' * indent + ' └─ No:')
            print_tree(node.no_branch, indent + 4)   # Print no branch

# Define the decision tree structure
tree = DecisionNode(
    "Is it a place?",
    yes_branch=DecisionNode(
        "Is it a country?",
        yes_branch=DecisionNode(
            "Is this country either in Asia or in Africa?",
            yes_branch=DecisionNode(
                "Is this country in Asia?",
                yes_branch=DecisionNode(summary='a country in Asia', examples=['Kazakhstan', 'South Korea']),
                no_branch=DecisionNode(summary='a country in Africa', examples=['Morocco', 'Ghana'])
            ),
            no_branch=DecisionNode(
                "Is this country in Europe?",
                yes_branch=DecisionNode(summary='a country in Europe', examples=['Romania', 'Germany']),
                no_branch=DecisionNode(
                    "Is this country in the Americas?",
                    yes_branch=DecisionNode(summary='a country in the Americas', examples=['Argentina', 'Canada']),
                    no_branch=DecisionNode(summary='a country in Oceania', examples=['New Zealand', 'Samoa'])
                )
            )
        ),
        no_branch=DecisionNode(
            "Is it a city?",
            yes_branch=DecisionNode(
                "Is it a capital city?",
                yes_branch=DecisionNode(summary='a capital city', examples=['Moscow', 'Santiago']),
                no_branch=DecisionNode(summary='a city which is not a capital', examples=['Chicago', 'Tianjin'])
            ),
            no_branch=DecisionNode(examples=["Park", "Stadium"])
        )
    ),
    no_branch=DecisionNode(
        "Is it a man-made thing?",
        yes_branch=DecisionNode(
            "Is it something found indoors?",
            yes_branch=DecisionNode(
                "Is it something found in a home?",
                yes_branch=DecisionNode(summary='a man-made thing found in people\'s homes', examples=["Bed frame", "Stove"]),
                no_branch=DecisionNode(summary='a man-made thing not found in people\'s homes', examples=["Hospital bed", "Erlenmeyer flask"])
            ),
            no_branch=DecisionNode(summary='a man-made thing found outdoors', examples=["School", "Fence"])
        ),
        no_branch=DecisionNode(
            "Is it a living thing?",
            yes_branch=DecisionNode(
                "Is it an animal?",
                yes_branch=DecisionNode(summary='an animal', examples=["Elephant", "Sea Urchin"]),
                no_branch=DecisionNode(
                    "Is it a plant?",
                    yes_branch=DecisionNode(summary='a plant', examples=["Oak tree", "Cactus"]),
                    no_branch=DecisionNode(summary='a fungus or bacteria', examples=['E Coli', 'Wood ear mushroom'])
                )
            ),
            no_branch=DecisionNode(
                "Is it a geological ?",
                yes_branch=DecisionNode(examples=["Gravity", "Evolution"]),
                no_branch=DecisionNode(examples=["Happiness", "Freedom"])
            )
        )
    )
)

# Print the decision tree
print_tree(tree)
# Out:
# Turn 1: Is it a place?
#  ├─ Yes:
#     Turn 2: Is it a country?
#      ├─ Yes:
#         Turn 3: Is this country either in Asia or in Africa?
#          ├─ Yes:
#             Turn 4: Is this country in Asia?
#              ├─ Yes:
#                 → Summary: The keyword is a country in Asia.
#                 → Examples: Kazakhstan, South Korea
#              └─ No:
#                 → Summary: The keyword is a country in Africa.
#                 → Examples: Morocco, Ghana
#          └─ No:
#             Turn 4: Is this country in Europe?
#              ├─ Yes:
#                 → Summary: The keyword is a country in Europe.
#                 → Examples: Romania, Germany
#              └─ No:
#                 Turn 5: Is this country in the Americas?
#                  ├─ Yes:
#                     → Summary: The keyword is a country in the Americas.
#                     → Examples: Argentina, Canada
#                  └─ No:
#                     → Summary: The keyword is a country in Oceania.
#                     → Examples: New Zealand, Samoa
#      └─ No:
#         Turn 3: Is it a city?
#          ├─ Yes:
#             Turn 4: Is it a capital city?
#              ├─ Yes:
#                 → Summary: The keyword is a capital city.
#                 → Examples: Moscow, Santiago
#              └─ No:
#                 → Summary: The keyword is a city which is not a capital.
#                 → Examples: Chicago, Tianjin
#          └─ No:
#             → Examples: Park, Stadium
#  └─ No:
#     Turn 2: Is it a man-made thing?
#      ├─ Yes:
#         Turn 3: Is it something found indoors?
#          ├─ Yes:
#             Turn 4: Is it something found in a home?
#              ├─ Yes:
#                 → Summary: The keyword is a man-made thing found in people's homes.
#                 → Examples: Bed frame, Stove
#              └─ No:
#                 → Summary: The keyword is a man-made thing not found in people's homes.
#                 → Examples: Hospital bed, Erlenmeyer flask
#          └─ No:
#             → Summary: The keyword is a man-made thing found outdoors.
#             → Examples: School, Fence
#      └─ No:
#         Turn 3: Is it a living thing?
#          ├─ Yes:
#             Turn 4: Is it an animal?
#              ├─ Yes:
#                 → Summary: The keyword is an animal.
#                 → Examples: Elephant, Sea Urchin
#              └─ No:
#                 Turn 5: Is it a plant?
#                  ├─ Yes:
#                     → Summary: The keyword is a plant.
#                     → Examples: Oak tree, Cactus
#                  └─ No:
#                     → Summary: The keyword is a fungus or bacteria.
#                     → Examples: E Coli, Wood ear mushroom
#          └─ No:
#             Turn 4: Is it a geological ?
#              ├─ Yes:
#                 → Examples: Gravity, Evolution
#              └─ No:
#                 → Examples: Happiness, Freedom

# %%
def generate_games_for_leaves(node, path=None, games=None):
    if path is None:
        path = []
    if games is None:
        games = []

    if node.examples or node.summary:
        # We've reached a leaf node; append the game
        games.append(path.copy())

    if node.yes_branch:
        path.append({"role": "questioner", "content": node.question})
        path.append({"role": "answerer", "content": "Yes"})
        generate_games_for_leaves(node.yes_branch, path, games)
        # Backtrack
        path.pop()
        path.pop()

    if node.no_branch:
        path.append({"role": "questioner", "content": node.question})
        path.append({"role": "answerer", "content": "No"})
        generate_games_for_leaves(node.no_branch, path, games)
        # Backtrack
        path.pop()
        path.pop()

    return games

def game_to_string(game):
    return '\n'.join([f'{step["role"]}: {step["content"]}' for step in game])

def print_game(game):
    print(game_to_string(game))

def print_games(games):
    for x, game in enumerate(games):
        print(x)
        print_game(game)
        print()  # Newline between games

# Generate games for the provided decision tree
games = generate_games_for_leaves(tree)

# Print out the games
print_games(games)
# Out:
# 0
# questioner: Is it a place?
# answerer: Yes
# questioner: Is it a country?
# answerer: Yes
# questioner: Is this country either in Asia or in Africa?
# answerer: Yes
# questioner: Is this country in Asia?
# answerer: Yes
#
# 1
# questioner: Is it a place?
# answerer: Yes
# questioner: Is it a country?
# answerer: Yes
# questioner: Is this country either in Asia or in Africa?
# answerer: Yes
# questioner: Is this country in Asia?
# answerer: No
#
# 2
# questioner: Is it a place?
# answerer: Yes
# questioner: Is it a country?
# answerer: Yes
# questioner: Is this country either in Asia or in Africa?
# answerer: No
# questioner: Is this country in Europe?
# answerer: Yes
#
# 3
# questioner: Is it a place?
# answerer: Yes
# questioner: Is it a country?
# answerer: Yes
# questioner: Is this country either in Asia or in Africa?
# answerer: No
# questioner: Is this country in Europe?
# answerer: No
# questioner: Is this country in the Americas?
# answerer: Yes
#
# 4
# questioner: Is it a place?
# answerer: Yes
# questioner: Is it a country?
# answerer: Yes
# questioner: Is this country either in Asia or in Africa?
# answerer: No
# questioner: Is this country in Europe?
# answerer: No
# questioner: Is this country in the Americas?
# answerer: No
#
# 5
# questioner: Is it a place?
# answerer: Yes
# questioner: Is it a country?
# answerer: No
# questioner: Is it a city?
# answerer: Yes
# questioner: Is it a capital city?
# answerer: Yes
#
# 6
# questioner: Is it a place?
# answerer: Yes
# questioner: Is it a country?
# answerer: No
# questioner: Is it a city?
# answerer: Yes
# questioner: Is it a capital city?
# answerer: No
#
# 7
# questioner: Is it a place?
# answerer: Yes
# questioner: Is it a country?
# answerer: No
# questioner: Is it a city?
# answerer: No
#
# 8
# questioner: Is it a place?
# answerer: No
# questioner: Is it a man-made thing?
# answerer: Yes
# questioner: Is it something found indoors?
# answerer: Yes
# questioner: Is it something found in a home?
# answerer: Yes
#
# 9
# questioner: Is it a place?
# answerer: No
# questioner: Is it a man-made thing?
# answerer: Yes
# questioner: Is it something found indoors?
# answerer: Yes
# questioner: Is it something found in a home?
# answerer: No
#
# 10
# questioner: Is it a place?
# answerer: No
# questioner: Is it a man-made thing?
# answerer: Yes
# questioner: Is it something found indoors?
# answerer: No
#
# 11
# questioner: Is it a place?
# answerer: No
# questioner: Is it a man-made thing?
# answerer: No
# questioner: Is it a living thing?
# answerer: Yes
# questioner: Is it an animal?
# answerer: Yes
#
# 12
# questioner: Is it a place?
# answerer: No
# questioner: Is it a man-made thing?
# answerer: No
# questioner: Is it a living thing?
# answerer: Yes
# questioner: Is it an animal?
# answerer: No
# questioner: Is it a plant?
# answerer: Yes
#
# 13
# questioner: Is it a place?
# answerer: No
# questioner: Is it a man-made thing?
# answerer: No
# questioner: Is it a living thing?
# answerer: Yes
# questioner: Is it an animal?
# answerer: No
# questioner: Is it a plant?
# answerer: No
#
# 14
# questioner: Is it a place?
# answerer: No
# questioner: Is it a man-made thing?
# answerer: No
# questioner: Is it a living thing?
# answerer: No
# questioner: Is it a geological ?
# answerer: Yes
#
# 15
# questioner: Is it a place?
# answerer: No
# questioner: Is it a man-made thing?
# answerer: No
# questioner: Is it a living thing?
# answerer: No
# questioner: Is it a geological ?
# answerer: No

# %%
def construct_messages(game, role, keyword = None, guesses = []):
    if role == "questioner":
        prompt = {
            "role": "system",
            "content": "You are an AI assistant playing the 20 Questions game. In this game the Answerer is given a secret keyword. The Questioner then asks yes-or-no questions regarding the keyword, and the Answerer answers them accurately. Then the Guesser tries to guess the keyword based on the questions and answers in the game. The keyword is a specific place or thing. You are participating in a new game of 20 Questions. Your role is to be the Questioner. You will ask successive yes-or-no questions to determine the keyword. You have a limited number of questions to ask, so choose a question that will eliminate half of the possible keywords to maximize efficiency. Avoid asking questions that are too specific too early on. Be as vague as possible while still eliminating half of the remaining possibilities. DO NOT try to guess the specific keyword, leave that to the guesser. Try to ask the full 20 questions. If you accidentally guessed correctly though, simply output [GAME OVER]. Do not output any text other than the question.",
        }
        messages = [prompt]
        for message in game:
            if message["role"] == "questioner":
                messages.append({
                    "role": "assistant",
                    "content": message["content"]
                })
            else:
                messages.append({
                    "role": "user",
                    "content": message["content"]
                })
    elif role == "answerer":
        prompt = {
            "role": "system",
            "content": f"You are an AI assistant playing the 20 Questions game. In this game the Answerer is given a secret keyword. The Questioner then asks yes-or-no questions regarding the keyword, and the Answerer answers them accurately. Then the Guesser tries to guess the keyword based on the questions and answers in the game. The keyword is a specific place or thing. You are participating in a new game of 20 Questions. Your role is to be the Answerer. The keyword is {keyword}. Answer only Yes or No based on the keyword. Do not output any other text.",
        }
        messages = [prompt]
        for message in game:
            if message["role"] == "questioner":
                messages.append({
                    "role": "user",
                    "content": message["content"]
                })
            else:
                messages.append({
                    "role": "assistant",
                    "content": message["content"]
                })
    elif role == "guesser":
        prompt = {
            "role": "system",
            "content": "You are an AI assistant playing the 20 Questions game. In this game the Answerer is given a secret keyword. The Questioner then asks yes-or-no questions regarding the keyword, and the Answerer answers them accurately. Then the Guesser tries to guess the keyword based on the questions and answers in the game. The keyword is a specific place or thing. You are participating in a new game of 20 Questions. Your role is to be the Guesser. Based on the given questions and answers, guess the keyword at this point. Do not ask a question, just state the guessed keyword with no other text except the keyword itself. DO NOT output any other text other than the guessed keyword.", #The game will end immediately when you guess correctly, so never repeat a guess. 
        }
        messages = [prompt, {
            "role": "user",
            "content": game_to_string(game) + "\nYour guess: "# + "\nPrevious guesses:\n" + '\n'.join(guesses)
        }]
    return messages

construct_messages(games[3], "guesser", "", guesses=["a", "b"])
# Out:
# [{'role': 'system',
#   'content': 'You are an AI assistant playing the 20 Questions game. In this game the Answerer is given a secret keyword. The Questioner then asks yes-or-no questions regarding the keyword, and the Answerer answers them accurately. Then the Guesser tries to guess the keyword based on the questions and answers in the game. The keyword is a specific place or thing. You are participating in a new game of 20 Questions. Your role is to be the Guesser. Based on the given questions and answers, guess the keyword at this point. Do not ask a question, just state the guessed keyword with no other text except the keyword itself. DO NOT output any other text other than the guessed keyword.'},
#  {'role': 'user',
#   'content': 'questioner: Is it a place?\nanswerer: Yes\nquestioner: Is it a country?\nanswerer: Yes\nquestioner: Is this country either in Asia or in Africa?\nanswerer: No\nquestioner: Is this country in Europe?\nanswerer: No\nquestioner: Is this country in the Americas?\nanswerer: Yes\nYour guess: '}]

# %%
import json
def generate_possible_keywords(game, num_keywords = 10):
    def inner():
        prompt = {
                "role": "system",
                "content": f"You are an AI assistant playing the 20 Questions game. In this game the Answerer is given a secret keyword. The Questioner then asks yes-or-no questions regarding the keyword, and the Answerer answers them accurately. Then the Guesser tries to guess the keyword based on the questions and answers in the game. The keyword is a specific place or thing. You are helping set up the game by coming up with potential keywords that fit the start of a game. Given the start of a game, give a list of {num_keywords} that could be answers to the game. Output the keywords in a JSON array of strings E.g. [\"apple\", ...]. Do NOT output any other text besides the array.",
            }
        messages = [prompt, {
                "role": "user",
                "content": game_to_string(game) + "\nKeywords: "
            }]
        result = client.chat.completions.create(
                messages=messages,
                model="gpt-4o",
            ).choices[0].message.content
        return result
    for attempt in range(5):
        result = json.loads(inner())
        if len(result) < 10:
            print("Too few results")
            continue
        elif len(result) > 10:
            return result[:10]
        return result

generate_possible_keywords(games[9])
# Out:
# ['printer',
#  'desk',
#  'chair',
#  'whiteboard',
#  'projector',
#  'vending machine',
#  'elevator',
#  'filing cabinet',
#  'conference table',
#  'fire extinguisher']

# %%
def simulate_game(starting_game, keyword):
    game = starting_game[:]

    starting_game_length = int(len(starting_game) / 2)

    questions = [step["content"] for step in game if step["role"] == "questioner"]
    answers = [step["content"] for step in game if step["role"] == "answerer"]
    guesses = []

    guesser_finished = False

    for i in range(0,starting_game_length * 2, 2):
        slice = game[i:i+2]
        guess = client.chat.completions.create(
            messages=construct_messages(slice, "guesser", keyword),
            model="gpt-4o",
        ).choices[0].message.content

        guesses.append(guess)

        print("questioner: " + slice[0]["content"])
        print("answerer: " + slice[1]["content"])
        print(f"guesser: {guess}\n")

    for _ in range(20 - starting_game_length):
        question = client.chat.completions.create(
            messages=construct_messages(game, "questioner", keyword),
            model="gpt-4o",
        ).choices[0].message.content
    
        game.append({
            "role": "questioner",
            "content": question
        })

        print(f"questioner: {question}")

        if "OVER" in question:
            break
        
        questions.append(question)
    
        answer = client.chat.completions.create(
            messages=construct_messages(game, "answerer", keyword),
            model="gpt-4o",
        ).choices[0].message.content
    
        game.append({
            "role": "answerer",
            "content": answer
        })

        answers.append(answer)
        print(f"answerer: {answer}")
        
        guess = client.chat.completions.create(
            messages=construct_messages(game, "guesser", keyword),
            model="gpt-4o",
        ).choices[0].message.content

        guesses.append(guess)
        print(f"guesser: {guess}\n")

    return {
        "keyword": keyword,
        "questions": questions,
        "answers": answers,
        "guesses": guesses
    }

result = simulate_game(games[8], "folder")
print(result)
# Out:
# questioner: Is it a place?
# answerer: No
# guesser: thing
#
# questioner: Is it a man-made thing?
# answerer: Yes
# guesser: Clock
#
# questioner: Is it something found indoors?
# answerer: Yes
# guesser: Chair
#
# questioner: Is it something found in a home?
# answerer: Yes
# guesser: Table
#
# questioner: Is it an electronic device?
# answerer: No
# guesser: Chair
#
# questioner: Is it typically found in the kitchen?
# answerer: No
# guesser: Chair
#
# questioner: Is it used for entertainment or recreation?
# answerer: No
# guesser: Chair
#
# questioner: Is it a piece of furniture?
# answerer: No
# guesser: Book
#
# questioner: Is it something you use daily?
# answerer: Yes
# guesser: Toothbrush
#
# questioner: Is it smaller than a microwave oven?
# answerer: Yes
# guesser: Toothbrush
#
# questioner: Is it something that you wear?
# answerer: No
# guesser: Toothbrush
#
# questioner: Is it used for personal hygiene?
# answerer: No
# guesser: Toothbrush
#
# questioner: Is it used for work or productivity?
# answerer: Yes
# guesser: Pen
#
# questioner: Is it commonly found in a home office or study?
# answerer: Yes
# guesser: Pen
#
# questioner: Is it used for writing or drawing?
# answerer: No
# guesser: Stapler
#
# questioner: Does it require electricity to function?
# answerer: No
# guesser: Pen
#
# questioner: Is it used for organizing or storing items?
# answerer: Yes
# guesser: Notebook
#
# questioner: Is it made mostly of paper or cardboard?
# answerer: Yes
# guesser: Folder
#
# questioner: Is it a folder or binder?
# answerer: Yes
# guesser: Binder
#
# questioner: Is it a file folder?
# answerer: Yes
# guesser: file folder
#
# {'keyword': 'folder', 'questions': ['Is it a place?', 'Is it a man-made thing?', 'Is it something found indoors?', 'Is it something found in a home?', 'Is it an electronic device?', 'Is it typically found in the kitchen?', 'Is it used for entertainment or recreation?', 'Is it a piece of furniture?', 'Is it something you use daily?', 'Is it smaller than a microwave oven?', 'Is it something that you wear?', 'Is it used for personal hygiene?', 'Is it used for work or productivity?', 'Is it commonly found in a home office or study?', 'Is it used for writing or drawing?', 'Does it require electricity to function?', 'Is it used for organizing or storing items?', 'Is it made mostly of paper or cardboard?', 'Is it a folder or binder?', 'Is it a file folder?'], 'answers': ['No', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Yes', 'Yes', 'No', 'No', 'Yes', 'Yes', 'No', 'No', 'Yes', 'Yes', 'Yes', 'Yes'], 'guesses': ['thing', 'Clock', 'Chair', 'Table', 'Chair', 'Chair', 'Chair', 'Book', 'Toothbrush', 'Toothbrush', 'Toothbrush', 'Toothbrush', 'Pen', 'Pen', 'Stapler', 'Pen', 'Notebook', 'Folder', 'Binder', 'file folder']}

# %% [markdown]
# ## Generate all the games

# %%
game_results = []
for g_index,g in enumerate(games):
    print("Game:", g_index)
    generated_keywords = generate_possible_keywords(g, num_keywords=10)
    for generated_keyword in generated_keywords:
        print("Generated keyword:", generated_keyword)
        game_result = simulate_game(g, generated_keyword)
        game_results.append(game_result)
# Out:
# Game: 0
# Generated keyword: Japan
# questioner: Is it a place?
# answerer: Yes
# guesser: Paris
#
# questioner: Is it a country?
# answerer: Yes
# guesser: France
#
# questioner: Is this country either in Asia or in Africa?
# answerer: Yes
# guesser: India
#
# questioner: Is this country in Asia?
# answerer: Yes
# guesser: China
#
# questioner: Is this country located in East Asia?
# answerer: Yes
# guesser: China
#
# questioner: Is this country an island nation?
# answerer: Yes
# guesser: Japan
#
# questioner: Is this country part of the United Nations?
# answerer: Yes
# guesser: Japan
#
# questioner: Is this country Japan?
# answerer: Yes
# guesser: Japan
#
# questioner: [GAME OVER]
# Generated keyword: China
# questioner: Is it a place?
# answerer: Yes
# guesser: Park
#
# questioner: Is it a country?
# answerer: Yes
# guesser: Japan
#
# questioner: Is this country either in Asia or in Africa?
# answerer: Yes
# guesser: India
#
# questioner: Is this country in Asia?
# answerer: Yes
# guesser: China
#
# questioner: Is it located in East Asia?
# answerer: Yes
# guesser: China
#
# questioner: Is it an island nation?
# answerer: No
# guesser: China
#
# questioner: Is it a landlocked country?
# answerer: No
# guesser: China
#
# questioner: Is this country known for having a large population?
# answerer: Yes
# guesser: China
#
# questioner: Is this country part of the United Nations Security Council's permanent members?
# answerer: Yes
# guesser: China
#
# questioner: Is this country China?
# answerer: Yes
# guesser: China
#
# questioner: [GAME OVER]
# Generated keyword: India
# questioner: Is it a place?
# answerer: Yes
# guesser: Paris
#
# questioner: Is it a country?
# answerer: Yes
# guesser: France
#
# questioner: Is this country either in Asia or in Africa?
# answerer: Yes
# guesser: Japan
#
# questioner: Is this country in Asia?
# answerer: Yes
# guesser: Japan
#
# questioner: Is this country located in the eastern part of Asia?
# answerer: No
# guesser: India
#
# questioner: Is this country part of the Middle East?
# answerer: No
# guesser: India
#
# questioner: Is this country in South Asia?
# answerer: Yes
# guesser: India
#
# questioner: Is it bordered by India?
# answerer: Yes
# guesser: Pakistan
#
# questioner: Is it an island nation?
# answerer: No
# guesser: Pakistan
#
# questioner: Is it a landlocked country?
# answerer: No
# guesser: Bangladesh
#
# questioner: Is it Pakistan?
# answerer: No
# guesser: Bangladesh
#
# questioner: Does this country have a coastline on the Bay of Bengal?
# answerer: Yes
# guesser: Bangladesh
#
# questioner: Is it Bangladesh?
# answerer: No
# guesser: Sri Lanka
#
# questioner: Is this country known for its tropical climate and beaches?
# answerer: No
# guesser: Myanmar
#
# questioner: Is this country Nepal?
# answerer: No
# guesser: Sri Lanka
#
# questioner: Does this country have a significant Buddhist population?
# answerer: No
# guesser: Myanmar
#
# questioner: Is this country in the Indian subcontinent?
# answerer: Yes
# guesser: Sri Lanka
#
# questioner: Does this country have a larger population than Bangladesh?
# answerer: Yes
# guesser: Myanmar
#
# questioner: Is it Sri Lanka?
# answerer: No
# guesser: Myanmar
#
# questioner: Is it Myanmar?
# answerer: No
# guesser: Maldives
#
# Generated keyword: South Korea
# questioner: Is it a place?
# answerer: Yes
# guesser: Paris
#
# questioner: Is it a country?
# answerer: Yes
# guesser: Japan
#
# questioner: Is this country either in Asia or in Africa?
# answerer: Yes
# guesser: Japan
#
# questioner: Is this country in Asia?
# answerer: Yes
# guesser: Japan
#
# questioner: Is this country in East Asia?
# answerer: Yes
# guesser: Japan
#
# questioner: Is it an island country?
# answerer: No
# guesser: China
#
# questioner: Is this country larger in area than 1 million square kilometers?
# answerer: No
# guesser: South Korea
#
# questioner: Is this country landlocked?
# answerer: No
# guesser: South Korea
#
# questioner: Has this country hosted the Olympics?
# answerer: Yes
# guesser: South Korea
#
# questioner: Is this country known for having a significant and historic influence on technology and electronics?
# answerer: Yes
# guesser: South Korea
#
# questioner: Is the primary language spoken in this country Japanese?
# answerer: No
# guesser: South Korea
#
# questioner: Is the primary language spoken in this country Korean?
# answerer: Yes
# guesser: South Korea
#
# questioner: Is the country South Korea?
# answerer: Yes
# guesser: South Korea
#
# questioner: [GAME OVER]
# Generated keyword: Thailand
# questioner: Is it a place?
# answerer: Yes
# guesser: Paris
#
# questioner: Is it a country?
# answerer: Yes
# guesser: Japan
#
# questioner: Is this country either in Asia or in Africa?
# answerer: Yes
# guesser: India
#
# questioner: Is this country in Asia?
# answerer: Yes
# guesser: India
#
# questioner: Is it an island nation?
# answerer: No.
# guesser: China
#
# questioner: Is this country located in the eastern part of Asia?
# answerer: No.
# guesser: India
#
# questioner: Does this country share a border with China?
# answerer: No.
# guesser: India
#
# questioner: Is this country predominantly an Islamic nation?
# answerer: No.
# guesser: India
#
# questioner: Is this country in South Asia?
# answerer: No.
# guesser: Kazakhstan
#
# questioner: Is this country in Central Asia?
# answerer: No.
# guesser: Saudi Arabia
#
# questioner: Is this country in the Middle East?
# answerer: No.
# guesser: Russia
#
# questioner: Is this country part of Southeast Asia?
# answerer: Yes.
# guesser: Thailand
#
# questioner: Does this country share a land border with another country?
# answerer: Yes.
# guesser: Vietnam
#
# questioner: Is this country a member of the Association of Southeast Asian Nations (ASEAN)?
# answerer: Yes.
# guesser: Thailand
#
# questioner: Is it known for having a large population?
# answerer: No.
# guesser: Laos
#
# questioner: Is it known for having a significant amount of forests and biodiversity?
# answerer: Yes.
# guesser: Laos
#
# questioner: Is this country part of the Indochina peninsula?
# answerer: Yes.
# guesser: Laos
#
# questioner: Is this country known for the Mekong River flowing through it?
# answerer: No.
# guesser: Cambodia
#
# questioner: Does this country share a border with Vietnam?
# answerer: No.
# guesser: Myanmar
#
# questioner: Is this country Thailand?
# answerer: Yes.
# guesser: Thailand
#
# Generated keyword: Vietnam
# questioner: Is it a place?
# answerer: Yes
# guesser: Paris
#
# questioner: Is it a country?
# answerer: Yes
# guesser: Japan
#
# questioner: Is this country either in Asia or in Africa?
# answerer: Yes
# guesser: Egypt
#
# questioner: Is this country in Asia?
# answerer: Yes
# guesser: China
#
# questioner: Is this country located in the Middle East?
# answerer: No
# guesser: Japan
#
# questioner: Is this country located in East Asia?
# answerer: No
# guesser: India
#
# questioner: Is this country in Southeast Asia?
# answerer: Yes
# guesser: Thailand
#
# questioner: Is this country an island nation?
# answerer: No
# guesser: Thailand
#
# questioner: Is this country larger than 1 million square kilometers in area?
# answerer: No
# guesser: Thailand
#
# questioner: Is this country known for having a monarchy?
# answerer: No
# guesser: Vietnam
#
# questioner: Is this country part of the ASEAN (Association of Southeast Asian Nations)?
# answerer: Yes
# guesser: Vietnam
#
# questioner: Does this country share a border with China?
# answerer: Yes
# guesser: Vietnam
#
# questioner: Is this country Vietnam?
# answerer: Yes
# guesser: Vietnam
#
# questioner: [GAME OVER]
# Generated keyword: Malaysia
# questioner: Is it a place?
# answerer: Yes
# guesser: Paris
#
# questioner: Is it a country?
# answerer: Yes
# guesser: Japan
#
# questioner: Is this country either in Asia or in Africa?
# answerer: Yes
# guesser: Japan
#
# questioner: Is this country in Asia?
# answerer: Yes
# guesser: Japan
#
# questioner: Is this country located in the eastern part of Asia?
# answerer: No
# guesser: India
#
# questioner: Is this country located in the southern part of Asia?
# answerer: No
# guesser: Kazakhstan
#
# questioner: Is this country located in the western part of Asia?
# answerer: No
# guesser: Kazakhstan
#
# questioner: Is this country located in Central Asia?
# answerer: No
# guesser: Russia
#
# questioner: Is this country located in the Middle East?
# answerer: No
# guesser: Russia
#
# questioner: Is this country landlocked?
# answerer: No
# guesser: India
#
# questioner: Is this country located on an island or composed of islands?
# answerer: Yes
# guesser: Sri Lanka
#
# questioner: Is this country located in Southeast Asia?
# answerer: Yes
# guesser: Indonesia
#
# questioner: Is this country part of ASEAN (Association of Southeast Asian Nations)?
# answerer: Yes
# guesser: Indonesia
#
# questioner: Is this country known for having a significant number of volcanoes?
# answerer: No
# guesser: Singapore
#
# questioner: Is this country an archipelago (a chain or cluster of islands)?
# answerer: Yes
# guesser: Philippines
#
# questioner: Is this country located north of the equator?
# answerer: Yes
# guesser: Philippines
#
# questioner: Is this country predominantly Muslim?
# answerer: Yes
# guesser: Indonesia
#
# questioner: Is this country the largest in terms of land area among others in Southeast Asia?
# answerer: No
# guesser: Malaysia
#
# questioner: Does this country have over 50 million people in population?
# answerer: Yes
# guesser: Philippines
#
# questioner: Is this country the only one in Southeast Asia whose name starts with the letter 'P'?
# answerer: No
# guesser: Malaysia
#
# Generated keyword: Indonesia
# questioner: Is it a place?
# answerer: Yes
# guesser: Paris
#
# questioner: Is it a country?
# answerer: Yes
# guesser: France
#
# questioner: Is this country either in Asia or in Africa?
# answerer: Yes
# guesser: India
#
# questioner: Is this country in Asia?
# answerer: Yes
# guesser: Japan
#
# questioner: Is this country larger than 1 million square kilometers in area?
# answerer: Yes
# guesser: China
#
# questioner: Is this country located in East Asia?
# answerer: No
# guesser: India
#
# questioner: Is this country located in South Asia?
# answerer: No
# guesser: Saudi Arabia
#
# questioner: Is this country located in Southeast Asia?
# answerer: Yes
# guesser: Indonesia
#
# questioner: Is this country an archipelago?
# answerer: Yes
# guesser: Indonesia
#
# questioner: Is this country predominantly a Muslim nation?
# answerer: Yes
# guesser: Indonesia
#
# questioner: Is this country Indonesia?
# answerer: Yes
# guesser: Indonesia
#
# questioner: [GAME OVER]
# Generated keyword: Saudi Arabia
# questioner: Is it a place?
# answerer: Yes
# guesser: Paris
#
# questioner: Is it a country?
# answerer: Yes
# guesser: Brazil
#
# questioner: Is this country either in Asia or in Africa?
# answerer: Yes
# guesser: Japan
#
# questioner: Is this country in Asia?
# answerer: Yes
# guesser: Japan
#
# questioner: Is this country in East Asia?
# answerer: No
# guesser: India
#
# questioner: Is this country in Southeast Asia?
# answerer: No
# guesser: India
#
# questioner: Is this country in South Asia?
# answerer: No
# guesser: Kazakhstan
#
# questioner: Is this country in Central Asia?
# answerer: No
# guesser: Saudi Arabia
#
# questioner: Is this country in the Middle East?
# answerer: Yes
# guesser: Saudi Arabia
#
# questioner: Is this country a member of the Gulf Cooperation Council (GCC)?
# answerer: Yes
# guesser: Saudi Arabia
#
# questioner: Does this country have a coastline on the Persian Gulf?
# answerer: Yes
# guesser: Saudi Arabia
#
# questioner: Is this country known for having one of the world's largest oil reserves?
# answerer: Yes
# guesser: Saudi Arabia
#
# questioner: Is this country Saudi Arabia?
# answerer: Yes
# guesser: Saudi Arabia
#
# questioner: [GAME OVER]
# Generated keyword: Iran
# questioner: Is it a place?
# answerer: Yes
# guesser: Paris
#
# questioner: Is it a country?
# answerer: Yes
# guesser: Japan
#
# questioner: Is this country either in Asia or in Africa?
# answerer: Yes
# guesser: China
#
# questioner: Is this country in Asia?
# answerer: Yes
# guesser: China
#
# questioner: Is this country located in East Asia?
# answerer: No
# guesser: India
#
# questioner: Is this country located in Southeast Asia?
# answerer: No
# guesser: India
#
# questioner: Is this country located in South Asia?
# answerer: No
# guesser: Kazakhstan
#
# questioner: Is this country located in Central Asia?
# answerer: No
# guesser: Saudi Arabia
#
# questioner: Is this country located in Western Asia (also known as the Middle East)?
# answerer: Yes
# guesser: Saudi Arabia
#
# questioner: Is this country a member of the Gulf Cooperation Council (GCC)?
# answerer: No
# guesser: Turkey
#
# questioner: Is this country larger than 500,000 square kilometers in area?
# answerer: Yes
# guesser: Iran
#
# questioner: Does this country border the Mediterranean Sea?
# answerer: No
# guesser: Iran
#
# questioner: Does this country border Saudi Arabia?
# answerer: No
# guesser: Iran
#
# questioner: Does this country have a coastline on the Arabian Sea?
# answerer: No
# guesser: Iran
#
# questioner: Does this country have significant mountain ranges?
# answerer: Yes
# guesser: Iran
#
# questioner: Is this country bordered by Turkey?
# answerer: Yes
# guesser: Iran
#
# questioner: Is this country predominantly Kurdish?
# answerer: No
# guesser: Iran
#
# questioner: Is this country Iraq?
# answerer: No
# guesser: Iran
#
# questioner: Is this country Iran?
# answerer: Yes
# guesser: Iran
#
# questioner: [GATE OVER]
# Game: 1
# Generated keyword: Nigeria
# questioner: Is it a place?
# answerer: Yes
# guesser: Paris
#
# questioner: Is it a country?
# answerer: Yes
# guesser: France
#
# questioner: Is this country either in Asia or in Africa?
# answerer: Yes
# guesser: China
#
# questioner: Is this country in Asia?
# answerer: No
# guesser: France
#
# questioner: Is this country located in Northern Africa?
# answerer: No
# guesser: South Africa
#
# questioner: Is this country in East Africa?
# answerer: No
# guesser: South Africa
#
# questioner: Is this country in West Africa?
# answerer: Yes
# guesser: Nigeria
#
# questioner: Is this country landlocked?
# answerer: No
# guesser: Nigeria
#
# questioner: Does this country have a population of over 20 million people?
# answerer: Yes
# guesser: Nigeria
#
# questioner: Is this country officially an English-speaking country?
# answerer: Yes
# guesser: Nigeria
#
# questioner: Is this country Nigeria?
# answerer: Yes
# guesser: Nigeria
#
# questioner: [GAME OVER]
# Generated keyword: Egypt
# questioner: Is it a place?
# answerer: Yes
# guesser: Paris
#
# questioner: Is it a country?
# answerer: Yes
# guesser: France
#
# questioner: Is this country either in Asia or in Africa?
# answerer: Yes
# guesser: India
#
# questioner: Is this country in Asia?
# answerer: No
# guesser: Canada
#
# questioner: Is this country in the northern part of Africa?
# answerer: Yes
# guesser: Egypt
#
# questioner: Is this country a member of the Arab League?
# answerer: Yes
# guesser: Egypt
#
# questioner: Is this country located in the Maghreb region of Northern Africa?
# answerer: No
# guesser: Egypt
#
# questioner: Does this country have a coastline on the Mediterranean Sea?
# answerer: Yes
# guesser: Egypt
#
# questioner: Is this country to the west of Egypt?
# answerer: No
# guesser: Egypt
#
# questioner: Is this country Sudan?
# answerer: No
# guesser: Libya
#
# questioner: Is this country Libya?
# answerer: No
# guesser: Tunisia
#
# questioner: Is this country to the west of Israel?
# answerer: Yes
# guesser: Egypt
#
# questioner: Is this country Lebanon?
# answerer: No
# guesser: Syria
#
# questioner: Is this country Syria?
# answerer: No
# guesser: Palestine
#
# questioner: Is this country to the south of Israel?
# answerer: Yes
# guesser: Egypt
#
# questioner: Is this country partially located in the Sinai Peninsula?
# answerer: Yes
# guesser: Egypt
#
# questioner: Is this country Egypt?
# answerer: Yes
# guesser: Egypt
#
# questioner: [GAME OVER]
# Generated keyword: Kenya
# questioner: Is it a place?
# answerer: Yes
# guesser: Paris
#
# questioner: Is it a country?
# answerer: Yes
# guesser: Japan
#
# questioner: Is this country either in Asia or in Africa?
# answerer: Yes
# guesser: India
#
# questioner: Is this country in Asia?
# answerer: No
# guesser: Brazil
#
# questioner: Is this country in the northern part of Africa?
# answerer: No
# guesser: South Africa
#
# questioner: Is this country in the eastern part of Africa?
# answerer: Yes
# guesser: Kenya
#
# questioner: Is this country landlocked?
# answerer: No
# guesser: Kenya
#
# questioner: Does this country have a population over 10 million?
# answerer: Yes
# guesser: Kenya
#
# questioner: Is this country known for having a coastline along the Indian Ocean?
# answerer: Yes
# guesser: Tanzania
#
# questioner: Is this country located south of the equator?
# answerer: Partially
# guesser: Kenya
#
# questioner: Does this country share a border with Tanzania?
# answerer: Yes
# guesser: Kenya
#
# questioner: Does this country have the Swahili language as one of its official languages?
# answerer: Yes
# guesser: Kenya
#
# questioner: Is this country Kenya?
# answerer: Yes
# guesser: Kenya
#
# questioner: [GAME OVER]
# Generated keyword: South Africa
# questioner: Is it a place?
# answerer: Yes
# guesser: Mall
#
# questioner: Is it a country?
# answerer: Yes
# guesser: France
#
# questioner: Is this country either in Asia or in Africa?
# answerer: Yes
# guesser: Japan
#
# questioner: Is this country in Asia?
# answerer: No
# guesser: Brazil
#
# questioner: Is this country located in Northern Africa?
# answerer: No
# guesser: South Africa
#
# questioner: Is this country located in Western Africa?
# answerer: No
# guesser: South Africa
#
# questioner: Is this country located in Central Africa?
# answerer: No
# guesser: South Africa
#
# questioner: Is this country located in Eastern Africa?
# answerer: No
# guesser: South Africa
#
# questioner: Is this country located in Southern Africa?
# answerer: Yes
# guesser: South Africa
#
# questioner: Is this country landlocked?
# answerer: No
# guesser: South Africa
#
# questioner: Is this country known for a significant coastline along the Indian Ocean?
# answerer: Yes
# guesser: Mozambique
#
# questioner: Is this country the largest by area in Southern Africa?
# answerer: No
# guesser: Mozambique
#
# questioner: Is this country known for its tourism industry?
# answerer: Yes
# guesser: Tanzania
#
# questioner: Does this country have multiple official languages, including English?
# answerer: Yes
# guesser: Tanzania
#
# questioner: Is this country known for having large deserts within its territory?
# answerer: No
# guesser: Mozambique
#
# questioner: Is this country bordered by the Atlantic Ocean as well?
# answerer: Yes
# guesser: Namibia
#
# questioner: Is this country located directly south of Namibia?
# answerer: Yes
# guesser: South Africa
#
# questioner: Is this country South Africa?
# answerer: Yes
# guesser: South Africa
#
# questioner: [GAME OVER]
# Generated keyword: Morocco
# questioner: Is it a place?
# answerer: Yes
# guesser: Paris
#
# questioner: Is it a country?
# answerer: Yes
# guesser: France
#
# questioner: Is this country either in Asia or in Africa?
# answerer: Yes
# guesser: India
#
# questioner: Is this country in Asia?
# answerer: No
# guesser: United States
#
# questioner: Is this country located in Northern Africa?
# answerer: Yes
# guesser: Egypt
#
# questioner: Is this country predominantly Arabic-speaking?
# answerer: Yes
# guesser: Egypt
#
# questioner: Is this country Egypt?
# answerer: No
# guesser: Morocco
#
# questioner: Is this country bordered by the Mediterranean Sea?
# answerer: Yes
# guesser: Morocco
#
# questioner: Is this country Libya?
# answerer: No
# guesser: Algeria
#
# questioner: Is this country Algeria?
# answerer: No
# guesser: Morocco
#
# questioner: Is this country Tunisia?
# answerer: No
# guesser: Morocco
#
# questioner: Is this country Morocco?
# answerer: Yes
# guesser: Morocco
#
# questioner: Is it a member of the African Union?
# answerer: No
# guesser: Morocco
#
# questioner: Do you want to guess the keyword?
# answerer: No
# guesser: Morocco
#
# questioner: Is this country known for the Sahara Desert?
# answerer: Yes
# guesser: Morocco
#
# questioner: Can this country be found in the western part of North Africa?
# answerer: Yes
# guesser: Western Sahara
#
# questioner: Does this country share a border with the Atlantic Ocean?
# answerer: Yes
# guesser: Morocco
#
# questioner: Is this country known for the city of Marrakesh?
# answerer: Yes
# guesser: Morocco
#
# questioner: Is the capital of this country Rabat?
# answerer: Yes
# guesser: Morocco
#
# questioner: Is this country known for its historical city of Fes?
# answerer: Yes
# guesser: Morocco
#
# Generated keyword: Ghana
# questioner: Is it a place?
# answerer: Yes
# guesser: Paris
#
# questioner: Is it a country?
# answerer: Yes
# guesser: Japan
#
# questioner: Is this country either in Asia or in Africa?
# answerer: Yes
# guesser: Japan
#
# questioner: Is this country in Asia?
# answerer: No
# guesser: France
#
# questioner: Is this country in the northern hemisphere?
# answerer: Yes
# guesser: Egypt
#
# questioner: Is this country located in the central or eastern part of Africa?
# answerer: No
# guesser: Egypt
#
# questioner: Is this country on the western coast of Africa?
# answerer: Yes
# guesser: Nigeria
#
# questioner: Is this country smaller in area than 500,000 square kilometers?
# answerer: Yes
# guesser: Liberia
#
# questioner: Is this country known for having English as one of its official languages?
# answerer: Yes
# guesser: Ghana
#
# questioner: Was this country formerly a British colony?
# answerer: Yes
# guesser: Ghana
#
# questioner: Is this country landlocked?
# answerer: No
# guesser: Ghana
#
# questioner: Is this country known for having a tropical climate?
# answerer: Yes
# guesser: Ghana
#
# questioner: Is the capital of this country a major port city?
# answerer: Yes
# guesser: Ghana
#
# questioner: Is this country located between the latitudes of the Equator and Tropic of Cancer?
# answerer: Yes
# guesser: Ghana
#
# questioner: Does this country share a border with Ghana?
# answerer: No
# guesser: Sierra Leone
#
# questioner: Does this country have a coastline along the Atlantic Ocean?
# answerer: Yes
# guesser: Sierra Leone
#
# questioner: Is this country bordered by both Liberia and Cote d'Ivoire?
# answerer: No
# guesser: Sierra Leone
#
# questioner: Is this country Sierra Leone?
# answerer: No
# guesser: Gambia
#
# questioner: Is this country bordered by Guinea?
# answerer: No
# guesser: The Gambia
#
# questioner: Is this country Nigeria?
# answerer: No
# guesser: Gambia
#
# Generated keyword: Ethiopia
# questioner: Is it a place?
# answerer: Yes
# guesser: Paris
#
# questioner: Is it a country?
# answerer: Yes
# guesser: Japan
#
# questioner: Is this country either in Asia or in Africa?
# answerer: Yes
# guesser: Japan
#
# questioner: Is this country in Asia?
# answerer: No
# guesser: Spain
#
# questioner: Is this country located in northern Africa?
# answerer: No
# guesser: South Africa
#
# questioner: Is this country located in eastern Africa?
# answerer: Yes
# guesser: Kenya
#
# questioner: Is this country landlocked?
# answerer: Yes
# guesser: Ethiopia
#
# questioner: Is this country Ethiopia?
# answerer: Yes
# guesser: Ethiopia
#
# questioner: [GAME OVER]
# Generated keyword: Tanzania
# questioner: Is it a place?
# answerer: Yes
# guesser: Paris
#
# questioner: Is it a country?
# answerer: Yes
# guesser: France
#
# questioner: Is this country either in Asia or in Africa?
# answerer: Yes
# guesser: India
#
# questioner: Is this country in Asia?
# answerer: No
# guesser: France
#
# questioner: Is this country located in Northern Africa?
# answerer: No
# guesser: South Africa
#
# questioner: Is this country located in Western Africa?
# answerer: No
# guesser: South Africa
#
# questioner: Is this country located in Eastern Africa?
# answerer: Yes
# guesser: Kenya
#
# questioner: Is this country classified as a landlocked country?
# answerer: No
# guesser: Kenya
#
# questioner: Does this country have a coastline along the Indian Ocean?
# answerer: Yes
# guesser: Kenya
#
# questioner: Is this country Tanzania?
# answerer: Yes
# guesser: Tanzania
#
# questioner: [GAME OVER]
# Generated keyword: Algeria
# questioner: Is it a place?
# answerer: Yes
# guesser: Paris
#
# questioner: Is it a country?
# answerer: Yes
# guesser: Japan
#
# questioner: Is this country either in Asia or in Africa?
# answerer: Yes
# guesser: Japan
#
# questioner: Is this country in Asia?
# answerer: No
# guesser: Brazil
#
# questioner: Is this country located in North Africa?
# answerer: Yes
# guesser: Egypt
#
# questioner: Is this country bordered by the Mediterranean Sea?
# answerer: Yes
# guesser: Egypt
#
# questioner: Does this country share a border with both Libya and Tunisia?
# answerer: Yes
# guesser: Algeria
#
# questioner: Is this country Egypt?
# answerer: No
# guesser: Algeria
#
# questioner: Does this country have a coastline along the Atlantic Ocean as well as the Mediterranean Sea?
# answerer: No
# guesser: Algeria
#
# questioner: Is this country Algeria?
# answerer: Yes
# guesser: Algeria
#
# questioner: [GAME OVER]
# Generated keyword: Uganda
# questioner: Is it a place?
# answerer: Yes
# guesser: New York
#
# questioner: Is it a country?
# answerer: Yes
# guesser: Japan
#
# questioner: Is this country either in Asia or in Africa?
# answerer: Yes
# guesser: India
#
# questioner: Is this country in Asia?
# answerer: No
# guesser: Brazil
#
# questioner: Is this country located in Northern Africa?
# answerer: No
# guesser: South Africa
#
# questioner: Is this country in Western Africa?
# answerer: No
# guesser: South Africa
#
# questioner: Is this country in Eastern Africa?
# answerer: Yes
# guesser: Kenya
#
# questioner: Is this country landlocked?
# answerer: Yes
# guesser: Ethiopia
#
# questioner: Is this country bordered by Kenya?
# answerer: Yes
# guesser: Uganda
#
# questioner: Is this country Ethiopia?
# answerer: No
# guesser: Uganda
#
# questioner: Is this country bordered by Tanzania?
# answerer: Yes
# guesser: Uganda
#
# questioner: Is this country Uganda?
# answerer: Yes
# guesser: Uganda
#
# questioner: [GAME OVER]
# Game: 2
# Generated keyword: France
# questioner: Is it a place?
# answerer: Yes
# guesser: Paris
#
# questioner: Is it a country?
# answerer: Yes
# guesser: Brazil
#
# questioner: Is this country either in Asia or in Africa?
# answerer: No
# guesser: France
#
# questioner: Is this country in Europe?
# answerer: Yes
# guesser: France
#
# questioner: Is this country a member of the European Union?
# answerer: Yes
# guesser: Germany
#
# questioner: Is this country located in Northern Europe?
# answerer: No
# guesser: Italy
#
# questioner: Is this country located in Southern Europe?
# answerer: No
# guesser: France
#
# questioner: Is this country located in Eastern Europe?
# answerer: No
# guesser: France
#
# questioner: Is this country located in Western Europe?
# answerer: Yes
# guesser: France
#
# questioner: Is this country landlocked?
# answerer: No
# guesser: France
#
# questioner: Does this country share a land border with Germany?
# answerer: Yes
# guesser: France
#
# questioner: Is this country known primarily for its romance language?
# answerer: Yes
# guesser: France
#
# questioner: Is this country France?
# answerer: Yes
# guesser: France
#
# questioner: [GAME OVER]
# Generated keyword: Germany
# questioner: Is it a place?
# answerer: Yes
# guesser: Paris
#
# questioner: Is it a country?
# answerer: Yes
# guesser: Japan
#
# questioner: Is this country either in Asia or in Africa?
# answerer: No
# guesser: Brazil
#
# questioner: Is this country in Europe?
# answerer: Yes
# guesser: France
#
# questioner: Is this country a member of the European Union?
# answerer: Yes
# guesser: France
#
# questioner: Is this country located in Eastern Europe?
# answerer: No
# guesser: France
#
# questioner: Is this country part of the Schengen Area?
# answerer: Yes
# guesser: Germany
#
# questioner: Is this country known for its Mediterranean coastline?
# answerer: No
# guesser: Germany
#
# questioner: Is this country an island or does it have islands?
# answerer: No
# guesser: Germany
#
# questioner: Is this country landlocked?
# answerer: No
# guesser: France
#
# questioner: Is English the official language of this country?
# answerer: No
# guesser: Germany
#
# questioner: Is this country known for its significant influence in art and culture?
# answerer: Yes
# guesser: France
#
# questioner: Is this country known for its historical significance in the formation of the European Union?
# answerer: Yes
# guesser: France
#
# questioner: Is this country located in Western Europe?
# answerer: Yes
# guesser: France
#
# questioner: Is the official language of this country one of the Romance languages?
# answerer: No
# guesser: Germany
#
# questioner: Is this country known for its contributions to classical music?
# answerer: Yes
# guesser: Germany
#
# questioner: Is this country Germany?
# answerer: Yes
# guesser: Germany
#
# questioner: [GAME OVER]
# Generated keyword: Italy
# questioner: Is it a place?
# answerer: Yes
# guesser: Paris
#
# questioner: Is it a country?
# answerer: Yes
# guesser: Japan
#
# questioner: Is this country either in Asia or in Africa?
# answerer: No
# guesser: No guess
#
# questioner: Is this country in Europe?
# answerer: Yes
# guesser: France
#
# questioner: Is this country part of the European Union?
# answerer: Yes
# guesser: France
#
# questioner: Is this country located in Southern Europe?
# answerer: Yes
# guesser: Italy
#
# questioner: Is this country known for its cuisine?
# answerer: Yes
# guesser: Italy
#
# questioner: Is this country bordered by the Mediterranean Sea?
# answerer: Yes
# guesser: Italy
#
# questioner: Is this country famous for its historical landmarks?
# answerer: Yes
# guesser: Italy
#
# questioner: Is the official language of this country primarily a Romance language?
# answerer: Yes
# guesser: Italy
#
# questioner: Is this country known for its wine production?
# answerer: Yes
# guesser: Italy
#
# questioner: Is this country Italy?
# answerer: Yes
# guesser: Italy
#
# questioner: [GAME OVER]
# Generated keyword: Spain
# questioner: Is it a place?
# answerer: Yes
# guesser: Paris
#
# questioner: Is it a country?
# answerer: Yes
# guesser: France
#
# questioner: Is this country either in Asia or in Africa?
# answerer: No
# guesser: Brazil
#
# questioner: Is this country in Europe?
# answerer: Yes
# guesser: France
#
# questioner: Is it a member of the European Union?
# answerer: Yes
# guesser: France
#
# questioner: Is its official language Germanic?
# answerer: No
# guesser: France
#
# questioner: Is it a Southern European country?
# answerer: Yes
# guesser: Italy
#
# questioner: Is this country located on the Iberian Peninsula?
# answerer: Yes
# guesser: Spain
#
# questioner: Is Spanish the official language of this country?
# answerer: Yes
# guesser: Spain
#
# questioner: Is it Spain?
# answerer: Yes
# guesser: Spain
#
# questioner: [GAME OVER]
# Generated keyword: Greece
# questioner: Is it a place?
# answerer: Yes
# guesser: Museum
#
# questioner: Is it a country?
# answerer: Yes
# guesser: France
#
# questioner: Is this country either in Asia or in Africa?
# answerer: No
# guesser: No guess
#
# questioner: Is this country in Europe?
# answerer: Yes
# guesser: France
#
# questioner: Is this country a part of the European Union?
# answerer: Yes
# guesser: France
#
# questioner: Is this country in Southern Europe?
# answerer: Yes
# guesser: Italy
#
# questioner: Is this country located on the Mediterranean Sea?
# answerer: Yes
# guesser: Italy
#
# questioner: Is this country an island?
# answerer: No
# guesser: Italy
#
# questioner: Is this country known for its historical landmarks and ancient ruins?
# answerer: Yes
# guesser: Greece
#
# questioner: Is this country Greece?
# answerer: Yes
# guesser: Greece
#
# questioner: [GAME OVER]
# Generated keyword: Portugal
# questioner: Is it a place?
# answerer: Yes
# guesser: Paris
#
# questioner: Is it a country?
# answerer: Yes
# guesser: Brazil
#
# questioner: Is this country either in Asia or in Africa?
# answerer: No
# guesser: Brazil
#
# questioner: Is this country in Europe?
# answerer: Yes
# guesser: France
#
# questioner: Is it a member of the European Union?
# answerer: Yes
# guesser: Germany
#
# questioner: Is it located in Eastern Europe?
# answerer: No
# guesser: France
#
# questioner: Is it a landlocked country?
# answerer: No
# guesser: France
#
# questioner: Is it a Mediterranean country?
# answerer: No
# guesser: France
#
# questioner: Is it a Nordic country?
# answerer: No
# guesser: France
#
# questioner: Is it part of the United Kingdom?
# answerer: No
# guesser: France
#
# questioner: Is it a country that primarily speaks a Romance language?
# answerer: Yes
# guesser: France
#
# questioner: Is it located in Southern Europe?
# answerer: Yes
# guesser: Spain
#
# questioner: Does it have a coastline on the Atlantic Ocean?
# answerer: Yes
# guesser: Portugal
#
# questioner: Is it Spain?
# answerer: No
# guesser: Portugal
#
# questioner: Is it Portugal?
# answerer: Yes
# guesser: Portugal
#
# questioner: [GAME OVER]
# Generated keyword: Netherlands
# questioner: Is it a place?
# answerer: Yes
# guesser: Park
#
# questioner: Is it a country?
# answerer: Yes
# guesser: France
#
# questioner: Is this country either in Asia or in Africa?
# answerer: No
# guesser: No
#
# questioner: Is this country in Europe?
# answerer: Yes
# guesser: France
#
# questioner: Is this country a member of the European Union?
# answerer: Yes
# guesser: France
#
# questioner: Is this country located in Northern Europe?
# answerer: No
# guesser: France
#
# questioner: Is this country located in Southern Europe?
# answerer: No
# guesser: France
#
# questioner: Is this country located in Western Europe?
# answerer: Yes
# guesser: France
#
# questioner: Is this country a part of the Eurozone?
# answerer: Yes
# guesser: France
#
# questioner: Is this country known for having a significant coastal area along the Atlantic Ocean or North Sea?
# answerer: Yes
# guesser: France
#
# questioner: Is this country larger than 150,000 square kilometers in area?
# answerer: No
# guesser: Netherlands
#
# questioner: Is this country landlocked?
# answerer: No
# guesser: Portugal
#
# questioner: Is this country Belgium?
# answerer: No
# guesser: Netherlands
#
# questioner: Is this country known for having a significant cultural influence historically in the arts and philosophy?
# answerer: Yes
# guesser: Netherlands
#
# questioner: Is this country France?
# answerer: No
# guesser: Netherlands
#
# questioner: Is this country known for its neutrality and banking system?
# answerer: No
# guesser: Netherlands
#
# questioner: Is this country known for being composed of regions that were historically independent?
# answerer: Yes
# guesser: Netherlands
#
# questioner: Is this country Spain?
# answerer: No
# guesser: Netherlands
#
# questioner: Is this country the Netherlands?
# answerer: Yes
# guesser: The Netherlands
#
# questioner: [GAME OVER]
# Generated keyword: Sweden
# questioner: Is it a place?
# answerer: Yes
# guesser: Paris
#
# questioner: Is it a country?
# answerer: Yes
# guesser: Japan
#
# questioner: Is this country either in Asia or in Africa?
# answerer: No
# guesser: United States
#
# questioner: Is this country in Europe?
# answerer: Yes
# guesser: France
#
# questioner: Is it part of the European Union?
# answerer: Yes
# guesser: France
#
# questioner: Is this country located in Western Europe?
# answerer: No
# guesser: Poland
#
# questioner: Is this country in Eastern Europe?
# answerer: No
# guesser: Italy
#
# questioner: Is it located in Northern Europe?
# answerer: Yes
# guesser: Sweden
#
# questioner: Is it a Scandinavian country?
# answerer: Yes
# guesser: Sweden
#
# questioner: Does the country have a monarchy?
# answerer: Yes
# guesser: Sweden
#
# questioner: Is this country Norway?
# answerer: No
# guesser: Sweden
#
# questioner: Is this country Sweden?
# answerer: Yes
# guesser: Sweden
#
# questioner: [GAME OVER]
# Generated keyword: Norway
# questioner: Is it a place?
# answerer: Yes
# guesser: Paris
#
# questioner: Is it a country?
# answerer: Yes
# guesser: Japan
#
# questioner: Is this country either in Asia or in Africa?
# answerer: No
# guesser: Canada
#
# questioner: Is this country in Europe?
# answerer: Yes
# guesser: France
#
# questioner: Is this country a member of the European Union?
# answerer: No
# guesser: Norway
#
# questioner: Is this country an island nation?
# answerer: No
# guesser: Switzerland
#
# questioner: Is this country landlocked?
# answerer: No
# guesser: Norway
#
# questioner: Is this country in Western Europe?
# answerer: No
# guesser: Norway
#
# questioner: Is this country in Eastern Europe?
# answerer: No
# guesser: Norway
#
# questioner: Is this country in Northern Europe?
# answerer: Yes
# guesser: Norway
#
# questioner: Is this country a part of Scandinavia?
# answerer: Yes
# guesser: Norway
#
# questioner: Is this country Norway?
# answerer: Yes
# guesser: Norway
#
# questioner: [GAME OVER]
# Generated keyword: Poland
# questioner: Is it a place?
# answerer: Yes
# guesser: Paris
#
# questioner: Is it a country?
# answerer: Yes
# guesser: Japan
#
# questioner: Is this country either in Asia or in Africa?
# answerer: No
# guesser: Brazil
#
# questioner: Is this country in Europe?
# answerer: Yes
# guesser: France
#
# questioner: Is this country a member of the European Union?
# answerer: Yes
# guesser: France
#
# questioner: Is this country located in Southern Europe?
# answerer: No
# guesser: Germany
#
# questioner: Is this country in Western Europe?
# answerer: No
# guesser: Germany
#
# questioner: Is this country located in Northern Europe?
# answerer: No
# guesser: Poland
#
# questioner: Is this country in Eastern Europe?
# answerer: Yes
# guesser: Poland
#
# questioner: Does this country border Russia?
# answerer: No
# guesser: Poland
#
# questioner: Is this country landlocked?
# answerer: No
# guesser: Romania
#
# questioner: Does this country have a coastline on the Baltic Sea?
# answerer: Yes
# guesser: Poland
#
# questioner: Is this country part of the Baltic States (Estonia, Latvia, Lithuania)?
# answerer: No
# guesser: Poland
#
# questioner: Does this country border Poland?
# answerer: Yes
# guesser: Germany
#
# questioner: Is this country Ukraine?
# answerer: No
# guesser: Germany
#
# questioner: Is this country Germany?
# answerer: No
# guesser: Lithuania
#
# questioner: Is this country Slovakia?
# answerer: No
# guesser: Lithuania
#
# questioner: Is this country the Czech Republic?
# answerer: No
# guesser: Lithuania
#
# questioner: Is this country located entirely on the European continent?
# answerer: Yes
# guesser: Romania
#
# questioner: Does this country have a population of over 10 million people?
# answerer: Yes
# guesser: Romania
#
# Game: 3
# Generated keyword: Canada
# questioner: Is it a place?
# answerer: Yes
# guesser: Tokyo
#
# questioner: Is it a country?
# answerer: Yes
# guesser: Japan
#
# questioner: Is this country either in Asia or in Africa?
# answerer: No
# guesser: No guess
#
# questioner: Is this country in Europe?
# answerer: No
# guesser: Brazil
#
# questioner: Is this country in the Americas?
# answerer: Yes
# guesser: Brazil
#
# questioner: Is it in North America?
# answerer: Yes
# guesser: Canada
#
# questioner: Is this country part of the United States of America?
# answerer: No
# guesser: Canada
#
# questioner: Is this country located in Central America?
# answerer: No
# guesser: Canada
#
# questioner: Is this country located in Canada?
# answerer: No
# guesser: Mexico
#
# questioner: Is this country an island nation?
# answerer: No
# guesser: Mexico
#
# questioner: Is Spanish the official language of this country?
# answerer: No
# guesser: Mexico
#
# questioner: Is this country located in the Caribbean?
# answerer: No
# guesser: Mexico
#
# questioner: Is this country in South America?
# answerer: No
# guesser: Mexico
#
# questioner: Is this country a member of the Commonwealth of Nations?
# answerer: Yes
# guesser: Mexico
#
# questioner: Is this country located predominantly in the Northern Hemisphere?
# answerer: Yes
# guesser: Belize
#
# questioner: Is English the official language of this country?
# answerer: Yes
# guesser: Belize
#
# questioner: Was this country formerly a colony of the British Empire?
# answerer: Yes
# guesser: Belize
#
# questioner: Is this country known for having a colder climate?
# answerer: Yes
# guesser: Canada
#
# questioner: Does this country have a population of over 10 million people?
# answerer: Yes
# guesser: Canada
#
# questioner: Is this country known for large, untouched natural landscapes?
# answerer: Yes
# guesser: Canada
#
# Generated keyword: Brazil
# questioner: Is it a place?
# answerer: Yes
# guesser: Paris
#
# questioner: Is it a country?
# answerer: Yes
# guesser: Brazil
#
# questioner: Is this country either in Asia or in Africa?
# answerer: No
# guesser: No text
#
# questioner: Is this country in Europe?
# answerer: No
# guesser: Japan
#
# questioner: Is this country in the Americas?
# answerer: Yes
# guesser: Brazil
#
# questioner: Is this country in North America?
# answerer: No
# guesser: Brazil
#
# questioner: Is this country in South America?
# answerer: Yes
# guesser: Brazil
#
# questioner: Is this country landlocked?
# answerer: No
# guesser: Brazil
#
# questioner: Is this country the largest by area in South America?
# answerer: Yes
# guesser: Brazil
#
# questioner: Is this country Brazil?
# answerer: Yes
# guesser: Brazil
#
# questioner: [GAME OVER]
# Generated keyword: Mexico
# questioner: Is it a place?
# answerer: Yes
# guesser: Paris
#
# questioner: Is it a country?
# answerer: Yes
# guesser: France
#
# questioner: Is this country either in Asia or in Africa?
# answerer: No
# guesser: United States
#
# questioner: Is this country in Europe?
# answerer: No
# guesser: Brazil
#
# questioner: Is this country in the Americas?
# answerer: Yes
# guesser: Canada
#
# questioner: Is this country in North America?
# answerer: Yes
# guesser: United States
#
# questioner: Is this country primarily English-speaking?
# answerer: No
# guesser: Mexico
#
# questioner: Is this country located in Central America?
# answerer: No
# guesser: Mexico
#
# questioner: Is this country Canada?
# answerer: No
# guesser: Mexico
#
# questioner: Is this country located on an island or group of islands?
# answerer: No
# guesser: Mexico
#
# questioner: Is this country south of the United States?
# answerer: Yes
# guesser: Mexico
#
# questioner: Does this country share a border with the United States?
# answerer: Yes
# guesser: Mexico
#
# questioner: Is this country Mexico?
# answerer: Yes
# guesser: Mexico
#
# questioner: [GAME OVER]
# Generated keyword: Argentina
# questioner: Is it a place?
# answerer: Yes
# guesser: Paris
#
# questioner: Is it a country?
# answerer: Yes
# guesser: Japan
#
# questioner: Is this country either in Asia or in Africa?
# answerer: No
# guesser: No guess
#
# questioner: Is this country in Europe?
# answerer: No
# guesser: Japan
#
# questioner: Is this country in the Americas?
# answerer: Yes
# guesser: Brazil
#
# questioner: Is this country in North America?
# answerer: No
# guesser: Brazil
#
# questioner: Is this country in South America?
# answerer: Yes
# guesser: Brazil
#
# questioner: Is this country known for having a significant portion of the Amazon Rainforest?
# answerer: No
# guesser: Argentina
#
# questioner: Is this country landlocked?
# answerer: No
# guesser: Chile
#
# questioner: Is this country known for having a coast along the Pacific Ocean?
# answerer: No
# guesser: Uruguay
#
# questioner: Is this country famous for its beaches along the Atlantic Ocean?
# answerer: Yes
# guesser: Brazil
#
# questioner: Is this country located in the northern part of South America?
# answerer: No
# guesser: Uruguay
#
# questioner: Is this country bilingual, with a notable use of both European and indigenous languages?
# answerer: No
# guesser: Uruguay
#
# questioner: Is this country known for its carnival celebrations?
# answerer: No
# guesser: Uruguay
#
# questioner: Is this country an island?
# answerer: No
# guesser: Uruguay
#
# questioner: Is this country famous for tango music and dance?
# answerer: Yes
# guesser: Argentina
#
# questioner: Is this country Argentina?
# answerer: Yes
# guesser: Argentina
#
# questioner: [GAME OVER]
# Generated keyword: Chile
# questioner: Is it a place?
# answerer: Yes
# guesser: Paris
#
# questioner: Is it a country?
# answerer: Yes
# guesser: Japan
#
# questioner: Is this country either in Asia or in Africa?
# answerer: No
# guesser: France
#
# questioner: Is this country in Europe?
# answerer: No
# guesser: Japan
#
# questioner: Is this country in the Americas?
# answerer: Yes
# guesser: Brazil
#
# questioner: Is this country located in North America?
# answerer: No
# guesser: Brazil
#
# questioner: Is this country located in South America?
# answerer: Yes
# guesser: Brazil
#
# questioner: Is the capital of this country located near the equator?
# answerer: No
# guesser: Argentina
#
# questioner: Is this country landlocked?
# answerer: No
# guesser: Brazil
#
# questioner: Does this country have a population greater than 10 million?
# answerer: Yes
# guesser: Argentina
#
# questioner: Is this country one of the largest by area in South America?
# answerer: Yes
# guesser: Argentina
#
# questioner: Is this country Brazil?
# answerer: No
# guesser: Argentina
#
# questioner: Is this country Argentina?
# answerer: No
# guesser: Peru
#
# questioner: Is this country bordered by the Andes Mountains?
# answerer: Yes
# guesser: Chile
#
# questioner: Is this country Chile?
# answerer: Yes
# guesser: Chile
#
# questioner: [GAMER OVER]
# Generated keyword: Colombia
# questioner: Is it a place?
# answerer: Yes
# guesser: Paris
#
# questioner: Is it a country?
# answerer: Yes
# guesser: France
#
# questioner: Is this country either in Asia or in Africa?
# answerer: No
# guesser: No guesses yet.
#
# questioner: Is this country in Europe?
# answerer: No
# guesser: Japan
#
# questioner: Is this country in the Americas?
# answerer: Yes
# guesser: United States
#
# questioner: Is this country in North America?
# answerer: No
# guesser: Brazil
#
# questioner: Is this country in South America?
# answerer: Yes
# guesser: Brazil
#
# questioner: Is the primary language of this country Spanish?
# answerer: Yes
# guesser: Argentina
#
# questioner: Is this country bordered by the Atlantic Ocean?
# answerer: Yes
# guesser: Argentina
#
# questioner: Is this country north of the equator?
# answerer: Yes
# guesser: Venezuela
#
# questioner: Is this country known for its involvement in coffee production?
# answerer: Yes
# guesser: Colombia
#
# questioner: Is this country's capital city Bogotá?
# answerer: Yes
# guesser: Colombia
#
# questioner: Is the country Colombia?
# answerer: Yes
# guesser: Colombia
#
# questioner: [GAME OVER]
# Generated keyword: Peru
# questioner: Is it a place?
# answerer: Yes
# guesser: Paris
#
# questioner: Is it a country?
# answerer: Yes
# guesser: France
#
# questioner: Is this country either in Asia or in Africa?
# answerer: No
# guesser: No guess yet
#
# questioner: Is this country in Europe?
# answerer: No
# guesser: Japan
#
# questioner: Is this country in the Americas?
# answerer: Yes
# guesser: Canada
#
# questioner: Is this country in North America?
# answerer: No
# guesser: Brazil
#
# questioner: Is this country in South America?
# answerer: Yes
# guesser: Brazil
#
# questioner: Is the country known for being predominantly Spanish-speaking?
# answerer: Yes
# guesser: Argentina
#
# questioner: Is this country on the western side of South America?
# answerer: Yes
# guesser: Chile
#
# questioner: Does this country have a coastline along the Pacific Ocean?
# answerer: Yes
# guesser: Chile
#
# questioner: Is this country north of the Equator?
# answerer: No
# guesser: Peru
#
# questioner: Is this country known for having a significant portion of the Amazon rainforest?
# answerer: Yes
# guesser: Peru
#
# questioner: Is this country bordered by Brazil?
# answerer: Yes
# guesser: Peru
#
# questioner: Is the capital of this country Lima?
# answerer: Yes
# guesser: Peru
#
# questioner: Is this country named Peru?
# answerer: Yes
# guesser: Peru
#
# questioner: [GAME OVER]
# Generated keyword: Cuba
# questioner: Is it a place?
# answerer: Yes
# guesser: Paris
#
# questioner: Is it a country?
# answerer: Yes
# guesser: France
#
# questioner: Is this country either in Asia or in Africa?
# answerer: No
# guesser: No guess
#
# questioner: Is this country in Europe?
# answerer: No
# guesser: Japan
#
# questioner: Is this country in the Americas?
# answerer: Yes
# guesser: Brazil
#
# questioner: Is this country in North America?
# answerer: Yes
# guesser: United States
#
# questioner: Is this country located on an island?
# answerer: Yes
# guesser: Cuba
#
# questioner: Is this country part of the Caribbean?
# answerer: Yes
# guesser: Cuba
#
# questioner: Is this country known for its significant tourism industry?
# answerer: Yes
# guesser: Jamaica
#
# questioner: Is this country a member of the Commonwealth of Nations?
# answerer: No
# guesser: Cuba
#
# questioner: Is this country predominantly Spanish-speaking?
# answerer: Yes
# guesser: Cuba
#
# questioner: Is this country Cuba?
# answerer: Yes
# guesser: Cuba
#
# questioner: [GAME OVER]
# Generated keyword: Uruguay
# questioner: Is it a place?
# answerer: Yes
# guesser: Paris
#
# questioner: Is it a country?
# answerer: Yes
# guesser: France
#
# questioner: Is this country either in Asia or in Africa?
# answerer: No
# guesser: Iceland
#
# questioner: Is this country in Europe?
# answerer: No
# guesser: India
#
# questioner: Is this country in the Americas?
# answerer: Yes
# guesser: Brazil
#
# questioner: Is this country in North America?
# answerer: No
# guesser: Brazil
#
# questioner: Is this country located in South America?
# answerer: Yes
# guesser: Brazil
#
# questioner: Is it a coastal country?
# answerer: Yes
# guesser: Brazil
#
# questioner: Is it located in the northern part of South America?
# answerer: No
# guesser: Argentina
#
# questioner: Is it located in the southern part of South America?
# answerer: Yes
# guesser: Chile
#
# questioner: Is this country predominantly Spanish-speaking?
# answerer: Yes
# guesser: Chile
#
# questioner: Is Argentina the country you're thinking of?
# answerer: No
# guesser: Chile
#
# questioner: Is the country known for its significant rainforests?
# answerer: No
# guesser: Chile
#
# questioner: Is this country landlocked on at least one side?
# answerer: No
# guesser: Chile
#
# questioner: Is this country known for having a large indigenous population?
# answerer: No
# guesser: Chile
#
# questioner: Is this country known for its wine production?
# answerer: No
# guesser: Chile
#
# questioner: Is this country known for a long coastline along the Pacific Ocean?
# answerer: No
# guesser: Uruguay
#
# questioner: Is this country known for being home to the Andes mountain range?
# answerer: No
# guesser: Uruguay
#
# questioner: Is this country primarily located in the temperate climate zone?
# answerer: Yes
# guesser: Uruguay
#
# questioner: Is this country known for having a vibrant carnival culture?
# answerer: No
# guesser: Uruguay
#
# Generated keyword: Panama
# questioner: Is it a place?
# answerer: Yes
# ...
# guesser: Mountain
#
# questioner: Is it often associated with mountains?
# answerer: Yes
# guesser: Rock
#
# questioner: Is it part of a mountain?
# answerer: No
# guesser: Valley
#
# questioner: Is it typically found in specific climatic regions, such as deserts or polar areas?
# answerer: No
# guesser: Valley
#
# questioner: Is it composed primarily of rock?
# answerer: No
# guesser: Glacier
#
# questioner: Is it primarily composed of soil?
# answerer: No
# guesser: Valley
#
# questioner: Is it typically associated with water?
# answerer: Yes
# guesser: Glacier
#
# questioner: Is it created by the movement of glaciers?
# answerer: No
# guesser: Valley
#
# questioner: Is it associated with a volcanic activity?
# answerer: No
# guesser: Valley
#
# questioner: Is it commonly found in river valleys or near rivers?
# answerer: Yes
# guesser: Canyon
#
# questioner: Is it a type of landform?
# answerer: Yes
# guesser: Canyon
#
# questioner: Is it a type of plain?
# answerer: No
# guesser: Canyon
#
# questioner: Is it a feature formed by erosion?
# answerer: Yes
# guesser: Canyon
#
# questioner: Is it commonly a narrow, steep-sided valley?
# answerer: No
# guesser: Canyon
#
# questioner: Is it typically expansive and wide?
# answerer: No
# guesser: canyon
#
# Game: 15
# Generated keyword: cloud
# questioner: Is it a place?
# answerer: No
# guesser: thing
#
# questioner: Is it a man-made thing?
# answerer: No
# guesser: tree
#
# questioner: Is it a living thing?
# answerer: No
# guesser: statue
#
# questioner: Is it a geological ?
# answerer: No
# guesser: Eiffel Tower
#
# questioner: Is it something that occurs naturally?
# answerer: Yes
# guesser: Water
#
# questioner: Is it related to weather?
# answerer: Yes
# guesser: Cloud
#
# questioner: Is it a form of precipitation?
# answerer: No
# guesser: Cloud
#
# questioner: Is it a type of cloud?
# answerer: Yes
# guesser: Cumulus
#
# questioner: Does it typically produce thunderstorms?
# answerer: No
# guesser: Stratus cloud
#
# questioner: Is it a low-altitude cloud?
# answerer: Yes
# guesser: Stratus
#
# questioner: Is it commonly found near ground level, like fog?
# answerer: Yes
# guesser: Stratus cloud
#
# questioner: Is it a type of stratus cloud?
# answerer: Yes
# guesser: Stratus
#
# questioner: Is it often associated with overcast skies and light drizzle?
# answerer: Yes
# guesser: Stratus cloud
#
# questioner: Is it known to create a uniform gray sheet across the sky?
# answerer: Yes
# guesser: Stratus
#
# questioner: Is it a nimbostratus cloud?
# answerer: No
# guesser: Stratus cloud
#
# questioner: Is it a stratus cloud?
# answerer: Yes
# guesser: Stratus cloud
#
# questioner: Is it the most common type of low-altitude cloud?
# answerer: Yes
# guesser: Stratus cloud
#
# questioner: Are these clouds typically seen in stable atmospheric conditions?
# answerer: Yes
# guesser: Stratus cloud
#
# questioner: Do stratus clouds typically cover large areas of the sky?
# answerer: Yes
# guesser: Stratus clouds
#
# questioner: Are stratus clouds often seen during the winter season?
# answerer: Yes
# guesser: Stratus cloud
#
# Generated keyword: comet
# questioner: Is it a place?
# answerer: No
# guesser: A car
#
# questioner: Is it a man-made thing?
# answerer: No
# guesser: mountain
#
# questioner: Is it a living thing?
# answerer: No
# guesser: book
#
# questioner: Is it a geological ?
# answerer: No
# guesser: Giraffe
#
# questioner: Is it an astronomical object?
# answerer: Yes
# guesser: Star
#
# questioner: Is it part of our Solar System?
# answerer: Yes
# guesser: Sun
#
# questioner: Is it a planet?
# answerer: No
# guesser: Moon
#
# questioner: Is it a moon?
# answerer: No
# guesser: Star
#
# questioner: Is it a star?
# answerer: No
# guesser: Asteroid
#
# questioner: Is it a part of a planet, such as a ring or an asteroid belt?
# answerer: No
# guesser: comet
#
# questioner: Is it a comet?
# answerer: Yes
# guesser: Halley's Comet
#
# questioner: Is it currently visible to the naked eye from Earth?
# answerer: Varies
# guesser: Halley's Comet
#
# questioner: Is it associated with a specific period when it becomes more visible, such as a particular time of year or specific years?
# answerer: Yes
# guesser: Halley's Comet
#
# questioner: Is it Halley's Comet?
# answerer: Yes
# guesser: Halley's Comet
#
# questioner: [GAMER OVER]
# Generated keyword: rainbow
# questioner: Is it a place?
# answerer: No
# guesser: thing
#
# questioner: Is it a man-made thing?
# answerer: No
# guesser: Mountain
#
# questioner: Is it a living thing?
# answerer: No
# guesser: chair
#
# questioner: Is it a geological ?
# answerer: No
# guesser: Eiffel Tower
#
# questioner: Is it related to weather or atmosphere?
# answerer: Yes
# guesser: Cloud
#
# questioner: Is it a type of precipitation?
# answerer: No
# guesser: Cloud
#
# questioner: Is it related to air movement?
# answerer: No
# guesser: Cloud
#
# questioner: Is it a type of cloud or cloud formation?
# answerer: No
# guesser: Rainbow
#
# questioner: Is it a naturally occurring phenomenon?
# answerer: Yes
# guesser: Rainbow
#
# questioner: Is it related to temperature?
# answerer: No
# guesser: Rainbow
#
# questioner: Is it related to light or visibility?
# answerer: Yes
# guesser: Rainbow
#
# questioner: Is it a form of optical phenomenon?
# answerer: Yes
# guesser: Rainbow
#
# questioner: Does it involve reflection or refraction of light?
# answerer: Yes
# guesser: Rainbow
#
# questioner: Is it commonly seen near water or after rain?
# answerer: Yes
# guesser: Rainbow
#
# questioner: Is it a rainbow?
# answerer: Yes
# guesser: Rainbow
#
# questioner: [GAME OVER]
# Generated keyword: mist
# questioner: Is it a place?
# answerer: No
# guesser: thing
#
# questioner: Is it a man-made thing?
# answerer: No
# guesser: tree
#
# questioner: Is it a living thing?
# answerer: No
# guesser: computer
#
# questioner: Is it a geological ?
# answerer: No
# guesser: computer
#
# questioner: Is it something found in nature?
# answerer: Yes
# guesser: Water
#
# questioner: Is it a type of weather phenomenon?
# answerer: Yes
# guesser: Rainbow
#
# questioner: Is it related to precipitation?
# answerer: No
# guesser: Rainbow
#
# questioner: Is it related to atmospheric conditions?
# answerer: Yes
# guesser: Wind
#
# questioner: Is it a type of wind?
# answerer: No
# guesser: Rainbow
#
# questioner: Is it something that occurs in a specific season?
# answerer: No
# guesser: Rainbow
#
# questioner: Is it related to temperature?
# answerer: Yes
# guesser: Fog
#
# questioner: Can it cause extreme heat?
# answerer: No
# guesser: Frost
#
# questioner: Does it involve low temperatures or cold conditions?
# answerer: No
# guesser: Humidity
#
# questioner: Is it related to changes in air pressure?
# answerer: Yes
# guesser: Humidity
#
# questioner: Does it involve rapid changes or fluctuations?
# answerer: No
# guesser: Humidity
#
# questioner: Is it a large-scale weather event?
# answerer: No
# guesser: Fog
#
# questioner: Is it commonly associated with storms?
# answerer: No
# guesser: Humidity
#
# questioner: Is it a regular atmospheric phenomenon?
# answerer: Yes
# guesser: Inversion
#
# questioner: Is it related to clouds?
# answerer: Yes
# guesser: Humidity
#
# questioner: Is it a type of cloud?
# answerer: Yes
# guesser: Cumulus
#
# Generated keyword: snowflake
# questioner: Is it a place?
# answerer: No
# guesser: thing
#
# questioner: Is it a man-made thing?
# answerer: No
# guesser: Tree
#
# questioner: Is it a living thing?
# answerer: No
# guesser: Rock
#
# questioner: Is it a geological ?
# answerer: No
# guesser: Eiffel Tower
#
# questioner: Is it an astronomical object?
# answerer: No
# guesser: Cloud
#
# questioner: Is it a type of food?
# answerer: No
# guesser: Cloud
#
# questioner: Is it a natural phenomenon?
# answerer: No
# guesser: Atom
#
# questioner: Is it related to sports?
# answerer: No
# guesser: rainbow
#
# questioner: Can it be used in everyday life?
# answerer: No
# guesser: concept
#
# questioner: Is it a type of entertainment?
# answerer: No
# guesser: Concept
#
# questioner: Is it something found in a household?
# answerer: No
# guesser: Idea
#
# questioner: Is it related to technology?
# answerer: No
# guesser: Emotion
#
# questioner: Could it be considered art?
# answerer: No
# guesser: Emotion
#
# questioner: Is it an element from the periodic table?
# answerer: No
# guesser: Concept
#
# questioner: Is it a type of plant?
# answerer: No
# guesser: Concept
#
# questioner: Is it a weather-related object?
# answerer: Yes
# guesser: Cloud
#
# questioner: Is it a type of precipitation?
# answerer: Yes
# guesser: Snow
#
# questioner: Is it solid?
# answerer: Yes
# guesser: Snow
#
# questioner: Is it snow?
# answerer: No
# guesser: Hail
#
# questioner: Is it hail?
# answerer: No
# guesser: Sleet
#
# Generated keyword: thunder
# questioner: Is it a place?
# answerer: No
# guesser: an object
#
# questioner: Is it a man-made thing?
# answerer: No
# guesser: Mountain
#
# questioner: Is it a living thing?
# answerer: No
# guesser: Statue
#
# questioner: Is it a geological ?
# answerer: No
# guesser: Eiffel Tower
#
# questioner: Is it found outdoors?
# answerer: Yes
# guesser: Weather
#
# questioner: Is it related to weather?
# answerer: Yes
# guesser: Cloud
#
# questioner: Is it a form of precipitation?
# answerer: No
# guesser: Sunlight
#
# questioner: Is it a type of wind phenomenon?
# answerer: No
# guesser: Sunlight
#
# questioner: Is it a weather-related event that occurs primarily during a specific season?
# answerer: No
# guesser: Cloud
#
# questioner: Is it a natural atmospheric phenomenon?
# answerer: Yes
# guesser: Clouds
#
# questioner: Is it related to temperature changes?
# answerer: No
# guesser: Rainbow
#
# questioner: Is it visible to the human eye?
# answerer: No
# guesser: Humidity
#
# questioner: Is it related to pressure changes in the atmosphere?
# answerer: Yes
# guesser: Humidity
#
# questioner: Is it a type of storm?
# answerer: No
# guesser: Humidity
#
# questioner: Does it affect weather patterns globally?
# answerer: No
# guesser: Humidity
#
# questioner: Is it an atmospheric layer or field related phenomenon?
# answerer: No
# guesser: Air pressure
#
# questioner: Is it related to sound or waves in the atmosphere?
# answerer: Yes
# guesser: Thunder
#
# questioner: Is it something that can be measured with instruments like barometers or seismometers?
# answerer: No
# guesser: Thunder
#
# questioner: Is it something that animals can sense or respond to?
# answerer: Yes
# guesser: Infrasound
#
# questioner: Is it related to thunder or lightning?
# answerer: Yes
# guesser: Infrasound
#
# Generated keyword: lightning
# questioner: Is it a place?
# answerer: No
# guesser: thing
#
# questioner: Is it a man-made thing?
# answerer: No
# guesser: tree
#
# questioner: Is it a living thing?
# answerer: No
# guesser: rock
#
# questioner: Is it a geological ?
# answerer: No
# guesser: Eiffel Tower
#
# questioner: Does it involve water?
# answerer: No
# guesser: Star
#
# questioner: Is it found in the sky?
# answerer: Yes
# guesser: Star
#
# questioner: Is it larger than a car?
# answerer: No
# guesser: star
#
# questioner: Can it change its shape?
# answerer: Yes
# guesser: Cloud
#
# questioner: Is it visible during both day and night?
# answerer: Yes
# guesser: Cloud
#
# questioner: Is it a weather phenomenon?
# answerer: Yes
# guesser: Cloud
#
# questioner: Is it usually seen during storms?
# answerer: Yes
# guesser: Lightning
#
# questioner: Does it produce lightning?
# answerer: Yes
# guesser: Thundercloud
#
# questioner: Is it often accompanied by thunder?
# answerer: Yes
# guesser: Thundercloud
#
# questioner: Is it a single occurrence, not a series of events?
# answerer: Yes
# guesser: Lightning
#
# questioner: Is it commonly referred to as a "storm"?
# answerer: No
# guesser: Lightning
#
# questioner: Does it involve severe weather conditions?
# answerer: Yes
# guesser: Thunderstorm
#
# questioner: Is it a type of cloud?
# answerer: No
# guesser: Lightning
#
# questioner: Is it related to precipitation?
# answerer: No
# guesser: Lightning
#
# questioner: Is it a type of atmospheric disturbance?
# answerer: Yes
# guesser: Lightning
#
# questioner: Is it a form of electrical discharge?
# answerer: Yes
# guesser: Lightning
#
# Generated keyword: tornado
# questioner: Is it a place?
# answerer: No
# guesser: thing
#
# questioner: Is it a man-made thing?
# answerer: No
# guesser: Mountain
#
# questioner: Is it a living thing?
# answerer: No
# guesser: chair
#
# questioner: Is it a geological ?
# answerer: No
# guesser: Eiffel Tower
#
# questioner: Is it a naturally occurring object?
# answerer: Yes
# guesser: Water
#
# questioner: Is it smaller than a breadbox?
# answerer: No
# guesser: Mountain
#
# questioner: Is it found outdoors?
# answerer: Yes
# guesser: Tree
#
# questioner: Is it found in forests?
# answerer: No
# guesser: Mountain
#
# questioner: Is it commonly found in a body of water?
# answerer: No
# guesser: Mountain
#
# questioner: Is it found in deserts?
# answerer: No
# guesser: Mountain
#
# questioner: Is it found in mountainous regions?
# answerer: No
# guesser: Sky
#
# questioner: Is it related to weather phenomena?
# answerer: Yes
# guesser: Cloud
#
# questioner: Is it a type of precipitation?
# answerer: No
# guesser: Rainbow
#
# questioner: Is it related to temperature?
# answerer: No
# guesser: Rainbow
#
# questioner: Is it visible to the naked eye?
# answerer: Yes
# guesser: Cloud
#
# questioner: Does it produce light or have a luminous quality?
# answerer: No
# guesser: Cloud
#
# questioner: Is it a cloud?
# answerer: No
# guesser: Rainbow
#
# questioner: Is it related to wind?
# answerer: Yes
# guesser: Tornado
#
# questioner: Is it a tornado?
# answerer: Yes
# guesser: Tornado
#
# questioner: [GAME OVER]
# Generated keyword: aurora
# questioner: Is it a place?
# answerer: No
# guesser: Thing
#
# questioner: Is it a man-made thing?
# answerer: No
# guesser: Mountain
#
# questioner: Is it a living thing?
# answerer: No
# guesser: Rock
#
# questioner: Is it a geological ?
# answerer: No
# guesser: Eiffel Tower
#
# questioner: Is it related to weather or climate?
# answerer: No
# guesser: Star
#
# questioner: Is it found in outer space?
# answerer: No
# guesser: Water
#
# questioner: Is it used in everyday life?
# answerer: No
# guesser: Dinosaur fossil
#
# questioner: Is it part of the natural environment?
# answerer: Yes
# guesser: Mineral
#
# questioner: Is it a type of plant?
# answerer: No
# guesser: Rock
#
# questioner: Is it a type of mineral?
# answerer: No
# guesser: Water
#
# questioner: Is it related to water?
# answerer: No
# guesser: Mountain
#
# questioner: Is it something that can be found in the ground?
# answerer: No
# guesser: Mountain
#
# questioner: Is it related to animals?
# answerer: No
# guesser: Air
#
# questioner: Is it something that can be seen in the sky?
# answerer: Yes
# guesser: Star
#
# questioner: Is it a type of weather phenomenon?
# answerer: No
# guesser: Star
#
# questioner: Is it a celestial body?
# answerer: No
# guesser: Rainbows
#
# questioner: Is it a type of cloud?
# answerer: No
# guesser: Rainbow
#
# questioner: Is it a type of natural light?
# answerer: Yes
# guesser: Rainbow
#
# questioner: Is it created by the interaction of light with the Earth's atmosphere?
# answerer: Yes
# guesser: Rainbow
#
# questioner: Is it a rainbow?
# answerer: No
# guesser: Aurora
#
# Generated keyword: dew
# questioner: Is it a place?
# answerer: No
# guesser: thing
#
# questioner: Is it a man-made thing?
# answerer: No
# guesser: Ocean
#
# questioner: Is it a living thing?
# answerer: No
# guesser: is it a landmark?
#
# questioner: Is it a geological ?
# answerer: No
# guesser: Statue of Liberty
#
# questioner: Is it something found in nature?
# answerer: Yes
# guesser: Water
#
# questioner: Is it something that can be categorized as a type of weather or atmospheric phenomenon?
# answerer: Yes
# guesser: Cloud
#
# questioner: Is it something that occurs regularly?
# answerer: Yes
# guesser: Rain
#
# questioner: Is it a type of precipitation?
# answerer: No
# guesser: Sunshine
#
# questioner: Is it related to wind or air movement?
# answerer: No
# guesser: Cloud
#
# questioner: Is it related to temperature?
# answerer: Yes
# guesser: Season
#
# questioner: Does it primarily occur during a specific season?
# answerer: No
# guesser: Humidity
#
# questioner: Can it be associated with extreme weather conditions?
# answerer: No
# guesser: Humidity
#
# questioner: Is it visible to the naked eye?
# answerer: Yes
# guesser: Sunshine
#
# questioner: Does it involve changes in the sky, such as cloud formations or the position of the sun?
# answerer: No
# guesser: Fog
#
# questioner: Is it related to the measurement of temperature?
# answerer: No
# guesser: Rainbow
#
# questioner: Is it a natural phenomenon that can be felt physically?
# answerer: No
# guesser: Frost
#
# questioner: Can it be seen during both day and night?
# answerer: Yes
# guesser: Rainbow
#
# questioner: Is it a type of light or illumination?
# answerer: No
# guesser: Rainbow
#
# questioner: Is it a natural occurrence that affects plants or the environment?
# answerer: Yes
# guesser: Dew
#
# questioner: Does it have to do with the moisture content in the air?
# answerer: Yes
# guesser: Humidity

# %%
len(game_results)
# Out:
# 160

# %% [markdown]
# ## Save as JSONL

# %%
with open("games-1.jsonl", "w") as f:
    for i in game_results:
        json.dump(i, f)
        f.write('\n')

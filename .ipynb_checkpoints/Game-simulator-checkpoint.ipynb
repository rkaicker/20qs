# %% [markdown]
# # TODO
#
# ~~1. Generate a few keywords for each starting game~~
#
# ~~2. Write a guesser agent to guess the keyword after each answer~~
#
# ~~3. Generate a JSON list of all the games~~

# %%
# %%capture
# !{sys.executable} -m pip install openai

# %%
import os
import sys

from openai import OpenAI

os.environ["OPENAI_API_KEY"]= 'sk-proj-m2nlV3Z8caGtFrxYq8tFT3BlbkFJE1DuMruKA3B1JGaceJNr'

client = OpenAI(
    api_key=os.environ.get("OPENAI_API_KEY"),
)

# %%
class Node:
    def __init__(self, question=None, yes_branch=None, no_branch=None, examples=None, summary=None):
        self.question = question
        self.yes_branch = yes_branch
        self.no_branch = no_branch
        self.examples = examples
        self.summary = summary

def print_tree(node, indent=0):
    """ Recursively print the decision tree. """
    if node is None:
        return
    if node.summary:
        # Print leaf node summary
        print(' ' * indent + f'→ Summary: The keyword is {node.summary}.')
    if node.examples:
        # Print leaf node examples
        print(' ' * indent + f'→ Examples: {", ".join(node.examples)}')
    if node.question:
        # Print the question node
        turn = indent // 4 + 1
        print(' ' * indent + f'Turn {turn}: {node.question}')
        if node.yes_branch or node.no_branch:
            print(' ' * indent + ' ├─ Yes:')
            print_tree(node.yes_branch, indent + 4)  # Print yes branch
            print(' ' * indent + ' └─ No:')
            print_tree(node.no_branch, indent + 4)   # Print no branch

# Define the decision tree structure
tree = Node(
    "Is it a place?",
    yes_branch=Node(
        examples=['Lesotho', 'Acapulco', 'Oceania', 'Parking lot'],
        question="Is it a country?",
        yes_branch=Node(
            examples=['Brazil', 'Japan', 'Kenya', 'Norway'],
            question="Is this country either in Asia or in Africa?",
            yes_branch=Node(
                examples=['Thailand', 'North Korea', 'Egypt', 'Nigeria'],
                question="Is this country in Asia?",
                yes_branch=Node(summary='a country in Asia', examples=['Kazakhstan', 'South Korea']),
                no_branch=Node(summary='a country in Africa', examples=['Morocco', 'Ghana'])
            ),
            no_branch=Node(
                examples=['Lithuania', 'Papua New Guinea', 'Uruguay', 'Slovakia'],
                question="Is this country in Europe?",
                yes_branch=Node(summary='a country in Europe', examples=['Romania', 'Germany']),
                no_branch=Node(
                    examples=['Australia', 'Nicaragua', 'Chile', 'United States'],
                    question="Is this country in the Americas?",
                    yes_branch=Node(summary='a country in the Americas', examples=['Argentina', 'Canada']),
                    no_branch=Node(summary='a country in Oceania', examples=['New Zealand', 'Samoa'])
                )
            )
        ),
        no_branch=Node(
            examples=['Venice', 'Lagos', 'Times Square', 'Colosseum'],
            question="Is it a city?",
            yes_branch=Node(
                examples=['Paris', 'Astana', 'Alexandria', 'Sao Paulo'],
                question="Is it a capital city?",
                yes_branch=Node(summary='a capital city', examples=['Moscow', 'Santiago']),
                no_branch=Node(summary='a city which is not a capital', examples=['Chicago', 'Tianjin'])
            ),
            no_branch=Node(
                examples=['Oceania', 'Nevada', 'Times Square', 'Colosseum'],
                question="Is it either a continent or a state of a country?",
                yes_branch=Node(
                    examples=['North America', 'Nevada', 'Roraima', 'Uttar Pradesh'],
                    question="Is it a continent?",
                    yes_branch=Node(summary='a continent', examples=['Africa', 'Asia']),
                    no_branch=Node(summary='a state of a country', examples=['Kentucky', 'Santa Catarina Brazil'])
                ),
                no_branch=Node(
                    examples=['Copacabana beach', 'university campus', 'Antarctica', 'tundra'],
                    question="Is it a location made by humans?",
                    yes_branch=Node(summary='a location made by humans', examples=['Champs-Elysees', 'Amusement park']),
                    no_branch=Node(summary='a natural location', examples=['Amazon rainforest', 'Desert'])
                )
            )
        )
    ),
    no_branch=Node(
        examples=['Pencil sharpener', 'cloud', 'chimney', 'electric vehicle'],
        question="Is it a man-made thing?",
        yes_branch=Node(
            examples=['plastic bottle', 'martini', 'earbuds', 'helicopter'],
            question="Is it something found indoors?",
            yes_branch=Node(
                examples=['pencil sharpener', 'refrigerator', 'coffee machine', 'escalator'],
                question="Is it something found in a home?",
                yes_branch=Node(summary='a man-made thing found in people\'s homes', examples=["Bed frame", "Stove"]),
                no_branch=Node(summary='a man-made thing found indoors but not in people\'s homes', examples=["Hospital bed", "Erlenmeyer flask"])
            ),
            no_branch=Node(
                examples=['pickup truck', 'train', 'fountain', 'obelisk'],
                question="Is it something found in a city?",
                yes_branch=Node(summary='a man-made thing found outdoors in cities', examples=['Apartment Building', 'Fire Hydrant']),
                no_branch=Node(summary='a man-made thing found outdoors outside of cities', examples=['Satellite', 'Barn'])
            ),
        ),
        no_branch=Node(
            examples=['thunder', 'Acacia', 'giraffe', 'river'],
            question="Is it a living thing?",
            yes_branch=Node(
                examples=['Palm tree', 'beetle', 'whale', 'apple'],
                question="Is it an animal?",
                yes_branch=Node(
                    examples=['sea lion', 'cape toad', 'kangaroo', 'peacock'],
                    question="Is it a mammal or a bird?",
                    yes_branch=Node(summary='either a mammal or a bird', examples=["Elephant", "Seagull"]),
                    no_branch=Node(summary='either a fish, insect, reptilian or amphibian', examples=["Shark", "Wasp", "Frog", "Alligator"])
                ),
                no_branch=Node(
                    examples=['mold', 'deciduous tree', 'yeast', 'agave'],
                    question="Is it a plant?",
                    yes_branch=Node(
                        examples=['orchid', 'poison ivy', 'maple tree', 'sunflower'],
                        question="Is it a tree?",
                        yes_branch=Node(summary='a tree', examples=["Oak tree", "Cactus"]),
                        no_branch=Node(summary='a plant which is not a tree', examples=["Rose", "Fern"])
                    ),
                    no_branch=Node(
                        examples=['black mold', 'truffle', 'cremini mushroom', 'bacillus'],
                        question="Is it a fungus?",
                        yes_branch=Node(summary='a fungus', examples=["Wood ear mushroom", "Yeast"]),
                        no_branch=Node(summary='a bacteria', examples=['E Coli', 'Streptococcus'])
                    )
                )
            ),
            no_branch=Node(
                examples=['uranus', 'seine river', 'carbon', 'electron'],
                question="Is it a geological feature?",
                yes_branch=Node(
                    examples=['Mount Fuji', 'volcano', 'canyon', 'Rocky mountains'],
                    question="Is it a body of water?",
                    yes_branch=Node(summary='a body of water', examples=["River", "Mediterranean Sea"]),
                    no_branch=Node(summary='a geological feature which is not a body of water', examples=["Cave", "Volcano"])
                ),
                no_branch=Node(
                    examples=['mercury', 'sun', 'iron', 'lead'],
                    question="Is it a chemical element, molecule or compound?",
                    yes_branch=Node(summary='a chemical element, molecule or compound', examples=["Salt", "Oxygen"]),
                    no_branch=Node(summary='a non-living thing not made by humans', examples=['Pebble', 'Milky Way'])
                )
            )
        )
    )
)

# Print the decision tree
print_tree(tree)
# Out:
# Turn 1: Is it a place?
#  ├─ Yes:
#     → Examples: Lesotho, Acapulco, Oceania, Parking lot
#     Turn 2: Is it a country?
#      ├─ Yes:
#         → Examples: Brazil, Japan, Kenya, Norway
#         Turn 3: Is this country either in Asia or in Africa?
#          ├─ Yes:
#             → Examples: Thailand, North Korea, Egypt, Nigeria
#             Turn 4: Is this country in Asia?
#              ├─ Yes:
#                 → Summary: The keyword is a country in Asia.
#                 → Examples: Kazakhstan, South Korea
#              └─ No:
#                 → Summary: The keyword is a country in Africa.
#                 → Examples: Morocco, Ghana
#          └─ No:
#             → Examples: Lithuania, Papua New Guinea, Uruguay, Slovakia
#             Turn 4: Is this country in Europe?
#              ├─ Yes:
#                 → Summary: The keyword is a country in Europe.
#                 → Examples: Romania, Germany
#              └─ No:
#                 → Examples: Australia, Nicaragua, Chile, United States
#                 Turn 5: Is this country in the Americas?
#                  ├─ Yes:
#                     → Summary: The keyword is a country in the Americas.
#                     → Examples: Argentina, Canada
#                  └─ No:
#                     → Summary: The keyword is a country in Oceania.
#                     → Examples: New Zealand, Samoa
#      └─ No:
#         → Examples: Venice, Lagos, Times Square, Colosseum
#         Turn 3: Is it a city?
#          ├─ Yes:
#             → Examples: Paris, Astana, Alexandria, Sao Paulo
#             Turn 4: Is it a capital city?
#              ├─ Yes:
#                 → Summary: The keyword is a capital city.
#                 → Examples: Moscow, Santiago
#              └─ No:
#                 → Summary: The keyword is a city which is not a capital.
#                 → Examples: Chicago, Tianjin
#          └─ No:
#             → Examples: Oceania, Nevada, Times Square, Colosseum
#             Turn 4: Is it either a continent or a state of a country?
#              ├─ Yes:
#                 → Examples: North America, Nevada, Roraima, Uttar Pradesh
#                 Turn 5: Is it a continent?
#                  ├─ Yes:
#                     → Summary: The keyword is a continent.
#                     → Examples: Africa, Asia
#                  └─ No:
#                     → Summary: The keyword is a state of a country.
#                     → Examples: Kentucky, Santa Catarina Brazil
#              └─ No:
#                 → Examples: Copacabana beach, university campus, Antarctica, tundra
#                 Turn 5: Is it a location made by humans?
#                  ├─ Yes:
#                     → Summary: The keyword is a location made by humans.
#                     → Examples: Champs-Elysees, Amusement park
#                  └─ No:
#                     → Summary: The keyword is a natural location.
#                     → Examples: Amazon rainforest, Desert
#  └─ No:
#     → Examples: Pencil sharpener, cloud, chimney, electric vehicle
#     Turn 2: Is it a man-made thing?
#      ├─ Yes:
#         → Examples: plastic bottle, martini, earbuds, helicopter
#         Turn 3: Is it something found indoors?
#          ├─ Yes:
#             → Examples: pencil sharpener, refrigerator, coffee machine, escalator
#             Turn 4: Is it something found in a home?
#              ├─ Yes:
#                 → Summary: The keyword is a man-made thing found in people's homes.
#                 → Examples: Bed frame, Stove
#              └─ No:
#                 → Summary: The keyword is a man-made thing found indoors but not in people's homes.
#                 → Examples: Hospital bed, Erlenmeyer flask
#          └─ No:
#             → Examples: pickup truck, train, fountain, obelisk
#             Turn 4: Is it something found in a city?
#              ├─ Yes:
#                 → Summary: The keyword is a man-made thing found outdoors in cities.
#                 → Examples: Apartment Building, Fire Hydrant
#              └─ No:
#                 → Summary: The keyword is a man-made thing found outdoors outside of cities.
#                 → Examples: Satellite, Barn
#      └─ No:
#         → Examples: thunder, Acacia, giraffe, river
#         Turn 3: Is it a living thing?
#          ├─ Yes:
#             → Examples: Palm tree, beetle, whale, apple
#             Turn 4: Is it an animal?
#              ├─ Yes:
#                 → Examples: sea lion, cape toad, kangaroo, peacock
#                 Turn 5: Is it a mammal or a bird?
#                  ├─ Yes:
#                     → Summary: The keyword is either a mammal or a bird.
#                     → Examples: Elephant, Seagull
#                  └─ No:
#                     → Summary: The keyword is either a fish, insect, reptilian or amphibian.
#                     → Examples: Shark, Wasp, Frog, Alligator
#              └─ No:
#                 → Examples: mold, deciduous tree, yeast, agave
#                 Turn 5: Is it a plant?
#                  ├─ Yes:
#                     → Examples: orchid, poison ivy, maple tree, sunflower
#                     Turn 6: Is it a tree?
#                      ├─ Yes:
#                         → Summary: The keyword is a tree.
#                         → Examples: Oak tree, Cactus
#                      └─ No:
#                         → Summary: The keyword is a plant which is not a tree.
#                         → Examples: Rose, Fern
#                  └─ No:
#                     → Examples: black mold, truffle, cremini mushroom, bacillus
#                     Turn 6: Is it a fungus?
#                      ├─ Yes:
#                         → Summary: The keyword is a fungus.
#                         → Examples: Wood ear mushroom, Yeast
#                      └─ No:
#                         → Summary: The keyword is a bacteria.
#                         → Examples: E Coli, Streptococcus
#          └─ No:
#             → Examples: uranus, seine river, carbon, electron
#             Turn 4: Is it a geological feature?
#              ├─ Yes:
#                 → Examples: Mount Fuji, volcano, canyon, Rocky mountains
#                 Turn 5: Is it a body of water?
#                  ├─ Yes:
#                     → Summary: The keyword is a body of water.
#                     → Examples: River, Mediterranean Sea
#                  └─ No:
#                     → Summary: The keyword is a geological feature which is not a body of water.
#                     → Examples: Cave, Volcano
#              └─ No:
#                 → Examples: mercury, sun, iron, lead
#                 Turn 5: Is it a chemical element, molecule or compound?
#                  ├─ Yes:
#                     → Summary: The keyword is a chemical element, molecule or compound.
#                     → Examples: Salt, Oxygen
#                  └─ No:
#                     → Summary: The keyword is a non-living thing not made by humans.
#                     → Examples: Pebble, Milky Way

# %%
def generate_games_for_leaves(node, path=None, games=None):
    if path is None:
        path = []
    if games is None:
        games = []

    if node.summary:
        # We've reached a leaf node; append the game
        games.append(path.copy())
        return  # Stop further processing since it's a leaf node

    if node.yes_branch:
        path.append({"role": "questioner", "content": node.question})
        path.append({"role": "answerer", "content": "Yes"})
        generate_games_for_leaves(node.yes_branch, path, games)
        # Backtrack
        path.pop()
        path.pop()

    if node.no_branch:
        path.append({"role": "questioner", "content": node.question})
        path.append({"role": "answerer", "content": "No"})
        generate_games_for_leaves(node.no_branch, path, games)
        # Backtrack
        path.pop()
        path.pop()

    return games

def game_to_string(game):
    return '\n'.join([f'{step["role"]}: {step["content"]}' for step in game])

def print_game(game):
    print(game_to_string(game))

def print_games(games):
    for x, game in enumerate(games):
        print(x)
        print_game(game)
        print()  # Newline between games

# Generate games for the provided decision tree
games = generate_games_for_leaves(tree)

# Print out the games
print_games(games)
# Out:
# 0
# questioner: Is it a place?
# answerer: Yes
# questioner: Is it a country?
# answerer: Yes
# questioner: Is this country either in Asia or in Africa?
# answerer: Yes
# questioner: Is this country in Asia?
# answerer: Yes
#
# 1
# questioner: Is it a place?
# answerer: Yes
# questioner: Is it a country?
# answerer: Yes
# questioner: Is this country either in Asia or in Africa?
# answerer: Yes
# questioner: Is this country in Asia?
# answerer: No
#
# 2
# questioner: Is it a place?
# answerer: Yes
# questioner: Is it a country?
# answerer: Yes
# questioner: Is this country either in Asia or in Africa?
# answerer: No
# questioner: Is this country in Europe?
# answerer: Yes
#
# 3
# questioner: Is it a place?
# answerer: Yes
# questioner: Is it a country?
# answerer: Yes
# questioner: Is this country either in Asia or in Africa?
# answerer: No
# questioner: Is this country in Europe?
# answerer: No
# questioner: Is this country in the Americas?
# answerer: Yes
#
# 4
# questioner: Is it a place?
# answerer: Yes
# questioner: Is it a country?
# answerer: Yes
# questioner: Is this country either in Asia or in Africa?
# answerer: No
# questioner: Is this country in Europe?
# answerer: No
# questioner: Is this country in the Americas?
# answerer: No
#
# 5
# questioner: Is it a place?
# answerer: Yes
# questioner: Is it a country?
# answerer: No
# questioner: Is it a city?
# answerer: Yes
# questioner: Is it a capital city?
# answerer: Yes
#
# 6
# questioner: Is it a place?
# answerer: Yes
# questioner: Is it a country?
# answerer: No
# questioner: Is it a city?
# answerer: Yes
# questioner: Is it a capital city?
# answerer: No
#
# 7
# questioner: Is it a place?
# answerer: Yes
# questioner: Is it a country?
# answerer: No
# questioner: Is it a city?
# answerer: No
# questioner: Is it either a continent or a state of a country?
# answerer: Yes
# questioner: Is it a continent?
# answerer: Yes
#
# 8
# questioner: Is it a place?
# answerer: Yes
# questioner: Is it a country?
# answerer: No
# questioner: Is it a city?
# answerer: No
# questioner: Is it either a continent or a state of a country?
# answerer: Yes
# questioner: Is it a continent?
# answerer: No
#
# 9
# questioner: Is it a place?
# answerer: Yes
# questioner: Is it a country?
# answerer: No
# questioner: Is it a city?
# answerer: No
# questioner: Is it either a continent or a state of a country?
# answerer: No
# questioner: Is it a location made by humans?
# answerer: Yes
#
# 10
# questioner: Is it a place?
# answerer: Yes
# questioner: Is it a country?
# answerer: No
# questioner: Is it a city?
# answerer: No
# questioner: Is it either a continent or a state of a country?
# answerer: No
# questioner: Is it a location made by humans?
# answerer: No
#
# 11
# questioner: Is it a place?
# answerer: No
# questioner: Is it a man-made thing?
# answerer: Yes
# questioner: Is it something found indoors?
# answerer: Yes
# questioner: Is it something found in a home?
# answerer: Yes
#
# 12
# questioner: Is it a place?
# answerer: No
# questioner: Is it a man-made thing?
# answerer: Yes
# questioner: Is it something found indoors?
# answerer: Yes
# questioner: Is it something found in a home?
# answerer: No
#
# 13
# questioner: Is it a place?
# answerer: No
# questioner: Is it a man-made thing?
# answerer: Yes
# questioner: Is it something found indoors?
# answerer: No
# questioner: Is it something found in a city?
# answerer: Yes
#
# 14
# questioner: Is it a place?
# answerer: No
# questioner: Is it a man-made thing?
# answerer: Yes
# questioner: Is it something found indoors?
# answerer: No
# questioner: Is it something found in a city?
# answerer: No
#
# 15
# questioner: Is it a place?
# answerer: No
# questioner: Is it a man-made thing?
# answerer: No
# questioner: Is it a living thing?
# answerer: Yes
# questioner: Is it an animal?
# answerer: Yes
# questioner: Is it a mammal or a bird?
# answerer: Yes
#
# 16
# questioner: Is it a place?
# answerer: No
# questioner: Is it a man-made thing?
# answerer: No
# questioner: Is it a living thing?
# answerer: Yes
# questioner: Is it an animal?
# answerer: Yes
# questioner: Is it a mammal or a bird?
# answerer: No
#
# 17
# questioner: Is it a place?
# answerer: No
# questioner: Is it a man-made thing?
# answerer: No
# questioner: Is it a living thing?
# answerer: Yes
# questioner: Is it an animal?
# answerer: No
# questioner: Is it a plant?
# answerer: Yes
# questioner: Is it a tree?
# answerer: Yes
#
# 18
# questioner: Is it a place?
# answerer: No
# questioner: Is it a man-made thing?
# answerer: No
# questioner: Is it a living thing?
# answerer: Yes
# questioner: Is it an animal?
# answerer: No
# questioner: Is it a plant?
# answerer: Yes
# questioner: Is it a tree?
# answerer: No
#
# 19
# questioner: Is it a place?
# answerer: No
# questioner: Is it a man-made thing?
# answerer: No
# questioner: Is it a living thing?
# answerer: Yes
# questioner: Is it an animal?
# answerer: No
# questioner: Is it a plant?
# answerer: No
# questioner: Is it a fungus?
# answerer: Yes
#
# 20
# questioner: Is it a place?
# answerer: No
# questioner: Is it a man-made thing?
# answerer: No
# questioner: Is it a living thing?
# answerer: Yes
# questioner: Is it an animal?
# answerer: No
# questioner: Is it a plant?
# answerer: No
# questioner: Is it a fungus?
# answerer: No
#
# 21
# questioner: Is it a place?
# answerer: No
# questioner: Is it a man-made thing?
# answerer: No
# questioner: Is it a living thing?
# answerer: No
# questioner: Is it a geological feature?
# answerer: Yes
# questioner: Is it a body of water?
# answerer: Yes
#
# 22
# questioner: Is it a place?
# answerer: No
# questioner: Is it a man-made thing?
# answerer: No
# questioner: Is it a living thing?
# answerer: No
# questioner: Is it a geological feature?
# answerer: Yes
# questioner: Is it a body of water?
# answerer: No
#
# 23
# questioner: Is it a place?
# answerer: No
# questioner: Is it a man-made thing?
# answerer: No
# questioner: Is it a living thing?
# answerer: No
# questioner: Is it a geological feature?
# answerer: No
# questioner: Is it a chemical element, molecule or compound?
# answerer: Yes
#
# 24
# questioner: Is it a place?
# answerer: No
# questioner: Is it a man-made thing?
# answerer: No
# questioner: Is it a living thing?
# answerer: No
# questioner: Is it a geological feature?
# answerer: No
# questioner: Is it a chemical element, molecule or compound?
# answerer: No

# %%
def construct_messages(game, role, keyword = None, guesses = []):
    if role == "questioner":
        prompt = {
            "role": "system",
            "content": "You are an AI assistant playing the 20 Questions game. In this game the Answerer is given a secret keyword. The Questioner then asks yes-or-no questions regarding the keyword, and the Answerer answers them accurately. Then the Guesser tries to guess the keyword based on the questions and answers in the game. The keyword is a specific place or thing. You are participating in a new game of 20 Questions. Your role is to be the Questioner. You will ask successive yes-or-no questions to determine the keyword. You have a limited number of questions to ask, so choose a question that will eliminate half of the possible keywords to maximize efficiency. Avoid asking questions that are too specific too early on. Be as vague as possible while still eliminating half of the remaining possibilities. DO NOT try to guess the specific keyword, leave that to the guesser. Try to ask the full 20 questions. If you accidentally guessed correctly though, simply output [GAME OVER]. Do not output any text other than the question.",
        }
        messages = [prompt]
        for message in game:
            if message["role"] == "questioner":
                messages.append({
                    "role": "assistant",
                    "content": message["content"]
                })
            else:
                messages.append({
                    "role": "user",
                    "content": message["content"]
                })
    elif role == "answerer":
        prompt = {
            "role": "system",
            "content": f"You are an AI assistant playing the 20 Questions game. In this game the Answerer is given a secret keyword. The Questioner then asks yes-or-no questions regarding the keyword, and the Answerer answers them accurately. Then the Guesser tries to guess the keyword based on the questions and answers in the game. The keyword is a specific place or thing. You are participating in a new game of 20 Questions. Your role is to be the Answerer. The keyword is {keyword}. Answer only Yes or No based on the keyword. Do not output any other text.",
        }
        messages = [prompt]
        for message in game:
            if message["role"] == "questioner":
                messages.append({
                    "role": "user",
                    "content": message["content"]
                })
            else:
                messages.append({
                    "role": "assistant",
                    "content": message["content"]
                })
    elif role == "guesser":
        prompt = {
            "role": "system",
            "content": "You are an AI assistant playing the 20 Questions game. In this game the Answerer is given a secret keyword. The Questioner then asks yes-or-no questions regarding the keyword, and the Answerer answers them accurately. Then the Guesser tries to guess the keyword based on the questions and answers in the game. The keyword is a specific place or thing. You are participating in a new game of 20 Questions. Your role is to be the Guesser. Based on the given questions and answers, guess the keyword at this point. Do not ask a question, just state the guessed keyword with no other text except the keyword itself. DO NOT output any other text other than the guessed keyword.", #The game will end immediately when you guess correctly, so never repeat a guess. 
        }
        messages = [prompt, {
            "role": "user",
            "content": game_to_string(game) + "\nYour guess: "# + "\nPrevious guesses:\n" + '\n'.join(guesses)
        }]
    return messages

construct_messages(games[3], "guesser", "", guesses=["a", "b"])
# Out:
# [{'role': 'system',
#   'content': 'You are an AI assistant playing the 20 Questions game. In this game the Answerer is given a secret keyword. The Questioner then asks yes-or-no questions regarding the keyword, and the Answerer answers them accurately. Then the Guesser tries to guess the keyword based on the questions and answers in the game. The keyword is a specific place or thing. You are participating in a new game of 20 Questions. Your role is to be the Guesser. Based on the given questions and answers, guess the keyword at this point. Do not ask a question, just state the guessed keyword with no other text except the keyword itself. DO NOT output any other text other than the guessed keyword.'},
#  {'role': 'user',
#   'content': 'questioner: Is it a place?\nanswerer: Yes\nquestioner: Is it a country?\nanswerer: Yes\nquestioner: Is this country either in Asia or in Africa?\nanswerer: No\nquestioner: Is this country in Europe?\nanswerer: No\nquestioner: Is this country in the Americas?\nanswerer: Yes\nYour guess: '}]

# %%
import json
def generate_possible_keywords(game, num_keywords = 10):
    def inner():
        prompt = {
                "role": "system",
                "content": f"You are an AI assistant playing the 20 Questions game. In this game the Answerer is given a secret keyword. The Questioner then asks yes-or-no questions regarding the keyword, and the Answerer answers them accurately. Then the Guesser tries to guess the keyword based on the questions and answers in the game. The keyword is a specific place or thing. You are helping set up the game by coming up with potential keywords that fit the start of a game. Given the start of a game, give a list of {num_keywords} that could be answers to the game. Output the keywords in a JSON array of strings E.g. [\"apple\", ...]. Do NOT output any other text besides the array.",
            }
        messages = [prompt, {
                "role": "user",
                "content": game_to_string(game) + "\nKeywords: "
            }]
        result = client.chat.completions.create(
                messages=messages,
                model="gpt-4o",
            ).choices[0].message.content
        return result
    for attempt in range(5):
        result = json.loads(inner())
        if len(result) < 10:
            print("Too few results")
            continue
        elif len(result) > 10:
            return result[:10]
        return result

generate_possible_keywords(games[12])
# Out:
# ['computer',
#  'printer',
#  'desk',
#  'vending machine',
#  'elevator',
#  'fire extinguisher',
#  'water cooler',
#  'projector',
#  'whiteboard',
#  'trash can']

# %%
def simulate_game(starting_game, keyword):
    game = starting_game[:]

    starting_game_length = int(len(starting_game) / 2)

    questions = [step["content"] for step in game if step["role"] == "questioner"]
    answers = [step["content"] for step in game if step["role"] == "answerer"]
    guesses = []

    guesser_finished = False

    for i in range(0,starting_game_length * 2, 2):
        slice = game[i:i+2]
        guess = client.chat.completions.create(
            messages=construct_messages(slice, "guesser", keyword),
            model="gpt-4o",
        ).choices[0].message.content

        guesses.append(guess)

        print("questioner: " + slice[0]["content"])
        print("answerer: " + slice[1]["content"])
        print(f"guesser: {guess}\n")

    for _ in range(20 - starting_game_length):
        question = client.chat.completions.create(
            messages=construct_messages(game, "questioner", keyword),
            model="gpt-4o",
        ).choices[0].message.content
    
        game.append({
            "role": "questioner",
            "content": question
        })

        print(f"questioner: {question}")

        if "OVER" in question:
            break
        
        questions.append(question)
    
        answer = client.chat.completions.create(
            messages=construct_messages(game, "answerer", keyword),
            model="gpt-4o",
        ).choices[0].message.content
    
        game.append({
            "role": "answerer",
            "content": answer
        })

        answers.append(answer)
        print(f"answerer: {answer}")
        
        guess = client.chat.completions.create(
            messages=construct_messages(game, "guesser", keyword),
            model="gpt-4o",
        ).choices[0].message.content

        guesses.append(guess)
        print(f"guesser: {guess}\n")

    return {
        "keyword": keyword,
        "questions": questions,
        "answers": answers,
        "guesses": guesses
    }

result = simulate_game(games[14], "haystack")
print(result)
# Out:
# questioner: Is it a place?
# answerer: No
# guesser: thing
#
# questioner: Is it a man-made thing?
# answerer: Yes
# guesser: Building
#
# questioner: Is it something found indoors?
# answerer: No
# guesser: Tree
#
# questioner: Is it something found in a city?
# answerer: No
# guesser: Forest
#
# questioner: Is it related to transportation?
# answerer: No
# guesser: Statue
#
# questioner: Is it used for recreational purposes?
# answerer: No
# guesser: Bridge
#
# questioner: Is it used in agriculture?
# answerer: Yes
# guesser: Tractor
#
# questioner: Is it a machine or tool?
# answerer: No
# guesser: Scarecrow
#
# questioner: Is it a structure?
# answerer: Yes
# guesser: Barn
#
# questioner: Is it used to store something?
# answerer: Yes
# guesser: Silo
#
# questioner: Is it used to store crops?
# answerer: Yes
# guesser: Silo
#
# questioner: Is it commonly larger than a house?
# answerer: No
# guesser: Silo
#
# questioner: Is it specifically designed for a single type of crop?
# answerer: No
# guesser: Silo
#
# questioner: Is it commonly made of wood?
# answerer: No
# guesser: Silo
#
# questioner: Does it have a roof?
# answerer: No
# guesser: Silo
#
# questioner: Is it portable?
# answerer: No
# guesser: Silo
#
# questioner: Is it used to store hay?
# answerer: Yes
# guesser: Silo
#
# questioner: Is it cylindrical in shape?
# answerer: No
# guesser: Haystack
#
# questioner: Is it commonly found on farms?
# answerer: Yes
# guesser: Silo
#
# questioner: Is it involved in the drying process of crops?
# answerer: No
# guesser: Haystack
#
# {'keyword': 'haystack', 'questions': ['Is it a place?', 'Is it a man-made thing?', 'Is it something found indoors?', 'Is it something found in a city?', 'Is it related to transportation?', 'Is it used for recreational purposes?', 'Is it used in agriculture?', 'Is it a machine or tool?', 'Is it a structure?', 'Is it used to store something?', 'Is it used to store crops?', 'Is it commonly larger than a house?', 'Is it specifically designed for a single type of crop?', 'Is it commonly made of wood?', 'Does it have a roof?', 'Is it portable?', 'Is it used to store hay?', 'Is it cylindrical in shape?', 'Is it commonly found on farms?', 'Is it involved in the drying process of crops?'], 'answers': ['No', 'Yes', 'No', 'No', 'No', 'No', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Yes', 'No', 'Yes', 'No'], 'guesses': ['thing', 'Building', 'Tree', 'Forest', 'Statue', 'Bridge', 'Tractor', 'Scarecrow', 'Barn', 'Silo', 'Silo', 'Silo', 'Silo', 'Silo', 'Silo', 'Silo', 'Silo', 'Haystack', 'Silo', 'Haystack']}

# %% [markdown]
# ## Generate all the games

# %%
game_results = []
for g_index,g in enumerate(games):
    print("Game:", g_index)
    generated_keywords = generate_possible_keywords(g, num_keywords=10)
    for generated_keyword in generated_keywords:
        print("Generated keyword:", generated_keyword)
        game_result = simulate_game(g, generated_keyword)
        game_results.append(game_result)
# Out:
# Game: 0
# Generated keyword: China
# questioner: Is it a place?
# answerer: Yes
# guesser: Paris
#
# questioner: Is it a country?
# answerer: Yes
# guesser: Brazil
#
# questioner: Is this country either in Asia or in Africa?
# answerer: Yes
# guesser: Japan
#
# questioner: Is this country in Asia?
# answerer: Yes
# guesser: Japan
#
# questioner: Is this country in the Eastern part of Asia?
# answerer: Yes
# guesser: China
#
# questioner: Is this country an island nation?
# answerer: No
# guesser: China
#
# questioner: Is this country landlocked?
# answerer: No
# guesser: China
#
# questioner: Is this country known for having a very large population?
# answerer: Yes
# guesser: China
#
# questioner: Is this country China?
# answerer: Yes
# guesser: China
#
# questioner: [GAME OVER]
# Generated keyword: India
# questioner: Is it a place?
# answerer: Yes
# guesser: Paris
#
# questioner: Is it a country?
# answerer: Yes
# guesser: France
#
# questioner: Is this country either in Asia or in Africa?
# answerer: Yes
# guesser: Japan
#
# questioner: Is this country in Asia?
# answerer: Yes
# guesser: Japan
#
# questioner: Is this country located in East Asia?
# answerer: No
# guesser: India
#
# questioner: Is this country located in South Asia?
# answerer: Yes
# guesser: India
#
# questioner: Is this country the largest in South Asia by area?
# answerer: Yes
# guesser: India
#
# questioner: Is the country India?
# answerer: Yes
# guesser: India
#
# questioner: [GAME OVER]
# Generated keyword: Japan
# questioner: Is it a place?
# answerer: Yes
# guesser: Paris
#
# questioner: Is it a country?
# answerer: Yes
# guesser: France
#
# questioner: Is this country either in Asia or in Africa?
# answerer: Yes
# guesser: China
#
# questioner: Is this country in Asia?
# answerer: Yes
# guesser: China
#
# questioner: Is this country located in the eastern part of Asia?
# answerer: Yes
# guesser: China
#
# questioner: Is this country an island nation?
# answerer: Yes
# guesser: Japan
#
# questioner: Is this country Japan?
# answerer: Yes
# guesser: Japan
#
# questioner: [GAME OVER]
# Generated keyword: South Korea
# questioner: Is it a place?
# answerer: Yes
# guesser: Paris
#
# questioner: Is it a country?
# answerer: Yes
# guesser: Japan
#
# questioner: Is this country either in Asia or in Africa?
# answerer: Yes
# guesser: India
#
# questioner: Is this country in Asia?
# answerer: Yes
# guesser: Japan
#
# questioner: Is this country located in East Asia?
# answerer: Yes
# guesser: China
#
# questioner: Is this country an island nation?
# answerer: No
# guesser: China
#
# questioner: Is this country larger than 1 million square kilometers in area?
# answerer: No
# guesser: South Korea
#
# questioner: Is this country landlocked?
# answerer: No
# guesser: South Korea
#
# questioner: Does this country have a population greater than 50 million people?
# answerer: Yes
# guesser: South Korea
#
# questioner: Is this country part of the Association of Southeast Asian Nations (ASEAN)?
# answerer: No
# guesser: South Korea
#
# questioner: Is this country South Korea?
# answerer: Yes
# guesser: South Korea
#
# questioner: [GAME OVER]
# Generated keyword: Thailand
# questioner: Is it a place?
# answerer: Yes
# guesser: Mall
#
# questioner: Is it a country?
# answerer: Yes
# guesser: Brazil
#
# questioner: Is this country either in Asia or in Africa?
# answerer: Yes
# guesser: India
#
# questioner: Is this country in Asia?
# answerer: Yes
# guesser: India
#
# questioner: Is this country located in Southeast Asia?
# answerer: Yes
# guesser: Thailand
#
# questioner: Is this country an island nation?
# answerer: No
# guesser: Vietnam
#
# questioner: Does this country share a border with China?
# answerer: No
# guesser: Thailand
#
# questioner: Does this country have a coastline?
# answerer: Yes
# guesser: Thailand
#
# questioner: Is this country a member of the Association of Southeast Asian Nations (ASEAN)?
# answerer: Yes
# guesser: Vietnam
#
# questioner: Is this country known for having a large population?
# answerer: No
# guesser: Laos
#
# questioner: Is this country known for its tropical climate?
# answerer: Yes
# guesser: Thailand
#
# questioner: Is this country known for having a significant amount of tourism?
# answerer: Yes
# guesser: Cambodia
#
# questioner: Is the official language of this country a language other than English?
# answerer: Yes
# guesser: Cambodia
#
# questioner: Was this country previously colonized by a European power?
# answerer: No
# guesser: Thailand
#
# questioner: Does this country have a constitutional monarchy?
# answerer: Yes
# guesser: Thailand
#
# questioner: Is this country Brunei?
# answerer: No
# guesser: Thailand
#
# questioner: Is this country Thailand?
# answerer: Yes
# guesser: Thailand
#
# questioner: Is the capital city of this country Bangkok?
# answerer: Yes
# guesser: Thailand
#
# questioner: Is this country known for its unique and vibrant street food culture?
# answerer: Yes
# guesser: Thailand
#
# questioner: Is this country a significant exporter of rice?
# answerer: Yes
# guesser: Thailand
#
# Generated keyword: Vietnam
# questioner: Is it a place?
# answerer: Yes
# guesser: Paris
#
# questioner: Is it a country?
# answerer: Yes
# guesser: Brazil
#
# questioner: Is this country either in Asia or in Africa?
# answerer: Yes
# guesser: India
#
# questioner: Is this country in Asia?
# answerer: Yes
# guesser: Japan
#
# questioner: Is this country located on an island or group of islands?
# answerer: No
# guesser: China
#
# questioner: Is this country landlocked?
# answerer: No
# guesser: India
#
# questioner: Is this country known for having a large population?
# answerer: Yes
# guesser: India
#
# questioner: Is this country part of South Asia?
# answerer: No
# guesser: China
#
# questioner: Is this country part of East Asia?
# answerer: No
# guesser: Indonesia
#
# questioner: Is this country part of Southeast Asia?
# answerer: Yes
# guesser: Indonesia
#
# questioner: Is this country predominantly Muslim?
# answerer: No
# guesser: Vietnam
#
# questioner: Is this country a member of ASEAN (Association of Southeast Asian Nations)?
# answerer: Yes
# guesser: Thailand
#
# questioner: Is this country known for its beaches and tourism?
# answerer: Yes
# guesser: Thailand
#
# questioner: Is this country Thailand?
# answerer: No
# guesser: Indonesia
#
# questioner: Does this country share a border with Thailand?
# answerer: Yes
# guesser: Malaysia
#
# questioner: Is this country Vietnam?
# answerer: Yes
# guesser: Vietnam
#
# questioner: [GAME OVER]
# Generated keyword: Malaysia
# questioner: Is it a place?
# answerer: Yes
# guesser: New York City
#
# questioner: Is it a country?
# answerer: Yes
# guesser: Japan
#
# questioner: Is this country either in Asia or in Africa?
# answerer: Yes
# guesser: India
#
# questioner: Is this country in Asia?
# answerer: Yes
# guesser: Japan
#
# questioner: Is it located in the Middle East?
# answerer: No
# guesser: Japan
#
# questioner: Is it located in East Asia?
# answerer: No
# guesser: India
#
# questioner: Is it in South Asia?
# answerer: No
# guesser: Russia
#
# questioner: Is it in Southeast Asia?
# answerer: Yes
# guesser: Indonesia
#
# questioner: Is it an island country?
# answerer: No
# guesser: Thailand
#
# questioner: Is it a member of the Association of Southeast Asian Nations (ASEAN)?
# answerer: Yes
# guesser: Thailand
#
# questioner: Is it predominantly a Buddhist country?
# answerer: No
# guesser: Indonesia
#
# questioner: Is it on the mainland of Southeast Asia?
# answerer: No
# guesser: Indonesia
#
# questioner: Is English one of its official languages?
# answerer: Yes
# guesser: Singapore
#
# questioner: Is it known for having a significant number of skyscrapers?
# answerer: Yes
# guesser: Singapore
#
# questioner: Is it a city-state?
# answerer: No
# guesser: Malaysia
#
# questioner: Is it Malaysia?
# answerer: Yes
# guesser: Malaysia
#
# questioner: [GAME OVER]
# Generated keyword: Indonesia
# questioner: Is it a place?
# answerer: Yes
# guesser: New York
#
# questioner: Is it a country?
# answerer: Yes
# guesser: Brazil
#
# questioner: Is this country either in Asia or in Africa?
# answerer: Yes
# guesser: Japan
#
# questioner: Is this country in Asia?
# answerer: Yes
# guesser: Japan
#
# questioner: Does this country have a population of over 100 million people?
# answerer: Yes
# guesser: India
#
# questioner: Is this country located in East Asia?
# answerer: No
# guesser: India
#
# questioner: Is this country located in South Asia?
# answerer: No
# guesser: Indonesia
#
# questioner: Is this country located in Southeast Asia?
# answerer: Yes
# guesser: Indonesia
#
# questioner: Is this country an archipelago?
# answerer: Yes
# guesser: Indonesia
#
# questioner: Is this country made up of over 7,000 islands?
# answerer: No
# guesser: Indonesia
#
# questioner: Is this country located within the Malay Archipelago?
# answerer: Yes
# guesser: Indonesia
#
# questioner: Is this country predominantly Muslim?
# answerer: Yes
# guesser: Indonesia
#
# questioner: Is this country composed of two main landmasses divided by the sea?
# answerer: No
# guesser: Indonesia
#
# questioner: Is this country located directly on the equator?
# answerer: Yes
# guesser: Indonesia
#
# questioner: Is this country the largest by land area in Southeast Asia?
# answerer: Yes
# guesser: Indonesia
#
# questioner: Is this country Indonesia?
# answerer: Yes
# guesser: Indonesia
#
# questioner: [GAME OVER]
# Generated keyword: Philippines
# questioner: Is it a place?
# answerer: Yes
# guesser: Paris
#
# questioner: Is it a country?
# answerer: Yes
# guesser: France
#
# questioner: Is this country either in Asia or in Africa?
# answerer: Yes
# guesser: China
#
# questioner: Is this country in Asia?
# answerer: Yes
# guesser: Japan
#
# questioner: Is it located in East Asia?
# answerer: No
# guesser: India
#
# questioner: Is this country in South Asia?
# answerer: No
# guesser: Saudi Arabia
#
# questioner: Is it located in Southeast Asia?
# answerer: Yes
# guesser: Thailand
#
# questioner: Is it an island nation?
# answerer: Yes
# guesser: Indonesia
#
# questioner: Is this country part of the Malay Archipelago?
# answerer: Yes
# guesser: Indonesia
#
# questioner: Is it north of the equator?
# answerer: Yes
# guesser: Philippines
#
# questioner: Is it the Philippines?
# answerer: Yes
# guesser: Philippines
#
# questioner: [GAME OVER]
# Generated keyword: Pakistan
# questioner: Is it a place?
# answerer: Yes
# guesser: Paris
#
# questioner: Is it a country?
# answerer: Yes
# guesser: France
#
# questioner: Is this country either in Asia or in Africa?
# answerer: Yes
# guesser: Japan
#
# questioner: Is this country in Asia?
# answerer: Yes
# guesser: Japan
#
# questioner: Is this country in East Asia?
# answerer: No
# guesser: India
#
# questioner: Is this country in South Asia?
# answerer: Yes
# guesser: India
#
# questioner: Does this country have a population exceeding 100 million people?
# answerer: Yes
# guesser: India
#
# questioner: Is this country India?
# answerer: No
# guesser: Pakistan
#
# questioner: Is this country Pakistan?
# answerer: Yes
# guesser: Pakistan
#
# questioner: [GAMER OVER]
# Game: 1
# Generated keyword: Nigeria
# questioner: Is it a place?
# answerer: Yes
# guesser: Paris
#
# questioner: Is it a country?
# answerer: Yes
# guesser: Japan
#
# questioner: Is this country either in Asia or in Africa?
# answerer: Yes
# guesser: Japan
#
# questioner: Is this country in Asia?
# answerer: No
# guesser: Canada
#
# questioner: Is this country located in the northern hemisphere?
# answerer: Yes
# guesser: Egypt
#
# questioner: Is this country larger than 1 million square kilometers in area?
# answerer: No
# guesser: Egypt
#
# questioner: Is this country landlocked (not having any coastline)?
# answerer: No
# guesser: Egypt
#
# questioner: Is this country in East Africa?
# answerer: No
# guesser: Egypt
#
# questioner: Is it in West Africa?
# answerer: Yes
# guesser: Ghana
#
# questioner: Is this country a member of ECOWAS (Economic Community of West African States)?
# answerer: Yes
# guesser: Ghana
#
# questioner: Is French an official language of this country?
# answerer: No
# guesser: Nigeria
#
# questioner: Is English an official language of this country?
# answerer: Yes
# guesser: Nigeria
#
# questioner: Is this country Nigeria?
# answerer: Yes
# guesser: Nigeria
#
# questioner: [GAME OVER]
# Generated keyword: Egypt
# questioner: Is it a place?
# answerer: Yes
# guesser: Hawaii
#
# questioner: Is it a country?
# answerer: Yes
# guesser: Japan
#
# questioner: Is this country either in Asia or in Africa?
# answerer: Yes
# guesser: Japan
#
# questioner: Is this country in Asia?
# answerer: No
# guesser: Brazil
#
# questioner: Is this country located in Northern Africa?
# answerer: Yes
# guesser: Egypt
#
# questioner: Is it an Arabic-speaking country?
# answerer: Yes
# guesser: Egypt
#
# questioner: Is this country in the Maghreb region?
# answerer: No
# guesser: Egypt
#
# questioner: Is this country Egypt?
# answerer: Yes
# guesser: Egypt
#
# questioner: [GAME OVER]
# Generated keyword: Kenya
# questioner: Is it a place?
# answerer: Yes
# guesser: Paris
#
# questioner: Is it a country?
# answerer: Yes
# guesser: Japan
#
# questioner: Is this country either in Asia or in Africa?
# answerer: Yes
# guesser: India
#
# questioner: Is this country in Asia?
# answerer: No
# guesser: France
#
# questioner: Is this country located in Northern Africa?
# answerer: No
# guesser: South Africa
#
# questioner: Is this country in Sub-Saharan Africa?
# answerer: Yes
# guesser: South Africa
#
# questioner: Is this country landlocked?
# answerer: No
# guesser: Nigeria
#
# questioner: Is this country in Eastern Africa?
# answerer: Yes
# guesser: Kenya
#
# questioner: Does this country border the Indian Ocean?
# answerer: Yes
# guesser: Kenya
#
# questioner: Is this country known for having a significant cultural impact in the region?
# answerer: Yes
# guesser: Kenya
#
# questioner: Is this country one of the most populous in Africa?
# answerer: Yes
# guesser: Kenya
#
# questioner: Is this country Kenya?
# answerer: Yes
# guesser: Kenya
#
# questioner: [GAME OVER]
# Generated keyword: South Africa
# questioner: Is it a place?
# answerer: Yes
# guesser: Paris
#
# questioner: Is it a country?
# answerer: Yes
# guesser: France
#
# questioner: Is this country either in Asia or in Africa?
# answerer: Yes
# guesser: India
#
# questioner: Is this country in Asia?
# answerer: No
# guesser: Brazil
#
# questioner: Is this country located in the northern hemisphere?
# answerer: No
# guesser: South Africa
#
# questioner: Is this country part of Sub-Saharan Africa?
# answerer: Yes
# guesser: South Africa
#
# questioner: Is this country landlocked?
# answerer: No
# guesser: South Africa
#
# questioner: Is this country located on the eastern coast of Africa?
# answerer: No
# guesser: South Africa
#
# questioner: Is this country located on the western coast of Africa?
# answerer: No
# guesser: South Africa
#
# questioner: Is this country located in Southern Africa?
# answerer: Yes
# guesser: South Africa
#
# questioner: Is this country known for being a popular tourist destination?
# answerer: Yes
# guesser: South Africa
#
# questioner: Is this country known for its diverse wildlife and national parks?
# answerer: Yes
# guesser: South Africa
#
# questioner: Is the official language of this country English?
# answerer: Yes
# guesser: South Africa
#
# questioner: Is this country South Africa?
# answerer: Yes
# guesser: South Africa
#
# questioner: [GAME OVER]
# Generated keyword: Ethiopia
# questioner: Is it a place?
# answerer: Yes
# guesser: Paris
#
# questioner: Is it a country?
# answerer: Yes
# guesser: France
#
# questioner: Is this country either in Asia or in Africa?
# answerer: Yes
# guesser: India
#
# questioner: Is this country in Asia?
# answerer: No
# guesser: Brazil
#
# questioner: Is this country in the northern part of Africa?
# answerer: No
# guesser: South Africa
#
# questioner: Is this country in the southern part of Africa?
# answerer: No
# guesser: Nigeria
#
# questioner: Is this country in the western part of Africa?
# answerer: No
# guesser: Kenya
#
# questioner: Is this country in the eastern part of Africa?
# answerer: Yes
# guesser: Kenya
#
# questioner: Is this country located along the coast?
# answerer: No
# guesser: Ethiopia
#
# questioner: Is this country landlocked?
# answerer: Yes
# guesser: Ethiopia
#
# questioner: Is this country Uganda?
# answerer: No
# guesser: Ethiopia
#
# questioner: Is this country Ethiopia?
# answerer: Yes
# guesser: Ethiopia
#
# questioner: [GAME OVER]
# Generated keyword: Ghana
# questioner: Is it a place?
# answerer: Yes
# guesser: Paris
#
# questioner: Is it a country?
# answerer: Yes
# guesser: France
#
# questioner: Is this country either in Asia or in Africa?
# answerer: Yes
# guesser: China
#
# questioner: Is this country in Asia?
# answerer: No
# guesser: France
#
# questioner: Is this country in northern Africa?
# answerer: No
# guesser: South Africa
#
# questioner: Is this country in western Africa?
# answerer: Yes
# guesser: Nigeria
#
# questioner: Is this country larger than 500,000 square kilometers?
# answerer: No
# guesser: Ghana
#
# questioner: Is this country bordered by the Atlantic Ocean?
# answerer: Yes
# guesser: Ghana
#
# questioner: Is this country a former French colony?
# answerer: No
# guesser: Ghana
#
# questioner: Is this country bordered by more than two countries?
# answerer: No
# guesser: Ghana
#
# questioner: Is this country considered a part of the ECOWAS (Economic Community of West African States)?
# answerer: Yes
# guesser: Liberia
#
# questioner: Is this country known to have a predominantly English-speaking population?
# answerer: Yes
# guesser: Sierra Leone
#
# questioner: Is this country sometimes referred to as "Gambia" for short?
# answerer: No
# guesser: Liberia
#
# questioner: Is this country bordered by Nigeria?
# answerer: No
# guesser: Ghana
#
# questioner: Is this country known for having a significant level of tourism?
# answerer: Yes
# guesser: Ghana
#
# questioner: Is this country known for its extensive beaches?
# answerer: Yes
# guesser: Ghana
#
# questioner: Is this country bordered by only one other country?
# answerer: No
# guesser: Ghana
#
# questioner: Is this country Sierra Leone?
# answerer: No
# guesser: Ghana
#
# questioner: Is this country known for having a large lagoon city?
# answerer: No
# guesser: Ghana
#
# questioner: Is this country Ghana?
# answerer: Yes
# guesser: Ghana
#
# Generated keyword: Morocco
# questioner: Is it a place?
# answerer: Yes
# guesser: Paris
#
# questioner: Is it a country?
# answerer: Yes
# guesser: Canada
#
# questioner: Is this country either in Asia or in Africa?
# answerer: Yes
# guesser: China
#
# questioner: Is this country in Asia?
# answerer: No
# guesser: Brazil
#
# questioner: Is this country in North Africa?
# answerer: Yes
# guesser: Egypt
#
# questioner: Is this country Egypt?
# answerer: No
# guesser: Morocco
#
# questioner: Is this country on the Mediterranean coast?
# answerer: Yes
# guesser: Morocco
#
# questioner: Is this country Libya?
# answerer: No
# guesser: Morocco
#
# questioner: Is this country further west than Libya?
# answerer: Yes
# guesser: Tunisia
#
# questioner: Is this country Tunisia?
# answerer: No
# guesser: Algeria
#
# questioner: Is this country Algeria?
# answerer: No
# guesser: Morocco
#
# questioner: Is this country Morocco?
# answerer: Yes
# guesser: Morocco
#
# questioner: Is this country predominantly Arabic-speaking?
# answerer: Yes
# guesser: Morocco
#
# questioner: Is this country a member of the African Union?
# answerer: Yes
# guesser: Morocco
#
# questioner: Is the capital of this country Rabat?
# answerer: Yes
# guesser: Morocco
#
# questioner: Is tourism an important industry in this country?
# answerer: Yes
# guesser: Morocco
#
# questioner: Is this country known for its historical landmarks and cultural heritage?
# answerer: Yes
# guesser: Morocco
#
# questioner: Is this country home to the Atlas Mountains?
# answerer: Yes
# guesser: Morocco
#
# questioner: Is this country located at the intersection of the Atlantic Ocean and the Mediterranean Sea?
# answerer: Yes
# guesser: Morocco
#
# questioner: Is this country known for cities like Casablanca and Marrakesh?
# answerer: Yes
# guesser: Morocco
#
# Generated keyword: Uganda
# questioner: Is it a place?
# answerer: Yes
# guesser: Paris
#
# questioner: Is it a country?
# answerer: Yes
# guesser: Brazil
#
# questioner: Is this country either in Asia or in Africa?
# answerer: Yes
# guesser: China
#
# questioner: Is this country in Asia?
# answerer: No
# guesser: Canada
#
# questioner: Is this country located in North Africa?
# answerer: No
# guesser: South Africa
#
# questioner: Is this country located in West Africa?
# answerer: No
# guesser: South Africa
#
# questioner: Is this country located in Central Africa?
# answerer: No
# guesser: South Africa
#
# questioner: Is this country located in East Africa?
# answerer: Yes
# guesser: Kenya
#
# questioner: Is this country landlocked?
# answerer: Yes
# guesser: Ethiopia
#
# questioner: Does this country have a population of less than 20 million people?
# answerer: No
# guesser: Ethiopia
#
# questioner: Is this country bordered by more than three other countries?
# answerer: Yes
# guesser: Ethiopia
#
# questioner: Is this country Tanzania?
# answerer: No
# guesser: Ethiopia
#
# questioner: Is this country Ethiopia?
# answerer: No
# guesser: Uganda
#
# questioner: Is this country Uganda?
# answerer: Yes
# guesser: Uganda
#
# questioner: Is this country famous for being a tourist destination?
# answerer: Yes
# guesser: Uganda
#
# questioner: Do tourists mainly visit this country to see wildlife and natural parks?
# answerer: Yes
# guesser: Uganda
#
# questioner: Is this country known for having access to Lake Victoria?
# answerer: Yes
# guesser: Uganda
#
# questioner: Is this country known for its capital, Kampala?
# answerer: Yes
# guesser: Uganda
#
# questioner: Is Uganda the keyword?
# answerer: Yes
# guesser: Uganda
#
# questioner: [GAME OVER]
# Generated keyword: Algeria
# questioner: Is it a place?
# answerer: Yes
# guesser: Paris
#
# questioner: Is it a country?
# answerer: Yes
# guesser: Canada
#
# questioner: Is this country either in Asia or in Africa?
# answerer: Yes
# guesser: India
#
# questioner: Is this country in Asia?
# answerer: No
# guesser: France
#
# questioner: Is this country located in the northern part of Africa?
# answerer: Yes
# guesser: Egypt
#
# questioner: Is this country in the Maghreb region?
# answerer: Yes
# guesser: Morocco
#
# questioner: Is it the largest country in Africa by land area?
# answerer: Yes
# guesser: Algeria
#
# questioner: Is the official language of this country Arabic?
# answerer: Yes
# guesser: Algeria
#
# questioner: Is this country Algeria?
# answerer: Yes
# guesser: Algeria
#
# questioner: [GAME OVER]
# Generated keyword: Tanzania
# questioner: Is it a place?
# answerer: Yes
# guesser: Paris
#
# questioner: Is it a country?
# answerer: Yes
# guesser: Japan
#
# questioner: Is this country either in Asia or in Africa?
# answerer: Yes
# guesser: Japan
#
# questioner: Is this country in Asia?
# answerer: No
# guesser: France
#
# questioner: Is this country in North Africa?
# answerer: No
# guesser: South Africa
#
# questioner: Is this country in East Africa?
# answerer: Yes
# guesser: Kenya
#
# questioner: Is this country landlocked?
# answerer: No
# guesser: Kenya
#
# questioner: Does this country have a population greater than 40 million?
# answerer: Yes
# guesser: Ethiopia
#
# questioner: Is this country located along the Indian Ocean?
# answerer: Yes
# guesser: Tanzania
#
# questioner: Is Kenya the country in question?
# answerer: No
# guesser: Tanzania
#
# questioner: Is this country known for having significant areas of tropical rainforest?
# answerer: No
# guesser: Tanzania
#
# questioner: Is this country primarily known for its coastal beaches and islands?
# answerer: No
# guesser: Tanzania
#
# questioner: Is this country located south of the Equator?
# answerer: Yes
# guesser: Tanzania
#
# questioner: Has this country experienced significant political turmoil in the past 30 years?
# answerer: No
# guesser: Tanzania
#
# questioner: Is this country famous for its unique wildlife, such as lemurs?
# answerer: No
# guesser: Tanzania
#
# questioner: Is this country well-known for its production of coffee?
# answerer: Yes
# guesser: Tanzania
#
# questioner: Is Ethiopia the country in question?
# answerer: No
# guesser: Tanzania
#
# questioner: Is Tanzania the country in question?
# answerer: Yes
# guesser: Tanzania
#
# questioner: [GUESSED CORRECTLY]
# answerer: Congratulations! You guessed it correctly. Would you like to play again or do something else?
# guesser: Tanzania
#
# questioner: Sure, I'd be happy to play again! Let me know when you have a new keyword, and I'll start asking questions.
# answerer: I have a new keyword. You can start asking your questions!
# guesser: Tanzania
#
# Game: 2
# Generated keyword: France
# questioner: Is it a place?
# answerer: Yes
# guesser: Park
#
# questioner: Is it a country?
# answerer: Yes
# guesser: France
#
# questioner: Is this country either in Asia or in Africa?
# answerer: No
# guesser: No guesses yet
#
# questioner: Is this country in Europe?
# answerer: Yes
# guesser: France
#
# questioner: Is this country part of the European Union?
# answerer: Yes
# guesser: France
#
# questioner: Is this country known for its Mediterranean coastline?
# answerer: Yes
# guesser: Italy
#
# questioner: Is this country located on the Iberian Peninsula?
# answerer: No
# guesser: Italy
#
# questioner: Is this country in Southern Europe?
# answerer: No
# guesser: France
#
# questioner: Is this country known for having a large number of lakes?
# answerer: No
# guesser: France
#
# questioner: Is this country known for its alpine regions?
# answerer: Yes
# guesser: Austria
#
# questioner: Is this country famous for its chocolate?
# answerer: No
# guesser: Austria
#
# questioner: Is this country known for being a popular tourist destination for winter sports?
# answerer: Yes
# guesser: Austria
#
# questioner: Is this country bordered by Austria?
# answerer: No
# guesser: France
#
# questioner: Is this country primarily German-speaking?
# answerer: No
# guesser: France
#
# questioner: Is this country known for being neutral in conflicts?
# answerer: No
# guesser: France
#
# questioner: Is this country located east of Germany?
# answerer: No
# guesser: France
#
# questioner: Is this country known for its high level of wealth and banking industry?
# answerer: No
# guesser: Italy
#
# questioner: Is this country bordered by France?
# answerer: Yes
# guesser: Italy
#
# questioner: Is this country bordered by Germany?
# answerer: No
# guesser: Italy
#
# questioner: Does this country have a coastline on the Mediterranean Sea?
# answerer: Yes
# guesser: Italy
#
# Generated keyword: Germany
# questioner: Is it a place?
# answerer: Yes
# guesser: Paris
#
# questioner: Is it a country?
# answerer: Yes
# guesser: Japan
#
# questioner: Is this country either in Asia or in Africa?
# answerer: No
# guesser: France
#
# questioner: Is this country in Europe?
# answerer: Yes
# guesser: France
#
# questioner: Is this country part of the European Union?
# answerer: Yes
# guesser: France
#
# questioner: Is this country located in Southern Europe?
# answerer: No
# guesser: Germany
#
# questioner: Is it a landlocked country?
# answerer: No
# guesser: France
#
# questioner: Is it located in Western Europe?
# answerer: Yes
# guesser: France
#
# questioner: Does this country have a monarchy?
# answerer: No
# guesser: France
#
# questioner: Is this country known for speaking a Romance language?
# answerer: No
# guesser: Germany
#
# questioner: Is this country known for speaking a Germanic language?
# answerer: Yes
# guesser: Germany
#
# questioner: Is this country known for its neutrality in international conflicts?
# answerer: No
# guesser: Germany
#
# questioner: Is this country famous for its beer culture?
# answerer: Yes
# guesser: Germany
#
# questioner: Is this country a founding member of the European Union?
# answerer: Yes
# guesser: Germany
#
# questioner: Is it the largest economy in Europe?
# answerer: Yes
# guesser: Germany
#
# questioner: Is the country's capital Berlin?
# answerer: Yes
# guesser: Germany
#
# questioner: Is the country Germany?
# answerer: Yes
# guesser: Germany
#
# questioner: [GAME OVER]
# Generated keyword: Italy
# questioner: Is it a place?
# answerer: Yes
# guesser: Paris
#
# questioner: Is it a country?
# answerer: Yes
# guesser: Japan
#
# questioner: Is this country either in Asia or in Africa?
# answerer: No
# guesser: France
#
# questioner: Is this country in Europe?
# answerer: Yes
# guesser: France
#
# questioner: Is this country part of the European Union?
# answerer: Yes
# guesser: France
#
# questioner: Is this country located in Southern Europe?
# answerer: Yes
# guesser: Italy
#
# questioner: Is this country known for its Mediterranean coastline?
# answerer: Yes
# guesser: Italy
#
# questioner: Is this country famous for its cuisine, particularly pasta and pizza?
# answerer: Yes
# guesser: Italy
#
# questioner: Is the capital of this country Rome?
# answerer: Yes
# guesser: Italy
#
# questioner: Is the country Italy?
# answerer: Yes
# guesser: Italy
#
# questioner: [GAME OVER]
# Generated keyword: Spain
# questioner: Is it a place?
# answerer: Yes
# guesser: Park
#
# questioner: Is it a country?
# answerer: Yes
# guesser: Japan
#
# questioner: Is this country either in Asia or in Africa?
# answerer: No
# guesser: France
#
# questioner: Is this country in Europe?
# answerer: Yes
# guesser: France
#
# questioner: Is this country a member of the European Union?
# answerer: Yes
# guesser: France
#
# questioner: Is this country geographically larger than France?
# answerer: No
# guesser: Germany
#
# questioner: Is this country part of the Schengen Area?
# answerer: Yes
# guesser: Germany
#
# questioner: Is this country landlocked?
# answerer: No
# guesser: Italy
#
# questioner: Is this country located in Southern Europe?
# answerer: Yes
# guesser: Italy
#
# questioner: Does this country share a border with the Mediterranean Sea?
# answerer: Yes
# guesser: Italy
#
# questioner: Is this country an island or does it include islands?
# answerer: Yes
# guesser: Italy
#
# questioner: Is this country known for its significant historical landmarks?
# answerer: Yes
# guesser: Greece
#
# questioner: Is this country Italy?
# answerer: No
# guesser: Greece
#
# questioner: Is this country known for being a popular tourist destination?
# answerer: Yes
# guesser: Greece
#
# questioner: Is this country Greece?
# answerer: No
# guesser: Spain
#
# questioner: Is this country Spain?
# answerer: Yes
# guesser: Spain
#
# questioner: Thank you. The guesser may now try to guess the keyword.
# answerer: You're welcome! Feel free to ask if you'd like to play again.
# guesser: Spain
#
# questioner: Would you like to play another round of 20 Questions?
# answerer: Sure! I'm ready to play another round of 20 Questions. Please start asking your yes-or-no questions whenever you're ready.
# guesser: Spain
#
# questioner: Is it a place?
# answerer: Yes
# guesser: Spain
#
# questioner: Is it a country?
# answerer: No
# guesser: Paris
#
# Generated keyword: United Kingdom
# questioner: Is it a place?
# answerer: Yes
# guesser: Paris
#
# questioner: Is it a country?
# answerer: Yes
# guesser: France
#
# questioner: Is this country either in Asia or in Africa?
# answerer: No
# guesser: No guess yet
#
# questioner: Is this country in Europe?
# answerer: Yes
# guesser: Germany
#
# questioner: Is this country part of the European Union?
# answerer: No
# guesser: United Kingdom
#
# questioner: Is this country located in Eastern Europe?
# answerer: No
# guesser: Norway
#
# questioner: Is this country an island nation?
# answerer: Yes
# guesser: United Kingdom
#
# questioner: Is this country located in the Northern Hemisphere?
# answerer: Yes
# guesser: United Kingdom
#
# questioner: Is the official language of this country English?
# answerer: Yes
# guesser: United Kingdom
#
# questioner: Is this country part of the British Isles?
# answerer: Yes
# guesser: United Kingdom
#
# questioner: Is the capital city of this country London?
# answerer: Yes
# guesser: United Kingdom
#
# questioner: Is the keyword the United Kingdom?
# answerer: Yes
# guesser: United Kingdom
#
# questioner: [GAME OVER]
# Generated keyword: Netherlands
# questioner: Is it a place?
# answerer: Yes
# guesser: Paris
#
# questioner: Is it a country?
# answerer: Yes
# guesser: Japan
#
# questioner: Is this country either in Asia or in Africa?
# answerer: No
# guesser: No guess yet
#
# questioner: Is this country in Europe?
# answerer: Yes
# guesser: Germany
#
# questioner: Is this country a member of the European Union?
# answerer: Yes
# guesser: France
#
# questioner: Is this country located in Southern Europe?
# answerer: No
# guesser: Germany
#
# questioner: Is this country found in Northern Europe?
# answerer: No
# guesser: France
#
# questioner: Is this country located in Western Europe?
# answerer: Yes
# guesser: France
#
# questioner: Is this country known for being predominantly German-speaking?
# answerer: No
# guesser: France
#
# questioner: Is this country known for being predominantly French-speaking?
# answerer: No
# guesser: Netherlands
#
# questioner: Is this country an island nation?
# answerer: No
# guesser: Netherlands
#
# questioner: Is this country part of the Benelux region?
# answerer: Yes
# guesser: Belgium
#
# questioner: Is this country famous for its tulips and windmills?
# answerer: Yes
# guesser: Netherlands
#
# questioner: Is the country you are thinking of the Netherlands?
# answerer: Yes
# guesser: Netherlands
#
# questioner: [GAME OVER]
# Generated keyword: Switzerland
# questioner: Is it a place?
# answerer: Yes
# guesser: Park
#
# questioner: Is it a country?
# answerer: Yes
# guesser: Japan
#
# questioner: Is this country either in Asia or in Africa?
# answerer: No
# guesser: No guess yet.
#
# questioner: Is this country in Europe?
# answerer: Yes
# guesser: France
#
# questioner: Is this country a member of the European Union?
# answerer: No
# guesser: Switzerland
#
# questioner: Is this country an island nation?
# answerer: No
# guesser: Switzerland
#
# questioner: Is this country located in Eastern Europe?
# answerer: No
# guesser: Switzerland
#
# questioner: Is this country located in Western Europe?
# answerer: Yes
# guesser: Switzerland
#
# questioner: Is this country known for having a predominantly Germanic language?
# answerer: Yes
# guesser: Switzerland
#
# questioner: Has this country ever been part of a historic empire that influenced much of Europe?
# answerer: No
# guesser: Switzerland
#
# questioner: Is this country known for being landlocked?
# answerer: Yes
# guesser: Switzerland
#
# questioner: Does this country share a border with Germany?
# answerer: Yes
# guesser: Switzerland
#
# questioner: Is this country known for its high standard of living and neutrality in conflicts?
# answerer: Yes
# guesser: Switzerland
#
# questioner: Is this country Switzerland?
# answerer: Yes
# guesser: Switzerland
#
# questioner: [GOME OVER]
# Generated keyword: Sweden
# questioner: Is it a place?
# answerer: Yes
# guesser: Paris
#
# questioner: Is it a country?
# answerer: Yes
# guesser: Italy
#
# questioner: Is this country either in Asia or in Africa?
# answerer: No
# guesser: Australia
#
# questioner: Is this country in Europe?
# answerer: Yes
# guesser: France
#
# questioner: Is this country part of the European Union?
# answerer: Yes
# guesser: France
#
# questioner: Is this country primarily an English-speaking country?
# answerer: No
# guesser: France
#
# questioner: Is this country known for its Mediterranean coastline?
# answerer: No
# guesser: Germany
#
# questioner: Is this country landlocked?
# answerer: No
# guesser: France
#
# questioner: Is this country geographically larger than France?
# answerer: No
# guesser: Germany
#
# questioner: Is this country part of Scandinavia?
# answerer: Yes
# guesser: Sweden
#
# questioner: Is this country known for having a monarchy?
# answerer: Yes
# guesser: Sweden
#
# questioner: Is this country famous for fjords?
# answerer: No
# guesser: Sweden
#
# questioner: Is this country part of the European Economic Area (EEA)?
# answerer: Yes
# guesser: Denmark
#
# questioner: Is this country known for having a significant number of islands?
# answerer: Yes
# guesser: Sweden
#
# questioner: Is this country known for its culinary delights being associated with seafood and pastries?
# answerer: Yes
# guesser: Denmark
#
# questioner: Is this country Denmark?
# answerer: No
# guesser: Sweden
#
# questioner: Does this country share a land border with Germany?
# answerer: No
# guesser: Sweden
#
# questioner: Does this country have a population of less than 10 million?
# answerer: No
# guesser: Sweden
#
# questioner: Is this country known for its significant contributions to music and design?
# answerer: Yes
# guesser: Sweden
#
# questioner: Is this country Sweden?
# answerer: Yes
# guesser: Sweden
#
# Generated keyword: Norway
# questioner: Is it a place?
# answerer: Yes
# guesser: Paris
#
# questioner: Is it a country?
# answerer: Yes
# guesser: Canada
#
# questioner: Is this country either in Asia or in Africa?
# answerer: No
# guesser: Canada
#
# questioner: Is this country in Europe?
# answerer: Yes
# guesser: France
#
# questioner: Is this country a member of the European Union?
# answerer: No
# guesser: United Kingdom
#
# questioner: Is this country an island nation?
# answerer: No
# guesser: Norway
#
# questioner: Is this country landlocked?
# answerer: No
# guesser: Norway
#
# questioner: Is this country located in Southern Europe?
# answerer: No
# guesser: Norway
#
# questioner: Is this country located in Eastern Europe?
# answerer: No
# guesser: Norway
#
# questioner: Is this country located in Northern Europe?
# answerer: Yes
# guesser: Norway
#
# questioner: Is this country part of Scandinavia?
# answerer: Yes
# guesser: Norway
#
# questioner: Is this country the largest by area in Scandinavia?
# answerer: No
# guesser: Denmark
#
# questioner: Is this country known for its fjords?
# answerer: Yes
# guesser: Norway
#
# questioner: Is this country Norway?
# answerer: Yes
# guesser: Norway
#
# questioner: [GAME OVER]
# Generated keyword: Greece
# questioner: Is it a place?
# answerer: Yes
# guesser: New York City
#
# questioner: Is it a country?
# answerer: Yes
# guesser: Japan
#
# questioner: Is this country either in Asia or in Africa?
# answerer: No
# guesser: France
#
# questioner: Is this country in Europe?
# answerer: Yes
# guesser: France
#
# questioner: Is this country part of the European Union?
# answerer: Yes
# guesser: Germany
#
# questioner: Is this country located in Southern Europe?
# answerer: Yes
# guesser: Italy
#
# questioner: Is this country bordered by the Mediterranean Sea?
# answerer: Yes
# guesser: Italy
#
# questioner: Is this country a peninsula?
# answerer: Yes
# guesser: Italy
#
# questioner: Is this country known for having a prominent boot-shaped peninsula?
# answerer: No
# guesser: Spain
#
# questioner: Is this country known for its history involving ancient Greece?
# answerer: Yes
# guesser: Greece
#
# questioner: Is this country Greece?
# answerer: Yes
# guesser: Greece
#
# questioner: [GAME OVER]
# Game: 3
# Generated keyword: Canada
# questioner: Is it a place?
# answerer: Yes
# guesser: Paris
#
# questioner: Is it a country?
# answerer: Yes
# guesser: Japan
#
# questioner: Is this country either in Asia or in Africa?
# answerer: No
# guesser: Brazil
#
# questioner: Is this country in Europe?
# answerer: No
# guesser: Japan
#
# questioner: Is this country in the Americas?
# answerer: Yes
# guesser: Canada
#
# questioner: Is it in South America?
# answerer: No
# guesser: Canada
#
# questioner: Is it in North America?
# answerer: Yes
# guesser: United States
#
# questioner: Is it an island nation?
# answerer: No
# guesser: Canada
#
# questioner: Is it part of the United States?
# answerer: No
# guesser: Canada
#
# questioner: Is the country's primary language Spanish?
# answerer: No
# guesser: Canada
#
# questioner: Is it a part of Canada?
# answerer: No
# guesser: Mexico
#
# questioner: Does the country border the United States?
# answerer: Yes
# guesser: Mexico
#
# questioner: Is the country's primary language English?
# answerer: Yes
# guesser: Canada
#
# questioner: Is this country known for having a large number of tourists visiting its beaches?
# answerer: No
# guesser: Canada
#
# questioner: Does this country have a larger population than Canada?
# answerer: No
# guesser: Mexico
#
# questioner: Is the country's capital city Mexico City?
# answerer: No
# guesser: Mexico
#
# questioner: Was this country formerly a British colony?
# answerer: Yes
# guesser: Belize
#
# questioner: Is this country known for its maple syrup production?
# answerer: Yes
# guesser: Canada
#
# questioner: Is this country predominantly French-speaking in one of its significant regions?
# answerer: Yes
# guesser: Canada
#
# questioner: Is this place Canada?
# answerer: Yes
# guesser: Canada
#
# Generated keyword: Mexico
# questioner: Is it a place?
# answerer: Yes
# guesser: Paris
#
# questioner: Is it a country?
# answerer: Yes
# guesser: Canada
#
# questioner: Is this country either in Asia or in Africa?
# answerer: No
# guesser: No guess
#
# questioner: Is this country in Europe?
# answerer: No
# guesser: Japan
#
# questioner: Is this country in the Americas?
# answerer: Yes
# guesser: Brazil
#
# questioner: Is this country in North America?
# answerer: Yes
# guesser: United States
#
# questioner: Is this country bordered by the United States?
# answerer: Yes
# guesser: Canada
#
# questioner: Is it Mexico?
# answerer: Yes
# guesser: Mexico
#
# questioner: [GAME OVER]
# Generated keyword: Brazil
# questioner: Is it a place?
# answerer: Yes
# guesser: Paris
#
# questioner: Is it a country?
# answerer: Yes
# guesser: Canada
#
# questioner: Is this country either in Asia or in Africa?
# answerer: No
# guesser: No guess
#
# questioner: Is this country in Europe?
# answerer: No
# guesser: Japan
#
# questioner: Is this country in the Americas?
# answerer: Yes
# guesser: Canada
#
# questioner: Is this country in North America?
# answerer: No
# guesser: Brazil
#
# questioner: Is this country in South America?
# answerer: Yes
# guesser: Brazil
#
# questioner: Is this country landlocked?
# answerer: No
# guesser: Brazil
#
# questioner: Is this country located predominantly in the Southern Hemisphere?
# answerer: Yes
# guesser: Brazil
#
# questioner: Is the official language of this country Portuguese?
# answerer: Yes
# guesser: Brazil
#
# questioner: Is the population of this country over 100 million people?
# answerer: Yes
# guesser: Brazil
#
# questioner: Does this country border any other countries?
# answerer: Yes
# guesser: Brazil
#
# questioner: Does this country share a border with more than five countries?
# answerer: Yes
# guesser: Brazil
#
# questioner: Is this country the largest by area in South America?
# answerer: Yes
# guesser: Brazil
#
# questioner: Is this country Brazil?
# answerer: Yes
# guesser: Brazil
#
# questioner: [GAME OVER]
# Generated keyword: Argentina
# questioner: Is it a place?
# answerer: Yes
# guesser: Paris
#
# questioner: Is it a country?
# answerer: Yes
# guesser: Japan
#
# questioner: Is this country either in Asia or in Africa?
# answerer: No
# guesser: Brazil
#
# questioner: Is this country in Europe?
# answerer: No
# guesser: Nigeria
#
# questioner: Is this country in the Americas?
# answerer: Yes
# guesser: Brazil
#
# questioner: Is it in North America?
# answerer: No
# guesser: Brazil
#
# questioner: Is it in South America?
# answerer: Yes
# guesser: Brazil
#
# questioner: Is this country known for its large Amazon rainforest?
# answerer: No
# guesser: Argentina
#
# questioner: Is this country on the Pacific coast of South America?
# answerer: No
# guesser: Argentina
#
# questioner: Is this country known for its significant involvement in the production of coffee?
# answerer: No
# guesser: Argentina
#
# questioner: Is this country entirely landlocked?
# answerer: No
# guesser: Argentina
#
# questioner: Is this country located on the Atlantic coast of South America?
# answerer: Yes
# guesser: Uruguay
#
# questioner: Is this country known for its tango dance and music?
# answerer: Yes
# guesser: Argentina
#
# questioner: Is this country Argentina?
# answerer: Yes
# guesser: Argentina
#
# questioner: [GAME OVER]
# Generated keyword: Chile
# questioner: Is it a place?
# answerer: Yes
# guesser: Paris
#
# questioner: Is it a country?
# answerer: Yes
# guesser: France
#
# questioner: Is this country either in Asia or in Africa?
# answerer: No
# guesser: Brazil
#
# questioner: Is this country in Europe?
# answerer: No
# guesser: United States
#
# questioner: Is this country in the Americas?
# answerer: Yes
# guesser: Canada
#
# questioner: Is this country in North America?
# answerer: No
# guesser: Brazil
#
# questioner: Is this country in South America?
# answerer: Yes
# guesser: Brazil
#
# questioner: Is this country landlocked?
# answerer: No
# guesser: Brazil
#
# questioner: Is this country part of the Amazon rainforest?
# answerer: No
# guesser: Argentina
#
# questioner: Does this country have a coastline along the Pacific Ocean?
# answerer: Yes
# guesser: Chile
#
# questioner: Does this country share a border with Brazil?
# answerer: No
# guesser: Chile
#
# questioner: Is this country predominantly Spanish-speaking?
# answerer: Yes
# guesser: Chile
#
# questioner: Is this country Chile?
# answerer: Yes
# guesser: Chile
#
# questioner: [GAME OVER]
# Generated keyword: Colombia
# questioner: Is it a place?
# answerer: Yes
# guesser: Paris
#
# questioner: Is it a country?
# answerer: Yes
# guesser: Japan
#
# questioner: Is this country either in Asia or in Africa?
# answerer: No
# guesser: France
#
# questioner: Is this country in Europe?
# answerer: No
# guesser: Canada
#
# questioner: Is this country in the Americas?
# answerer: Yes
# guesser: Brazil
#
# questioner: Is this country in North America?
# answerer: No
# guesser: Brazil
#
# questioner: Is this country in South America?
# answerer: Yes
# guesser: Brazil
#
# questioner: Is this country landlocked?
# answerer: No
# guesser: Brazil
#
# questioner: Is this country in the southern part of South America?
# answerer: No
# guesser: Brazil
#
# questioner: Is this country known for its coffee production?
# answerer: Yes
# guesser: Colombia
#
# questioner: Is this country bordered by the Pacific Ocean?
# answerer: Yes
# guesser: Colombia
#
# questioner: Does this country have a significant Amazon Rainforest coverage?
# answerer: Yes
# guesser: Colombia
#
# questioner: Is this country Colombia?
# answerer: Yes
# guesser: Colombia
#
# questioner: [GAME OVER]
# Generated keyword: Peru
# questioner: Is it a place?
# answerer: Yes
# guesser: Paris
#
# questioner: Is it a country?
# answerer: Yes
# guesser: France
#
# questioner: Is this country either in Asia or in Africa?
# answerer: No
# guesser: No input visible
#
# questioner: Is this country in Europe?
# answerer: No
# guesser: Japan
#
# questioner: Is this country in the Americas?
# answerer: Yes
# guesser: Brazil
#
# questioner: Is this country in North America?
# answerer: No
# guesser: Brazil
#
# questioner: Is this country in South America?
# answerer: Yes
# guesser: Brazil
#
# questioner: Is this country the largest by area in South America?
# answerer: No
# guesser: Argentina
#
# questioner: Is this country landlocked?
# answerer: No
# guesser: Argentina
#
# questioner: Is this country known for having a significant portion of the Amazon rainforest within its borders?
# answerer: Yes
# guesser: Peru
#
# questioner: Is this country Spanish-speaking?
# answerer: Yes
# guesser: Peru
#
# questioner: Is this country located on the western coast of South America?
# answerer: Yes
# guesser: Peru
#
# questioner: Is this country known for its ancient Incan city, Machu Picchu?
# answerer: Yes
# guesser: Peru
#
# questioner: Is this country Peru?
# answerer: Yes
# guesser: Peru
#
# questioner: [GAME OVER]
# Generated keyword: Cuba
# questioner: Is it a place?
# answerer: Yes
# guesser: Paris
#
# questioner: Is it a country?
# answerer: Yes
# guesser: Japan
#
# questioner: Is this country either in Asia or in Africa?
# answerer: No
# guesser: Canada
#
# questioner: Is this country in Europe?
# answerer: No
# guesser: Japan
#
# questioner: Is this country in the Americas?
# answerer: Yes
# guesser: United States
#
# questioner: Is this country in North America?
# answerer: Yes
# guesser: United States
#
# questioner: Is it part of Central America?
# answerer: No
# guesser: United States
#
# questioner: Is it the United States?
# answerer: No
# guesser: Canada
#
# questioner: Is it Canada?
# answerer: No
# guesser: Mexico
#
# questioner: Is it in the Caribbean?
# answerer: Yes
# guesser: Cuba
#
# questioner: Is it an island republic?
# answerer: Yes
# guesser: Cuba
#
# questioner: Is the official language Spanish?
# answerer: Yes
# guesser: Cuba
#
# questioner: Is it Cuba?
# answerer: Yes
# guesser: Cuba
#
# questioner: [GAME OVER]
# Generated keyword: Costa Rica
# questioner: Is it a place?
# answerer: Yes
# guesser: New York
#
# questioner: Is it a country?
# answerer: Yes
# guesser: France
#
# questioner: Is this country either in Asia or in Africa?
# answerer: No
# guesser: No guess
#
# questioner: Is this country in Europe?
# answerer: No
# guesser: Brazil
#
# questioner: Is this country in the Americas?
# answerer: Yes
# guesser: United States
#
# questioner: Is this country in North America?
# answerer: No
# guesser: Brazil
#
# questioner: Is this country in South America?
# answerer: No
# guesser: Central America
#
# questioner: Is this country in Central America?
# answerer: Yes
# guesser: Panama
#
# questioner: Is this country bordered by both the Caribbean Sea and the Pacific Ocean?
# answerer: Yes
# guesser: Costa Rica
#
# questioner: Is this country known for its significant coffee production?
# answerer: Yes
# guesser: Costa Rica
#
# questioner: Is this country known for its canal connecting the Atlantic and Pacific Oceans?
# answerer: No
# guesser: Honduras
#
# questioner: Does this country share a border with Nicaragua?
# answerer: Yes
# guesser: Costa Rica
#
# questioner: Does this country also share a border with Panama?
# answerer: Yes
# guesser: Costa Rica
#
# questioner: Is the official language of this country Spanish?
# answerer: Yes
# guesser: Costa Rica
#
# questioner: Is this country home to the Monteverde Cloud Forest Reserve?
# answerer: Yes
# guesser: Costa Rica
#
# questioner: Is this country Costa Rica?
# answerer: Yes
# guesser: Costa Rica
#
# questioner: [GAME OVER]
# Generated keyword: Panama
# questioner: Is it a place?
# answerer: Yes
# guesser: Paris
#
# questioner: Is it a country?
# answerer: Yes
# guesser: Japan
#
# questioner: Is this country either in Asia or in Africa?
# answerer: No
# guesser: Europe
#
# questioner: Is this country in Europe?
# answerer: No
# guesser: China
#
# questioner: Is this country in the Americas?
# answerer: Yes
# guesser: Brazil
#
# questioner: Is this country located in North America?
# answerer: Yes
# guesser: United States
#
# questioner: Is this country primarily English-speaking?
# answerer: No
# guesser: Mexico
#
# questioner: Is this country located in Central America?
# answerer: Yes
# guesser: Mexico
#
# ...
# answerer: Yes
# guesser: Molecule
#
# questioner: Is it essential for life?
# answerer: Yes
# guesser: Water
#
# questioner: Is it commonly found in nature?
# answerer: Yes
# guesser: Water
#
# questioner: Is it a gas at room temperature?
# answerer: No
# guesser: Water
#
# questioner: Is it a solid at room temperature?
# answerer: No
# guesser: Water
#
# questioner: Is it water?
# answerer: No
# guesser: Oxygen
#
# questioner: Is it found in the human body?
# answerer: Yes
# guesser: Blood
#
# questioner: Is it a macronutrient? (e.g., proteins, fats, carbohydrates)
# answerer: No
# guesser: Oxygen
#
# questioner: Is it a micronutrient? (e.g., vitamins, minerals)
# answerer: No
# guesser: Blood
#
# questioner: Does it have a pH level of 7 (neither acidic nor basic)?
# answerer: No
# guesser: Blood
#
# questioner: Is it a basic (alkaline) compound?
# answerer: No
# guesser: Hydrochloric acid
#
# questioner: Is it an acidic compound?
# answerer: Yes
# guesser: Hydrochloric acid
#
# questioner: Is it an organic acid?
# answerer: No
# guesser: Hydrochloric acid
#
# questioner: Is it carbonated acid?
# answerer: No
# guesser: Hydrochloric acid
#
# questioner: Is it hydrochloric acid?
# answerer: Yes
# guesser: hydrochloric acid
#
# questioner: [GAME OVER]
# Game: 24
# Generated keyword: rock
# questioner: Is it a place?
# answerer: No
# guesser: Is it a thing?
#
# questioner: Is it a man-made thing?
# answerer: No
# guesser: Mountain
#
# questioner: Is it a living thing?
# answerer: No
# guesser: Not enough information
#
# questioner: Is it a geological feature?
# answerer: No
# guesser: Eiffel Tower
#
# questioner: Is it a chemical element, molecule or compound?
# answerer: No
# guesser: Mount Everest
#
# questioner: Is it related to space or astronomy?
# answerer: No
# guesser: weather phenomenon
#
# questioner: Is it found in nature?
# answerer: Yes
# guesser: Weather
#
# questioner: Does it have a fixed shape?
# answerer: Yes
# guesser: Rock
#
# questioner: Is it smaller than a car?
# answerer: Yes
# guesser: Rock
#
# questioner: Is it something that can be held with one hand?
# answerer: Yes
# guesser: Rock
#
# questioner: Is it commonly found in households?
# answerer: No
# guesser: Rock
#
# questioner: Is it a type of mineral?
# answerer: Yes
# guesser: Crystal
#
# questioner: Is it a precious or semi-precious stone?
# answerer: No
# guesser: Quartz
#
# questioner: Is it commonly found on Earth's surface?
# answerer: Yes
# guesser: Quartz
#
# questioner: Is it metallic?
# answerer: No
# guesser: Quartz
#
# questioner: Is it used in construction or manufacturing?
# answerer: Yes
# guesser: Limestone
#
# questioner: Is it a type of rock?
# answerer: Yes
# guesser: Granite
#
# questioner: Is it often used for decorative or architectural purposes?
# answerer: Yes
# guesser: Marble
#
# questioner: Is it typically used in sculpture?
# answerer: Yes
# guesser: Marble
#
# questioner: Is it marble?
# answerer: No
# guesser: Granite
#
# Generated keyword: sand
# questioner: Is it a place?
# answerer: No
# guesser: thing
#
# questioner: Is it a man-made thing?
# answerer: No
# guesser: Tree
#
# questioner: Is it a living thing?
# answerer: No
# guesser: rock
#
# questioner: Is it a geological feature?
# answerer: No
# guesser: Yellowstone National Park
#
# questioner: Is it a chemical element, molecule or compound?
# answerer: No
# guesser: No guess
#
# questioner: Is it celestial?
# answerer: No
# guesser: Toy
#
# questioner: Is it a physical object?
# answerer: Yes
# guesser: Weather phenomenon
#
# questioner: Can it be found in nature?
# answerer: Yes
# guesser: Rock
#
# questioner: Is it smaller than a car?
# answerer: Yes
# guesser: Rock
#
# questioner: Is it commonly found indoors?
# answerer: No
# guesser: Rock
#
# questioner: Is it typically found in water?
# answerer: No
# guesser: Rock
#
# questioner: Is it related to plants?
# answerer: No
# guesser: Rock
#
# questioner: Is it related to animals?
# answerer: No
# guesser: Rock
#
# questioner: Can it be found in the sky?
# answerer: No
# guesser: Rock
#
# questioner: Is it primarily found on the ground?
# answerer: Yes
# guesser: Rock
#
# questioner: Is it composed of minerals?
# answerer: Yes
# guesser: Rock
#
# questioner: Is it commonly used in construction?
# answerer: Yes
# guesser: Rock
#
# questioner: Is it a type of stone?
# answerer: No
# guesser: Sand
#
# questioner: Is it often extracted from the ground?
# answerer: Yes
# guesser: Clay
#
# questioner: Is it a metal?
# answerer: No
# guesser: Sand
#
# Generated keyword: cloud
# questioner: Is it a place?
# answerer: No
# guesser: thing
#
# questioner: Is it a man-made thing?
# answerer: No
# guesser: mountain
#
# questioner: Is it a living thing?
# answerer: No
# guesser: Rock
#
# questioner: Is it a geological feature?
# answerer: No
# guesser:
#
# questioner: Is it a chemical element, molecule or compound?
# answerer: No
# guesser: Water
#
# questioner: Is it related to weather phenomena?
# answerer: Yes
# guesser: Cloud
#
# questioner: Is it a type of precipitation?
# answerer: No
# guesser: Cloud
#
# questioner: Is it associated with a specific season?
# answerer: No
# guesser: Cloud
#
# questioner: Is it a type of cloud?
# answerer: Yes
# guesser: Cumulonimbus
#
# questioner: Does it typically form at high altitudes?
# answerer: Yes
# guesser: Cirrus cloud
#
# questioner: Is it a cirrus cloud?
# answerer: No
# guesser: Cumulonimbus
#
# questioner: Does it have a wispy appearance?
# answerer: No
# guesser: Cumulonimbus cloud
#
# questioner: Is it associated with fair weather?
# answerer: Yes
# guesser: Cumulus cloud
#
# questioner: Is it a cumulus cloud?
# answerer: No
# guesser: Altocumulus cloud
#
# questioner: Does it indicate a change in weather conditions is coming?
# answerer: No
# guesser: Altocumulus cloud
#
# questioner: Is it an altostratus cloud?
# answerer: No
# guesser: Altocumulus cloud
#
# questioner: Is it a type of cirrostratus cloud?
# answerer: Yes
# guesser: Cirrostratus
#
# questioner: Is it known for producing halos around the sun or moon?
# answerer: Yes
# guesser: Cirrostratus
#
# questioner: Is it a cirrostratus fibratus cloud?
# answerer: Yes
# guesser: cirrostratus fibratus cloud
#
# questioner: [GAMER OVER]
# Generated keyword: water
# questioner: Is it a place?
# answerer: No
# guesser: thing
#
# questioner: Is it a man-made thing?
# answerer: No
# guesser: Mountain
#
# questioner: Is it a living thing?
# answerer: No
# guesser: Statue
#
# questioner: Is it a geological feature?
# answerer: No
# guesser: Mount Rushmore
#
# questioner: Is it a chemical element, molecule or compound?
# answerer: No
# guesser: Grand Canyon
#
# questioner: Is it something that can be found in space?
# answerer: Yes
# guesser: Star
#
# questioner: Is it part of our solar system?
# answerer: Yes
# guesser: The Sun
#
# questioner: Is it a planet?
# answerer: No
# guesser: Moon
#
# questioner: Is it a moon?
# answerer: No
# guesser: Asteroid
#
# questioner: Is it a star?
# answerer: No
# guesser: Asteroid
#
# questioner: Is it smaller than a planet?
# answerer: Yes
# guesser: Asteroid
#
# questioner: Is it a comet?
# answerer: No
# guesser: Asteroid
#
# questioner: Is it an asteroid?
# answerer: No
# guesser: meteor
#
# questioner: Is it an artificial satellite?
# answerer: No
# guesser: Meteor
#
# questioner: Is it a type of radiation or particle?
# answerer: No
# guesser: Meteor
#
# questioner: Is it part of a planet?
# answerer: No
# guesser: Meteor
#
# questioner: Is it related to the sun?
# answerer: No
# guesser: Space dust
#
# questioner: Is it a natural satellite of any celestial body?
# answerer: No
# guesser: Meteor
#
# questioner: Is it part of a galaxy?
# answerer: No
# guesser: meteorite
#
# questioner: Is it a specific region of interstellar space?
# answerer: No
# guesser: meteoroid
#
# Generated keyword: lightning
# questioner: Is it a place?
# answerer: No
# guesser: thing
#
# questioner: Is it a man-made thing?
# answerer: No
# guesser: Tree
#
# questioner: Is it a living thing?
# answerer: No
# guesser: Statue
#
# questioner: Is it a geological feature?
# answerer: No
# guesser: Need more information
#
# questioner: Is it a chemical element, molecule or compound?
# answerer: No
# guesser: airplane
#
# questioner: Is it related to outer space?
# answerer: No
# guesser: cloud
#
# questioner: Is it found in nature?
# answerer: Yes
# guesser: Rock
#
# questioner: Is it a type of weather phenomenon?
# answerer: Yes
# guesser: Rainbow
#
# questioner: Is it associated with precipitation?
# answerer: Yes
# guesser: Rain
#
# questioner: Is it a type of severe weather?
# answerer: Yes
# guesser: Hurricane
#
# questioner: Is it a cyclone, hurricane, or storm?
# answerer: No
# guesser: Tornado
#
# questioner: Is it associated with lightning or thunder?
# answerer: Yes
# guesser: Tornado
#
# questioner: Does it occur mainly in tropical regions?
# answerer: No
# guesser: Tornado
#
# questioner: Is it a form of precipitation itself, like rain or snow?
# answerer: No
# guesser: Thunderstorm
#
# questioner: Is it a thunderstorm?
# answerer: No
# guesser: Tornado
#
# questioner: Is it a tornado?
# answerer: No
# guesser: Hailstorm
#
# questioner: Does it involve heavy winds?
# answerer: No
# guesser: Hailstorm
#
# questioner: Does it typically happen in mountainous areas?
# answerer: No
# guesser: Hailstorm
#
# questioner: Is it related to cold weather?
# answerer: No
# guesser: Hailstorm
#
# questioner: Is it a rare weather phenomenon?
# answerer: No
# guesser: Lightning
#
# Generated keyword: asteroid
# questioner: Is it a place?
# answerer: No
# guesser: thing
#
# questioner: Is it a man-made thing?
# answerer: No
# guesser: Mount Everest
#
# questioner: Is it a living thing?
# answerer: No
# guesser: Computer
#
# questioner: Is it a geological feature?
# answerer: No
# guesser: Taj Mahal
#
# questioner: Is it a chemical element, molecule or compound?
# answerer: No
# guesser: house
#
# questioner: Is it found in outer space?
# answerer: Yes
# guesser: Star
#
# questioner: Is it a celestial body?
# answerer: Yes
# guesser: Star
#
# questioner: Is it a star?
# answerer: No
# guesser: Planet
#
# questioner: Is it a planet?
# answerer: No
# guesser: Moon
#
# questioner: Is it a moon?
# answerer: No
# guesser: Asteroid
#
# questioner: Is it a comet?
# answerer: No
# guesser: Asteroid
#
# questioner: Is it an asteroid?
# answerer: Yes
# guesser: Asteroid
#
# questioner: Is it an asteroid in our solar system?
# answerer: Yes
# guesser: Asteroid Belt
#
# questioner: Is it part of the asteroid belt between Mars and Jupiter?
# answerer: Yes
# guesser: Ceres
#
# questioner: Is it larger than 100 kilometers in diameter?
# answerer: Yes
# guesser: Ceres
#
# questioner: Is it classified as a dwarf planet?
# answerer: No
# guesser: Ceres
#
# questioner: Is it the largest asteroid in the asteroid belt?
# answerer: Yes
# guesser: Ceres
#
# questioner: Is it Ceres?
# answerer: Yes
# guesser: Ceres
#
# questioner: [GAME OVER]
# Generated keyword: volcano ash
# questioner: Is it a place?
# answerer: No
# guesser: thing
#
# questioner: Is it a man-made thing?
# answerer: No
# guesser: mountain
#
# questioner: Is it a living thing?
# answerer: No
# guesser: chair
#
# questioner: Is it a geological feature?
# answerer: No
# guesser: Eiffel Tower
#
# questioner: Is it a chemical element, molecule or compound?
# answerer: No
# guesser: No guessing yet
#
# questioner: Is it related to weather or natural phenomena?
# answerer: Yes
# guesser: Lightning
#
# questioner: Is it associated with precipitation?
# answerer: No
# guesser: Rainbow
#
# questioner: Is it a type of storm?
# answerer: No
# guesser: Aurora Borealis
#
# questioner: Is it related to temperature?
# answerer: No
# guesser: Rainbow
#
# questioner: Is it an atmospheric phenomenon?
# answerer: Yes
# guesser: Aurora
#
# questioner: Is it typically visible to the naked eye?
# answerer: Yes
# guesser: Rainbow
#
# questioner: Is it related to light?
# answerer: No
# guesser: Rainbow
#
# questioner: Is it typically associated with wind?
# answerer: Yes
# guesser: Tornado
#
# questioner: Is it a type of cloud formation?
# answerer: No
# guesser: Tornado
#
# questioner: Is it a specific pattern or effect created by wind?
# answerer: No
# guesser: Tornado
#
# questioner: Is it related to a specific atmospheric layer?
# answerer: No
# guesser: Tornado
#
# questioner: Is it related to air pressure differences?
# answerer: No
# guesser: Cyclone
#
# questioner: Is it a type of wind?
# answerer: No
# guesser: Rainbow
#
# questioner: Does it create a visual atmospheric effect?
# answerer: Yes
# guesser: Rainbow
#
# questioner: Is it related to the movement of air particles?
# answerer: Yes
# guesser: Dust devil
#
# Generated keyword: stardust
# questioner: Is it a place?
# answerer: No
# guesser: Is it a thing?
#
# questioner: Is it a man-made thing?
# answerer: No
# guesser: Tree
#
# questioner: Is it a living thing?
# answerer: No
# guesser: Is it a commonly used object in daily life?
#
# questioner: Is it a geological feature?
# answerer: No
# guesser: Eiffel Tower
#
# questioner: Is it a chemical element, molecule or compound?
# answerer: No
# guesser: oxygen
#
# questioner: Is it smaller than a breadbox?
# answerer: Yes
# guesser: Snowflake
#
# questioner: Is it a natural object found in space?
# answerer: Yes
# guesser: Asteroid
#
# questioner: Is it part of our solar system?
# answerer: No
# guesser: Star
#
# questioner: Is it visible to the naked eye?
# answerer: No
# guesser: exoplanet
#
# questioner: Is it a type of star?
# answerer: No
# guesser: Exoplanet
#
# questioner: Is it a celestial body that can be observed with a telescope?
# answerer: No
# guesser: Black hole
#
# questioner: Is it a small particle or a form of matter?
# answerer: Yes
# guesser: Dark matter
#
# questioner: Does it belong to the category of subatomic particles?
# answerer: No
# guesser: interstellar dust
#
# questioner: Is it a type of electromagnetic radiation?
# answerer: No
# guesser: Dark matter
#
# questioner: Is it a type of interstellar dust or gas?
# answerer: Yes
# guesser: Interstellar dust
#
# questioner: Is it primarily composed of hydrogen?
# answerer: No
# guesser: Interstellar dust
#
# questioner: Is it associated with the formation of stars?
# answerer: Yes
# guesser: Nebula
#
# questioner: Is it a molecular cloud?
# answerer: No
# guesser: Nebula
#
# questioner: Is it a planetary nebula?
# answerer: No
# guesser: Interstellar Medium
#
# questioner: Is it a nebula?
# answerer: No
# guesser: Dark matter
#
# Generated keyword: comet
# questioner: Is it a place?
# answerer: No
# guesser: thing
#
# questioner: Is it a man-made thing?
# answerer: No
# guesser: mountain
#
# questioner: Is it a living thing?
# answerer: No
# guesser: Chair
#
# questioner: Is it a geological feature?
# answerer: No
# guesser: pass
#
# questioner: Is it a chemical element, molecule or compound?
# answerer: No
# guesser: Mount Everest
#
# questioner: Is it a celestial object?
# answerer: Yes
# guesser: Star
#
# questioner: Is it located within our solar system?
# answerer: Yes
# guesser: The Sun
#
# questioner: Is it a planet?
# answerer: No
# guesser: Moon
#
# questioner: Is it a moon?
# answerer: No
# guesser: Asteroid
#
# questioner: Is it a star?
# answerer: No
# guesser: Asteroid
#
# questioner: Is it an asteroid?
# answerer: No
# guesser: Comet
#
# questioner: Is it a comet?
# answerer: Yes
# guesser: Halley's Comet
#
# questioner: Is it one of the best-known comets?
# answerer: This would go beyond yes or no responses. Please guess a specific place or thing based on the keyword provided (comet).
# guesser: Halley's Comet
#
# questioner: Halley's Comet. [GAME OVER]
# Generated keyword: moon dust
# questioner: Is it a place?
# answerer: No
# guesser: thing
#
# questioner: Is it a man-made thing?
# answerer: No
# guesser: tree
#
# questioner: Is it a living thing?
# answerer: No
# guesser: Statue
#
# questioner: Is it a geological feature?
# answerer: No
# guesser:
#
# questioner: Is it a chemical element, molecule or compound?
# answerer: No
# guesser: Paris
#
# questioner: Is it found in nature?
# answerer: Yes
# guesser: Star
#
# questioner: Is it related to weather or atmospheric conditions?
# answerer: No
# guesser: Stone
#
# questioner: Is it related to space or celestial bodies?
# answerer: Yes
# guesser: star
#
# questioner: Is it a star?
# answerer: No
# guesser: Planet
#
# questioner: Is it a planet?
# answerer: No
# guesser: Asteroid
#
# questioner: Is it a celestial body within our solar system?
# answerer: No
# guesser: Galaxy
#
# questioner: Is it a galaxy?
# answerer: No
# guesser: Black hole
#
# questioner: Is it a type of cosmic phenomenon?
# answerer: No
# guesser: Black hole
#
# questioner: Is it a moon?
# answerer: No
# guesser: Black hole
#
# questioner: Is it a type of nebula?
# answerer: No
# guesser: Black hole
#
# questioner: Is it a black hole?
# answerer: No
# guesser: asteroid
#
# questioner: Is it an asteroid?
# answerer: No
# guesser: comet
#
# questioner: Is it a comet?
# answerer: No
# guesser: Exoplanet
#
# questioner: Is it related to cosmology or the science of the origin and development of the universe?
# answerer: No
# guesser: exoplanet
#
# questioner: Is it artificial?
# answerer: No
# guesser: Constellation

# %%
len(game_results)
# Out:
# 250

# %% [markdown]
# ## Save as JSONL

# %%
with open("games-2.jsonl", "w") as f:
    for i in game_results:
        json.dump(i, f)
        f.write('\n')
